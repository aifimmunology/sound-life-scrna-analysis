# %% [markdown]
# # Label cell types using CellTypist Models
#
# To build our reference, we would like to start with labels that originate from published cell type references.
#
# One of the approaches for this cell type labeling is CellTypist, a model-based approach to cell type labeling.
#
# CellTypist is described [on their website](https://www.celltypist.org/), and in this publication:
#
# Domínguez Conde, C. et al. Cross-tissue immune cell analysis reveals tissue-specific features in humans. Science 376, eabl5197 (2022)
#
# Here, we'll load in our cells individually, and assign labels based on our 3-level annotated PBMC reference:
#
# - AIFI_L1:
#     - 9 types
# - AIFI_L2:
#     - 29 types
# - AIFI_L3:
#     - 71 types

# %% [markdown]
# ## Load Packages
#
# `anndata`: Data structures for scRNA-seq
# `celltypist`: Model-based cell type annotation
# `concurrent.futures`: parallelization methods
# `datetime`: date and time functions
# `h5py`: HDF5 file I/O
# `hisepy`: The HISE SDK for Python
# `numpy`: Mathematical data structures and computation
# `os`: operating system calls
# `pandas`: DataFrame data structures
# `re`: Regular expressions
# `scanpy`: scRNA-seq analysis
# `scipy.sparse`: Spare matrix data structures
# `shutil`: Shell utilities

# %%
import anndata
import celltypist
from celltypist import models
import concurrent.futures
from datetime import date
import h5py
import hisepy
import numpy as np
import os
import pandas as pd 
import re
import scanpy as sc
import scipy.sparse as scs
import shutil

# %% [markdown]
# Load a model to prevent CellTypist from loading all models per core

# %%
models.download_models(
    force_update = True,
    model = ['Immune_All_High.pkl']
)
# Out:
# 📜 Retrieving model list from server https://celltypist.cog.sanger.ac.uk/models/models.json
# 📚 Total models in list: 44
# 📂 Storing models in /root/.celltypist/data/models
# 💾 Total models to download: 1
# 💾 Downloading model [1/1]: Immune_All_High.pkl

# %% [markdown]
# ## Helper functions
#
# This function allows easy reading of .csv files stored in HISE

# %%
def read_csv_uuid(csv_uuid):
    csv_path = '/home/jupyter/cache/{u}'.format(u = csv_uuid)
    if not os.path.isdir(csv_path):
        hise_res = hisepy.reader.cache_files([csv_uuid])
    csv_filename = os.listdir(csv_path)[0]
    csv_file = '{p}/{f}'.format(p = csv_path, f = csv_filename)
    df = pd.read_csv(csv_file, index_col = 0)
    return df

# %% [markdown]
# This function allows easy identification of the cached file path for files retrieved from HISE

# %%
def read_path_uuid(file_uuid):
    file_path = '/home/jupyter/cache/{u}'.format(u = file_uuid)
    if not os.path.isdir(file_path):
        hise_res = hisepy.reader.cache_files([file_uuid])
    filename = os.listdir(file_path)[0]
    full_path = '{p}/{f}'.format(p = file_path, f = filename)
    return full_path

# %% [markdown]
# These functions will retrieve data for a sample, assemble an AnnData object, perform normalization and log transformation, then generate predictions for each of the 3 models retrieved.

# %%
# define a function to read count data
def read_mat(h5_con):
    mat = scs.csc_matrix(
        (h5_con['matrix']['data'][:], # Count values
         h5_con['matrix']['indices'][:], # Row indices
         h5_con['matrix']['indptr'][:]), # Pointers for column positions
        shape = tuple(h5_con['matrix']['shape'][:]) # Matrix dimensions
    )
    return mat

# define a function to read obeservation metadata (i.e. cell metadata)
def read_obs(h5con):
    bc = h5con['matrix']['barcodes'][:]
    bc = [x.decode('UTF-8') for x in bc]

    # Initialized the DataFrame with cell barcodes
    obs_df = pd.DataFrame({ 'barcodes' : bc })

    # Get the list of available metadata columns
    obs_columns = h5con['matrix']['observations'].keys()

    # For each column
    for col in obs_columns:
        # Read the values
        values = h5con['matrix']['observations'][col][:]
        # Check for byte storage
        if(isinstance(values[0], (bytes, bytearray))):
            # Decode byte strings
            values = [x.decode('UTF-8') for x in values]
        # Add column to the DataFrame
        obs_df[col] = values

    obs_df = obs_df.set_index('barcodes', drop = False)
    
    return obs_df

# define a function to construct anndata object from a h5 file
def read_h5_anndata(h5_con):
    #h5_con = h5py.File(h5_file, mode = 'r')
    # extract the expression matrix
    mat = read_mat(h5_con)
    # extract gene names
    genes = h5_con['matrix']['features']['name'][:]
    genes = [x.decode('UTF-8') for x in genes]
    # extract metadata
    obs_df = read_obs(h5_con)
    # construct anndata
    adata = anndata.AnnData(mat.T,
                             obs = obs_df)
    # make sure the gene names aligned
    adata.var_names = genes

    adata.var_names_make_unique()
    return adata

# %%
def get_adata(uuid):
    # Load the file using HISE
    res = hisepy.reader.read_files([uuid])

    # If there's an error, read_files returns a list instead of a dictionary.
    # We should raise and exception with the message when this happens.
    if(isinstance(res, list)):
        error_message = res[0]['message']
        raise Exception(error_message)
    
    # Read the file to adata
    h5_con = res['values'][0]
    adata = read_h5_anndata(h5_con)
    
    # Close the file now that we're done with it
    h5_con.close()

    return(adata)

# %%
def run_prediction(adata, model, model_name, out_dir = "output"):
    # Perform prediction
    predictions = celltypist.annotate(
        adata, 
        model = model, 
        majority_voting = True)

    # Make output directories
    model_dir = "{d}/{m}".format(d = out_dir, m = model_name)
    if not os.path.isdir(model_dir):
        os.makedirs(model_dir)

    # Write output
    sample_id = adata.obs['pbmc_sample_id'].unique()[0]
    
    prob_file = "{d}/{s}_{m}_probability_mat.parquet".format(d = model_dir, s = sample_id, m = model_name)
    prob = predictions.probability_matrix
    prob.to_parquet(prob_file)

    dec_file = "{d}/{s}_{m}_decision_mat.parquet".format(d = model_dir, s = sample_id, m = model_name)
    predictions.decision_matrix.to_parquet(dec_file)
    
    label_file = "{d}/{s}_{m}_labels.csv".format(d = model_dir, s = sample_id, m = model_name)
    labels = predictions.predicted_labels
    labels = labels.rename({'predicted_labels': model_name}, axis = 1)
    
    prob_scores = []
    for i in range(labels.shape[0]):
        prob_scores.append(prob.loc[labels.index.to_list()[i],labels[model_name][i]])
    labels['{m}_score'.format(m = model_name)] = prob_scores
    labels.to_csv(label_file)
    
    
def process_data(file_uuid):
    out_dir = "output"

    # Load cells from HISE .h5 files
    adata = get_adata(file_uuid)
    
    # Normalize data
    sc.pp.normalize_total(adata, target_sum=1e4)
    sc.pp.log1p(adata)
    adata.obs.index = adata.obs['barcodes']
    
    # Predict cell types
    for model_name,model_path in model_paths.items():
        run_prediction(
            adata,
            model_path,
            model_name,
            out_dir
        )
    
    del adata

# %% [markdown]
# ## Obtain CellTypist Models

# %%
model_uuids = {
    'AIFI_L1': '54d9399c-3bfd-4619-a32d-8c7f3c0911f6',
    'AIFI_L2': 'e2898db9-e121-4263-b0c6-a19eadd4217a',
    'AIFI_L3': 'd18fe8b3-b8e7-4b25-9966-0c05a1ba9d7a'
}
model_feature_uuids = {
    'AIFI_L1': 'd5c0707a-c566-4ddf-8c86-f9b223f9364f',
    'AIFI_L2': '9e684069-fbf5-4f95-8ae5-89d87918e571',
    'AIFI_L3': 'dd8fa995-a3ce-419f-844a-279cf69a4629'
}

# %%
model_paths = {}
for name,uuid in model_uuids.items():
    model_paths[name] = read_path_uuid(uuid)

# %%
model_paths
# Out:
# {'AIFI_L1': '/home/jupyter/cache/54d9399c-3bfd-4619-a32d-8c7f3c0911f6/ref_pbmc_clean_celltypist_model_AIFI_L1_2024-03-09.pkl',
#  'AIFI_L2': '/home/jupyter/cache/e2898db9-e121-4263-b0c6-a19eadd4217a/ref_pbmc_clean_celltypist_model_AIFI_L2_2024-03-10.pkl',
#  'AIFI_L3': '/home/jupyter/cache/d18fe8b3-b8e7-4b25-9966-0c05a1ba9d7a/ref_pbmc_clean_celltypist_model_AIFI_L3_2024-03-11.pkl'}

# %%
model_features = {}
for name,uuid in model_feature_uuids.items():
    model_features[name] = read_csv_uuid(uuid)

# %%
model_features['AIFI_L1'].head()
# Out:
#        gene
# 0      HES4
# 1    TTLL10
# 2  TNFRSF18
# 3   TNFRSF4
# 4     RPL22

# %% [markdown]
# ## Read sample metadata from HISE

# %%
sample_meta_file_uuid = 'd82c5c42-ae5f-4e67-956e-cd3b7bf88105'
file_query = hisepy.reader.read_files(
    [sample_meta_file_uuid]
)

# %%
meta_data = file_query['values']

# %%
meta_data.shape
# Out:
# (868, 33)

# %% [markdown]
# ## Apply across files
#
# Here, we'll use `concurrent.futures` to apply the function above to our files in parallel.

# %%
out_dir = 'output'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
file_uuids = meta_data['file.id'].to_list()

# %%
# Process each subset in parallel
pool_executor = concurrent.futures.ProcessPoolExecutor(max_workers = 60)
with pool_executor as executor:
    
    futures = []
    for file_uuid in file_uuids:
        futures.append(executor.submit(process_data, file_uuid))

    # Check for errors when parallel processes return results
    for future in concurrent.futures.as_completed(futures):
        try:
            future.result()
        except Exception as e:
            print(f'Error: {e}')
# Out:
# 🔬 Input data has 19186 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 12699 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🔬 Input data has 14433 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 15039 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 15160 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🔬 Input data has 24003 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 20995 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16266 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🔬 Input data has 19585 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18359 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🖋️ Predicting labels
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 18135 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🔬 Input data has 18346 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18976 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20856 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21940 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 16653 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🔬 Input data has 17886 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18031 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 22078 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18572 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21789 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18199 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18547 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20444 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18094 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19563 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19537 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20068 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19127 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 22592 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 17918 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21593 cells and 33538 genes
# 🔬 Input data has 20901 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20740 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20170 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 23491 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18769 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19917 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19733 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 19067 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20342 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21840 cells and 33538 genes
# 🔬 Input data has 20643 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19195 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20691 cells and 33538 genes
# 🔬 Input data has 19960 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19669 cells and 33538 genes
# 🔬 Input data has 20633 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 23016 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20854 cells and 33538 genes
# 🔬 Input data has 21621 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🔬 Input data has 21134 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21486 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 23974 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21455 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 22011 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21567 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 23419 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21200 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# 🔬 Input data has 17637 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1102 features used for prediction
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1102 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🖋️ Predicting labels
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1102 features used for prediction
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🧬 1102 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🧬 1102 features used for prediction
# 🧬 1102 features used for prediction
# 🧬 1102 features used for prediction
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🧬 1102 features used for prediction
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1102 features used for prediction
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# 🖋️ Predicting labels
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 12699 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 14433 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# 🔬 Input data has 19186 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Majority voting done!
# 🔬 Input data has 15160 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# ✅ Majority voting done!
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 15039 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 19563 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# 🔬 Input data has 16266 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 18572 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 19733 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# 🔬 Input data has 18346 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# ✅ Majority voting done!
# 🔬 Input data has 12699 cells and 33538 genes
# 🧬 1931 features used for prediction
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🔬 Input data has 14433 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# 🗳️ Majority voting the predictions
# 🖋️ Predicting labels
# ✅ Majority voting done!
# ✅ Majority voting done!
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# 🔬 Input data has 17886 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ⛓️ Over-clustering input data with resolution set to 10
# 🔬 Input data has 17637 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 18359 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17918 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 16653 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18031 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 18547 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🔬 Input data has 19669 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1931 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🧬 2507 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🧬 1931 features used for prediction
# 🧬 2507 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# 🖋️ Predicting labels
# 🔬 Input data has 21840 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Majority voting done!
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🔬 Input data has 22592 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🖋️ Predicting labels
# 🧬 1931 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 19195 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19585 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18094 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 20068 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🔬 Input data has 18199 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 18769 cells and 33538 genes
# 🔬 Input data has 20643 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🔬 Input data has 19537 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🔬 Input data has 19917 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18976 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🔬 Input data has 20444 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19067 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20170 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 21567 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20901 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🧬 1931 features used for prediction
# ✅ Majority voting done!
# ⚖️ Scaling input data
# 🔬 Input data has 22011 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🧬 1931 features used for prediction
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🔬 Input data has 20691 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🗳️ Majority voting the predictions
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🧬 1931 features used for prediction
# ✅ Majority voting done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 18135 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1931 features used for prediction
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⚖️ Scaling input data
# ⛓️ Over-clustering input data with resolution set to 10
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🖋️ Predicting labels
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# 🔬 Input data has 22078 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21134 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🗳️ Majority voting the predictions
# ✅ Prediction done!
# ✅ Majority voting done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 19127 cells and 33538 genes
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# 🔗 Matching reference genes in the model
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🧬 1931 features used for prediction
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 21940 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21486 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 19960 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# 🗳️ Majority voting the predictions
# ⛓️ Over-clustering input data with resolution set to 15
# ✅ Majority voting done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🗳️ Majority voting the predictions
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# ✅ Majority voting done!
# 🔬 Input data has 15160 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 23016 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20856 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🧬 2507 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 20740 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 19186 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 23974 cells and 33538 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 20854 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21593 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🔬 Input data has 21455 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 21200 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21621 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🧬 2507 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 17513 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🔬 Input data has 20633 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20013 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 15039 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# 🖋️ Predicting labels
# ✅ Majority voting done!
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1102 features used for prediction
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⚖️ Scaling input data
# ⛓️ Over-clustering input data with resolution set to 15
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🖋️ Predicting labels
# 🗳️ Majority voting the predictions
# ✅ Prediction done!
# 🔬 Input data has 21789 cells and 33538 genes
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# 🔗 Matching reference genes in the model
# ⛓️ Over-clustering input data with resolution set to 15
# ✅ Majority voting done!
# 🔬 Input data has 20342 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 20995 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🗳️ Majority voting the predictions
# 🔬 Input data has 19563 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# 🔬 Input data has 18572 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# 🖋️ Predicting labels
# 🧬 2507 features used for prediction
# ⚖️ Scaling input data
# ✅ Majority voting done!
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 19733 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 16266 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🧬 2507 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 18346 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2507 features used for prediction
# ⚖️ Scaling input data
# 🧬 2507 features used for prediction
# ⚖️ Scaling input data
# 🧬 2507 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🧬 2507 features used for prediction
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 17886 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17918 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 23491 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17637 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# 🖋️ Predicting labels
# ✅ Majority voting done!
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🔬 Input data has 16653 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# ✅ Majority voting done!
# ...
# ⛓️ Over-clustering input data with resolution set to 15
# 🔬 Input data has 19980 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 14322 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2507 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 19876 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19768 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18672 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# ✅ Majority voting done!
# 🖋️ Predicting labels
# 🗳️ Majority voting the predictions
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# ✅ Prediction done!
# ✅ Majority voting done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🗳️ Majority voting the predictions
# 🔬 Input data has 21560 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Majority voting done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 16431 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# ⛓️ Over-clustering input data with resolution set to 10
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# 🧬 1931 features used for prediction
# ✅ Majority voting done!
# ⚖️ Scaling input data
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🖋️ Predicting labels
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🔬 Input data has 16733 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🧬 1931 features used for prediction
# 🗳️ Majority voting the predictions
# ⚖️ Scaling input data
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🔬 Input data has 18376 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# 🔬 Input data has 20333 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20908 cells and 33538 genes
# ✅ Majority voting done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18937 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 24003 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 10
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🗳️ Majority voting the predictions
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Majority voting done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 17597 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# ✅ Majority voting done!
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 18279 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🧬 2507 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 19233 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🔬 Input data has 20013 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 18039 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🗳️ Majority voting the predictions
# 🔬 Input data has 11372 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 21119 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1931 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🔬 Input data has 20410 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🧬 2507 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 20068 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Prediction done!
# 🔬 Input data has 18864 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 1108 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20480 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1228 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🖋️ Predicting labels
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 20186 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 17718 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🖋️ Predicting labels
# 🔬 Input data has 19123 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🔬 Input data has 16981 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🗳️ Majority voting the predictions
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Majority voting done!
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 18966 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# 🗳️ Majority voting the predictions
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ✅ Majority voting done!
# 🔬 Input data has 17629 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ⛓️ Over-clustering input data with resolution set to 10
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🧬 1102 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 15
# ⛓️ Over-clustering input data with resolution set to 15
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 5
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 1228 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# ✅ Majority voting done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# 🔬 Input data has 1108 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1931 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🗳️ Majority voting the predictions
# 🗳️ Majority voting the predictions
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# ✅ Majority voting done!
# ✅ Majority voting done!
# ⛓️ Over-clustering input data with resolution set to 10
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🔬 Input data has 1137 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🗳️ Majority voting the predictions
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!
# ✅ Majority voting done!
# 🔬 Input data has 21392 cells and 33538 genes
# 🔗 Matching reference genes in the model
#
# KeyboardInterrupt
#
# Process ForkProcess-37:
# Process ForkProcess-27:
# Process ForkProcess-20:
# Process ForkProcess-45:
# Process ForkProcess-40:
# Process ForkProcess-39:
# Process ForkProcess-25:
# Process ForkProcess-42:
# Process ForkProcess-52:
# Process ForkProcess-6:
# Process ForkProcess-9:
# Process ForkProcess-31:
# Process ForkProcess-58:
# Process ForkProcess-3:
# Process ForkProcess-49:
# Process ForkProcess-5:
# Process ForkProcess-43:
# Process ForkProcess-21:
# Process ForkProcess-22:
# Process ForkProcess-60:
# Process ForkProcess-51:
# Process ForkProcess-8:
# Process ForkProcess-44:
# Process ForkProcess-38:
# Process ForkProcess-19:
# Process ForkProcess-10:
# Process ForkProcess-16:
# Process ForkProcess-46:
# Process ForkProcess-56:
# Process ForkProcess-18:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/concurrent/futures/process.py", line 246, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/concurrent/futures/process.py", line 246, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#   File "/tmp/ipykernel_12443/4108814636.py", line 38, in process_data
#     adata = get_adata(file_uuid)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/concurrent/futures/process.py", line 246, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#   File "/opt/conda/lib/python3.10/concurrent/futures/process.py", line 246, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):

# %% [markdown]
# ## Assemble results
#
# For each model, we'll assemble the results as a .csv file that we can utilize later for subclustering and analysis of major cell classes.

# %%
models = ['High', 'Low', 'Covid_Healthy']

# %%
out_files = []
for model in models:
    model_path = 'output/{m}'.format(m = model)
    model_files = os.listdir(model_path)
    model_list = []
    for model_file in model_files:
        df = pd.read_csv('output/{m}/{f}'.format(m = model, f = model_file))
        model_list.append(df)
    model_df = pd.concat(model_list)

    out_file = 'output/ref_celltypist_labels_{m}_{d}.csv'.format(m = model, d = date.today())
    out_files.append(out_file)
    
    model_df.to_csv(out_file)

# %% [markdown]
# ## Upload assembled data to HISE
#
# Finally, we'll use `hisepy.upload.upload_files()` to send a copy of our output to HISE to use for downstream analysis steps.

# %%
study_space_uuid = '64097865-486d-43b3-8f94-74994e0a72e0'
title = 'Ref. CellTypist Predictions {d}'.format(d = date.today())

# %%
in_files = [sample_meta_file_uuid] + meta_data['file.id'].to_list()

# %%
in_files[0:5]
# Out:
# ['2da66a1a-17cc-498b-9129-6858cf639caf',
#  'fec489f9-9a74-4635-aa91-d2bf09d1faec',
#  '7c0c7979-eebd-4aba-b5b2-6e76b4643623',
#  '40efd03a-cb2f-4677-af42-a056cbfe5a17',
#  '68fbcd34-1d63-461d-8195-df5b8dc61b31']

# %%
out_files
# Out:
# ['output/ref_celltypist_labels_High_2024-02-18.csv',
#  'output/ref_celltypist_labels_Low_2024-02-18.csv',
#  'output/ref_celltypist_labels_Covid_Healthy_2024-02-18.csv']

# %%
hisepy.upload.upload_files(
    files = out_files,
    study_space_id = study_space_uuid,
    title = title,
    input_file_ids = in_files
)
# Out:
# you are trying to upload file_ids... ['output/ref_celltypist_labels_High_2024-02-18.csv', 'output/ref_celltypist_labels_Low_2024-02-18.csv', 'output/ref_celltypist_labels_Covid_Healthy_2024-02-18.csv']. Do you truly want to proceed?
# (y/n) y
# {'trace_id': '60c20ada-f8aa-4c7f-ae24-8973a487a491',
#  'files': ['output/ref_celltypist_labels_High_2024-02-18.csv',
#   'output/ref_celltypist_labels_Low_2024-02-18.csv',
#   'output/ref_celltypist_labels_Covid_Healthy_2024-02-18.csv']}

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.10.3
# celltypist          1.6.1
# h5py                3.10.0
# hisepy              0.3.0
# numpy               1.24.0
# pandas              2.1.4
# scanpy              1.9.6
# scipy               1.11.4
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.0.1
# anyio                       NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# beatrix_jupyterlab          NA
# brotli                      NA
# cachetools                  5.3.1
# certifi                     2023.11.17
# cffi                        1.16.0
# charset_normalizer          3.3.2
# cloudpickle                 2.2.1
# colorama                    0.4.6
# comm                        0.1.4
# cryptography                41.0.7
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# db_dtypes                   1.1.1
# debugpy                     1.8.0
# decorator                   5.1.1
# defusedxml                  0.7.1
# deprecated                  1.2.14
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fqdn                        NA
# google                      NA
# greenlet                    2.0.2
# grpc                        1.58.0
# grpc_status                 NA
# idna                        3.6
# igraph                      0.10.8
# importlib_metadata          NA
# ipykernel                   6.28.0
# ipython_genutils            0.2.0
# ipywidgets                  8.1.1
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.2
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.20.0
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.1
# jupyterlab_server           2.25.2
# jwt                         2.8.0
# kiwisolver                  1.4.5
# leidenalg                   0.10.1
# llvmlite                    0.41.0
# lz4                         4.3.2
# markupsafe                  2.1.3
# matplotlib                  3.8.0
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# mpmath                      1.3.0
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.58.0
# opentelemetry               NA
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                4.1.0
# plotly                      5.18.0
# prettytable                 3.9.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# proto                       NA
# psutil                      NA
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pyarrow                     13.0.0
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pynvml                      NA
# pyparsing                   3.1.1
# pyreadr                     0.5.0
# pythonjsonlogger            NA
# pytz                        2023.3.post1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# send2trash                  NA
# shapely                     1.8.5.post1
# six                         1.16.0
# sklearn                     1.3.2
# sniffio                     1.3.0
# socks                       1.7.1
# sql                         NA
# sqlalchemy                  2.0.21
# sqlparse                    0.4.4
# stack_data                  0.6.2
# sympy                       1.12
# termcolor                   NA
# texttable                   1.7.0
# threadpoolctl               3.2.0
# torch                       2.1.2+cu121
# torchgen                    NA
# tornado                     6.3.3
# tqdm                        4.66.1
# traitlets                   5.9.0
# typing_extensions           NA
# uri_template                NA
# urllib3                     1.26.18
# wcwidth                     0.2.12
# webcolors                   1.13
# websocket                   1.7.0
# wrapt                       1.15.0
# xarray                      2023.12.0
# yaml                        6.0.1
# zipp                        NA
# zmq                         25.1.2
# zoneinfo                    NA
# zstandard                   0.22.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.19.0
# jupyter_client      8.6.0
# jupyter_core        5.6.1
# jupyterlab          4.0.10
# notebook            6.5.4
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-5.15.0-1051-gcp-x86_64-with-glibc2.31
# -----
# Session information updated at 2024-02-18 03:29
# </pre>
# </details>

# %% [markdown]
# # Label cell types using CellTypist Models
#
# To build our reference, we would like to start with labels that originate from published cell type references.
#
# One of the approaches for this cell type labeling is CellTypist, a model-based approach to cell type labeling.
#
# CellTypist is described [on their website](https://www.celltypist.org/), and in this publication:
#
# Domínguez Conde, C. et al. Cross-tissue immune cell analysis reveals tissue-specific features in humans. Science 376, eabl5197 (2022)
#
# Here, we'll load in our cells individually, and assign labels based on 2 of our 3-level annotated PBMC reference:
#
# - AIFI_L1:
#     - 9 types
# - AIFI_L2:
#     - 29 types

# %% [markdown]
# ## Load Packages
#
# `anndata`: Data structures for scRNA-seq
# `celltypist`: Model-based cell type annotation
# `concurrent.futures`: parallelization methods
# `datetime`: date and time functions
# `h5py`: HDF5 file I/O
# `hisepy`: The HISE SDK for Python
# `numpy`: Mathematical data structures and computation
# `os`: operating system calls
# `pandas`: DataFrame data structures
# `re`: Regular expressions
# `scanpy`: scRNA-seq analysis
# `scipy.sparse`: Spare matrix data structures
# `shutil`: Shell utilities

# %%
import anndata
import celltypist
from celltypist import models
import concurrent.futures
from datetime import date
import h5py
import hisepy
import numpy as np
import os
import pandas as pd 
import re
import scanpy as sc
import scipy.sparse as scs
import shutil

# %%
cohort = 'BR2'
subject_sex = 'Male'

# %% [markdown]
# Load a model to prevent CellTypist from loading all models per core

# %%
models.download_models(
    force_update = True,
    model = ['Immune_All_High.pkl']
)
# Out:
# 📜 Retrieving model list from server https://celltypist.cog.sanger.ac.uk/models/models.json
# 📚 Total models in list: 44
# 📂 Storing models in /root/.celltypist/data/models
# 💾 Total models to download: 1
# 💾 Downloading model [1/1]: Immune_All_High.pkl

# %% [markdown]
# ## Helper functions
#
# This function allows easy reading of .csv files stored in HISE

# %%
def read_csv_uuid(csv_uuid):
    csv_path = '/home/jupyter/cache/{u}'.format(u = csv_uuid)
    if not os.path.isdir(csv_path):
        hise_res = hisepy.reader.cache_files([csv_uuid])
    csv_filename = os.listdir(csv_path)[0]
    csv_file = '{p}/{f}'.format(p = csv_path, f = csv_filename)
    df = pd.read_csv(csv_file, index_col = 0)
    return df

# %% [markdown]
# This function allows easy identification of the cached file path for files retrieved from HISE

# %%
def read_path_uuid(file_uuid):
    file_path = '/home/jupyter/cache/{u}'.format(u = file_uuid)
    if not os.path.isdir(file_path):
        hise_res = hisepy.reader.cache_files([file_uuid])
    filename = os.listdir(file_path)[0]
    full_path = '{p}/{f}'.format(p = file_path, f = filename)
    return full_path

# %% [markdown]
# These functions will retrieve data for a sample, assemble an AnnData object, perform normalization and log transformation, then generate predictions for each of the 3 models retrieved.

# %%
# define a function to read count data
def read_mat(h5_con):
    mat = scs.csc_matrix(
        (h5_con['matrix']['data'][:], # Count values
         h5_con['matrix']['indices'][:], # Row indices
         h5_con['matrix']['indptr'][:]), # Pointers for column positions
        shape = tuple(h5_con['matrix']['shape'][:]) # Matrix dimensions
    )
    return mat

# define a function to read obeservation metadata (i.e. cell metadata)
def read_obs(h5con):
    bc = h5con['matrix']['barcodes'][:]
    bc = [x.decode('UTF-8') for x in bc]

    # Initialized the DataFrame with cell barcodes
    obs_df = pd.DataFrame({ 'barcodes' : bc })

    # Get the list of available metadata columns
    obs_columns = h5con['matrix']['observations'].keys()

    # For each column
    for col in obs_columns:
        # Read the values
        values = h5con['matrix']['observations'][col][:]
        # Check for byte storage
        if(isinstance(values[0], (bytes, bytearray))):
            # Decode byte strings
            values = [x.decode('UTF-8') for x in values]
        # Add column to the DataFrame
        obs_df[col] = values

    obs_df = obs_df.set_index('barcodes', drop = False)
    
    return obs_df

# define a function to construct anndata object from a h5 file
def read_h5_anndata(h5_con):
    #h5_con = h5py.File(h5_file, mode = 'r')
    # extract the expression matrix
    mat = read_mat(h5_con)
    # extract gene names
    genes = h5_con['matrix']['features']['name'][:]
    genes = [x.decode('UTF-8') for x in genes]
    # extract metadata
    obs_df = read_obs(h5_con)
    # construct anndata
    adata = anndata.AnnData(mat.T,
                             obs = obs_df)
    # make sure the gene names aligned
    adata.var_names = genes

    adata.var_names_make_unique()
    return adata

# %%
def get_adata(uuid):
    # Load the file using HISE
    res = hisepy.reader.read_files([uuid])

    # If there's an error, read_files returns a list instead of a dictionary.
    # We should raise and exception with the message when this happens.
    if(isinstance(res, list)):
        error_message = res[0]['message']
        raise Exception('{u}: {e}'.format(u = uuid, e = error_message))
    
    # Read the file to adata
    h5_con = res['values'][0]
    adata = read_h5_anndata(h5_con)
    
    # Close the file now that we're done with it
    h5_con.close()

    return(adata)

# %%
def run_prediction(adata, model, model_name, out_dir = "output"):
    # Make output directories
    model_dir = "{d}/{m}".format(d = out_dir, m = model_name)
    if not os.path.isdir(model_dir):
        os.makedirs(model_dir)
    
    sample_id = adata.obs['pbmc_sample_id'].unique()[0]
    label_file = "{d}/{s}_{m}_labels.csv".format(d = model_dir, s = sample_id, m = model_name)

    if os.path.exists(label_file):
        print("{s}: {m} Previously computed; Skipping.".format(s = sample_id, m = model_name))
    else:
        # Perform prediction
        predictions = celltypist.annotate(
            adata, 
            model = model, 
            majority_voting = True)
    
        # Write output
        
        prob_file = "{d}/{s}_{m}_probability_mat.parquet".format(d = model_dir, s = sample_id, m = model_name)
        prob = predictions.probability_matrix
        prob.to_parquet(prob_file)
    
        dec_file = "{d}/{s}_{m}_decision_mat.parquet".format(d = model_dir, s = sample_id, m = model_name)
        predictions.decision_matrix.to_parquet(dec_file)
        
        labels = predictions.predicted_labels
        labels = labels.rename({'predicted_labels': model_name}, axis = 1)
        
        prob_scores = []
        for i in range(labels.shape[0]):
            prob_scores.append(prob.loc[labels.index.to_list()[i],labels[model_name][i]])
        labels['{m}_score'.format(m = model_name)] = prob_scores
        labels.to_csv(label_file)
    
def process_data(file_uuid, sample_id):
    out_dir = "output"
    check_file = '{d}/{m}/{s}_{m}_labels.csv'.format(d = out_dir, m = 'AIFI_L3', s = sample_id)

    if os.path.exists(check_file):
        print('{s} Previously labeled; Skipping.'.format(s = sample_id))
    else:
        # Load cells from HISE .h5 files
        adata = get_adata(file_uuid)
        
        # Normalize data
        sc.pp.normalize_total(adata, target_sum=1e4)
        sc.pp.log1p(adata)
        adata.obs.index = adata.obs['barcodes']
        
        # Predict cell types
        for model_name,model_path in model_paths.items():
            run_prediction(
                adata,
                model_path,
                model_name,
                out_dir
            )
        
        del adata

# %%
def element_id(n = 3):
    import periodictable
    from random import randrange
    rand_el = []
    for i in range(n):
        el = randrange(0,118)
        rand_el.append(periodictable.elements[el].name)
    rand_str = '-'.join(rand_el)
    return rand_str

# %% [markdown]
# ## Obtain CellTypist Models

# %%
model_uuids = {
    'AIFI_L1': '54d9399c-3bfd-4619-a32d-8c7f3c0911f6',
    'AIFI_L2': 'e2898db9-e121-4263-b0c6-a19eadd4217a'
}

# %%
model_paths = {}
for name,uuid in model_uuids.items():
    model_paths[name] = read_path_uuid(uuid)

# %%
model_paths
# Out:
# {'AIFI_L1': '/home/jupyter/cache/54d9399c-3bfd-4619-a32d-8c7f3c0911f6/ref_pbmc_clean_celltypist_model_AIFI_L1_2024-03-09.pkl',
#  'AIFI_L2': '/home/jupyter/cache/e2898db9-e121-4263-b0c6-a19eadd4217a/ref_pbmc_clean_celltypist_model_AIFI_L2_2024-03-10.pkl',
#  'AIFI_L3': '/home/jupyter/cache/d18fe8b3-b8e7-4b25-9966-0c05a1ba9d7a/ref_pbmc_clean_celltypist_model_AIFI_L3_2024-03-11.pkl'}

# %% [markdown]
# ## Read sample metadata from HISE

# %%
sample_meta_file_uuid = 'd82c5c42-ae5f-4e67-956e-cd3b7bf88105'
file_query = hisepy.reader.read_files(
    [sample_meta_file_uuid]
)

# %%
meta_data = file_query['values']

# %%
meta_data.shape
# Out:
# (868, 33)

# %% [markdown]
# ### Filter metadata for selected cohort and sex

# %%
meta_data = meta_data[meta_data['cohort.cohortGuid'] == cohort]
meta_data = meta_data[meta_data['subject.biologicalSex'] == subject_sex]

# %% [markdown]
# ## Apply across files
#
# Here, we'll use `concurrent.futures` to apply the function above to our files in parallel.

# %%
out_dir = 'output'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
file_uuids = meta_data['file.id'].to_list()
sample_ids = meta_data['pbmc_sample_id'].to_list()

# %%
# Process each subset in parallel
pool_executor = concurrent.futures.ProcessPoolExecutor(max_workers = 60)
with pool_executor as executor:
    
    futures = []
    for i in range(len(file_uuids)):
        file_uuid = file_uuids[i]
        sample_id = sample_ids[i]
        futures.append(executor.submit(process_data, file_uuid, sample_id))

    # Check for errors when parallel processes return results
    for future in concurrent.futures.as_completed(futures):
        try:
            print(future.result())
        except Exception as e:
            print(f'Error: {e}')
# Out:
# PB00001-01 Previously labeled; Skipping.
# PB00002-01 Previously labeled; Skipping.PB00004-01 Previously labeled; Skipping.PB00003-01 Previously labeled; Skipping.
# PB00006-01 Previously labeled; Skipping.
#
#
# PB00008-01 Previously labeled; Skipping.PB00007-01 Previously labeled; Skipping.PB00009-01 Previously labeled; Skipping.PB00010-02 Previously labeled; Skipping.PB00012-01 Previously labeled; Skipping.PB00011-01 Previously labeled; Skipping.PB00014-01 Previously labeled; Skipping.PB00013-01 Previously labeled; Skipping.PB00016-01 Previously labeled; Skipping.PB00015-01 Previously labeled; Skipping.
#
#
# PB00017-01 Previously labeled; Skipping.PB00018-01 Previously labeled; Skipping.PB00019-01 Previously labeled; Skipping.
# PB00020-01 Previously labeled; Skipping.
#
# PB00021-01 Previously labeled; Skipping.PB00023-05 Previously labeled; Skipping.
# PB00022-01 Previously labeled; Skipping.PB00024-01 Previously labeled; Skipping.
#
#
# PB00025-04 Previously labeled; Skipping.PB00027-05 Previously labeled; Skipping.PB00026-05 Previously labeled; Skipping.PB00028-05 Previously labeled; Skipping.PB00044-01 Previously labeled; Skipping.PB00029-02 Previously labeled; Skipping.
#
#
#
# PB00032-05 Previously labeled; Skipping.
# PB00033-06 Previously labeled; Skipping.PB00034-01 Previously labeled; Skipping.
# PB00035-01 Previously labeled; Skipping.
# PB00037-01 Previously labeled; Skipping.
# PB00039-03 Previously labeled; Skipping.PB00036-01 Previously labeled; Skipping.
# PB00040-01 Previously labeled; Skipping.PB00041-01 Previously labeled; Skipping.
# PB00042-01 Previously labeled; Skipping.
# PB00045-01 Previously labeled; Skipping.
#
#
# PB00046-01 Previously labeled; Skipping.PB00048-01 Previously labeled; Skipping.PB00047-01 Previously labeled; Skipping.PB00049-01 Previously labeled; Skipping.PB00050-01 Previously labeled; Skipping.PB00155-01 Previously labeled; Skipping.PB00157-01 Previously labeled; Skipping.PB00158-01 Previously labeled; Skipping.PB00159-01 Previously labeled; Skipping.PB00161-01 Previously labeled; Skipping.PB00160-01 Previously labeled; Skipping.
# PB00141-01 Previously labeled; Skipping.PB00142-01 Previously labeled; Skipping.PB00143-01 Previously labeled; Skipping.
# PB00144-01 Previously labeled; Skipping.
# PB00146-02 Previously labeled; Skipping.PB00147-01 Previously labeled; Skipping.
#
# PB00148-01 Previously labeled; Skipping.PB00149-01 Previously labeled; Skipping.PB00150-01 Previously labeled; Skipping.
#
# PB00152-01 Previously labeled; Skipping.PB00153-01 Previously labeled; Skipping.PB00151-01 Previously labeled; Skipping.
# PB00154-01 Previously labeled; Skipping.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# PB00162-01 Previously labeled; Skipping.PB00164-01 Previously labeled; Skipping.PB00165-03 Previously labeled; Skipping.PB00167-01 Previously labeled; Skipping.PB00166-01 Previously labeled; Skipping.PB00168-01 Previously labeled; Skipping.PB00169-03 Previously labeled; Skipping.PB00170-01 Previously labeled; Skipping.PB00252-02 Previously labeled; Skipping.PB00255-01 Previously labeled; Skipping.PB00253-01 Previously labeled; Skipping.PB00254-01 Previously labeled; Skipping.PB00256-01 Previously labeled; Skipping.PB00257-01 Previously labeled; Skipping.
# PB00259-01 Previously labeled; Skipping.PB00258-04 Previously labeled; Skipping.
# PB00262-01 Previously labeled; Skipping.PB00260-01 Previously labeled; Skipping.PB00264-01 Previously labeled; Skipping.PB00263-03 Previously labeled; Skipping.
#
#
# PB00268-01 Previously labeled; Skipping.PB00265-01 Previously labeled; Skipping.PB00267-01 Previously labeled; Skipping.PB00271-03 Previously labeled; Skipping.PB00269-01 Previously labeled; Skipping.PB00273-05 Previously labeled; Skipping.PB00272-01 Previously labeled; Skipping.PB00270-01 Previously labeled; Skipping.PB00276-03 Previously labeled; Skipping.PB00274-03 Previously labeled; Skipping.PB00275-03 Previously labeled; Skipping.
# PB00278-05 Previously labeled; Skipping.
# PB00280-01 Previously labeled; Skipping.PB00277-01 Previously labeled; Skipping.PB00163-01 Previously labeled; Skipping.PB00282-01 Previously labeled; Skipping.PB00281-01 Previously labeled; Skipping.
#
# PB00283-01 Previously labeled; Skipping.PB00286-05 Previously labeled; Skipping.
# PB00284-01 Previously labeled; Skipping.PB00287-01 Previously labeled; Skipping.PB00288-01 Previously labeled; Skipping.PB00285-01 Previously labeled; Skipping.PB00289-01 Previously labeled; Skipping.PB00290-01 Previously labeled; Skipping.
# PB00291-01 Previously labeled; Skipping.PB00293-02 Previously labeled; Skipping.
# PB00292-02 Previously labeled; Skipping.PB00294-02 Previously labeled; Skipping.PB00295-02 Previously labeled; Skipping.
# PB00298-02 Previously labeled; Skipping.
# PB00296-02 Previously labeled; Skipping.PB00297-02 Previously labeled; Skipping.PB00300-01 Previously labeled; Skipping.PB00299-02 Previously labeled; Skipping.
# PB00323-01 Previously labeled; Skipping.
# PB00326-01 Previously labeled; Skipping.PB00325-01 Previously labeled; Skipping.PB00322-01 Previously labeled; Skipping.
# PB00327-01 Previously labeled; Skipping.
#
#
# PB00328-01 Previously labeled; Skipping.
#
#
#
#
#
#
#
#
#
#
# PB00329-01 Previously labeled; Skipping.
# PB00330-01 Previously labeled; Skipping.
#
#
# PB00332-01 Previously labeled; Skipping.
#
# PB00331-01 Previously labeled; Skipping.PB00333-01 Previously labeled; Skipping.
# PB00334-01 Previously labeled; Skipping.
#
# PB00335-05 Previously labeled; Skipping.
#
#
#
#
#
# PB00336-05 Previously labeled; Skipping.
# PB00338-01 Previously labeled; Skipping.
#
# PB00339-01 Previously labeled; Skipping.
#
# PB00340-01 Previously labeled; Skipping.
#
#
#
#
# PB00341-01 Previously labeled; Skipping.
# PB00342-01 Previously labeled; Skipping.
#
# PB00343-01 Previously labeled; Skipping.
# PB00344-01 Previously labeled; Skipping.
# PB00345-01 Previously labeled; Skipping.PB00348-01 Previously labeled; Skipping.PB00347-01 Previously labeled; Skipping.PB00349-01 Previously labeled; Skipping.PB00350-01 Previously labeled; Skipping.PB00353-04 Previously labeled; Skipping.PB00352-04 Previously labeled; Skipping.PB00354-01 Previously labeled; Skipping.PB00355-01 Previously labeled; Skipping.PB00356-01 Previously labeled; Skipping.PB00357-01 Previously labeled; Skipping.
# PB00358-01 Previously labeled; Skipping.PB00359-01 Previously labeled; Skipping.
# PB00360-01 Previously labeled; Skipping.PB00361-01 Previously labeled; Skipping.
# PB00362-01 Previously labeled; Skipping.
# PB00363-01 Previously labeled; Skipping.
#
#
# PB00030-02 Previously labeled; Skipping.
#
#
#
#
#
#
# PB00367-01 Previously labeled; Skipping.PB00366-01 Previously labeled; Skipping.PB00365-01 Previously labeled; Skipping.PB00370-05 Previously labeled; Skipping.PB00369-01 Previously labeled; Skipping.PB00368-07 Previously labeled; Skipping.
# PB00371-03 Previously labeled; Skipping.PB00373-01 Previously labeled; Skipping.PB00372-01 Previously labeled; Skipping.PB00374-01 Previously labeled; Skipping.PB00376-01 Previously labeled; Skipping.PB00377-01 Previously labeled; Skipping.
# PB00375-01 Previously labeled; Skipping.PB00378-01 Previously labeled; Skipping.PB00379-04 Previously labeled; Skipping.
# PB00380-01 Previously labeled; Skipping.
# PB00381-01 Previously labeled; Skipping.
#
#
#
#
#
# PB00383-01 Previously labeled; Skipping.PB00382-01 Previously labeled; Skipping.PB00384-01 Previously labeled; Skipping.PB00031-05 Previously labeled; Skipping.PB00386-01 Previously labeled; Skipping.PB00385-01 Previously labeled; Skipping.PB00387-01 Previously labeled; Skipping.PB00388-01 Previously labeled; Skipping.PB00390-01 Previously labeled; Skipping.PB00389-01 Previously labeled; Skipping.
#
#
# PB00391-01 Previously labeled; Skipping.
# PB00392-01 Previously labeled; Skipping.
#
#
# PB00393-01 Previously labeled; Skipping.
# PB00394-02 Previously labeled; Skipping.PB00395-01 Previously labeled; Skipping.PB00396-01 Previously labeled; Skipping.PB00398-01 Previously labeled; Skipping.PB00397-01 Previously labeled; Skipping.PB00399-01 Previously labeled; Skipping.
# PB00400-01 Previously labeled; Skipping.PB00501-01 Previously labeled; Skipping.PB00502-01 Previously labeled; Skipping.PB00503-01 Previously labeled; Skipping.
# PB00504-01 Previously labeled; Skipping.
#
#
#
#
#
#
# PB00505-01 Previously labeled; Skipping.
#
#
#
# PB00506-01 Previously labeled; Skipping.
#
#
# PB00507-01 Previously labeled; Skipping.
#
# PB00508-01 Previously labeled; Skipping.PB00509-01 Previously labeled; Skipping.PB00510-01 Previously labeled; Skipping.PB00512-01 Previously labeled; Skipping.PB00511-01 Previously labeled; Skipping.PB00513-02 Previously labeled; Skipping.PB00514-01 Previously labeled; Skipping.
#
#
#
#
#
#
#
#
#
# PB00516-01 Previously labeled; Skipping.PB00515-01 Previously labeled; Skipping.
# PB00517-01 Previously labeled; Skipping.PB00518-01 Previously labeled; Skipping.
# PB00519-01 Previously labeled; Skipping.PB00520-01 Previously labeled; Skipping.
#
#
# PB00521-01 Previously labeled; Skipping.
# PB00522-01 Previously labeled; Skipping.
#
#
#
#
#
# PB00524-01 Previously labeled; Skipping.
#
# PB00523-01 Previously labeled; Skipping.PB00526-01 Previously labeled; Skipping.PB00525-01 Previously labeled; Skipping.PB00528-01 Previously labeled; Skipping.PB00527-01 Previously labeled; Skipping.PB00530-01 Previously labeled; Skipping.PB00529-01 Previously labeled; Skipping.
# PB00531-01 Previously labeled; Skipping.PB00532-01 Previously labeled; Skipping.PB00533-01 Previously labeled; Skipping.PB00534-01 Previously labeled; Skipping.PB00535-01 Previously labeled; Skipping.
# PB00536-01 Previously labeled; Skipping.
# PB00538-01 Previously labeled; Skipping.PB00537-01 Previously labeled; Skipping.
# PB00539-01 Previously labeled; Skipping.PB00540-01 Previously labeled; Skipping.
#
#
#
#
#
# PB00541-01 Previously labeled; Skipping.PB00542-01 Previously labeled; Skipping.PB00543-01 Previously labeled; Skipping.PB00544-01 Previously labeled; Skipping.PB00545-01 Previously labeled; Skipping.PB00546-01 Previously labeled; Skipping.PB00548-01 Previously labeled; Skipping.PB00547-01 Previously labeled; Skipping.PB00549-01 Previously labeled; Skipping.PB00550-01 Previously labeled; Skipping.
#
#
# PB00551-01 Previously labeled; Skipping.
# PB00552-01 Previously labeled; Skipping.
#
# PB00554-01 Previously labeled; Skipping.PB00553-01 Previously labeled; Skipping.
# PB00555-01 Previously labeled; Skipping.
# PB00556-01 Previously labeled; Skipping.PB00557-01 Previously labeled; Skipping.PB00559-01 Previously labeled; Skipping.PB00560-01 Previously labeled; Skipping.PB00561-04 Previously labeled; Skipping.
# PB00563-01 Previously labeled; Skipping.PB00562-01 Previously labeled; Skipping.PB00564-04 Previously labeled; Skipping.
#
# PB00565-01 Previously labeled; Skipping.
#
#
#
#
#
# PB00566-01 Previously labeled; Skipping.
#
#
#
#
# PB00567-01 Previously labeled; Skipping.
# PB00568-01 Previously labeled; Skipping.
#
# PB00569-01 Previously labeled; Skipping.
# PB00570-01 Previously labeled; Skipping.PB00571-01 Previously labeled; Skipping.PB00574-01 Previously labeled; Skipping.PB00572-01 Previously labeled; Skipping.PB00576-01 Previously labeled; Skipping.
# PB00575-01 Previously labeled; Skipping.
#
#
#
#
#
#
#
#
# PB00577-02 Previously labeled; Skipping.PB00578-01 Previously labeled; Skipping.PB00579-01 Previously labeled; Skipping.
#
# PB00580-01 Previously labeled; Skipping.PB00581-01 Previously labeled; Skipping.PB00582-01 Previously labeled; Skipping.
#
#
# PB00583-01 Previously labeled; Skipping.
# PB00584-01 Previously labeled; Skipping.
#
#
#
#
# PB00585-01 Previously labeled; Skipping.
#
#
# PB00588-01 Previously labeled; Skipping.PB00587-01 Previously labeled; Skipping.PB00586-01 Previously labeled; Skipping.PB00589-01 Previously labeled; Skipping.PB00590-01 Previously labeled; Skipping.PB00591-01 Previously labeled; Skipping.PB00592-01 Previously labeled; Skipping.
# PB00593-01 Previously labeled; Skipping.PB00594-01 Previously labeled; Skipping.PB00595-01 Previously labeled; Skipping.PB00597-01 Previously labeled; Skipping.PB00596-01 Previously labeled; Skipping.PB00598-01 Previously labeled; Skipping.
#
# PB00599-01 Previously labeled; Skipping.PB00600-01 Previously labeled; Skipping.
# PB00601-01 Previously labeled; Skipping.PB00602-01 Previously labeled; Skipping.
#
#
#
#
# PB00603-01 Previously labeled; Skipping.
# PB00604-01 Previously labeled; Skipping.PB00605-01 Previously labeled; Skipping.PB00606-01 Previously labeled; Skipping.PB00607-02 Previously labeled; Skipping.PB00608-01 Previously labeled; Skipping.PB00610-02 Previously labeled; Skipping.PB00609-02 Previously labeled; Skipping.PB00612-01 Previously labeled; Skipping.
# PB00611-01 Previously labeled; Skipping.
#
# PB00614-01 Previously labeled; Skipping.
# PB00615-01 Previously labeled; Skipping.
#
# PB00617-01 Previously labeled; Skipping.PB00616-01 Previously labeled; Skipping.
# PB00618-01 Previously labeled; Skipping.PB00619-03 Previously labeled; Skipping.
# PB00620-01 Previously labeled; Skipping.PB00621-01 Previously labeled; Skipping.PB00622-01 Previously labeled; Skipping.PB00623-01 Previously labeled; Skipping.
# PB00624-01 Previously labeled; Skipping.PB00625-02 Previously labeled; Skipping.PB00626-01 Previously labeled; Skipping.
# PB00627-01 Previously labeled; Skipping.
#
#
#
#
#
# PB00628-01 Previously labeled; Skipping.
#
#
#
#
#
# PB00629-01 Previously labeled; Skipping.PB00630-01 Previously labeled; Skipping.
#
# PB00631-01 Previously labeled; Skipping.
#
# PB00632-03 Previously labeled; Skipping.PB00633-01 Previously labeled; Skipping.PB00635-01 Previously labeled; Skipping.PB00634-01 Previously labeled; Skipping.PB00636-01 Previously labeled; Skipping.
# PB00637-01 Previously labeled; Skipping.
#
#
#
#
#
#
# PB00638-01 Previously labeled; Skipping.
# PB00639-02 Previously labeled; Skipping.
#
# PB00640-01 Previously labeled; Skipping.
# PB00641-01 Previously labeled; Skipping.PB00643-01 Previously labeled; Skipping.PB00642-01 Previously labeled; Skipping.
#
#
# PB00644-01 Previously labeled; Skipping.
#
#
# PB00645-01 Previously labeled; Skipping.
#
#
#
#
# PB00646-01 Previously labeled; Skipping.
# PB00647-01 Previously labeled; Skipping.PB00649-04 Previously labeled; Skipping.PB00648-01 Previously labeled; Skipping.PB00650-01 Previously labeled; Skipping.PB01410-01 Previously labeled; Skipping.PB01411-01 Previously labeled; Skipping.PB01412-01 Previously labeled; Skipping.
# PB01413-01 Previously labeled; Skipping.PB01415-01 Previously labeled; Skipping.PB01414-01 Previously labeled; Skipping.PB01417-01 Previously labeled; Skipping.PB01416-01 Previously labeled; Skipping.
# PB01418-01 Previously labeled; Skipping.
# PB01419-01 Previously labeled; Skipping.
# PB01421-01 Previously labeled; Skipping.
# PB01420-01 Previously labeled; Skipping.PB01423-01 Previously labeled; Skipping.
#
#
#
# PB01424-01 Previously labeled; Skipping.
# PB01425-01 Previously labeled; Skipping.PB01426-01 Previously labeled; Skipping.PB01427-01 Previously labeled; Skipping.PB01428-01 Previously labeled; Skipping.PB01429-01 Previously labeled; Skipping.PB01430-01 Previously labeled; Skipping.
# PB01431-01 Previously labeled; Skipping.PB01433-01 Previously labeled; Skipping.
# PB01434-01 Previously labeled; Skipping.
# PB01435-01 Previously labeled; Skipping.
# PB01436-01 Previously labeled; Skipping.
#
# PB01438-01 Previously labeled; Skipping.PB01437-01 Previously labeled; Skipping.
# PB01439-01 Previously labeled; Skipping.PB01440-01 Previously labeled; Skipping.PB01441-01 Previously labeled; Skipping.
# PB01442-01 Previously labeled; Skipping.PB01444-01 Previously labeled; Skipping.PB01443-01 Previously labeled; Skipping.PB01445-01 Previously labeled; Skipping.PB01446-01 Previously labeled; Skipping.
#
# PB01447-02 Previously labeled; Skipping.PB01448-02 Previously labeled; Skipping.
#
#
#
#
#
#
#
#
# PB01449-01 Previously labeled; Skipping.
#
#
# PB01450-01 Previously labeled; Skipping.PB01451-01 Previously labeled; Skipping.
#
# PB01452-01 Previously labeled; Skipping.PB01453-02 Previously labeled; Skipping.
#
# PB01454-01 Previously labeled; Skipping.
# PB01455-01 Previously labeled; Skipping.PB01457-01 Previously labeled; Skipping.PB01456-01 Previously labeled; Skipping.PB01458-01 Previously labeled; Skipping.
#
#
#
#
#
# PB01459-01 Previously labeled; Skipping.
#
#
#
# PB01507-01 Previously labeled; Skipping.PB01508-01 Previously labeled; Skipping.
# PB01509-01 Previously labeled; Skipping.
# PB01510-01 Previously labeled; Skipping.
# PB01511-02 Previously labeled; Skipping.
# PB01512-02 Previously labeled; Skipping.
#
#
#
# PB01513-01 Previously labeled; Skipping.
#
#
# PB01514-01 Previously labeled; Skipping.
# PB01515-01 Previously labeled; Skipping.
# PB01516-03 Previously labeled; Skipping.PB01517-02 Previously labeled; Skipping.PB01518-02 Previously labeled; Skipping.PB01519-01 Previously labeled; Skipping.PB01520-01 Previously labeled; Skipping.PB01521-01 Previously labeled; Skipping.PB01522-01 Previously labeled; Skipping.PB01523-01 Previously labeled; Skipping.PB01524-01 Previously labeled; Skipping.
# PB01525-01 Previously labeled; Skipping.PB01526-01 Previously labeled; Skipping.
#
# PB01527-01 Previously labeled; Skipping.PB01528-02 Previously labeled; Skipping.
#
# PB01529-03 Previously labeled; Skipping.
# PB01530-01 Previously labeled; Skipping.PB01531-01 Previously labeled; Skipping.
# PB01532-02 Previously labeled; Skipping.
#
#
# PB01533-01 Previously labeled; Skipping.PB01534-01 Previously labeled; Skipping.PB01535-01 Previously labeled; Skipping.PB01536-01 Previously labeled; Skipping.PB01537-01 Previously labeled; Skipping.
# PB01538-01 Previously labeled; Skipping.PB01540-01 Previously labeled; Skipping.PB01541-01 Previously labeled; Skipping.
# PB01542-01 Previously labeled; Skipping.
# PB01543-01 Previously labeled; Skipping.
# PB01544-01 Previously labeled; Skipping.
# PB01545-01 Previously labeled; Skipping.
# PB01546-01 Previously labeled; Skipping.
# PB01547-01 Previously labeled; Skipping.PB01549-01 Previously labeled; Skipping.PB01548-01 Previously labeled; Skipping.
# PB01550-01 Previously labeled; Skipping.PB01552-01 Previously labeled; Skipping.PB01551-01 Previously labeled; Skipping.PB01553-01 Previously labeled; Skipping.PB01554-01 Previously labeled; Skipping.
# PB01555-01 Previously labeled; Skipping.
# PB01556-01 Previously labeled; Skipping.
#
#
#
#
#
#
#
#
#
# PB01557-01 Previously labeled; Skipping.
#
# PB01558-01 Previously labeled; Skipping.
# PB01559-01 Previously labeled; Skipping.PB01560-01 Previously labeled; Skipping.PB01561-01 Previously labeled; Skipping.
# PB01562-01 Previously labeled; Skipping.
# PB01563-01 Previously labeled; Skipping.
#
#
# PB01564-01 Previously labeled; Skipping.PB01565-01 Previously labeled; Skipping.PB01566-02 Previously labeled; Skipping.
#
#
#
#
# PB01567-01 Previously labeled; Skipping.
#
#
# PB01568-01 Previously labeled; Skipping.
# PB01569-01 Previously labeled; Skipping.
# PB01570-01 Previously labeled; Skipping.
#
# PB01571-01 Previously labeled; Skipping.PB01572-01 Previously labeled; Skipping.
# PB01573-01 Previously labeled; Skipping.
#
#
# PB01574-01 Previously labeled; Skipping.
#
#
#
#
#
# PB01575-01 Previously labeled; Skipping.PB01577-01 Previously labeled; Skipping.PB01576-01 Previously labeled; Skipping.PB01580-01 Previously labeled; Skipping.PB01578-01 Previously labeled; Skipping.PB01579-01 Previously labeled; Skipping.PB01581-01 Previously labeled; Skipping.PB01582-01 Previously labeled; Skipping.PB01583-01 Previously labeled; Skipping.PB01585-01 Previously labeled; Skipping.PB01586-01 Previously labeled; Skipping.PB01587-01 Previously labeled; Skipping.
# PB01588-02 Previously labeled; Skipping.
# PB01589-01 Previously labeled; Skipping.
# PB01590-01 Previously labeled; Skipping.
#
# PB01591-01 Previously labeled; Skipping.
#
# PB01593-01 Previously labeled; Skipping.PB01592-01 Previously labeled; Skipping.PB01594-01 Previously labeled; Skipping.
#
# PB01595-01 Previously labeled; Skipping.
# PB01596-01 Previously labeled; Skipping.PB01597-01 Previously labeled; Skipping.PB01598-01 Previously labeled; Skipping.PB01599-01 Previously labeled; Skipping.
# PB01602-01 Previously labeled; Skipping.PB01600-01 Previously labeled; Skipping.PB01603-01 Previously labeled; Skipping.PB01604-01 Previously labeled; Skipping.
# PB01605-01 Previously labeled; Skipping.
# PB01606-01 Previously labeled; Skipping.
#
# PB01965-01 Previously labeled; Skipping.PB01964-01 Previously labeled; Skipping.
# PB01966-01 Previously labeled; Skipping.
# PB01967-01 Previously labeled; Skipping.PB01968-01 Previously labeled; Skipping.PB01969-01 Previously labeled; Skipping.PB01970-01 Previously labeled; Skipping.
# PB01972-01 Previously labeled; Skipping.PB01971-02 Previously labeled; Skipping.PB01973-01 Previously labeled; Skipping.
# PB01974-01 Previously labeled; Skipping.PB01975-01 Previously labeled; Skipping.
#
#
#
#
#
#
#
#
#
#
#
# PB01976-01 Previously labeled; Skipping.PB01977-01 Previously labeled; Skipping.PB01978-01 Previously labeled; Skipping.
#
# PB01979-01 Previously labeled; Skipping.PB01980-01 Previously labeled; Skipping.
# PB01981-01 Previously labeled; Skipping.PB01982-01 Previously labeled; Skipping.
#
# PB01983-02 Previously labeled; Skipping.
# PB01984-01 Previously labeled; Skipping.
# PB01985-01 Previously labeled; Skipping.
#
#
#
# PB01986-01 Previously labeled; Skipping.
#
#
#
#
# PB01987-01 Previously labeled; Skipping.PB01988-01 Previously labeled; Skipping.
# PB01989-02 Previously labeled; Skipping.PB01990-01 Previously labeled; Skipping.
#
#
# PB01991-01 Previously labeled; Skipping.PB01992-01 Previously labeled; Skipping.
#
#
#
# PB01993-01 Previously labeled; Skipping.
#
#
# PB01994-01 Previously labeled; Skipping.
#
# PB01996-01 Previously labeled; Skipping.PB01995-01 Previously labeled; Skipping.PB01997-01 Previously labeled; Skipping.PB01998-04 Previously labeled; Skipping.PB01999-01 Previously labeled; Skipping.PB02000-01 Previously labeled; Skipping.PB02001-01 Previously labeled; Skipping.PB02002-01 Previously labeled; Skipping.PB02003-02 Previously labeled; Skipping.PB02004-01 Previously labeled; Skipping.PB02005-01 Previously labeled; Skipping.PB02006-01 Previously labeled; Skipping.
#
#
# PB02007-02 Previously labeled; Skipping.
#
#
# PB02008-04 Previously labeled; Skipping.
# PB02009-01 Previously labeled; Skipping.PB02010-01 Previously labeled; Skipping.PB02011-01 Previously labeled; Skipping.PB02012-01 Previously labeled; Skipping.
# PB02013-01 Previously labeled; Skipping.
#
# PB02228-03 Previously labeled; Skipping.PB02230-01 Previously labeled; Skipping.PB02229-01 Previously labeled; Skipping.
# PB02231-01 Previously labeled; Skipping.PB02233-01 Previously labeled; Skipping.PB02234-01 Previously labeled; Skipping.PB02235-04 Previously labeled; Skipping.PB02236-01 Previously labeled; Skipping.
# PB02237-04 Previously labeled; Skipping.
#
# PB02238-01 Previously labeled; Skipping.
# PB02239-01 Previously labeled; Skipping.PB02240-02 Previously labeled; Skipping.
# PB02241-01 Previously labeled; Skipping.PB02242-02 Previously labeled; Skipping.
# PB02243-01 Previously labeled; Skipping.PB02244-01 Previously labeled; Skipping.
# PB02245-02 Previously labeled; Skipping.PB02246-02 Previously labeled; Skipping.PB02247-01 Previously labeled; Skipping.PB02248-01 Previously labeled; Skipping.
# PB02249-01 Previously labeled; Skipping.
# PB02250-02 Previously labeled; Skipping.
#
#
#
#
#
#
#
#
#
#
# PB02251-01 Previously labeled; Skipping.
# PB02252-01 Previously labeled; Skipping.PB02253-01 Previously labeled; Skipping.PB02254-02 Previously labeled; Skipping.PB02255-01 Previously labeled; Skipping.
# PB02256-01 Previously labeled; Skipping.PB02257-01 Previously labeled; Skipping.
#
#
#
# PB02258-01 Previously labeled; Skipping.
# PB02259-01 Previously labeled; Skipping.PB02260-01 Previously labeled; Skipping.
#
#
#
# PB02261-01 Previously labeled; Skipping.
#
#
#
# PB02262-01 Previously labeled; Skipping.
# PB02263-02 Previously labeled; Skipping.PB02264-01 Previously labeled; Skipping.
# PB02265-02 Previously labeled; Skipping.
#
# PB02266-01 Previously labeled; Skipping.
#
# PB02267-01 Previously labeled; Skipping.
#
#
#
# PB02268-01 Previously labeled; Skipping.
#
# PB02269-01 Previously labeled; Skipping.
# PB02270-01 Previously labeled; Skipping.
# PB02271-01 Previously labeled; Skipping.PB02272-01 Previously labeled; Skipping.PB02273-01 Previously labeled; Skipping.PB02274-01 Previously labeled; Skipping.PB02275-01 Previously labeled; Skipping.PB02276-02 Previously labeled; Skipping.PB02277-01 Previously labeled; Skipping.PB02309-002 Previously labeled; Skipping.PB02310-001 Previously labeled; Skipping.PB02311-001 Previously labeled; Skipping.
# PB02312-001 Previously labeled; Skipping.PB02313-001 Previously labeled; Skipping.
#
#
#
#
#
# PB02314-001 Previously labeled; Skipping.PB02315-001 Previously labeled; Skipping.PB02316-001 Previously labeled; Skipping.PB02317-001 Previously labeled; Skipping.
#
# PB02318-002 Previously labeled; Skipping.
# PB02319-001 Previously labeled; Skipping.PB02320-001 Previously labeled; Skipping.PB02322-002 Previously labeled; Skipping.PB02321-001 Previously labeled; Skipping.
# PB02323-002 Previously labeled; Skipping.PB02324-001 Previously labeled; Skipping.PB02325-001 Previously labeled; Skipping.PB02326-001 Previously labeled; Skipping.PB02327-002 Previously labeled; Skipping.
#
# PB02328-001 Previously labeled; Skipping.
#
# PB02329-001 Previously labeled; Skipping.PB02331-001 Previously labeled; Skipping.PB02330-001 Previously labeled; Skipping.
# PB02332-001 Previously labeled; Skipping.PB02333-001 Previously labeled; Skipping.
# PB02334-001 Previously labeled; Skipping.PB02336-001 Previously labeled; Skipping.PB02335-002 Previously labeled; Skipping.PB02337-001 Previously labeled; Skipping.
# PB02338-001 Previously labeled; Skipping.
# PB02339-001 Previously labeled; Skipping.
# PB02340-001 Previously labeled; Skipping.PB02341-001 Previously labeled; Skipping.
#
#
#
#
#
#
#
#
#
# PB02342-001 Previously labeled; Skipping.
#
# PB02343-001 Previously labeled; Skipping.PB02344-001 Previously labeled; Skipping.PB02346-001 Previously labeled; Skipping.PB02347-001 Previously labeled; Skipping.PB02349-001 Previously labeled; Skipping.PB02348-001 Previously labeled; Skipping.
#
#
#
# PB02350-001 Previously labeled; Skipping.PB02351-001 Previously labeled; Skipping.PB02352-001 Previously labeled; Skipping.
#
#
#
#
#
# PB02353-001 Previously labeled; Skipping.
#
#
#
# PB02354-001 Previously labeled; Skipping.PB02355-001 Previously labeled; Skipping.PB02356-001 Previously labeled; Skipping.
# PB02357-001 Previously labeled; Skipping.
#
#
#
# PB02358-001 Previously labeled; Skipping.
# PB02444-001 Previously labeled; Skipping.
#
#
#
# PB02445-001 Previously labeled; Skipping.
#
# PB02446-001 Previously labeled; Skipping.
# PB02447-001 Previously labeled; Skipping.
# PB02449-001 Previously labeled; Skipping.PB02451-001 Previously labeled; Skipping.PB02450-001 Previously labeled; Skipping.PB02452-001 Previously labeled; Skipping.PB02453-001 Previously labeled; Skipping.PB02455-001 Previously labeled; Skipping.PB02454-001 Previously labeled; Skipping.PB02457-001 Previously labeled; Skipping.PB02456-001 Previously labeled; Skipping.
# PB02458-001 Previously labeled; Skipping.PB02459-001 Previously labeled; Skipping.PB02460-001 Previously labeled; Skipping.
#
#
#
#
#
# PB02461-001 Previously labeled; Skipping.PB02463-001 Previously labeled; Skipping.PB02464-001 Previously labeled; Skipping.PB02462-001 Previously labeled; Skipping.
#
#
# PB02466-001 Previously labeled; Skipping.PB02467-001 Previously labeled; Skipping.PB02465-001 Previously labeled; Skipping.PB02469-001 Previously labeled; Skipping.PB02468-001 Previously labeled; Skipping.
# PB02470-001 Previously labeled; Skipping.PB02471-001 Previously labeled; Skipping.PB02472-001 Previously labeled; Skipping.PB02473-001 Previously labeled; Skipping.
# PB02474-002 Previously labeled; Skipping.
#
# PB02475-001 Previously labeled; Skipping.PB02476-001 Previously labeled; Skipping.
# PB02477-001 Previously labeled; Skipping.PB02478-001 Previously labeled; Skipping.
# PB02479-001 Previously labeled; Skipping.PB02480-001 Previously labeled; Skipping.
# PB02481-001 Previously labeled; Skipping.PB02482-001 Previously labeled; Skipping.PB02483-001 Previously labeled; Skipping.PB02484-001 Previously labeled; Skipping.
# PB02485-001 Previously labeled; Skipping.
# PB02486-001 Previously labeled; Skipping.
# PB02487-001 Previously labeled; Skipping.
#
#
# PB02488-002 Previously labeled; Skipping.
#
#
#
#
#
# PB02489-001 Previously labeled; Skipping.
#
#
# PB02490-001 Previously labeled; Skipping.PB02491-001 Previously labeled; Skipping.PB02492-001 Previously labeled; Skipping.PB02493-001 Previously labeled; Skipping.PB02494-001 Previously labeled; Skipping.
#
# PB02495-001 Previously labeled; Skipping.
#
# PB02496-001 Previously labeled; Skipping.
# PB02497-001 Previously labeled; Skipping.
# PB02498-001 Previously labeled; Skipping.
#
#
#
#
#
# PB02499-001 Previously labeled; Skipping.PB02500-001 Previously labeled; Skipping.
#
# PB02501-002 Previously labeled; Skipping.
# PB02502-001 Previously labeled; Skipping.
# PB02503-001 Previously labeled; Skipping.
#
#
# PB02504-001 Previously labeled; Skipping.
# PB02505-002 Previously labeled; Skipping.
#
#
#
# PB02506-001 Previously labeled; Skipping.
#
# PB02507-001 Previously labeled; Skipping.
# PB02508-001 Previously labeled; Skipping.PB02509-001 Previously labeled; Skipping.PB02510-001 Previously labeled; Skipping.PB02511-001 Previously labeled; Skipping.
# PB02512-001 Previously labeled; Skipping.PB02513-001 Previously labeled; Skipping.PB02514-001 Previously labeled; Skipping.PB02515-002 Previously labeled; Skipping.PB02516-001 Previously labeled; Skipping.PB02517-001 Previously labeled; Skipping.
# PB02518-001 Previously labeled; Skipping.PB02519-001 Previously labeled; Skipping.PB02520-001 Previously labeled; Skipping.
#
#
#
# PB02521-001 Previously labeled; Skipping.
#
# PB02522-002 Previously labeled; Skipping.PB02523-001 Previously labeled; Skipping.PB02524-001 Previously labeled; Skipping.
# PB02525-001 Previously labeled; Skipping.
# PB02526-001 Previously labeled; Skipping.PB02527-002 Previously labeled; Skipping.
# PB02529-001 Previously labeled; Skipping.PB02528-001 Previously labeled; Skipping.PB02531-002 Previously labeled; Skipping.PB02530-001 Previously labeled; Skipping.
#
# PB02533-001 Previously labeled; Skipping.PB02532-001 Previously labeled; Skipping.
# PB02534-001 Previously labeled; Skipping.PB02535-001 Previously labeled; Skipping.
#
# PB02536-001 Previously labeled; Skipping.PB02538-002 Previously labeled; Skipping.PB02537-001 Previously labeled; Skipping.
# PB02540-001 Previously labeled; Skipping.PB02541-001 Previously labeled; Skipping.
# PB02542-001 Previously labeled; Skipping.PB02543-001 Previously labeled; Skipping.PB02545-001 Previously labeled; Skipping.PB02544-001 Previously labeled; Skipping.PB02546-002 Previously labeled; Skipping.
# PB02547-001 Previously labeled; Skipping.
#
# PB02548-001 Previously labeled; Skipping.
#
#
# PB02550-001 Previously labeled; Skipping.
#
#
#
#
#
#
# PB02551-001 Previously labeled; Skipping.
#
# PB02552-001 Previously labeled; Skipping.PB02553-002 Previously labeled; Skipping.PB02554-002 Previously labeled; Skipping.PB02555-001 Previously labeled; Skipping.
# PB02556-002 Previously labeled; Skipping.
#
# PB02557-002 Previously labeled; Skipping.PB02558-001 Previously labeled; Skipping.
#
#
# PB02559-002 Previously labeled; Skipping.
#
# PB02560-002 Previously labeled; Skipping.
#
#
# PB02562-001 Previously labeled; Skipping.PB02561-001 Previously labeled; Skipping.
#
#
# PB02563-001 Previously labeled; Skipping.
# PB02564-001 Previously labeled; Skipping.
#
# PB02565-001 Previously labeled; Skipping.
#
#
# PB02566-001 Previously labeled; Skipping.
# PB02567-001 Previously labeled; Skipping.
#
#
#
#
# PB02568-001 Previously labeled; Skipping.PB02569-001 Previously labeled; Skipping.
# PB02570-002 Previously labeled; Skipping.PB02572-001 Previously labeled; Skipping.PB02571-001 Previously labeled; Skipping.PB02573-001 Previously labeled; Skipping.PB02575-001 Previously labeled; Skipping.PB02574-001 Previously labeled; Skipping.
# PB02576-001 Previously labeled; Skipping.PB02577-001 Previously labeled; Skipping.PB02578-001 Previously labeled; Skipping.PB02579-001 Previously labeled; Skipping.
# PB02581-001 Previously labeled; Skipping.
#
# PB02582-001 Previously labeled; Skipping.PB02583-001 Previously labeled; Skipping.
# PB02584-001 Previously labeled; Skipping.
#
# PB02585-001 Previously labeled; Skipping.
# PB02586-001 Previously labeled; Skipping.
# PB02587-001 Previously labeled; Skipping.PB02588-002 Previously labeled; Skipping.PB02589-001 Previously labeled; Skipping.
# PB02590-001 Previously labeled; Skipping.
# PB02591-001 Previously labeled; Skipping.PB02593-001 Previously labeled; Skipping.PB02592-002 Previously labeled; Skipping.
#
# PB03061-001 Previously labeled; Skipping.PB03062-002 Previously labeled; Skipping.
# PB03063-001 Previously labeled; Skipping.PB03064-002 Previously labeled; Skipping.PB03065-001 Previously labeled; Skipping.
# PB03066-002 Previously labeled; Skipping.PB03067-001 Previously labeled; Skipping.
# PB03068-002 Previously labeled; Skipping.PB03069-001 Previously labeled; Skipping.
# PB03070-001 Previously labeled; Skipping.PB03071-001 Previously labeled; Skipping.
# PB03073-001 Previously labeled; Skipping.PB03072-001 Previously labeled; Skipping.PB03074-001 Previously labeled; Skipping.PB03075-001 Previously labeled; Skipping.PB03076-001 Previously labeled; Skipping.
# PB03077-001 Previously labeled; Skipping.
#
#
#
#
#
#
# PB03078-001 Previously labeled; Skipping.
#
#
#
#
# PB03079-001 Previously labeled; Skipping.PB03080-001 Previously labeled; Skipping.PB03081-001 Previously labeled; Skipping.
#
# PB03082-001 Previously labeled; Skipping.
#
# PB03084-001 Previously labeled; Skipping.PB03083-001 Previously labeled; Skipping.
# PB03085-001 Previously labeled; Skipping.PB03086-001 Previously labeled; Skipping.
#
#
#
# PB03088-002 Previously labeled; Skipping.
# PB03089-001 Previously labeled; Skipping.
#
# PB03091-001 Previously labeled; Skipping.
# PB03090-001 Previously labeled; Skipping.
# PB03092-001 Previously labeled; Skipping.
#
#
#
# PB03093-001 Previously labeled; Skipping.
#
#
# PB03094-001 Previously labeled; Skipping.
# PB03095-001 Previously labeled; Skipping.
# PB03096-001 Previously labeled; Skipping.
#
#
#
#
# PB03097-001 Previously labeled; Skipping.
# PB03098-001 Previously labeled; Skipping.PB03100-001 Previously labeled; Skipping.PB03101-001 Previously labeled; Skipping.PB03102-001 Previously labeled; Skipping.PB03099-001 Previously labeled; Skipping.PB03103-001 Previously labeled; Skipping.PB03104-002 Previously labeled; Skipping.
# PB03105-001 Previously labeled; Skipping.PB03106-001 Previously labeled; Skipping.PB03107-001 Previously labeled; Skipping.PB03108-002 Previously labeled; Skipping.PB03109-001 Previously labeled; Skipping.
#
#
#
# PB03110-003 Previously labeled; Skipping.PB03890-001 Previously labeled; Skipping.PB03891-001 Previously labeled; Skipping.PB03892-001 Previously labeled; Skipping.
#
#
#
# PB03894-001 Previously labeled; Skipping.PB03893-001 Previously labeled; Skipping.PB03895-001 Previously labeled; Skipping.
# PB03896-001 Previously labeled; Skipping.PB03897-001 Previously labeled; Skipping.
# PB03898-001 Previously labeled; Skipping.PB03899-001 Previously labeled; Skipping.PB03900-001 Previously labeled; Skipping.
# PB03901-001 Previously labeled; Skipping.
#
# PB03902-001 Previously labeled; Skipping.PB03903-001 Previously labeled; Skipping.PB03904-001 Previously labeled; Skipping.
# PB03905-002 Previously labeled; Skipping.PB03906-002 Previously labeled; Skipping.PB03907-001 Previously labeled; Skipping.PB03908-002 Previously labeled; Skipping.
# PB03909-001 Previously labeled; Skipping.
# PB03911-001 Previously labeled; Skipping.
# PB03913-001 Previously labeled; Skipping.PB03912-002 Previously labeled; Skipping.PB03914-001 Previously labeled; Skipping.PB03916-001 Previously labeled; Skipping.
# PB03915-001 Previously labeled; Skipping.PB03917-001 Previously labeled; Skipping.
# PB03918-001 Previously labeled; Skipping.
#
#
#
#
#
#
# PB03919-001 Previously labeled; Skipping.
#
#
#
# PB03921-001 Previously labeled; Skipping.PB03920-001 Previously labeled; Skipping.PB03922-001 Previously labeled; Skipping.PB03923-001 Previously labeled; Skipping.
#
#
#
# PB03924-002 Previously labeled; Skipping.PB03925-001 Previously labeled; Skipping.PB03926-001 Previously labeled; Skipping.PB03927-001 Previously labeled; Skipping.
#
#
#
# PB03928-001 Previously labeled; Skipping.

# %% [markdown]
# ## Assemble results
#
# For each model, we'll assemble the results as a .csv file that we can utilize later for subclustering and analysis of major cell classes.

# %%
models = list(model_paths.keys())

# %%
out_files = []
for model in models:
    model_path = 'output/{m}'.format(m = model)
    model_path_files = os.listdir(model_path)
    model_files = []
    for model_path_file in model_path_files:
        if 'labels' in model_path_file:
            model_files.append(model_path_file)
    
    model_list = []
    for model_file in model_files:
        df = pd.read_csv('output/{m}/{f}'.format(m = model, f = model_file))
        model_list.append(df)
    model_df = pd.concat(model_list)

    out_csv = 'output/diha_celltypist_{c}_{s}_{m}_{d}.csv'.format(
        c = cohort, s = subject_sex, m = model, d = date.today())
    out_files.append(out_csv)
    
    model_df.to_csv(out_csv)

    out_parquet = 'output/diha_celltypist_{c}_{s}_{m}_{d}.parquet'.format(
        c = cohort, s = subject_sex, m = model, d = date.today())
    out_files.append(out_parquet)
    
    model_df.to_parquet(out_parquet)

# %% [markdown]
# ## Upload assembled data to HISE
#
# Finally, we'll use `hisepy.upload.upload_files()` to send a copy of our output to HISE to use for downstream analysis steps.

# %%
study_space_uuid = 'de025812-5e73-4b3c-9c3b-6d0eac412f2a'
title = 'DIHA PBMC CellTypist {c} {s} {d}'.format(
    c = cohort, s = subject_sex, d = date.today())

# %%
search_id = element_id()
search_id

# %%
in_files = list(model_uuids.values()) + [sample_meta_file_uuid] + meta_data['file.id'].to_list()

# %%
in_files[0:10]
# Out:
# ['54d9399c-3bfd-4619-a32d-8c7f3c0911f6',
#  'e2898db9-e121-4263-b0c6-a19eadd4217a',
#  'd18fe8b3-b8e7-4b25-9966-0c05a1ba9d7a',
#  'd82c5c42-ae5f-4e67-956e-cd3b7bf88105',
#  'fec489f9-9a74-4635-aa91-d2bf09d1faec',
#  '7c0c7979-eebd-4aba-b5b2-6e76b4643623',
#  '40efd03a-cb2f-4677-af42-a056cbfe5a17',
#  '68fbcd34-1d63-461d-8195-df5b8dc61b31',
#  'ea8d98e9-e99e-4dc6-9e78-9866e0deac68',
#  '1faf2b5f-66e4-4787-8a8b-487621fc4c08']

# %%
out_files
# Out:
# ['output/diha_celltypist_labels_AIFI_L1_2024-03-12.csv',
#  'output/diha_celltypist_labels_AIFI_L1_2024-03-12.parquet',
#  'output/diha_celltypist_labels_AIFI_L2_2024-03-12.csv',
#  'output/diha_celltypist_labels_AIFI_L2_2024-03-12.parquet',
#  'output/diha_celltypist_labels_AIFI_L3_2024-03-12.csv',
#  'output/diha_celltypist_labels_AIFI_L3_2024-03-12.parquet']

# %%
hisepy.upload.upload_files(
    files = out_files,
    study_space_id = study_space_uuid,
    title = title,
    input_file_ids = in_files,
    destination = search_id
)
# Out:
# output/diha_celltypist_labels_AIFI_L1_2024-03-12.csv
# output/diha_celltypist_labels_AIFI_L1_2024-03-12.parquet
# output/diha_celltypist_labels_AIFI_L2_2024-03-12.csv
# output/diha_celltypist_labels_AIFI_L2_2024-03-12.parquet
# output/diha_celltypist_labels_AIFI_L3_2024-03-12.csv
# output/diha_celltypist_labels_AIFI_L3_2024-03-12.parquet
# Cannot determine the current notebook.
# 1) /home/jupyter/IH-A-Aging-Analysis-Notebooks/scrna-seq_analysis/02-reference_labeling/02-Python_label_predictions_celltypist.ipynb
# 2) /home/jupyter/IH-A-Aging-Analysis-Notebooks/scrna-seq_analysis/01-sample_selection/01-Python_retrieve_cmv_bmi.ipynb
# 3) /home/jupyter/IH-A-Aging-Analysis-Notebooks/scrna-seq_analysis/02-reference_labeling/03-Python_Doublet_detection.ipynb
# Please select (1-3)
#  1
# you are trying to upload file_ids... ['output/diha_celltypist_labels_AIFI_L1_2024-03-12.csv', 'output/diha_celltypist_labels_AIFI_L1_2024-03-12.parquet', 'output/diha_celltypist_labels_AIFI_L2_2024-03-12.csv', 'output/diha_celltypist_labels_AIFI_L2_2024-03-12.parquet', 'output/diha_celltypist_labels_AIFI_L3_2024-03-12.csv', 'output/diha_celltypist_labels_AIFI_L3_2024-03-12.parquet']. Do you truly want to proceed?
# (y/n) y
# {'trace_id': '8e47813b-7756-4a77-b304-3e4f32e13b5a',
#  'files': ['output/diha_celltypist_labels_AIFI_L1_2024-03-12.csv',
#   'output/diha_celltypist_labels_AIFI_L1_2024-03-12.parquet',
#   'output/diha_celltypist_labels_AIFI_L2_2024-03-12.csv',
#   'output/diha_celltypist_labels_AIFI_L2_2024-03-12.parquet',
#   'output/diha_celltypist_labels_AIFI_L3_2024-03-12.csv',
#   'output/diha_celltypist_labels_AIFI_L3_2024-03-12.parquet']}

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.10.3
# celltypist          1.6.2
# h5py                3.10.0
# hisepy              0.3.0
# numpy               1.24.0
# pandas              2.1.4
# scanpy              1.9.6
# scipy               1.11.4
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.0.1
# anyio                       NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# beatrix_jupyterlab          NA
# brotli                      NA
# cachetools                  5.3.1
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# cloudpickle                 2.2.1
# colorama                    0.4.6
# comm                        0.1.4
# cryptography                41.0.7
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# db_dtypes                   1.1.1
# debugpy                     1.8.0
# decorator                   5.1.1
# defusedxml                  0.7.1
# deprecated                  1.2.14
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fqdn                        NA
# google                      NA
# greenlet                    2.0.2
# grpc                        1.58.0
# grpc_status                 NA
# idna                        3.6
# igraph                      0.10.8
# importlib_metadata          NA
# ipykernel                   6.28.0
# ipython_genutils            0.2.0
# ipywidgets                  8.1.1
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.2
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.20.0
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.1
# jupyterlab_server           2.25.2
# jwt                         2.8.0
# kiwisolver                  1.4.5
# leidenalg                   0.10.1
# llvmlite                    0.41.0
# lz4                         4.3.2
# markupsafe                  2.1.3
# matplotlib                  3.8.0
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# mpmath                      1.3.0
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.58.0
# opentelemetry               NA
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                4.1.0
# plotly                      5.18.0
# prettytable                 3.9.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# proto                       NA
# psutil                      NA
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pyarrow                     13.0.0
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pynvml                      NA
# pyparsing                   3.1.1
# pyreadr                     0.5.0
# pythonjsonlogger            NA
# pytz                        2023.3.post1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# send2trash                  NA
# shapely                     1.8.5.post1
# six                         1.16.0
# sklearn                     1.3.2
# sniffio                     1.3.0
# socks                       1.7.1
# sql                         NA
# sqlalchemy                  2.0.21
# sqlparse                    0.4.4
# stack_data                  0.6.2
# sympy                       1.12
# termcolor                   NA
# texttable                   1.7.0
# threadpoolctl               3.2.0
# torch                       2.1.2+cu121
# torchgen                    NA
# tornado                     6.3.3
# tqdm                        4.66.1
# traitlets                   5.9.0
# typing_extensions           NA
# uri_template                NA
# urllib3                     1.26.18
# wcwidth                     0.2.12
# webcolors                   1.13
# websocket                   1.7.0
# wrapt                       1.15.0
# xarray                      2023.12.0
# yaml                        6.0.1
# zipp                        NA
# zmq                         25.1.2
# zoneinfo                    NA
# zstandard                   0.22.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.19.0
# jupyter_client      8.6.0
# jupyter_core        5.6.1
# jupyterlab          4.1.2
# notebook            6.5.4
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-5.15.0-1042-gcp-x86_64-with-glibc2.31
# -----
# Session information updated at 2024-03-12 06:17
# </pre>
# </details>

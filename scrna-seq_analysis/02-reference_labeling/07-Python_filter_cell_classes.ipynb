# %% [markdown]
# # Filter cell classes for doublets and low gene abundance
#
# In this notebook, we'll read the AIFI_L2 cell class partition subsets and filter Leiden clusters based on expression of marker genes from off-target cell types - these look like doublets that are missed by scrublet - as well as clusters with abnormally low average gene detection.
#
# We'll also generate plots of these results to help us manually review our filtering to double-check removed cells.

# %% [markdown]
# ## Load Packages

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=RuntimeWarning)

from datetime import date
import h5py
import hisepy
import os
import pandas as pd
import re
import scanpy as sc
import tarfile

# %%
out_dir = 'output'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
review_dir = 'output/review'
if not os.path.isdir(review_dir):
    os.makedirs(review_dir)

# %% [markdown]
# ## Helper functions

# %% [markdown]
# These functions make it easy to read our files from UUID in HISE

# %%
def cache_uuid_path(uuid):
    cache_path = '/home/jupyter/cache/{u}'.format(u = uuid)
    if not os.path.isdir(cache_path):
        hise_res = hisepy.reader.cache_files([uuid])
    filename = os.listdir(cache_path)[0]
    cache_file = '{p}/{f}'.format(p = cache_path, f = filename)
    return cache_file

# %%
def read_adata_uuid(uuid):
    cache_file = cache_uuid_path(uuid)
    res = sc.read_h5ad(cache_file)
    return res

# %% [markdown]
# These functions utilize scanpy's dotplot function to identify clusters to filter.
#
# The dotplot function needs to assemble the fraction of cells expressing a set of genes (or features), as well as the average per cluster, which is useful for applying threshholds to filter.

# %%
def marker_frac_df(adata, markers, clusters = 'leiden_2'):
    gene_cl_frac = sc.pl.dotplot(
        adata, 
        groupby = clusters,
        var_names = markers,
        return_fig = True
    ).dot_size_df
    return gene_cl_frac

def marker_mean_df(adata, markers, log = False, clusters = 'leiden_2'):
    gene_cl_mean = sc.pl.dotplot(
        adata, 
        groupby = clusters,
        var_names = markers,
        return_fig = True,
        log = log
    ).dot_color_df
    
    return gene_cl_mean

# %%
def select_clusters_above_gene_frac(adata, gene, cutoff, clusters = 'leiden_2'):
    gene_cl_frac = marker_frac_df(adata, gene, clusters)
    select_cl = gene_cl_frac.index[gene_cl_frac[gene] > cutoff].tolist()

    return select_cl

def select_clusters_above_gene_mean(adata, gene, cutoff, clusters = 'leiden_2'):
    gene_cl_mean = marker_mean_df(adata, gene, log = True, clusters = clusters)
    select_cl = gene_cl_mean.index[gene_cl_mean[gene] > cutoff].tolist()

    return select_cl

def select_clusters_by_low_gene_frac(adata, n_cutoff, frac_cutoff, clusters = 'leiden_2'):

    obs = adata.obs
    n_cells = obs.groupby(clusters)['barcodes'].count()

    low_obs = obs['n_genes'] < n_cutoff
    n_low = obs[low_obs].groupby(clusters)['barcodes'].count()

    frac_low = n_low / n_cells
    low_cl = frac_low[frac_low > frac_cutoff]
    low_cl = low_cl.index.tolist()

    return low_cl

# %%
def tidy_marker_df(adata, markers, clusters = 'leiden_2'):
    gene_cl_frac = marker_frac_df(adata, markers, clusters)
    gene_cl_frac = gene_cl_frac.reset_index(drop = False)
    gene_cl_frac = pd.melt(gene_cl_frac, id_vars = clusters, var_name = 'gene', value_name = 'gene_frac')
    
    gene_cl_mean = marker_mean_df(adata, markers, clusters)
    gene_cl_mean = gene_cl_mean.reset_index(drop = False)
    gene_cl_mean = pd.melt(gene_cl_mean, id_vars = clusters, var_name = 'gene', value_name = 'gene_mean')

    marker_df = gene_cl_frac.merge(gene_cl_mean, on = [clusters, 'gene'], how = 'left')
    return marker_df

# %%
def element_id(n = 3):
    import periodictable
    from random import randrange
    rand_el = []
    for i in range(n):
        el = randrange(0,118)
        rand_el.append(periodictable.elements[el].name)
    rand_str = '-'.join(rand_el)
    return rand_str

# %% [markdown]
# ## Set expression cutoffs

# %% [markdown]
# After generating the AIFI_L2 partitioned data, we interactively examined the expression of cell class-specific marker genes to identify good frequency or mean expression cutoffs for gene expression and gene detection. Here, we'll encode these cutoffs in a dictionary so that we can apply them to our datasets

# %% [markdown]
# ### Fraction filters
#
# Most filters work well using the frequency of gene detection. The dictionary below defines these cutoffs for each cell type, with this nested structure:
# `dict[cell_type][reason][marker] = cutoff`
#
# Markers for which the fraction of cells in a cluster are greater than the specified cutoff are flagged with the Reason for removal of the cluster.

# %%
frac_filter_dict = {
    'ASDC' : {
        'T cell doublet':      {'CD3E': 0.4}
    },
    'CD14 monocyte': {
        'T cell doublet':      {'CD3E':  0.1},
        'T cell doublet':      {'IL7R':  0.2},
        'B cell doublet':      {'MS4A1': 0.2},
        'Platelet doublet':    {'PPBP':  0.4}
    },
    'CD16 monocyte': {
        'T cell doublet':      {'CD3E':  0.2},
        'Erythrocyte doublet': {'HBB':   0.2},
        'B cell doublet':      {'MS4A1': 0.4},
        'Platelet doublet':    {'PPBP':  0.4}
    },
    'CD56bright NK cell': {
        'T cell doublet':      {'CD3D':  0.4},
        'Myeloid doublet':     {'FCN1':  0.4},
        'Erythrocyte doublet': {'HBB':   0.2},
        'B cell doublet':      {'MS4A1': 0.4},
        'Platelet doublet':    {'PPBP':  0.4}
    },
    'CD56dim NK cell': {
        'T cell doublet':      {'IL7R':  0.4},
        'Myeloid doublet':     {'FCN1':  0.4},
        'B cell doublet':      {'MS4A1': 0.4},
        'Platelet doublet':    {'PPBP':  0.4}
    },
    'CD8aa': {
        'Myeloid doublet':     {'FCN1':  0.2},
        'Platelet doublet':    {'PPBP':  0.4}
    },
    'cDC1': {
        'T cell doublet':      {'CD3D':  0.2},
        'Erythrocyte doublet': {'HBB':   0.4},
        'T cell doublet':      {'IL7R':  0.2},
        'B cell doublet':      {'MS4A1': 0.4},
        'Platelet doublet':    {'PPBP':  0.2}
    } ,
    'cDC2': {
        'T cell doublet':      {'CD3D':  0.2},
        'Erythrocyte doublet': {'HBB':   0.4},
        'Platelet doublet':    {'PPBP':  0.2}
    },
    'DN T cell': {
        'Myeloid doublet':     {'FCN1':  0.2},
        'Erythrocyte doublet': {'HBB':   0.4},
        'Platelet doublet':    {'PPBP':  0.4}
    },
    'Effector B cell': {
        'T cell doublet':      {'CD3D':  0.2},
        'Myeloid doublet':     {'FCN1':  0.2},
        'Erythrocyte doublet': {'HBB':   0.4},
        'T cell doublet':      {'IL7R':  0.2},
        'Platelet doublet':    {'PPBP':  0.4}
    },
    'Erythrocyte': {
        'Myeloid doublet':     {'FCN1':  0.2},
        'B cell doublet':      {'MS4A1': 0.4},
        'Platelet doublet':    {'PPBP':  0.4}
    },
    'gdT': {
        'Myeloid doublet':     {'FCN1':  0.2},
        'Erythrocyte doublet': {'HBB':   0.2},
        'B cell doublet':      {'MS4A1': 0.4},
        'Platelet doublet':    {'PPBP':  0.4}
    },
    'ILC': {
        'T cell doublet':      {'CD3D':  0.4},
        'Erythrocyte doublet': {'HBB':   0.4},
        'Platelet doublet':    {'PPBP':  0.2},
        'Myeloid doublet':     {'FCN1':  0.2}
    },
    'Intermediate monocyte': {
        'T cell doublet':      {'CD3D':  0.4},
        'Erythrocyte doublet': {'HBB':   0.4},
        'B cell doublet':      {'MS4A1': 0.4},
        'Platelet doublet':    {'PPBP':  0.2}
    },
    'MAIT': {
        'Myeloid doublet':     {'FCN1':  0.2},
        'Erythrocyte doublet': {'HBB':   0.4},
        'B cell doublet':      {'MS4A1': 0.4},
        'Platelet doublet':    {'PPBP':  0.2}
    },
    'Memory B cell': {
        'T cell doublet':      {'CD3D':  0.4},
        'Myeloid doublet':     {'FCN1':  0.2},
        'Erythrocyte doublet': {'HBB':   0.4},
        'Platelet doublet':    {'PPBP':  0.2}
    },
    'Memory CD4 T cell': {
        'Myeloid doublet':     {'FCN1':  0.2},
        'Erythrocyte doublet': {'HBB':   0.4},
        'B cell doublet':      {'MS4A1': 0.2}
    },
    'Memory CD8 T cell': {
        'Myeloid doublet':     {'FCN1':  0.2},
        'B cell doublet':      {'MS4A1': 0.4},
        'Platelet doublet':    {'PPBP':  0.2}
    },
    'Naive B cell': {
        'T cell doublet':      {'CD3D':  0.4},
        'Erythrocyte doublet': {'HBB':   0.4},
        'Platelet doublet':    {'PPBP':  0.2}        
    },
    'Naive CD4 T cell': {
        'Myeloid doublet':     {'FCN1':  0.2},
        'Erythrocyte doublet': {'HBB':   0.4},
        'Platelet doublet':    {'PPBP':  0.2},
        'B cell doublet':      {'MS4A1': 0.2},
    },
    'Naive CD8 T cell': {
        'Myeloid doublet':     {'FCN1':  0.2},
        'Erythrocyte doublet': {'HBB':   0.4},
        'B cell doublet':      {'MS4A1': 0.2},
        'Platelet doublet':    {'PPBP':  0.2}
    },
    'pDC' : {
        'T cell doublet':      {'CD3D':  0.4},
        'Myeloid doublet':     {'FCN1':  0.2},
        'Erythrocyte doublet': {'HBB':   0.4},
        'B cell doublet':      {'MS4A1': 0.2},
        'Platelet doublet':    {'PPBP':  0.2}
    },
    'Plasma cell': {
        'T cell doublet':      {'CD3D':  0.4},
        'Myeloid doublet':     {'FCN1':  0.2},
        'Erythrocyte doublet': {'HBB':   0.4},
        'B cell doublet':      {'MS4A1': 0.4},
        'Platelet doublet':    {'PPBP':  0.4}     
    },
    'Platelet' : {
        'T cell doublet':      {'CD3D':  0.4},
        'Myeloid doublet':     {'FCN1':  0.2},
        'Erythrocyte doublet': {'HBB':   0.4},
        'B cell doublet':      {'MS4A1': 0.4}        
    },
    'Progenitor cell': {
        'T cell doublet':      {'CD3E':  0.2},
        'Myeloid doublet':     {'FCN1':  0.2},
        'Erythrocyte doublet': {'HBB':   0.2},
        'Platelet doublet':    {'PPBP':  0.2}       
    },
    'Proliferating NK cell': {
        'T cell doublet':      {'CD3D':  0.4},
        'Myeloid doublet':     {'FCN1':  0.2},
        'Erythrocyte doublet': {'HBB':   0.4},
        'Platelet doublet':    {'PPBP':  0.2}       
    },
    'Proliferating T cell': {
        'Myeloid doublet':     {'FCN1':  0.2},
        'B cell doublet':      {'MS4A1': 0.4},
        'Platelet doublet':    {'PPBP':  0.2}       
    },
    'Transitional B cell': {
        'T cell doublet':      {'CD3D':  0.4},
        'Myeloid doublet':     {'FCN1':  0.2},
        'Erythrocyte doublet': {'HBB':   0.4},
        'Platelet doublet':    {'PPBP':  0.2}               
    },
    'Treg': {
        'Myeloid doublet':     {'FCN1':  0.2},
        'Erythrocyte doublet': {'HBB':   0.4},
        'B cell doublet':      {'MS4A1': 0.4}
    }
}

# %% [markdown]
# ### Mean cutoffs
#
# In some cases, the mean of gene expression rather than the fraction of cells works as a better cutoff for cleanup. We'll specify these cutoffs here in normalized, log-transformed units:

# %%
mean_filter_dict = {
    'CD14 monocyte': {
        'Erythrocyte doublet':    {'HBB':  1}
    },
    'CD56dim NK cell': {
        'Erythrocyte doublet':    {'HBB':  0.7}
    },
    'Memory CD8 T cell': {
        'Erythrocyte doublet':    {'HBB':  0.7}
    },
    'Proliferating T cell': {
        'Erythrocyte doublet':    {'HBB':  0.7}
    }
}

# %% [markdown]
# ## Assemble markers for review plots

# %%
all_filter_markers = []
for cell_type, filters in frac_filter_dict.items():
    for reason, filter in filters.items():
        for gene in filter.keys():
            if not gene in all_filter_markers:
                all_filter_markers.append(gene)
                
for cell_type, filters in mean_filter_dict.items():
    for reason, filter in filters.items():
        for gene in filter.keys():
            if not gene in all_filter_markers:
                all_filter_markers.append(gene)

# %%
all_filter_markers.sort()
all_filter_markers
# Out:
# ['CD3D', 'CD3E', 'FCN1', 'HBB', 'IL7R', 'MS4A1', 'PPBP']

# %% [markdown]
# Additional markers for review

# %%
additional_markers = ['NCAM1','ISG15', 'MKI67','CD4','CD8A']
all_filter_markers = all_filter_markers + additional_markers

# %% [markdown]
# ## Set Gene Detection cutoffs
#
# We'll use these cutoffs to filter clusters with low gene expression. If more than the `min_gene_frac` proportion of cells in a cluster have expression below `min_n_genes`, we'll flag that cluster for removal.
#
# Because Erythrocytes and Platelets normally have low gene detection, we'll add exceptions for these two classes for this filter.

# %%
min_n_genes = 750
min_gene_frac = 0.3
min_gene_exceptions = ['Erythrocyte', 'Platelet']

# %% [markdown]
# ## Identify files for use in HISE

# %%
search_ids = [
    'arsenic-iodine-polonium',
    'fermium-oxygen-cadmium',
    'iodine-titanium-livermorium',
    'mercury-protactinium-lead',
    'uranium-sodium-cesium'
]
search_id = '|'.join(search_ids)

# %% [markdown]
# Retrieve files stored in our HISE project store

# %%
ps_df = hisepy.list_files_in_project_store('cohorts')
ps_df = ps_df[['id', 'name']]

# %% [markdown]
# Filter for files from the previous notebook using our search_id

# %%
search_df = ps_df[ps_df['name'].str.contains(search_id)]
search_df = search_df.sort_values('name')

# %%
search_df.shape
# Out:
# (64, 2)

# %%
h5ad_uuids = {}
for i in range(search_df.shape[0]):
    group_name = re.sub('.+qc_','',search_df['name'].tolist()[i])
    group_name = re.sub('_20.+','',group_name)
    h5ad_uuids[group_name] = search_df['id'].tolist()[i]

# %%
h5ad_uuids
# Out:
# {'BR1_Female_Negative_CD14_monocyte': '9e0af64b-2173-4327-bee3-11944487d350',
#  'BR1_Female_Negative_CD56dim_NK_cell': '64b85675-4329-41a7-901d-9b738939f9e5',
#  'BR1_Female_Negative_Memory_CD4_T_cell': '84869ac0-5a4d-4377-9f0b-c81f90bca9b5',
#  'BR1_Female_Negative_Memory_CD8_T_cell': '4261fa08-3169-48a9-b2c4-a7cc767a1d0f',
#  'BR1_Female_Negative_Naive_CD4_T_cell': '710513ff-75c0-4ea0-bb50-2ab192a5a0c7',
#  'BR1_Female_Positive_CD14_monocyte': 'b458f394-8d94-40f7-a4fa-3aebbfd8f31b',
#  'BR1_Female_Positive_CD56dim_NK_cell': '6f0a57e9-f0ce-425d-a1d7-aad26e4147af',
#  'BR1_Female_Positive_Memory_CD4_T_cell': '5a9e0cd4-feb1-4e4e-84ca-4b16afb2f8d3',
#  'BR1_Female_Positive_Memory_CD8_T_cell': 'b3096a16-ff88-42d8-abf4-5f6e9a8367eb',
#  'BR1_Female_Positive_Naive_CD4_T_cell': '1c80095a-4184-4975-9875-963b3d2e5e30',
#  'BR1_Male_Negative_CD14_monocyte': '9e7dfd0b-608d-45de-b0d7-93a1c58ab030',
#  'BR1_Male_Negative_CD56dim_NK_cell': 'c1e99a0f-deb6-46b1-9a3b-5163f8a12e0d',
#  'BR1_Male_Negative_Memory_CD4_T_cell': '0318482c-b61c-437d-8f48-efa7b9a8ab18',
#  'BR1_Male_Negative_Memory_CD8_T_cell': '9aa54376-330c-4729-8b48-0ea5f5eca5fd',
#  'BR1_Male_Negative_Naive_CD4_T_cell': 'cf42563f-d819-492c-bb95-beff17ac4383',
#  'BR1_Male_Positive_CD14_monocyte': 'f34e55f1-5ddc-4373-830d-35f29b99d98d',
#  'BR1_Male_Positive_CD56dim_NK_cell': '61b54268-c6ed-4256-9b71-cfbef7c03851',
#  'BR1_Male_Positive_Memory_CD4_T_cell': '55cc7b51-d85c-4036-9c72-9f0d0fe7923b',
#  'BR1_Male_Positive_Memory_CD8_T_cell': '23178cdc-f7e9-4e31-b4f2-0f3d54a277e0',
#  'BR1_Male_Positive_Naive_CD4_T_cell': 'f2229916-c643-445b-ba98-f7362ac5650f',
#  'BR2_Female_Negative_CD14_monocyte': '3a93abec-a596-436b-a23e-057e60145997',
#  'BR2_Female_Negative_CD56dim_NK_cell': 'f7b5bd47-1bb5-4879-9972-a1d999e0a49a',
#  'BR2_Female_Negative_Memory_CD4_T_cell': 'a801a680-1213-4fed-aebe-0cd284b9a018',
#  'BR2_Female_Negative_Memory_CD8_T_cell': 'bf9dcb65-06b2-4b19-ad64-0a9b5f8acab6',
#  'BR2_Female_Negative_Naive_CD4_T_cell': 'deca727f-4a5e-4667-9302-3780e02bc66a',
#  'BR2_Female_Positive_CD14_monocyte': 'f9dd5a0f-9407-45d1-9692-0f5ba18f5eba',
#  'BR2_Female_Positive_CD56dim_NK_cell': '9ddd0164-4677-4f62-90f3-dabc195e06bc',
#  'BR2_Female_Positive_Memory_CD4_T_cell': 'c948ec3f-ef89-48fe-b1ac-c97bc4322060',
#  'BR2_Female_Positive_Memory_CD8_T_cell': 'a20e7c55-ae4e-4851-a36a-48b2e48dc82f',
#  'BR2_Female_Positive_Naive_CD4_T_cell': 'dbc98b58-3d99-4e50-a790-d242456b5047',
#  'BR2_Male_Negative_CD14_monocyte': '9dfdba3d-069b-409f-8f6f-28726800764b',
#  'BR2_Male_Negative_CD56dim_NK_cell': '86d24e7a-ca28-4b6a-979b-ab9519ad32cc',
#  'BR2_Male_Negative_Memory_CD4_T_cell': 'c4e26143-3e93-400f-9609-600707756e96',
#  'BR2_Male_Negative_Memory_CD8_T_cell': '25d4d213-b18b-4d2d-a40d-582c3f469dae',
#  'BR2_Male_Negative_Naive_CD4_T_cell': '33ba88cf-4857-4fb4-89a2-117a107da155',
#  'BR2_Male_Positive_CD14_monocyte': 'b768b683-249b-4ed9-b5ea-79efc19ef975',
#  'BR2_Male_Positive_CD56dim_NK_cell': 'e820fc38-6d65-4d1f-80a4-6d0234ee4f6e',
#  'BR2_Male_Positive_Memory_CD4_T_cell': 'eed33093-877f-4205-82b6-382535c0c5e7',
#  'BR2_Male_Positive_Memory_CD8_T_cell': '4fb9550f-236c-477b-8a40-acc75933b6cd',
#  'BR2_Male_Positive_Naive_CD4_T_cell': 'a5d6130e-8395-4be7-9a2f-07dd00aa0666',
#  'ASDC': '02112a03-447b-4a3d-ba4f-0e4e4cc91f0c',
#  'CD16_monocyte': 'a505a5d8-e884-48f0-a52a-24b2d92a23a0',
#  'CD56bright_NK_cell': '92c4bdd5-a246-4d54-ae11-9c28227097d6',
#  'CD8aa': '5e1d5882-e107-4e02-974a-b07a12e57cb0',
#  'DN_T_cell': '4e17b3db-a975-47cf-bee9-ee271959dd2e',
#  'Effector_B_cell': '0cfd114f-ded0-4bd0-9df6-72467a843fa3',
#  'Erythrocyte': 'c2ea513b-0f82-4de9-adb3-1b78dcc1e3ee',
#  'ILC': 'b5ab1cd6-838d-4a5d-9b25-cc2a7f75e191',
#  'Intermediate_monocyte': '7b5cc0da-5805-440e-a721-a6d248bdab3f',
#  'MAIT': '598aebc6-d838-4bb9-b3cd-40b0a777faab',
#  'Memory_B_cell': '404ecb42-c39d-413f-bcae-e5c7f311972a',
#  'Naive_B_cell': '8357ef26-c4a1-4ed0-b864-ec4cdec1669b',
#  'Naive_CD8_T_cell': '0d9f774f-6182-46d0-a932-b8c502a16aab',
#  'Plasma_cell': 'e1620390-6e37-44db-aa0d-ffd74a188d74',
#  'Platelet': '8583276f-f584-42b6-bbf2-cc0b483cb653',
#  'Progenitor_cell': 'a9e29502-e8b3-4093-a81c-0875f3e130c3',
#  'Proliferating_NK_cell': '648c8c8e-b349-4913-bf90-1943df16fc14',
#  'Proliferating_T_cell': '39d6f945-b0f4-4420-8411-6ab754aa4c80',
#  'Transitional_B_cell': 'd0a793ca-2f14-4640-b57c-3ab88ec69020',
#  'Treg': 'd195dbf6-1af8-414a-8436-4c842e1c18de',
#  'cDC1': '34da77a8-2090-4abc-96e7-704613c001c2',
#  'cDC2': 'dd69f5a4-40f4-4976-9f62-fa3dcfff9b48',
#  'gdT': 'c2a86cbe-7216-4dd5-9d7d-b2f32758c669',
#  'pDC': '80ed7b3f-ebc3-4802-bbe6-fd0596486650'}

# %% [markdown]
# ## Apply filters to datasets

# %%
out_files = []
for group_name, uuid in h5ad_uuids.items():
    print(group_name)
    out_file = 'output/diha_{g}_filtered_{d}.h5ad'.format(g = group_name, d = date.today())
    if os.path.isfile(out_file):
        print('Previously filtered {g}; Skipping.'.format(g = group_name))
        out_files.append(out_file)
    else:        
        adata = read_adata_uuid(uuid)
    
        cell_type = adata.obs['AIFI_L2'].iloc[0]

        # Track filter results
        filter_list = []
        filter_cl_list = []
        
        # Filter for low gene detection
        if not cell_type in min_gene_exceptions:
            filter_cl = select_clusters_by_low_gene_frac(
                adata,
                n_cutoff = min_n_genes, 
                frac_cutoff = min_gene_frac, 
                clusters = 'leiden_2'
            )
            reason = 'Low gene detection'
            check_cl = []
            for cl in filter_cl:
                if not cl in filter_cl_list:
                    check_cl.append(cl)
                    filter_cl_list.append(cl)
            
            filter_df = pd.DataFrame({'leiden_2': check_cl, 'remove_reason': [reason]*len(check_cl)})
            filter_list.append(filter_df)
        
        # Filter by Fractional gene expression
        marker_filters = frac_filter_dict[cell_type]
    
        for reason, filter in marker_filters.items():
            for marker, cutoff in filter.items():
                filter_cl = select_clusters_above_gene_frac(
                    adata,
                    gene = marker,
                    cutoff = cutoff,
                    clusters = 'leiden_2'
                )

                check_cl = []
                for cl in filter_cl:
                    if not cl in filter_cl_list:
                        check_cl.append(cl)
                        filter_cl_list.append(cl)
                
                filter_df = pd.DataFrame({'leiden_2': check_cl, 'remove_reason': [reason]*len(check_cl)})
                filter_list.append(filter_df)
    
        # Filter by Mean gene expression
        if cell_type in mean_filter_dict.keys():
            marker_filters = mean_filter_dict[cell_type]
        
            for reason, filter in marker_filters.items():
                for marker, cutoff in filter.items():
                    filter_cl = select_clusters_above_gene_mean(
                        adata,
                        gene = marker,
                        cutoff = cutoff,
                        clusters = 'leiden_2'
                    )
    
                    check_cl = []
                    for cl in filter_cl:
                        if not cl in filter_cl_list:
                            check_cl.append(cl)
                            filter_cl_list.append(cl)
                    
                    filter_df = pd.DataFrame({'leiden_2': check_cl, 'remove_reason': [reason]*len(check_cl)})
                    filter_list.append(filter_df)

        # Assemble all filtering results
        filter_df = pd.concat(filter_list)

        # Save filtered clusters for review
        rev_file = '{r}/diha_qc_{g}_filter_df_{d}.csv'.format(
            r = review_dir,
            g = group_name,
            d = date.today()
        )
        filter_df.to_csv(rev_file)
    
        # Add filters to cells
        obs = adata.obs.copy()
        obs = obs.merge(filter_df, on = 'leiden_2', how = 'left')
        obs['remove_reason'] = obs['remove_reason'].fillna('Not removed')
        
        # Save observations and UMAP coordinates for review
        review_obs = obs
        umap_mat = adata.obsm['X_umap']
        umap_df = pd.DataFrame(umap_mat, columns = ['umap_1', 'umap_2'])
        review_obs['umap_1'] = umap_df['umap_1']
        review_obs['umap_2'] = umap_df['umap_2']
        
        rev_file = '{r}/diha_qc_{g}_obs_df_{d}.csv'.format(
            r = review_dir,
            g = group_name,
            d = date.today()
        )
        review_obs.to_csv(rev_file)
        
        # Save expression of marker features for review
        marker_df = tidy_marker_df(adata, all_filter_markers, clusters = 'leiden_2')

        rev_file = '{r}/diha_qc_{g}_marker_df_{d}.csv'.format(
            r = review_dir,
            g = group_name,
            d = date.today()
        )
        marker_df.to_csv(rev_file)
    
        # Apply filters to data
        print(adata.shape)
        keep_cells = obs['remove_reason'] == 'Not removed'
        adata = adata[keep_cells]
        print(adata.shape)
        
        # Save filtered data
        adata.write_h5ad(out_file)
    
        out_files.append(out_file)

        # Clean up cache so we don't run out of disk space
        h5ad_path = cache_uuid_path(uuid)
        os.remove(h5ad_path)
        cache_path = '/home/jupyter/cache/{u}'.format(u = uuid)
        os.rmdir(cache_path)
# Out:
# BR1_Female_Negative_CD14_monocyte
# (405610, 773)
# (369171, 773)
# BR1_Female_Negative_CD56dim_NK_cell
# downloading fileID: 64b85675-4329-41a7-901d-9b738939f9e5
# Files have been successfully downloaded!
# (199092, 913)
# (180974, 913)
# BR1_Female_Negative_Memory_CD4_T_cell
# downloading fileID: 84869ac0-5a4d-4377-9f0b-c81f90bca9b5
# Files have been successfully downloaded!
# (446761, 1175)
# (444161, 1175)
# BR1_Female_Negative_Memory_CD8_T_cell
# downloading fileID: 4261fa08-3169-48a9-b2c4-a7cc767a1d0f
# Files have been successfully downloaded!
# (163921, 997)
# (157251, 997)
# BR1_Female_Negative_Naive_CD4_T_cell
# downloading fileID: 710513ff-75c0-4ea0-bb50-2ab192a5a0c7
# Files have been successfully downloaded!
# (659739, 504)
# (628955, 504)
# BR1_Female_Positive_CD14_monocyte
# downloading fileID: b458f394-8d94-40f7-a4fa-3aebbfd8f31b
# Files have been successfully downloaded!
# (194032, 858)
# (178275, 858)
# BR1_Female_Positive_CD56dim_NK_cell
# downloading fileID: 6f0a57e9-f0ce-425d-a1d7-aad26e4147af
# Files have been successfully downloaded!
# (82797, 955)
# (76956, 955)
# BR1_Female_Positive_Memory_CD4_T_cell
# downloading fileID: 5a9e0cd4-feb1-4e4e-84ca-4b16afb2f8d3
# Files have been successfully downloaded!
# (242062, 1301)
# (239931, 1301)
# BR1_Female_Positive_Memory_CD8_T_cell
# downloading fileID: b3096a16-ff88-42d8-abf4-5f6e9a8367eb
# Files have been successfully downloaded!
# (165155, 1100)
# (160316, 1100)
# BR1_Female_Positive_Naive_CD4_T_cell
# downloading fileID: 1c80095a-4184-4975-9875-963b3d2e5e30
# Files have been successfully downloaded!
# (243419, 499)
# (236586, 499)
# BR1_Male_Negative_CD14_monocyte
# downloading fileID: 9e7dfd0b-608d-45de-b0d7-93a1c58ab030
# Files have been successfully downloaded!
# (305469, 789)
# (284342, 789)
# BR1_Male_Negative_CD56dim_NK_cell
# downloading fileID: c1e99a0f-deb6-46b1-9a3b-5163f8a12e0d
# Files have been successfully downloaded!
# (163041, 886)
# (153445, 886)
# BR1_Male_Negative_Memory_CD4_T_cell
# downloading fileID: 0318482c-b61c-437d-8f48-efa7b9a8ab18
# Files have been successfully downloaded!
# (335140, 1146)
# (331644, 1146)
# BR1_Male_Negative_Memory_CD8_T_cell
# downloading fileID: 9aa54376-330c-4729-8b48-0ea5f5eca5fd
# Files have been successfully downloaded!
# (136151, 1076)
# (132254, 1076)
# BR1_Male_Negative_Naive_CD4_T_cell
# downloading fileID: cf42563f-d819-492c-bb95-beff17ac4383
# Files have been successfully downloaded!
# (352098, 514)
# (336729, 514)
# BR1_Male_Positive_CD14_monocyte
# downloading fileID: f34e55f1-5ddc-4373-830d-35f29b99d98d
# Files have been successfully downloaded!
# (180779, 907)
# (162121, 907)
# BR1_Male_Positive_CD56dim_NK_cell
# downloading fileID: 61b54268-c6ed-4256-9b71-cfbef7c03851
# Files have been successfully downloaded!
# (132552, 1082)
# (123345, 1082)
# BR1_Male_Positive_Memory_CD4_T_cell
# downloading fileID: 55cc7b51-d85c-4036-9c72-9f0d0fe7923b
# Files have been successfully downloaded!
# (180788, 1112)
# (178653, 1112)
# BR1_Male_Positive_Memory_CD8_T_cell
# downloading fileID: 23178cdc-f7e9-4e31-b4f2-0f3d54a277e0
# Files have been successfully downloaded!
# (196295, 978)
# (188659, 978)
# BR1_Male_Positive_Naive_CD4_T_cell
# downloading fileID: f2229916-c643-445b-ba98-f7362ac5650f
# Files have been successfully downloaded!
# (228431, 510)
# (215071, 510)
# BR2_Female_Negative_CD14_monocyte
# downloading fileID: 3a93abec-a596-436b-a23e-057e60145997
# Files have been successfully downloaded!
# (219053, 869)
# (196521, 869)
# BR2_Female_Negative_CD56dim_NK_cell
# downloading fileID: f7b5bd47-1bb5-4879-9972-a1d999e0a49a
# Files have been successfully downloaded!
# (129551, 1000)
# (119629, 1000)
# BR2_Female_Negative_Memory_CD4_T_cell
# downloading fileID: a801a680-1213-4fed-aebe-0cd284b9a018
# Files have been successfully downloaded!
# (307239, 1241)
# (297846, 1241)
# BR2_Female_Negative_Memory_CD8_T_cell
# downloading fileID: bf9dcb65-06b2-4b19-ad64-0a9b5f8acab6
# Files have been successfully downloaded!
# (81669, 1259)
# (77937, 1259)
# BR2_Female_Negative_Naive_CD4_T_cell
# downloading fileID: deca727f-4a5e-4667-9302-3780e02bc66a
# Files have been successfully downloaded!
# (350194, 514)
# (327902, 514)
# BR2_Female_Positive_CD14_monocyte
# downloading fileID: f9dd5a0f-9407-45d1-9692-0f5ba18f5eba
# Files have been successfully downloaded!
# (399151, 812)
# (363982, 812)
# BR2_Female_Positive_CD56dim_NK_cell
# downloading fileID: 9ddd0164-4677-4f62-90f3-dabc195e06bc
# Files have been successfully downloaded!
# (163751, 965)
# (151114, 965)
# BR2_Female_Positive_Memory_CD4_T_cell
# downloading fileID: c948ec3f-ef89-48fe-b1ac-c97bc4322060
# Files have been successfully downloaded!
# (593363, 1324)
# (586582, 1324)
# BR2_Female_Positive_Memory_CD8_T_cell
# downloading fileID: a20e7c55-ae4e-4851-a36a-48b2e48dc82f
# Files have been successfully downloaded!
# (413233, 1049)
# (397918, 1049)
# BR2_Female_Positive_Naive_CD4_T_cell
# downloading fileID: dbc98b58-3d99-4e50-a790-d242456b5047
# Files have been successfully downloaded!
# (571529, 465)
# (543913, 465)
# BR2_Male_Negative_CD14_monocyte
# downloading fileID: 9dfdba3d-069b-409f-8f6f-28726800764b
# Files have been successfully downloaded!
# (349401, 850)
# (325882, 850)
# BR2_Male_Negative_CD56dim_NK_cell
# downloading fileID: 86d24e7a-ca28-4b6a-979b-ab9519ad32cc
# Files have been successfully downloaded!
# (178389, 1004)
# (169400, 1004)
# BR2_Male_Negative_Memory_CD4_T_cell
# downloading fileID: c4e26143-3e93-400f-9609-600707756e96
# Files have been successfully downloaded!
# (369512, 1347)
# (368194, 1347)
# BR2_Male_Negative_Memory_CD8_T_cell
# downloading fileID: 25d4d213-b18b-4d2d-a40d-582c3f469dae
# Files have been successfully downloaded!
# (178119, 1151)
# (173122, 1151)
# BR2_Male_Negative_Naive_CD4_T_cell
# downloading fileID: 33ba88cf-4857-4fb4-89a2-117a107da155
# Files have been successfully downloaded!
# (332088, 501)
# (319537, 501)
# BR2_Male_Positive_CD14_monocyte
# downloading fileID: b768b683-249b-4ed9-b5ea-79efc19ef975
# Files have been successfully downloaded!
# (214616, 951)
# (196598, 951)
# BR2_Male_Positive_CD56dim_NK_cell
# downloading fileID: e820fc38-6d65-4d1f-80a4-6d0234ee4f6e
# Files have been successfully downloaded!
# (74387, 1091)
# (66472, 1091)
# BR2_Male_Positive_Memory_CD4_T_cell
# downloading fileID: eed33093-877f-4205-82b6-382535c0c5e7
# Files have been successfully downloaded!
# (337338, 1355)
# (336040, 1355)
# BR2_Male_Positive_Memory_CD8_T_cell
# downloading fileID: 4fb9550f-236c-477b-8a40-acc75933b6cd
# Files have been successfully downloaded!
# (205075, 1189)
# (195974, 1189)
# BR2_Male_Positive_Naive_CD4_T_cell
# downloading fileID: a5d6130e-8395-4be7-9a2f-07dd00aa0666
# Files have been successfully downloaded!
# (248782, 568)
# (234226, 568)
# ASDC
# downloading fileID: 02112a03-447b-4a3d-ba4f-0e4e4cc91f0c
# Files have been successfully downloaded!
# (4008, 1920)
# (3705, 1920)
# CD16_monocyte
# downloading fileID: a505a5d8-e884-48f0-a52a-24b2d92a23a0
# Files have been successfully downloaded!
# (405852, 1177)
# (349628, 1177)
# CD56bright_NK_cell
# downloading fileID: 92c4bdd5-a246-4d54-ae11-9c28227097d6
# Files have been successfully downloaded!
# (96063, 1343)
# (87863, 1343)
# CD8aa
# downloading fileID: 5e1d5882-e107-4e02-974a-b07a12e57cb0
# Files have been successfully downloaded!
# (17893, 1522)
# (17666, 1522)
# DN_T_cell
# downloading fileID: 4e17b3db-a975-47cf-bee9-ee271959dd2e
# Files have been successfully downloaded!
# (17648, 1995)
# (16983, 1995)
# Effector_B_cell
# downloading fileID: 0cfd114f-ded0-4bd0-9df6-72467a843fa3
# Files have been successfully downloaded!
# (86541, 1354)
# (80816, 1354)
# Erythrocyte
# downloading fileID: c2ea513b-0f82-4de9-adb3-1b78dcc1e3ee
# Files have been successfully downloaded!
# (28362, 4311)
# (21170, 4311)
# ILC
# downloading fileID: b5ab1cd6-838d-4a5d-9b25-cc2a7f75e191
# Files have been successfully downloaded!
# (5734, 1856)
# (5354, 1856)
# Intermediate_monocyte
# downloading fileID: 7b5cc0da-5805-440e-a721-a6d248bdab3f
# Files have been successfully downloaded!
# (76160, 1005)
# (64451, 1005)
# MAIT
# downloading fileID: 598aebc6-d838-4bb9-b3cd-40b0a777faab
# Files have been successfully downloaded!
# (381960, 1011)
# (366351, 1011)
# Memory_B_cell
# downloading fileID: 404ecb42-c39d-413f-bcae-e5c7f311972a
# Files have been successfully downloaded!
# (389804, 730)
# (362977, 730)
# Naive_B_cell
# downloading fileID: 8357ef26-c4a1-4ed0-b864-ec4cdec1669b
# Files have been successfully downloaded!
# (725113, 775)
# (686241, 775)
# Naive_CD8_T_cell
# downloading fileID: 0d9f774f-6182-46d0-a932-b8c502a16aab
# Files have been successfully downloaded!
# (833785, 910)
# (776909, 910)
# Plasma_cell
# downloading fileID: e1620390-6e37-44db-aa0d-ffd74a188d74
# Files have been successfully downloaded!
# (16569, 2569)
# (13100, 2569)
# Platelet
# downloading fileID: 8583276f-f584-42b6-bbf2-cc0b483cb653
# Files have been successfully downloaded!
# (72385, 2737)
# (58922, 2737)
# Progenitor_cell
# downloading fileID: a9e29502-e8b3-4093-a81c-0875f3e130c3
# Files have been successfully downloaded!
# (12457, 2068)
# (10532, 2068)
# Proliferating_NK_cell
# downloading fileID: 648c8c8e-b349-4913-bf90-1943df16fc14
# Files have been successfully downloaded!
# (20542, 2241)
# (18668, 2241)
# Proliferating_T_cell
# downloading fileID: 39d6f945-b0f4-4420-8411-6ab754aa4c80
# Files have been successfully downloaded!
# (18632, 2234)
# (17360, 2234)
# Transitional_B_cell
# downloading fileID: d0a793ca-2f14-4640-b57c-3ab88ec69020
# Files have been successfully downloaded!
# (79851, 1199)
# (76285, 1199)
# Treg
# downloading fileID: d195dbf6-1af8-414a-8436-4c842e1c18de
# Files have been successfully downloaded!
# (308864, 1321)
# (295424, 1321)
# cDC1
# downloading fileID: 34da77a8-2090-4abc-96e7-704613c001c2
# Files have been successfully downloaded!
# (8142, 1780)
# (7163, 1780)
# cDC2
# downloading fileID: dd69f5a4-40f4-4976-9f62-fa3dcfff9b48
# Files have been successfully downloaded!
# (113465, 1348)
# (101559, 1348)
# gdT
# downloading fileID: c2a86cbe-7216-4dd5-9d7d-b2f32758c669
# Files have been successfully downloaded!
# (318356, 1171)
# (309786, 1171)
# pDC
# downloading fileID: 80ed7b3f-ebc3-4802-bbe6-fd0596486650
# Files have been successfully downloaded!
# (62064, 1286)
# (53876, 1286)

# %% [markdown]
# ## Bundle Review data
#
# We saved review data, including cell metadata and UMAP coordinates, filtered clusters, and marker gene expression, to enable us to assemble figures to double-check our filtering process.

# %% [markdown]
# To help with file transfer, we'll use `tarfile` to bundle our review files.

# %%
review_files = os.listdir(review_dir)
review_files = ['{p}/{f}'.format(p = review_dir, f = fn) for fn in review_files]

review_tar = 'output/diha_qc_AIFI_L2_filter_review_{d}.tar.gz'.format(d = date.today())
tar = tarfile.open(review_tar, 'w:gz')
for review_file in review_files:
    tar.add(review_file)
tar.close()

# %% [markdown]
# ## Upload Cell Type data to HISE
#
# Finally, we'll use `hisepy.upload.upload_files()` to send a copy of our output to HISE to use for downstream analysis steps.

# %%
study_space_uuid = 'de025812-5e73-4b3c-9c3b-6d0eac412f2a'
title = 'DIHA PBMC AIFI_L2 Filter Cleanup .h5ad {d}'.format(d = date.today())

# %%
search_id = element_id()
search_id
# Out:
# 'molybdenum-germanium-copper'

# %%
in_files = list(h5ad_uuids.values())
in_files
# Out:
# ['9e0af64b-2173-4327-bee3-11944487d350',
#  '64b85675-4329-41a7-901d-9b738939f9e5',
#  '84869ac0-5a4d-4377-9f0b-c81f90bca9b5',
#  '4261fa08-3169-48a9-b2c4-a7cc767a1d0f',
#  '710513ff-75c0-4ea0-bb50-2ab192a5a0c7',
#  'b458f394-8d94-40f7-a4fa-3aebbfd8f31b',
#  '6f0a57e9-f0ce-425d-a1d7-aad26e4147af',
#  '5a9e0cd4-feb1-4e4e-84ca-4b16afb2f8d3',
#  'b3096a16-ff88-42d8-abf4-5f6e9a8367eb',
#  '1c80095a-4184-4975-9875-963b3d2e5e30',
#  '9e7dfd0b-608d-45de-b0d7-93a1c58ab030',
#  'c1e99a0f-deb6-46b1-9a3b-5163f8a12e0d',
#  '0318482c-b61c-437d-8f48-efa7b9a8ab18',
#  '9aa54376-330c-4729-8b48-0ea5f5eca5fd',
#  'cf42563f-d819-492c-bb95-beff17ac4383',
#  'f34e55f1-5ddc-4373-830d-35f29b99d98d',
#  '61b54268-c6ed-4256-9b71-cfbef7c03851',
#  '55cc7b51-d85c-4036-9c72-9f0d0fe7923b',
#  '23178cdc-f7e9-4e31-b4f2-0f3d54a277e0',
#  'f2229916-c643-445b-ba98-f7362ac5650f',
#  '3a93abec-a596-436b-a23e-057e60145997',
#  'f7b5bd47-1bb5-4879-9972-a1d999e0a49a',
#  'a801a680-1213-4fed-aebe-0cd284b9a018',
#  'bf9dcb65-06b2-4b19-ad64-0a9b5f8acab6',
#  'deca727f-4a5e-4667-9302-3780e02bc66a',
#  'f9dd5a0f-9407-45d1-9692-0f5ba18f5eba',
#  '9ddd0164-4677-4f62-90f3-dabc195e06bc',
#  'c948ec3f-ef89-48fe-b1ac-c97bc4322060',
#  'a20e7c55-ae4e-4851-a36a-48b2e48dc82f',
#  'dbc98b58-3d99-4e50-a790-d242456b5047',
#  '9dfdba3d-069b-409f-8f6f-28726800764b',
#  '86d24e7a-ca28-4b6a-979b-ab9519ad32cc',
#  'c4e26143-3e93-400f-9609-600707756e96',
#  '25d4d213-b18b-4d2d-a40d-582c3f469dae',
#  '33ba88cf-4857-4fb4-89a2-117a107da155',
#  'b768b683-249b-4ed9-b5ea-79efc19ef975',
#  'e820fc38-6d65-4d1f-80a4-6d0234ee4f6e',
#  'eed33093-877f-4205-82b6-382535c0c5e7',
#  '4fb9550f-236c-477b-8a40-acc75933b6cd',
#  'a5d6130e-8395-4be7-9a2f-07dd00aa0666',
#  '02112a03-447b-4a3d-ba4f-0e4e4cc91f0c',
#  'a505a5d8-e884-48f0-a52a-24b2d92a23a0',
#  '92c4bdd5-a246-4d54-ae11-9c28227097d6',
#  '5e1d5882-e107-4e02-974a-b07a12e57cb0',
#  '4e17b3db-a975-47cf-bee9-ee271959dd2e',
#  '0cfd114f-ded0-4bd0-9df6-72467a843fa3',
#  'c2ea513b-0f82-4de9-adb3-1b78dcc1e3ee',
#  'b5ab1cd6-838d-4a5d-9b25-cc2a7f75e191',
#  '7b5cc0da-5805-440e-a721-a6d248bdab3f',
#  '598aebc6-d838-4bb9-b3cd-40b0a777faab',
#  '404ecb42-c39d-413f-bcae-e5c7f311972a',
#  '8357ef26-c4a1-4ed0-b864-ec4cdec1669b',
#  '0d9f774f-6182-46d0-a932-b8c502a16aab',
#  'e1620390-6e37-44db-aa0d-ffd74a188d74',
#  '8583276f-f584-42b6-bbf2-cc0b483cb653',
#  'a9e29502-e8b3-4093-a81c-0875f3e130c3',
#  '648c8c8e-b349-4913-bf90-1943df16fc14',
#  '39d6f945-b0f4-4420-8411-6ab754aa4c80',
#  'd0a793ca-2f14-4640-b57c-3ab88ec69020',
#  'd195dbf6-1af8-414a-8436-4c842e1c18de',
#  '34da77a8-2090-4abc-96e7-704613c001c2',
#  'dd69f5a4-40f4-4976-9f62-fa3dcfff9b48',
#  'c2a86cbe-7216-4dd5-9d7d-b2f32758c669',
#  '80ed7b3f-ebc3-4802-bbe6-fd0596486650']

# %%
out_files = out_files + [review_tar]

# %%
out_files
# Out:
# ['output/diha_BR1_Female_Negative_CD14_monocyte_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Female_Negative_CD56dim_NK_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Female_Negative_Memory_CD4_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Female_Negative_Memory_CD8_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Female_Negative_Naive_CD4_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Female_Positive_CD14_monocyte_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Female_Positive_CD56dim_NK_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Female_Positive_Memory_CD4_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Female_Positive_Memory_CD8_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Female_Positive_Naive_CD4_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Male_Negative_CD14_monocyte_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Male_Negative_CD56dim_NK_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Male_Negative_Memory_CD4_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Male_Negative_Memory_CD8_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Male_Negative_Naive_CD4_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Male_Positive_CD14_monocyte_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Male_Positive_CD56dim_NK_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Male_Positive_Memory_CD4_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Male_Positive_Memory_CD8_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR1_Male_Positive_Naive_CD4_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Female_Negative_CD14_monocyte_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Female_Negative_CD56dim_NK_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Female_Negative_Memory_CD4_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Female_Negative_Memory_CD8_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Female_Negative_Naive_CD4_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Female_Positive_CD14_monocyte_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Female_Positive_CD56dim_NK_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Female_Positive_Memory_CD4_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Female_Positive_Memory_CD8_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Female_Positive_Naive_CD4_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Male_Negative_CD14_monocyte_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Male_Negative_CD56dim_NK_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Male_Negative_Memory_CD4_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Male_Negative_Memory_CD8_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Male_Negative_Naive_CD4_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Male_Positive_CD14_monocyte_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Male_Positive_CD56dim_NK_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Male_Positive_Memory_CD4_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Male_Positive_Memory_CD8_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_BR2_Male_Positive_Naive_CD4_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_ASDC_filtered_2024-04-21.h5ad',
#  'output/diha_CD16_monocyte_filtered_2024-04-21.h5ad',
#  'output/diha_CD56bright_NK_cell_filtered_2024-04-21.h5ad',
#  'output/diha_CD8aa_filtered_2024-04-21.h5ad',
#  'output/diha_DN_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_Effector_B_cell_filtered_2024-04-21.h5ad',
#  'output/diha_Erythrocyte_filtered_2024-04-21.h5ad',
#  'output/diha_ILC_filtered_2024-04-21.h5ad',
#  'output/diha_Intermediate_monocyte_filtered_2024-04-21.h5ad',
#  'output/diha_MAIT_filtered_2024-04-21.h5ad',
#  'output/diha_Memory_B_cell_filtered_2024-04-21.h5ad',
#  'output/diha_Naive_B_cell_filtered_2024-04-21.h5ad',
#  'output/diha_Naive_CD8_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_Plasma_cell_filtered_2024-04-21.h5ad',
#  'output/diha_Platelet_filtered_2024-04-21.h5ad',
#  'output/diha_Progenitor_cell_filtered_2024-04-21.h5ad',
#  'output/diha_Proliferating_NK_cell_filtered_2024-04-21.h5ad',
#  'output/diha_Proliferating_T_cell_filtered_2024-04-21.h5ad',
#  'output/diha_Transitional_B_cell_filtered_2024-04-21.h5ad',
#  'output/diha_Treg_filtered_2024-04-21.h5ad',
#  'output/diha_cDC1_filtered_2024-04-21.h5ad',
#  'output/diha_cDC2_filtered_2024-04-21.h5ad',
#  'output/diha_gdT_filtered_2024-04-21.h5ad',
#  'output/diha_pDC_filtered_2024-04-21.h5ad',
#  'output/diha_qc_AIFI_L2_filter_review_2024-04-21.tar.gz']

# %%
hisepy.upload.upload_files(
    files = out_files,
    study_space_id = study_space_uuid,
    title = title,
    input_file_ids = in_files,
    destination = search_id
)
# Out:
# you are trying to upload file_ids... ['output/diha_BR1_Female_Negative_CD14_monocyte_filtered_2024-04-21.h5ad', 'output/diha_BR1_Female_Negative_CD56dim_NK_cell_filtered_2024-04-21.h5ad', 'output/diha_BR1_Female_Negative_Memory_CD4_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR1_Female_Negative_Memory_CD8_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR1_Female_Negative_Naive_CD4_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR1_Female_Positive_CD14_monocyte_filtered_2024-04-21.h5ad', 'output/diha_BR1_Female_Positive_CD56dim_NK_cell_filtered_2024-04-21.h5ad', 'output/diha_BR1_Female_Positive_Memory_CD4_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR1_Female_Positive_Memory_CD8_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR1_Female_Positive_Naive_CD4_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR1_Male_Negative_CD14_monocyte_filtered_2024-04-21.h5ad', 'output/diha_BR1_Male_Negative_CD56dim_NK_cell_filtered_2024-04-21.h5ad', 'output/diha_BR1_Male_Negative_Memory_CD4_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR1_Male_Negative_Memory_CD8_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR1_Male_Negative_Naive_CD4_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR1_Male_Positive_CD14_monocyte_filtered_2024-04-21.h5ad', 'output/diha_BR1_Male_Positive_CD56dim_NK_cell_filtered_2024-04-21.h5ad', 'output/diha_BR1_Male_Positive_Memory_CD4_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR1_Male_Positive_Memory_CD8_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR1_Male_Positive_Naive_CD4_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR2_Female_Negative_CD14_monocyte_filtered_2024-04-21.h5ad', 'output/diha_BR2_Female_Negative_CD56dim_NK_cell_filtered_2024-04-21.h5ad', 'output/diha_BR2_Female_Negative_Memory_CD4_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR2_Female_Negative_Memory_CD8_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR2_Female_Negative_Naive_CD4_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR2_Female_Positive_CD14_monocyte_filtered_2024-04-21.h5ad', 'output/diha_BR2_Female_Positive_CD56dim_NK_cell_filtered_2024-04-21.h5ad', 'output/diha_BR2_Female_Positive_Memory_CD4_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR2_Female_Positive_Memory_CD8_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR2_Female_Positive_Naive_CD4_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR2_Male_Negative_CD14_monocyte_filtered_2024-04-21.h5ad', 'output/diha_BR2_Male_Negative_CD56dim_NK_cell_filtered_2024-04-21.h5ad', 'output/diha_BR2_Male_Negative_Memory_CD4_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR2_Male_Negative_Memory_CD8_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR2_Male_Negative_Naive_CD4_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR2_Male_Positive_CD14_monocyte_filtered_2024-04-21.h5ad', 'output/diha_BR2_Male_Positive_CD56dim_NK_cell_filtered_2024-04-21.h5ad', 'output/diha_BR2_Male_Positive_Memory_CD4_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR2_Male_Positive_Memory_CD8_T_cell_filtered_2024-04-21.h5ad', 'output/diha_BR2_Male_Positive_Naive_CD4_T_cell_filtered_2024-04-21.h5ad', 'output/diha_ASDC_filtered_2024-04-21.h5ad', 'output/diha_CD16_monocyte_filtered_2024-04-21.h5ad', 'output/diha_CD56bright_NK_cell_filtered_2024-04-21.h5ad', 'output/diha_CD8aa_filtered_2024-04-21.h5ad', 'output/diha_DN_T_cell_filtered_2024-04-21.h5ad', 'output/diha_Effector_B_cell_filtered_2024-04-21.h5ad', 'output/diha_Erythrocyte_filtered_2024-04-21.h5ad', 'output/diha_ILC_filtered_2024-04-21.h5ad', 'output/diha_Intermediate_monocyte_filtered_2024-04-21.h5ad', 'output/diha_MAIT_filtered_2024-04-21.h5ad', 'output/diha_Memory_B_cell_filtered_2024-04-21.h5ad', 'output/diha_Naive_B_cell_filtered_2024-04-21.h5ad', 'output/diha_Naive_CD8_T_cell_filtered_2024-04-21.h5ad', 'output/diha_Plasma_cell_filtered_2024-04-21.h5ad', 'output/diha_Platelet_filtered_2024-04-21.h5ad', 'output/diha_Progenitor_cell_filtered_2024-04-21.h5ad', 'output/diha_Proliferating_NK_cell_filtered_2024-04-21.h5ad', 'output/diha_Proliferating_T_cell_filtered ...
# (y/n) y
# {'trace_id': '22d3380c-9448-4152-9c48-6e0ca52acbb4',
#  'files': ['output/diha_BR1_Female_Negative_CD14_monocyte_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Female_Negative_CD56dim_NK_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Female_Negative_Memory_CD4_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Female_Negative_Memory_CD8_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Female_Negative_Naive_CD4_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Female_Positive_CD14_monocyte_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Female_Positive_CD56dim_NK_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Female_Positive_Memory_CD4_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Female_Positive_Memory_CD8_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Female_Positive_Naive_CD4_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Male_Negative_CD14_monocyte_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Male_Negative_CD56dim_NK_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Male_Negative_Memory_CD4_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Male_Negative_Memory_CD8_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Male_Negative_Naive_CD4_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Male_Positive_CD14_monocyte_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Male_Positive_CD56dim_NK_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Male_Positive_Memory_CD4_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Male_Positive_Memory_CD8_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR1_Male_Positive_Naive_CD4_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Female_Negative_CD14_monocyte_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Female_Negative_CD56dim_NK_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Female_Negative_Memory_CD4_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Female_Negative_Memory_CD8_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Female_Negative_Naive_CD4_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Female_Positive_CD14_monocyte_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Female_Positive_CD56dim_NK_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Female_Positive_Memory_CD4_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Female_Positive_Memory_CD8_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Female_Positive_Naive_CD4_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Male_Negative_CD14_monocyte_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Male_Negative_CD56dim_NK_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Male_Negative_Memory_CD4_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Male_Negative_Memory_CD8_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Male_Negative_Naive_CD4_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Male_Positive_CD14_monocyte_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Male_Positive_CD56dim_NK_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Male_Positive_Memory_CD4_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Male_Positive_Memory_CD8_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_BR2_Male_Positive_Naive_CD4_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_ASDC_filtered_2024-04-21.h5ad',
#   'output/diha_CD16_monocyte_filtered_2024-04-21.h5ad',
#   'output/diha_CD56bright_NK_cell_filtered_2024-04-21.h5ad',
#   'output/diha_CD8aa_filtered_2024-04-21.h5ad',
#   'output/diha_DN_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_Effector_B_cell_filtered_2024-04-21.h5ad',
#   'output/diha_Erythrocyte_filtered_2024-04-21.h5ad',
#   'output/diha_ILC_filtered_2024-04-21.h5ad',
#   'output/diha_Intermediate_monocyte_filtered_2024-04-21.h5ad',
#   'output/diha_MAIT_filtered_2024-04-21.h5ad',
#   'output/diha_Memory_B_cell_filtered_2024-04-21.h5ad',
#   'output/diha_Naive_B_cell_filtered_2024-04-21.h5ad',
#   'output/diha_Naive_CD8_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_Plasma_cell_filtered_2024-04-21.h5ad',
#   'output/diha_Platelet_filtered_2024-04-21.h5ad',
#   'output/diha_Progenitor_cell_filtered_2024-04-21.h5ad',
#   'output/diha_Proliferating_NK_cell_filtered_2024-04-21.h5ad',
#   'output/diha_Proliferating_T_cell_filtered_2024-04-21.h5ad',
#   'output/diha_Transitional_B_cell_filtered_2024-04-21.h5ad',
#   'output/diha_Treg_filtered_2024-04-21.h5ad',
#   'output/diha_cDC1_filtered_2024-04-21.h5ad',
#   'output/diha_cDC2_filtered_2024-04-21.h5ad',
#   'output/diha_gdT_filtered_2024-04-21.h5ad',
#   'output/diha_pDC_filtered_2024-04-21.h5ad',
#   'output/diha_qc_AIFI_L2_filter_review_2024-04-21.tar.gz']}

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.10.3
# h5py                3.10.0
# hisepy              0.3.0
# pandas              2.1.4
# scanpy              1.9.6
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.0.1
# anyio                       NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# beatrix_jupyterlab          NA
# brotli                      NA
# cachetools                  5.3.1
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# cloudpickle                 2.2.1
# colorama                    0.4.6
# comm                        0.1.4
# cryptography                41.0.7
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# db_dtypes                   1.1.1
# debugpy                     1.8.0
# decorator                   5.1.1
# defusedxml                  0.7.1
# deprecated                  1.2.14
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fqdn                        NA
# google                      NA
# greenlet                    2.0.2
# grpc                        1.58.0
# grpc_status                 NA
# idna                        3.6
# igraph                      0.10.8
# importlib_metadata          NA
# ipykernel                   6.28.0
# ipython_genutils            0.2.0
# ipywidgets                  8.1.1
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.2
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.20.0
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.1
# jupyterlab_server           2.25.2
# jwt                         2.8.0
# kiwisolver                  1.4.5
# leidenalg                   0.10.1
# llvmlite                    0.41.0
# lz4                         4.3.2
# markupsafe                  2.1.3
# matplotlib                  3.8.0
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# mpmath                      1.3.0
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.58.0
# numpy                       1.24.0
# opentelemetry               NA
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# periodictable               1.5.2
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                4.1.0
# plotly                      5.18.0
# prettytable                 3.9.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# proto                       NA
# psutil                      NA
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pyarrow                     13.0.0
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pynvml                      NA
# pyparsing                   3.1.1
# pyreadr                     0.5.0
# pythonjsonlogger            NA
# pytz                        2023.3.post1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.11.4
# send2trash                  NA
# shapely                     1.8.5.post1
# six                         1.16.0
# sklearn                     1.3.2
# sniffio                     1.3.0
# socks                       1.7.1
# sql                         NA
# sqlalchemy                  2.0.21
# sqlparse                    0.4.4
# stack_data                  0.6.2
# sympy                       1.12
# termcolor                   NA
# texttable                   1.7.0
# threadpoolctl               3.2.0
# torch                       2.1.2+cu121
# torchgen                    NA
# tornado                     6.3.3
# tqdm                        4.66.1
# traitlets                   5.9.0
# typing_extensions           NA
# uri_template                NA
# urllib3                     1.26.18
# wcwidth                     0.2.12
# webcolors                   1.13
# websocket                   1.7.0
# wrapt                       1.15.0
# xarray                      2023.12.0
# yaml                        6.0.1
# zipp                        NA
# zmq                         25.1.2
# zoneinfo                    NA
# zstandard                   0.22.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.19.0
# jupyter_client      8.6.0
# jupyter_core        5.6.1
# jupyterlab          4.1.5
# notebook            6.5.4
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-5.15.0-1042-gcp-x86_64-with-glibc2.31
# -----
# Session information updated at 2024-04-21 02:15
# </pre>
# </details>

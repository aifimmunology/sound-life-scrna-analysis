# %% [markdown]
# # Partition Cell Types for QC Review
#
# To ensure that our cell type labels are as accurate as possible, we'll subset our dataset based on our `AIFI_L2` labels for review.
#
# Previously, we split our dataset up into 8 subsets based on cohort, biological sex, and CMV status. Here, we'll combine these per L2 cell type for less abundant cell types to simplify review. For very abundant cell types (i.e. Naive CD4 T cells), we'll keep them separated into the 8 groups and review each.
#
# This should reduce the burden of trying to cluster >2M cells (which can be very slow) without significantly reducing our power to identify doublets or mislabeled cells, as we'll still have >100k cells for these large classes.
#
# In a later step, we'll generate rules to filter these clustered subsets of cells to help us in identifying doublets, contaminated clusters (i.e. with erythrocyte content), and mislabeled cells.

# %% [markdown]
# ## Load libraries

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=RuntimeWarning)

import concurrent.futures
from concurrent.futures import ThreadPoolExecutor
from datetime import date
import hisepy
import os
import pandas as pd
import re
import scanpy as sc
import scanpy.external as sce

# %%
out_dir = 'output'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %% [markdown]
# ## Helper functions
#
# These make it a bit simpler to cache and read in files from HISE

# %%
def cache_uuid_path(uuid):
    cache_path = '/home/jupyter/cache/{u}'.format(u = uuid)
    if not os.path.isdir(cache_path):
        hise_res = hisepy.reader.cache_files([uuid])
    filename = os.listdir(cache_path)[0]
    cache_file = '{p}/{f}'.format(p = cache_path, f = filename)
    return cache_file

# %%
def read_parquet_uuid(uuid):
    cache_file = cache_uuid_path(uuid)
    res = pd.read_parquet(cache_file)
    return res

# %%
def sort_adata_uuid(uuid, sort_cols = ['AIFI_L2', 'sample.sampleKitGuid']):
    cache_file = cache_uuid_path(uuid)
    adata = sc.read_h5ad(cache_file)
    obs = adata.obs
    obs = obs.sort_values(sort_cols)
    adata = adata[obs.index]
    adata.write_h5ad(cache_file)

# %% [markdown]
# This function will enable us to connect to our .h5ad files without loading the entire thing into memory. We'll then load only the cells that we want for each cell class to assemble them for writing. This should save us some overhead as we do our subsetting.

# %%
def read_adata_backed_uuid(uuid):
    cache_file = cache_uuid_path(uuid)
    res = sc.read_h5ad(cache_file, backed = 'r')
    return res

# %% [markdown]
# This function will apply a standard normalization, nearest neighbors, clustering, and UMAP process to our cell subsets:

# %%
def process_adata(adata):
    # Keep a copy of the raw data
    adata.raw = adata

    print('Normalizing')
    # Normalize and log transform
    sc.pp.normalize_total(adata)
    sc.pp.log1p(adata)

    print('Finding HVGs')
    # Restrict downstream steps to variable genes
    sc.pp.highly_variable_genes(adata)
    adata = adata[:, adata.var_names[adata.var['highly_variable']]].copy()
    print(adata.shape)

    print('Scaling')
    # Scale variable genes
    sc.pp.scale(adata)

    print('PCA')
    # Run PCA
    sc.tl.pca(adata, svd_solver = 'arpack')

    print('Neighbors')
    # Find nearest neighbors
    sc.pp.neighbors(
        adata, 
        n_neighbors = 50,
        n_pcs = 30
    )

    print('Louvain')
    # Find clusters
    sc.tl.louvain(
        adata, 
        resolution = 2, 
        key_added = 'louvain_2'
    )

    print('UMAP')
    # Run UMAP
    sc.tl.umap(adata, min_dist = 0.05)

    return adata

# %%
def format_cell_type(cell_type):
    cell_type = re.sub('\\+', 'pos', cell_type)
    cell_type = re.sub('-', 'neg', cell_type)
    cell_type = re.sub(' ', '_', cell_type)
    return cell_type

# %%
def element_id(n = 3):
    import periodictable
    from random import randrange
    rand_el = []
    for i in range(n):
        el = randrange(0,118)
        rand_el.append(periodictable.elements[el].name)
    rand_str = '-'.join(rand_el)
    return rand_str

# %% [markdown]
# ## Read cell metadata to identify large subsets

# %%
pq_uuids = {
    'BR1_Female_Negative': '',
    'BR1_Female_Positive': '',
    'BR1_Male_Negative':   '',
    'BR1_Male_Positive':   '',
    'BR2_Female_Negative': '',
    'BR2_Female_Positive': '',
    'BR2_Male_Negative':   '',
    'BR2_Male_Positive':   ''
}

# %%
meta_dict = {}
for group_name, uuid in pq_uuids.items():
    meta_dict[group_name] = read_parquet_uuid(uuid)

# %%
l2_counts = {}
for group_name, meta in meta_dict.items():
    counts = meta['AIFI_L2'].value_counts()
    l2_counts[group_name] = counts

# %%
total_l2_counts = sum(list(l2_counts.values()))

# %%
total_l2_counts
# Out:
# AIFI_L2
# ASDC                        4033
# CD14 monocyte            2267815
# CD16 monocyte             405940
# CD56bright NK cell         96149
# CD56dim NK cell          1123845
# CD8aa                      17893
# DN T cell                  17670
# Effector B cell            86715
# Erythrocyte                27862
# ILC                         5734
# Intermediate monocyte      76444
# MAIT                      382216
# Memory B cell             389681
# Memory CD4 T cell        2810416
# Memory CD8 T cell        1540017
# Naive B cell              725074
# Naive CD4 T cell         2986313
# Naive CD8 T cell          833824
# Plasma cell                16405
# Platelet                   72347
# Progenitor cell            12429
# Proliferating NK cell      20575
# Proliferating T cell       18588
# Transitional B cell        79970
# Treg                      309377
# cDC1                        8138
# cDC2                      114043
# gdT                       318347
# pDC                        62162
# Name: count, dtype: int64

# %% [markdown]
# These L2 labels have > 1M cells each. We'll keep them separated per sample group.

# %%
large_types = total_l2_counts.index[total_l2_counts > 1e6]
large_types.tolist()
# Out:
# ['CD14 monocyte',
#  'CD56dim NK cell',
#  'Memory CD4 T cell',
#  'Memory CD8 T cell',
#  'Naive CD4 T cell']

# %% [markdown]
# ## Download and sort .h5ad files
#
# Sorting the .h5ad files by AIFI_L2 will make reading each cell type much faster by placing cells of the same type next to each other in the sparse matrix.

# %%
h5ad_uuids = {
    'BR1_Female_Negative': '',
    'BR1_Female_Positive': ''
}

# %%
for uuid in h5ad_uuids.values():
    sort_adata_uuid(uuid, sort_cols = ['AIFI_L2', 'sample.sampleKitGuid'])

# %% [markdown]
# ## Open connections to .h5ad files
#
# Now that they're sorted, we can open these files with on-disk backing so we don't have to read the entire file at once.

# %%
h5ad_conn = {}
for group_name, uuid in h5ad_uuids.items():
    h5ad_conn[group_name] = read_adata_backed_uuid(uuid)

# %% [markdown]
# ## Process each cell type

# %%
l2_types = total_l2_counts.index.tolist()

# %%
def read_l2_type(adata, cell_type):
    type_adata = adata[adata.obs['AIFI_L2'] == cell_type].to_memory()
    return type_adata

# %%
out_files = []

# %%
for cell_type in l2_types:
    print(cell_type)
    
    # Read data from each group for this type in parallel
    print('Loading data')
    type_adata_dict = {}

    with ThreadPoolExecutor(max_workers = 8) as executor:
        futures = {
            executor.submit(
                read_l2_type, 
                h5ad_conn[group_name], 
                cell_type): group_name 
            for group_name in h5ad_conn.keys()
        }
        for future in concurrent.futures.as_completed(futures):
            future_group = futures[future]
            type_adata_dict[future_group] = future.result()
    
    if cell_type in large_types:
        # If large, process and save separately
        for group_name, type_adata in type_adata_dict.items():
            print('Processing {g}'.format(g = group_name))
            print(type_adata.shape)
            type_adata = process_adata(type_adata)
            print('Saving processed data')
            out_type = format_cell_type(cell_type)
            out_file = 'output/diha_qc_{g}_{c}_{d}.h5ad'.format(
                g = group_name,
                c = out_type,
                d = date.today()
            )
            type_adata.write_h5ad(out_file)
            out_files.append(out_file)
# Out:
# ASDC
# Loading data
# Combining and processing
# (4033, 33538)
# Normalizing
# Finding HVGs
# (4033, 1811)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# CD14 monocyte
# Loading data
# Processing BR1_Female_Positive
# (193982, 33538)
# Normalizing
# Finding HVGs
# (193982, 870)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR2_Male_Positive
# (214534, 33538)
# Normalizing
# Finding HVGs
# (214534, 956)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR2_Female_Negative
# (219030, 33538)
# Normalizing
# Finding HVGs
# (219030, 878)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR1_Male_Positive
# (180735, 33538)
# Normalizing
# Finding HVGs
# (180735, 906)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR1_Male_Negative
# (305415, 33538)
# Normalizing
# Finding HVGs
# (305415, 806)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR2_Male_Negative
# (349370, 33538)
# Normalizing
# Finding HVGs
# (349370, 860)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR1_Female_Negative
# (405572, 33538)
# Normalizing
# Finding HVGs
# (405572, 774)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR2_Female_Positive
# (399177, 33538)
# Normalizing
# Finding HVGs
# (399177, 800)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# CD16 monocyte
# Loading data
# Combining and processing
# (405940, 33538)
# Normalizing
# Finding HVGs
# (405940, 1158)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# CD56bright NK cell
# Loading data
# Combining and processing
# (96149, 33538)
# Normalizing
# Finding HVGs
# (96149, 1350)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# CD56dim NK cell
# Loading data
# Processing BR2_Male_Positive
# (74411, 33538)
# Normalizing
# Finding HVGs
# (74411, 1127)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR1_Female_Positive
# (82780, 33538)
# Normalizing
# Finding HVGs
# (82780, 888)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR1_Male_Positive
# (132602, 33538)
# Normalizing
# Finding HVGs
# (132602, 1048)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR2_Female_Negative
# (129579, 33538)
# Normalizing
# Finding HVGs
# (129579, 983)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR2_Female_Positive
# (163771, 33538)
# Normalizing
# Finding HVGs
# (163771, 950)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR1_Male_Negative
# (163072, 33538)
# Normalizing
# Finding HVGs
# (163072, 863)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR1_Female_Negative
# (199167, 33538)
# Normalizing
# Finding HVGs
# (199167, 899)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR2_Male_Negative
# (178463, 33538)
# Normalizing
# Finding HVGs
# (178463, 1005)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# CD8aa
# Loading data
# Combining and processing
# (17893, 33538)
# Normalizing
# Finding HVGs
# (17893, 1541)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# DN T cell
# Loading data
# Combining and processing
# (17670, 33538)
# Normalizing
# Finding HVGs
# (17670, 2012)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Effector B cell
# Loading data
# Combining and processing
# (86715, 33538)
# Normalizing
# Finding HVGs
# (86715, 1344)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Erythrocyte
# Loading data
# Combining and processing
# (27862, 33538)
# Normalizing
# Finding HVGs
# (27862, 4277)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# ILC
# Loading data
# Combining and processing
# (5734, 33538)
# Normalizing
# Finding HVGs
# (5734, 1757)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Intermediate monocyte
# Loading data
# Combining and processing
# (76444, 33538)
# Normalizing
# Finding HVGs
# (76444, 1031)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# MAIT
# Loading data
# Combining and processing
# (382216, 33538)
# Normalizing
# Finding HVGs
# (382216, 982)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Memory B cell
# Loading data
# Combining and processing
# (389681, 33538)
# Normalizing
# Finding HVGs
# (389681, 746)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Memory CD4 T cell
# Loading data
# Processing BR1_Male_Positive
# (180596, 33538)
# Normalizing
# Finding HVGs
# (180596, 1103)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR1_Female_Positive
# (241784, 33538)
# Normalizing
# Finding HVGs
# (241784, 1300)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR2_Female_Negative
# (307137, 33538)
# Normalizing
# Finding HVGs
# (307137, 1236)
# Scaling
# PCA
# Neighbors
# Louvain
# Saving processed data
# Processing BR2_Male_Positive
# (337155, 33538)
# Normalizing
# Finding HVGs
# (337155, 1334)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# IOStream.flush timed out
# IOStream.flush timed out
# Saving processed data
# Processing BR1_Male_Negative
# (334981, 33538)
# Normalizing
# Finding HVGs
# (334981, 1132)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR2_Male_Negative
# (369311, 33538)
# Normalizing
# Finding HVGs
# (369311, 1353)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR1_Female_Negative
# (446391, 33538)
# Normalizing
# Finding HVGs
# (446391, 1192)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# UMAP
# Saving processed data
# Memory CD8 T cell
# Loading data
# Processing BR2_Female_Negative
# (81648, 33538)
# Normalizing
# Finding HVGs
# (81648, 1243)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR1_Male_Negative
# (136184, 33538)
# Normalizing
# Finding HVGs
# (136184, 1057)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR1_Female_Negative
# (163963, 33538)
# Normalizing
# Finding HVGs
# (163963, 1017)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR1_Female_Positive
# (165278, 33538)
# Normalizing
# Finding HVGs
# (165278, 1120)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR2_Male_Negative
# (178121, 33538)
# Normalizing
# Finding HVGs
# (178121, 1158)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Processing BR2_Male_Positive
# (205207, 33538)
# Normalizing
# Finding HVGs
# (205207, 1194)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# UMAP
# Saving processed data
# Processing BR2_Female_Positive
# (413280, 33538)
# Normalizing
# Finding HVGs
# (413280, 1051)
# Scaling
# PCA
# Neighbors
# Louvain
# UMAP
# Saving processed data
# Naive B cell
# Loading data
# Combining and processing
# (725074, 33538)
# Normalizing
# Finding HVGs
# (725074, 773)
# Scaling
# PCA
# Neighbors
# Louvain
# Louvain

# %% [markdown]
# ## Upload Cell Type data to HISE
#
# Finally, we'll use `hisepy.upload.upload_files()` to send a copy of our output to HISE to use for downstream analysis steps.

# %%
study_space_uuid = 'de025812-5e73-4b3c-9c3b-6d0eac412f2a'
title = 'DIHA PBMC L2 Pre-cleanup BR1 Female {d}'.format(d = date.today())

# %%
search_id = element_id()
search_id

# %%
in_files = list(h5ad_uuids.values()) + list(pq_uuids.values())
in_files
# Out:
# ['7aa6743f-c9f1-4cc1-b879-b5528f6d4270',
#  'd4e6a54f-9703-4cce-a324-519a0ad0624c',
#  '2487c0f6-d9bb-4d63-98df-f185da3e2d88',
#  'c0d0ac72-13da-41a9-806c-2027141ea44a',
#  '824fcb67-d2c0-4db2-818e-966058da069b',
#  'ff7e1dcc-b4f4-4e44-90d3-33eae781940a',
#  '588b4802-e724-4a61-af21-d441f4dd0ad5',
#  '8eb02ae8-46fb-4d1d-83e3-088c55ddc3d5',
#  '2a639ff1-9544-4f55-a4be-f6589360dfb7',
#  'e637c51d-7e7f-4594-9249-dc768bcd3762',
#  '7c04ef25-9063-4281-8906-378ea6ac77f2',
#  '2a59562e-de72-4199-b219-f30f571406d8',
#  '56f2fa45-71b5-4ec5-833a-a8aac470f4b3',
#  '717d3165-7b36-4ac8-88a5-ef1b53c9b6cd',
#  '6603876a-9e51-496d-8666-d5441ac4375c',
#  'c1b0e096-9c48-4495-8096-e89828145700']

# %%
out_files
# Out:
# ['output/diha_qc_BR1_Male_Negative_Memory-CD4-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Female_Positive_Memory-CD4-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR1_Female_Positive_CD56dim-NK-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR1_Male_Positive_Memory-CD8-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Male_Positive_Naive-CD4-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR1_Female_Negative_CD56dim-NK-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Male_Negative_Naive-CD4-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_Naive-B-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Female_Negative_Memory-CD4-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Male_Negative_CD14-monocyte_2024-03-13.h5ad',
#  'output/diha_qc_BR1_Male_Positive_CD14-monocyte_2024-03-13.h5ad',
#  'output/diha_qc_BR1_Female_Negative_Memory-CD4-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_ASDC_2024-03-13.h5ad',
#  'output/diha_qc_BR1_Female_Positive_Naive-CD4-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_Progenitor-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR1_Male_Positive_Naive-CD4-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR1_Male_Positive_Memory-CD4-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR1_Female_Negative_Memory-CD8-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_Intermediate-monocyte_2024-03-14.h5ad',
#  'output/diha_qc_BR1_Male_Negative_Memory-CD8-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Female_Negative_Naive-CD4-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_DN-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_Memory-B-cell_2024-03-14.h5ad',
#  'output/diha_qc_MAIT_2024-03-14.h5ad',
#  'output/diha_qc_Erythrocyte_2024-03-14.h5ad',
#  'output/diha_qc_BR1_Female_Positive_CD14-monocyte_2024-03-13.h5ad',
#  'output/diha_qc_BR1_Male_Negative_CD56dim-NK-cell_2024-03-14.h5ad',
#  'output/diha_qc_CD16-monocyte_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Male_Negative_Memory-CD8-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Female_Negative_CD14-monocyte_2024-03-13.h5ad',
#  'output/diha_qc_BR2_Female_Positive_Memory-CD8-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Male_Positive_Memory-CD8-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Male_Negative_CD56dim-NK-cell_2024-03-14.h5ad',
#  'output/diha_qc_Proliferating-NK-cell_2024-03-14.h5ad',
#  'output/diha_qc_CD8aa_2024-03-14.h5ad',
#  'output/diha_qc_pDC_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Female_Negative_CD56dim-NK-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR1_Male_Negative_CD14-monocyte_2024-03-13.h5ad',
#  'output/diha_qc_BR1_Female_Negative_CD14-monocyte_2024-03-13.h5ad',
#  'output/diha_qc_BR2_Female_Positive_CD56dim-NK-cell_2024-03-14.h5ad',
#  'output/diha_qc_cDC2_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Female_Positive_CD14-monocyte_2024-03-13.h5ad',
#  'output/diha_qc_BR1_Male_Positive_CD56dim-NK-cell_2024-03-14.h5ad',
#  'output/diha_qc_gdT_2024-03-14.h5ad',
#  'output/diha_qc_Treg_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Male_Positive_CD56dim-NK-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR1_Female_Negative_Naive-CD4-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR1_Female_Positive_Memory-CD8-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_Platelet_2024-03-14.h5ad',
#  'output/diha_qc_Transitional-B-cell_2024-03-14.h5ad',
#  'output/diha_qc_Plasma-cell_2024-03-14.h5ad',
#  'output/diha_qc_ILC_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Male_Positive_CD14-monocyte_2024-03-13.h5ad',
#  'output/diha_qc_Naive-CD8-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_CD56bright-NK-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Female_Positive_Naive-CD4-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Female_Negative_Memory-CD8-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Male_Positive_Memory-CD4-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR2_Male_Negative_Memory-CD4-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR1_Male_Negative_Naive-CD4-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_cDC1_2024-03-14.h5ad',
#  'output/diha_qc_Effector-B-cell_2024-03-14.h5ad',
#  'output/diha_qc_Proliferating-T-cell_2024-03-14.h5ad',
#  'output/diha_qc_BR1_Female_Positive_Memory-CD4-T-cell_2024-03-14.h5ad']

# %%
hisepy.upload.upload_files(
    files = dash_out_files,
    study_space_id = study_space_uuid,
    title = title,
    input_file_ids = in_files
)
# Out:
# output/diha_qc_BR1_Male_Negative_Memory-CD4-T-cell_2024-03-14.h5ad
# output/diha_qc_BR2_Female_Positive_Memory-CD4-T-cell_2024-03-14.h5ad
# output/diha_qc_BR1_Female_Positive_CD56dim-NK-cell_2024-03-14.h5ad
# output/diha_qc_BR1_Male_Positive_Memory-CD8-T-cell_2024-03-14.h5ad
# output/diha_qc_BR2_Male_Positive_Naive-CD4-T-cell_2024-03-14.h5ad
# output/diha_qc_BR1_Female_Negative_CD56dim-NK-cell_2024-03-14.h5ad
# output/diha_qc_BR2_Male_Negative_Naive-CD4-T-cell_2024-03-14.h5ad
# output/diha_qc_Naive-B-cell_2024-03-14.h5ad
# output/diha_qc_BR2_Female_Negative_Memory-CD4-T-cell_2024-03-14.h5ad
# output/diha_qc_BR2_Male_Negative_CD14-monocyte_2024-03-13.h5ad
# output/diha_qc_BR1_Male_Positive_CD14-monocyte_2024-03-13.h5ad
# output/diha_qc_BR1_Female_Negative_Memory-CD4-T-cell_2024-03-14.h5ad
# output/diha_qc_ASDC_2024-03-13.h5ad
# output/diha_qc_BR1_Female_Positive_Naive-CD4-T-cell_2024-03-14.h5ad
# output/diha_qc_Progenitor-cell_2024-03-14.h5ad
# output/diha_qc_BR1_Male_Positive_Naive-CD4-T-cell_2024-03-14.h5ad
# output/diha_qc_BR1_Male_Positive_Memory-CD4-T-cell_2024-03-14.h5ad
# output/diha_qc_BR1_Female_Negative_Memory-CD8-T-cell_2024-03-14.h5ad
# output/diha_qc_Intermediate-monocyte_2024-03-14.h5ad
# output/diha_qc_BR1_Male_Negative_Memory-CD8-T-cell_2024-03-14.h5ad
# output/diha_qc_BR2_Female_Negative_Naive-CD4-T-cell_2024-03-14.h5ad
# output/diha_qc_DN-T-cell_2024-03-14.h5ad
# output/diha_qc_Memory-B-cell_2024-03-14.h5ad
# output/diha_qc_MAIT_2024-03-14.h5ad
# output/diha_qc_Erythrocyte_2024-03-14.h5ad
# output/diha_qc_BR1_Female_Positive_CD14-monocyte_2024-03-13.h5ad
# output/diha_qc_BR1_Male_Negative_CD56dim-NK-cell_2024-03-14.h5ad
# output/diha_qc_CD16-monocyte_2024-03-14.h5ad
# output/diha_qc_BR2_Male_Negative_Memory-CD8-T-cell_2024-03-14.h5ad
# output/diha_qc_BR2_Female_Negative_CD14-monocyte_2024-03-13.h5ad
# output/diha_qc_BR2_Female_Positive_Memory-CD8-T-cell_2024-03-14.h5ad
# output/diha_qc_BR2_Male_Positive_Memory-CD8-T-cell_2024-03-14.h5ad
# output/diha_qc_BR2_Male_Negative_CD56dim-NK-cell_2024-03-14.h5ad
# output/diha_qc_Proliferating-NK-cell_2024-03-14.h5ad
# output/diha_qc_CD8aa_2024-03-14.h5ad
# output/diha_qc_pDC_2024-03-14.h5ad
# output/diha_qc_BR2_Female_Negative_CD56dim-NK-cell_2024-03-14.h5ad
# output/diha_qc_BR1_Male_Negative_CD14-monocyte_2024-03-13.h5ad
# output/diha_qc_BR1_Female_Negative_CD14-monocyte_2024-03-13.h5ad
# output/diha_qc_BR2_Female_Positive_CD56dim-NK-cell_2024-03-14.h5ad
# output/diha_qc_cDC2_2024-03-14.h5ad
# output/diha_qc_BR2_Female_Positive_CD14-monocyte_2024-03-13.h5ad
# output/diha_qc_BR1_Male_Positive_CD56dim-NK-cell_2024-03-14.h5ad
# output/diha_qc_gdT_2024-03-14.h5ad
# output/diha_qc_Treg_2024-03-14.h5ad
# output/diha_qc_BR2_Male_Positive_CD56dim-NK-cell_2024-03-14.h5ad
# output/diha_qc_BR1_Female_Negative_Naive-CD4-T-cell_2024-03-14.h5ad
# output/diha_qc_BR1_Female_Positive_Memory-CD8-T-cell_2024-03-14.h5ad
# output/diha_qc_Platelet_2024-03-14.h5ad
# output/diha_qc_Transitional-B-cell_2024-03-14.h5ad
# output/diha_qc_Plasma-cell_2024-03-14.h5ad
# output/diha_qc_ILC_2024-03-14.h5ad
# output/diha_qc_BR2_Male_Positive_CD14-monocyte_2024-03-13.h5ad
# output/diha_qc_Naive-CD8-T-cell_2024-03-14.h5ad
# output/diha_qc_CD56bright-NK-cell_2024-03-14.h5ad
# output/diha_qc_BR2_Female_Positive_Naive-CD4-T-cell_2024-03-14.h5ad
# output/diha_qc_BR2_Female_Negative_Memory-CD8-T-cell_2024-03-14.h5ad
# output/diha_qc_BR2_Male_Positive_Memory-CD4-T-cell_2024-03-14.h5ad
# output/diha_qc_BR2_Male_Negative_Memory-CD4-T-cell_2024-03-14.h5ad
# output/diha_qc_BR1_Male_Negative_Naive-CD4-T-cell_2024-03-14.h5ad
# output/diha_qc_cDC1_2024-03-14.h5ad
# output/diha_qc_Effector-B-cell_2024-03-14.h5ad
# output/diha_qc_Proliferating-T-cell_2024-03-14.h5ad
# output/diha_qc_BR1_Female_Positive_Memory-CD4-T-cell_2024-03-14.h5ad
# you are trying to upload file_ids... ['output/diha_qc_BR1_Male_Negative_Memory-CD4-T-cell_2024-03-14.h5ad', 'output/diha_qc_BR2_Female_Positive_Memory-CD4-T-cell_2024-03-14.h5ad', 'output/diha_qc_BR1_Female_Positive_CD56dim-NK-cell_2024-03-14.h5ad', 'output/diha_qc_BR1_Male_Positive_Memory-CD8-T-cell_2024-03-14.h5ad', 'output/diha_qc_BR2_Male_Positive_Naive-CD4-T-cell_2024-03-14.h5ad', 'output/diha_qc_BR1_Female_Negative_CD56dim-NK-cell_2024-03-14.h5ad', 'output/diha_qc_BR2_Male_Negative_Naive-CD4-T-cell_2024-03-14.h5ad', 'output/diha_qc_Naive-B-cell_2024-03-14.h5ad', 'output/diha_qc_BR2_Female_Negative_Memory-CD4-T-cell_2024-03-14.h5ad', 'output/diha_qc_BR2_Male_Negative_CD14-monocyte_2024-03-13.h5ad', 'output/diha_qc_BR1_Male_Positive_CD14-monocyte_2024-03-13.h5ad', 'output/diha_qc_BR1_Female_Negative_Memory-CD4-T-cell_2024-03-14.h5ad', 'output/diha_qc_ASDC_2024-03-13.h5ad', 'output/diha_qc_BR1_Female_Positive_Naive-CD4-T-cell_2024-03-14.h5ad', 'output/diha_qc_Progenitor-cell_2024-03-14.h5ad', 'output/diha_qc_BR1_Male_Positive_Naive-CD4-T-cell_2024-03-14.h5ad', 'output/diha_qc_BR1_Male_Positive_Memory-CD4-T-cell_2024-03-14.h5ad', 'output/diha_qc_BR1_Female_Negative_Memory-CD8-T-cell_2024-03-14.h5ad', 'output/diha_qc_Intermediate-monocyte_2024-03-14.h5ad', 'output/diha_qc_BR1_Male_Negative_Memory-CD8-T-cell_2024-03-14.h5ad', 'output/diha_qc_BR2_Female_Negative_Naive-CD4-T-cell_2024-03-14.h5ad', 'output/diha_qc_DN-T-cell_2024-03-14.h5ad', 'output/diha_qc_Memory-B-cell_2024-03-14.h5ad', 'output/diha_qc_MAIT_2024-03-14.h5ad', 'output/diha_qc_Erythrocyte_2024-03-14.h5ad', 'output/diha_qc_BR1_Female_Positive_CD14-monocyte_2024-03-13.h5ad', 'output/diha_qc_BR1_Male_Negative_CD56dim-NK-cell_2024-03-14.h5ad', 'output/diha_qc_CD16-monocyte_2024-03-14.h5ad', 'output/diha_qc_BR2_Male_Negative_Memory-CD8-T-cell_2024-03-14.h5ad', 'output/diha_qc_BR2_Female_Negative_CD14-monocyte_2024-03-13.h5ad', 'output/diha_qc_BR2_Female_Positive_Memory-CD8-T-cell_2024-03-14.h5ad', 'output/diha_qc_BR2_Male_Positive_Memory-CD8-T-cell_2024-03-14.h5ad', 'output/diha_qc_BR2_Male_Negative_CD56dim-NK-cell_2024-03-14.h5ad', 'output/diha_qc_Proliferating-NK-cell_2024-03-14.h5ad', 'output/diha_qc_CD8aa_2024-03-14.h5ad', 'output/diha_qc_pDC_2024-03-14.h5ad', 'output/diha_qc_BR2_Female_Negative_CD56dim-NK-cell_2024-03-14.h5ad', 'output/diha_qc_BR1_Male_Negative_CD14-monocyte_2024-03-13.h5ad', 'output/diha_qc_BR1_Female_Negative_CD14-monocyte_2024-03-13.h5ad', 'output/diha_qc_BR2_Female_Positive_CD56dim-NK-cell_2024-03-14.h5ad', 'output/diha_qc_cDC2_2024-03-14.h5ad', 'output/diha_qc_BR2_Female_Positive_CD14-monocyte_2024-03-13.h5ad', 'output/diha_qc_BR1_Male_Positive_CD56dim-NK-cell_2024-03-14.h5ad', 'output/diha_qc_gdT_2024-03-14.h5ad', 'output/diha_qc_Treg_2024-03-14.h5ad', 'output/diha_qc_BR2_Male_Positive_CD56dim-NK-cell_2024-03-14.h5ad', 'output/diha_qc_BR1_Female_Negative_Naive-CD4-T-cell_2024-03-14.h5ad', 'output/diha_qc_BR1_Female_Positive_Memory-CD8-T-cell_2024-03-14.h5ad', 'output/diha_qc_Platelet_2024-03-14.h5ad', 'output/diha_qc_Transitional-B-cell_2024-03-14.h5ad', 'output/diha_qc_Plasma-cell_2024-03-14.h5ad', 'output/diha_qc_ILC_2024-03-14.h5ad', 'output/diha_qc_BR2_Male_Positive_CD14-monocyte_2024-03-13.h5ad', 'output/diha_qc_Naive-CD8-T-cell_2024-03-14.h5ad', 'output/diha_qc_CD56bright-NK-cell_2024-03-14.h5ad', 'output/diha_qc_BR2_Female_Positive_Naive-CD4-T-cell_2024-03-14.h5ad', 'output/diha_qc_BR2_Female_Negative_Memory-CD8-T-cell_2024-03-14.h5ad', 'output/diha_qc_BR2_Male_Positive_Memory-CD4-T-cell_2024-03-14.h5ad', 'output/diha_qc_BR2_Male_Negative_Memory-CD4-T-cell_2024-03-14.h5ad', 'output/diha_qc_BR1_Male_Negative_Naive-CD4-T-cell_2024-03-14.h5ad', 'output/diha_qc_cDC1_2024-03-14.h5ad', 'output/diha_qc_Effector-B-cell_2024-03-14.h5ad', 'output/diha_qc_Proliferating-T-cell_2024-03-14.h5ad', 'output/diha_qc_BR1_Female_Positive_Memory-CD4-T-cell_2024-03-14.h5ad']. Do you truly want to proceed?
# (y/n) y
# {'trace_id': '551c3ffa-5e00-4d11-b207-c17d77351076',
#  'files': ['output/diha_qc_BR1_Male_Negative_Memory-CD4-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Female_Positive_Memory-CD4-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR1_Female_Positive_CD56dim-NK-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR1_Male_Positive_Memory-CD8-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Male_Positive_Naive-CD4-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR1_Female_Negative_CD56dim-NK-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Male_Negative_Naive-CD4-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_Naive-B-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Female_Negative_Memory-CD4-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Male_Negative_CD14-monocyte_2024-03-13.h5ad',
#   'output/diha_qc_BR1_Male_Positive_CD14-monocyte_2024-03-13.h5ad',
#   'output/diha_qc_BR1_Female_Negative_Memory-CD4-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_ASDC_2024-03-13.h5ad',
#   'output/diha_qc_BR1_Female_Positive_Naive-CD4-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_Progenitor-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR1_Male_Positive_Naive-CD4-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR1_Male_Positive_Memory-CD4-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR1_Female_Negative_Memory-CD8-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_Intermediate-monocyte_2024-03-14.h5ad',
#   'output/diha_qc_BR1_Male_Negative_Memory-CD8-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Female_Negative_Naive-CD4-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_DN-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_Memory-B-cell_2024-03-14.h5ad',
#   'output/diha_qc_MAIT_2024-03-14.h5ad',
#   'output/diha_qc_Erythrocyte_2024-03-14.h5ad',
#   'output/diha_qc_BR1_Female_Positive_CD14-monocyte_2024-03-13.h5ad',
#   'output/diha_qc_BR1_Male_Negative_CD56dim-NK-cell_2024-03-14.h5ad',
#   'output/diha_qc_CD16-monocyte_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Male_Negative_Memory-CD8-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Female_Negative_CD14-monocyte_2024-03-13.h5ad',
#   'output/diha_qc_BR2_Female_Positive_Memory-CD8-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Male_Positive_Memory-CD8-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Male_Negative_CD56dim-NK-cell_2024-03-14.h5ad',
#   'output/diha_qc_Proliferating-NK-cell_2024-03-14.h5ad',
#   'output/diha_qc_CD8aa_2024-03-14.h5ad',
#   'output/diha_qc_pDC_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Female_Negative_CD56dim-NK-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR1_Male_Negative_CD14-monocyte_2024-03-13.h5ad',
#   'output/diha_qc_BR1_Female_Negative_CD14-monocyte_2024-03-13.h5ad',
#   'output/diha_qc_BR2_Female_Positive_CD56dim-NK-cell_2024-03-14.h5ad',
#   'output/diha_qc_cDC2_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Female_Positive_CD14-monocyte_2024-03-13.h5ad',
#   'output/diha_qc_BR1_Male_Positive_CD56dim-NK-cell_2024-03-14.h5ad',
#   'output/diha_qc_gdT_2024-03-14.h5ad',
#   'output/diha_qc_Treg_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Male_Positive_CD56dim-NK-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR1_Female_Negative_Naive-CD4-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR1_Female_Positive_Memory-CD8-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_Platelet_2024-03-14.h5ad',
#   'output/diha_qc_Transitional-B-cell_2024-03-14.h5ad',
#   'output/diha_qc_Plasma-cell_2024-03-14.h5ad',
#   'output/diha_qc_ILC_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Male_Positive_CD14-monocyte_2024-03-13.h5ad',
#   'output/diha_qc_Naive-CD8-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_CD56bright-NK-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Female_Positive_Naive-CD4-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Female_Negative_Memory-CD8-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Male_Positive_Memory-CD4-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR2_Male_Negative_Memory-CD4-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR1_Male_Negative_Naive-CD4-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_cDC1_2024-03-14.h5ad',
#   'output/diha_qc_Effector-B-cell_2024-03-14.h5ad',
#   'output/diha_qc_Proliferating-T-cell_2024-03-14.h5ad',
#   'output/diha_qc_BR1_Female_Positive_Memory-CD4-T-cell_2024-03-14.h5ad']}

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.10.3
# hisepy              0.3.0
# pandas              2.1.4
# scanpy              1.9.6
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.0.1
# anyio                       NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# beatrix_jupyterlab          NA
# brotli                      NA
# cachetools                  5.3.1
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# cloudpickle                 2.2.1
# colorama                    0.4.6
# comm                        0.1.4
# cryptography                41.0.7
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# db_dtypes                   1.1.1
# debugpy                     1.8.0
# decorator                   5.1.1
# defusedxml                  0.7.1
# deprecated                  1.2.14
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fqdn                        NA
# google                      NA
# greenlet                    2.0.2
# grpc                        1.58.0
# grpc_status                 NA
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.10.8
# importlib_metadata          NA
# ipykernel                   6.28.0
# ipython_genutils            0.2.0
# ipywidgets                  8.1.1
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.2
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.20.0
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.1
# jupyterlab_server           2.25.2
# jwt                         2.8.0
# kiwisolver                  1.4.5
# leidenalg                   0.10.1
# llvmlite                    0.41.0
# louvain                     0.8.1
# lz4                         4.3.2
# markupsafe                  2.1.3
# matplotlib                  3.8.0
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# mpmath                      1.3.0
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.58.0
# numpy                       1.24.0
# opentelemetry               NA
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                4.1.0
# plotly                      5.18.0
# prettytable                 3.9.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# proto                       NA
# psutil                      NA
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pyarrow                     13.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pynndescent                 0.5.11
# pynvml                      NA
# pyparsing                   3.1.1
# pyreadr                     0.5.0
# pythonjsonlogger            NA
# pytz                        2023.3.post1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.11.4
# send2trash                  NA
# shapely                     1.8.5.post1
# six                         1.16.0
# sklearn                     1.3.2
# sniffio                     1.3.0
# socks                       1.7.1
# sparse                      0.14.0
# sql                         NA
# sqlalchemy                  2.0.21
# sqlparse                    0.4.4
# stack_data                  0.6.2
# sympy                       1.12
# termcolor                   NA
# texttable                   1.7.0
# threadpoolctl               3.2.0
# torch                       2.1.2+cu121
# torchgen                    NA
# tornado                     6.3.3
# tqdm                        4.66.1
# traitlets                   5.9.0
# typing_extensions           NA
# umap                        0.5.5
# uri_template                NA
# urllib3                     1.26.18
# wcwidth                     0.2.12
# webcolors                   1.13
# websocket                   1.7.0
# wrapt                       1.15.0
# xarray                      2023.12.0
# yaml                        6.0.1
# zipp                        NA
# zmq                         25.1.2
# zoneinfo                    NA
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.19.0
# jupyter_client      8.6.0
# jupyter_core        5.6.1
# jupyterlab          4.1.2
# notebook            6.5.4
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-5.15.0-1042-gcp-x86_64-with-glibc2.31
# -----
# Session information updated at 2024-03-14 19:22
# </pre>
# </details>

# %% [markdown]
# # Assemble subset .h5ad files
#
# For QC and inspection of our cell type labels, we'll assemble samples based on subject metadata to get some reusable units that will be helpful for downstream analysis. We'll group subjects by their cohort (BR1 or BR2), biological sex (Female or Male), and CMV status (Negative or Positive). This should break up our very large dataset into chunks of a couple of million cells apiece.
#
# To each of these subsets, we'll add our CMV and BMI metadata, as well as cell type label predictions and scrublet scores and calls.
#
# We'll carry these subsets forward into QC filtering and cell type-based doublet and mislabeling clean-up in later notebooks.

# %% [markdown]
# ## Load Packages
#
# `anndata`: Data structures for scRNA-seq
# `datetime`: date and time functions
# `h5py`: HDF5 file I/O
# `hisepy`: The HISE SDK for Python
# `os`: operating system calls
# `pandas`: DataFrame data structures
# `re`: Regular expressions
# `scanpy`: scRNA-seq analysis
# `scipy.sparse`: Spare matrix data structures

# %%
import anndata
from datetime import date
import h5py
import hisepy
import os
import pandas as pd
from pandas.api.types import is_object_dtype
import re
import scanpy as sc
import scipy.sparse as scs

# %% [markdown]
# ## Helper functions

# %%
def cache_uuid_path(uuid):
    cache_path = '/home/jupyter/cache/{u}'.format(u = uuid)
    if not os.path.isdir(cache_path):
        hise_res = hisepy.reader.cache_files([uuid])
    filename = os.listdir(cache_path)[0]
    cache_file = '{p}/{f}'.format(p = cache_path, f = filename)
    return cache_file

# %%
def read_csv_uuid(uuid):
    cache_file = cache_uuid_path(uuid)
    res = pd.read_csv(cache_file)
    return res

# %%
def read_parquet_uuid(uuid):
    cache_file = cache_uuid_path(uuid)
    res = pd.read_parquet(cache_file)
    return res

# %% [markdown]
# Functions to read pipeline .h5 files as anndata

# %%
# define a function to read count data
def read_mat(h5_con):
    mat = scs.csc_matrix(
        (h5_con['matrix']['data'][:], # Count values
         h5_con['matrix']['indices'][:], # Row indices
         h5_con['matrix']['indptr'][:]), # Pointers for column positions
        shape = tuple(h5_con['matrix']['shape'][:]) # Matrix dimensions
    )
    return mat

# define a function to read obeservation metadata (i.e. cell metadata)
def read_obs(h5con):
    bc = h5con['matrix']['barcodes'][:]
    bc = [x.decode('UTF-8') for x in bc]

    # Initialized the DataFrame with cell barcodes
    obs_df = pd.DataFrame({ 'barcodes' : bc })

    # Get the list of available metadata columns
    obs_columns = h5con['matrix']['observations'].keys()
    
    # For each column
    for col in obs_columns:
        # Read the values
        values = h5con['matrix']['observations'][col][:]
        # Check for byte storage
        if(isinstance(values[0], (bytes, bytearray))):
            # Decode byte strings
            values = [x.decode('UTF-8') for x in values]
        # Add column to the DataFrame
        obs_df[col] = values

    obs_df = obs_df.set_index('barcodes', drop = False)
    
    return obs_df

# define a function to construct anndata object from a h5 file
def read_h5_anndata(h5_file):
    h5_con = h5py.File(h5_file, mode = 'r')
    # extract the expression matrix
    mat = read_mat(h5_con)
    # extract gene names
    genes = h5_con['matrix']['features']['name'][:]
    genes = [x.decode('UTF-8') for x in genes]
    # extract metadata
    obs_df = read_obs(h5_con)
    # construct anndata
    adata = anndata.AnnData(mat.T,
                             obs = obs_df)
    # make sure the gene names aligned
    adata.var_names = genes

    adata.var_names_make_unique()
    return adata

# %%
def element_id(n = 3):
    import periodictable
    from random import randrange
    rand_el = []
    for i in range(n):
        el = randrange(0,118)
        rand_el.append(periodictable.elements[el].name)
    rand_str = '-'.join(rand_el)
    return rand_str

# %% [markdown]
# ## Read sample metadata from HISE

# %%
in_uuids = {}

# %%
sample_meta_uuid = 'd82c5c42-ae5f-4e67-956e-cd3b7bf88105'
sample_meta = read_csv_uuid(sample_meta_uuid)
in_uuids['sample_meta'] = sample_meta_uuid
# Out:
# downloading fileID: d82c5c42-ae5f-4e67-956e-cd3b7bf88105
# Files have been successfully downloaded!

# %% [markdown]
# We only need to keep some of the metadata columns that pertain to cohort, subject, and sample. We'll also keep the originating File GUID to help us keep track of provenance. Let's select just these columns:

# %%
keep_meta = [
    'cohort.cohortGuid',
    'subject.subjectGuid', 'subject.biologicalSex', 
    'subject.race', 'subject.ethnicity', 'subject.birthYear',
    'sample.sampleKitGuid', 'sample.visitName', 'sample.drawDate',
    'file.id'
]

# %%
sample_meta = sample_meta[keep_meta]

# %%
cmv_meta_uuid = '9469f67c-b09a-454d-9fb9-f50ff3494d69'
cmv_meta = read_csv_uuid(cmv_meta_uuid)
in_uuids['cmv_meta'] = cmv_meta_uuid
# Out:
# downloading fileID: 9469f67c-b09a-454d-9fb9-f50ff3494d69
# Files have been successfully downloaded!

# %%
bmi_meta_uuid = 'e507258c-d175-4d8e-a455-5229870dc991'
bmi_meta = read_csv_uuid(bmi_meta_uuid)
in_uuids['bmi_meta'] = bmi_meta_uuid
# Out:
# downloading fileID: e507258c-d175-4d8e-a455-5229870dc991
# Files have been successfully downloaded!

# %% [markdown]
# ## Combine sample-level metadata

# %%
cmv_meta = cmv_meta[['subject.subjectGuid', 'subject.cmv']].drop_duplicates()

# %%
combined_sample_meta = sample_meta.merge(cmv_meta, on = 'subject.subjectGuid', how = 'left')

# %%
bmi_meta = bmi_meta[['sample.sampleKitGuid', 'subject.bmi']]

# %%
combined_sample_meta = combined_sample_meta.merge(bmi_meta, on = 'sample.sampleKitGuid', how = 'left')

# %%
combined_sample_meta.shape
# Out:
# (868, 12)

# %%
combined_sample_meta.head()
# Out:
#   cohort.cohortGuid subject.subjectGuid subject.biologicalSex subject.race  \
# 0               BR1              BR1001                Female    Caucasian
# 1               BR1              BR1002                  Male    Caucasian
# 2               BR1              BR1003                Female    Caucasian
# 3               BR1              BR1004                  Male    Caucasian
# 4               BR1              BR1005                Female    Caucasian
#
#      subject.ethnicity  subject.birthYear sample.sampleKitGuid  \
# 0  Non-Hispanic origin               1987              KT00001
# 1  Non-Hispanic origin               1991              KT00002
# 2  Non-Hispanic origin               1989              KT00003
# 3  Non-Hispanic origin               1989              KT00004
# 4  Non-Hispanic origin               1992              KT00006
#
#    sample.visitName       sample.drawDate  \
# 0  Flu Year 1 Day 0  2019-10-01T00:00:00Z
# 1  Flu Year 1 Day 0  2019-10-01T00:00:00Z
# 2  Flu Year 1 Day 0  2019-10-01T00:00:00Z
# 3  Flu Year 1 Day 0  2019-10-01T00:00:00Z
# 4  Flu Year 1 Day 0  2019-10-01T00:00:00Z
#
#                                 file.id subject.cmv  subject.bmi
# 0  fec489f9-9a74-4635-aa91-d2bf09d1faec    Negative    22.592400
# 1  7c0c7979-eebd-4aba-b5b2-6e76b4643623    Negative    22.332902
# 2  40efd03a-cb2f-4677-af42-a056cbfe5a17    Negative    20.956658
# 3  68fbcd34-1d63-461d-8195-df5b8dc61b31    Negative    21.502340
# 4  ea8d98e9-e99e-4dc6-9e78-9866e0deac68    Negative    20.484429

# %% [markdown]
# ## Read labels and doublet calls from HISE

# %%
l1_uuids = ['65c30bb1-111d-4137-9648-5db3f7d88386',
            'd7212d9f-49bc-4f23-94b2-cce164503dcb',
            '7534fb06-9aa6-4aa6-9813-2c3bbb92f9c1',
            '3935e870-cd4d-4daf-81dc-2e94bff46843']
l1_list = []
for l1_uuid in l1_uuids:
    l1_list.append(read_parquet_uuid(l1_uuid))
l1_labels = pd.concat(l1_list)
in_uuids['l1_labels'] = l1_uuids
# Out:
# downloading fileID: 65c30bb1-111d-4137-9648-5db3f7d88386
# Files have been successfully downloaded!
# downloading fileID: d7212d9f-49bc-4f23-94b2-cce164503dcb
# Files have been successfully downloaded!
# downloading fileID: 7534fb06-9aa6-4aa6-9813-2c3bbb92f9c1
# Files have been successfully downloaded!
# downloading fileID: 3935e870-cd4d-4daf-81dc-2e94bff46843
# Files have been successfully downloaded!

# %%
l1_labels = l1_labels[['barcodes', 'AIFI_L1', 'AIFI_L1_score']]

# %%
l2_uuids = ['d2d1d6bf-ea44-44b2-bfa5-09a5321a8ef0',
            '520156ca-bc37-4c7e-895d-fb2259d6ed1e',
            '3c45f3b2-2628-4e8d-8629-28ab8b1045dd',
            '55c53d17-1a31-4a37-8d67-06d8e4218df7']
l2_list = []
for l2_uuid in l2_uuids:
    l2_list.append(read_parquet_uuid(l2_uuid))
l2_labels = pd.concat(l2_list)
in_uuids['l2_labels'] = l2_uuids
# Out:
# downloading fileID: d2d1d6bf-ea44-44b2-bfa5-09a5321a8ef0
# Files have been successfully downloaded!
# downloading fileID: 520156ca-bc37-4c7e-895d-fb2259d6ed1e
# Files have been successfully downloaded!
# downloading fileID: 3c45f3b2-2628-4e8d-8629-28ab8b1045dd
# Files have been successfully downloaded!
# downloading fileID: 55c53d17-1a31-4a37-8d67-06d8e4218df7
# Files have been successfully downloaded!

# %%
l2_labels = l2_labels[['barcodes', 'AIFI_L2', 'AIFI_L2_score']]

# %%
doublet_uuid = 'b2bea832-a41e-4699-9d1d-a05a3ea1cf88'
doublet_labels = read_parquet_uuid(doublet_uuid)
in_uuids['doublet_labels'] = doublet_uuid
# Out:
# downloading fileID: b2bea832-a41e-4699-9d1d-a05a3ea1cf88
# Files have been successfully downloaded!

# %% [markdown]
# ## Combine label sets to simplify merges

# %%
all_labels = l1_labels.merge(l2_labels, on = 'barcodes', how = 'left')
all_labels = all_labels.merge(doublet_labels, on = 'barcodes', how = 'left')

# %%
all_labels.head()
# Out:
#                            barcodes AIFI_L1  AIFI_L1_score  \
# 0  a2d395708e7011ecb207eeccf5f10377  B cell       1.000000
# 1  a2d3982c8e7011ecb207eeccf5f10377  T cell       0.999465
# 2  a2d399d08e7011ecb207eeccf5f10377  T cell       0.999995
# 3  a2d39f668e7011ecb207eeccf5f10377  T cell       0.999990
# 4  a2d3a3948e7011ecb207eeccf5f10377  T cell       0.999990
#
#                AIFI_L2  AIFI_L2_score  predicted_doublet  doublet_score
# 0  Transitional B cell       0.998853              False       0.012551
# 1    Memory CD8 T cell       0.703823              False       0.038824
# 2                 MAIT       0.991137              False       0.028543
# 3                  gdT       0.999946              False       0.050659
# 4                 Treg       0.999947              False       0.034787

# %% [markdown]
# ## Define subsets

# %%
subset_columns = ['cohort.cohortGuid', 'subject.biologicalSex', 'subject.cmv']

# %%
subset_counts = combined_sample_meta[subset_columns].value_counts()
subset_counts
# Out:
# cohort.cohortGuid  subject.biologicalSex  subject.cmv
# BR2                Female                 Positive       163
# BR1                Female                 Negative       162
# BR2                Male                   Negative       116
# BR1                Male                   Negative       107
# BR2                Female                 Negative        91
#                    Male                   Positive        80
# BR1                Female                 Positive        76
#                    Male                   Positive        73
# Name: count, dtype: int64

# %%
subset_sample_meta = combined_sample_meta.groupby(subset_columns)

# %% [markdown]
# ## Read and assemble anndata objects for each subset

# %%
group_input_dict = {}
group_adata_dict = {}
for group, df in subset_sample_meta:
    group_name = '_'.join(group)
    #df = df.iloc[0:5] # Remove for full run
    group_uuids = df['file.id'].tolist()
    group_input_dict[group_name] = group_uuids

    # Cache files
    cache_dir = '/home/jupyter/cache'
    cache_paths = []
    for uuid in group_uuids:
        cache_path = '{d}/{u}'.format(d = cache_dir, u = uuid)
        if not os.path.isdir(cache_path):
            hise_res = hisepy.reader.cache_files([uuid])
        cache_paths.append(cache_path)

    # Get cached file paths
    cache_files = []
    for cache_path in cache_paths:
        fn = os.listdir(cache_path)[0]
        cache_files.append('{d}/{f}'.format(d = cache_path, f = fn))

    # Read cached files as anndata
    adata_list = []
    for cache_file in cache_files:
        adata = read_h5_anndata(cache_file)
        adata_list.append(adata)
    group_adata = sc.concat(adata_list)
    
    group_adata_dict[group_name] = group_adata
# Out:
# downloading fileID: fec489f9-9a74-4635-aa91-d2bf09d1faec
# Files have been successfully downloaded!
# downloading fileID: 1faf2b5f-66e4-4787-8a8b-487621fc4c08
# Files have been successfully downloaded!
# downloading fileID: cda87fcc-a50e-4c0f-b26c-482a6a88ef41
# Files have been successfully downloaded!
# downloading fileID: cd86a3b7-4955-4d76-9b2c-f076024a04eb
# Files have been successfully downloaded!
# downloading fileID: 9d5d8b77-6fb9-4f6c-8f0f-a24d87968962
# Files have been successfully downloaded!
# downloading fileID: 07528ecf-0d7d-4935-9244-b263883e69ca
# Files have been successfully downloaded!
# downloading fileID: 99c4ef81-a7b5-4828-ac71-fea1aa8b7580
# Files have been successfully downloaded!
# downloading fileID: dffa2241-a366-44ff-8f0a-894dd7cbbe6c
# Files have been successfully downloaded!
# downloading fileID: 2022f329-08b6-4b26-b71b-162bc30b19c9
# Files have been successfully downloaded!
# downloading fileID: 8513bba7-658f-4158-a73c-98845071abcf
# Files have been successfully downloaded!
# downloading fileID: 30faa01b-7e0a-41b5-a948-025aac545d4c
# Files have been successfully downloaded!
# downloading fileID: ca2fc682-b62b-4c05-a400-64c62f4c2933
# Files have been successfully downloaded!
# downloading fileID: 97da56b5-604c-4a29-9dff-c837c87dc885
# Files have been successfully downloaded!
# downloading fileID: 6cc1cc8c-f32a-4f95-bc18-c7031aeff2e9
# Files have been successfully downloaded!
# downloading fileID: f334c8fe-3b40-4882-8423-30303c0a38cf
# Files have been successfully downloaded!
# downloading fileID: 1eefbf6f-2f0d-4371-bad4-053989fe89a6
# Files have been successfully downloaded!
# downloading fileID: df0c9a12-7a8d-48df-9774-36891ba670c1
# Files have been successfully downloaded!
# downloading fileID: 8f355043-7aa5-4e33-8c6e-187905d32206
# Files have been successfully downloaded!
# downloading fileID: 47010438-5df6-43dc-81ee-a5d0e11559e2
# Files have been successfully downloaded!
# downloading fileID: 5900995c-f72b-4637-9673-11a32cb170b8
# Files have been successfully downloaded!
# downloading fileID: d3389b29-aec9-4596-814c-e83e124a3bd6
# Files have been successfully downloaded!
# downloading fileID: f6b968f9-44de-4798-9d3f-54150330c158
# Files have been successfully downloaded!
# downloading fileID: ed315c29-e352-4930-a682-1abed3194824
# Files have been successfully downloaded!
# downloading fileID: 0c6205b4-3a32-4143-b3c6-39b520eb3e26
# Files have been successfully downloaded!
# downloading fileID: 89659479-4bcf-4104-a9c3-52387b2a7c9b
# Files have been successfully downloaded!
# downloading fileID: 502644df-54a1-45b8-a279-f6898bf5b294
# Files have been successfully downloaded!
# downloading fileID: 92563925-e0bc-44f3-b254-69f18ce7f6d3
# Files have been successfully downloaded!
# downloading fileID: 07535f5b-003d-447e-a41d-cf742d885d34
# Files have been successfully downloaded!
# downloading fileID: 0d91b339-9bf1-4a9b-827a-dc829b91ede8
# Files have been successfully downloaded!
# downloading fileID: 4a3b72a0-c87a-4425-b954-136b3868cd4a
# Files have been successfully downloaded!
# downloading fileID: 96a931f2-7721-451b-9f8d-b2eaf3b5b029
# Files have been successfully downloaded!
# downloading fileID: 8dd5c8ca-5ff3-4bfd-aba7-dec02f78b750
# Files have been successfully downloaded!
# downloading fileID: 8147de2b-9fef-4d52-adce-08e31cabcbbe
# Files have been successfully downloaded!
# downloading fileID: 5efa981d-24d2-4dda-a101-1dbccbeb7991
# Files have been successfully downloaded!
# downloading fileID: 57a879d5-6423-469d-afdd-0e5d710f2735
# Files have been successfully downloaded!
# downloading fileID: df2a9523-a8ce-4b88-bab3-1d5af55252ef
# Files have been successfully downloaded!
# downloading fileID: 650a2d1d-397b-479b-a10e-51a8231ea391
# Files have been successfully downloaded!
# downloading fileID: e9bbd3da-49c1-462a-9f5a-a31866a7b97e
# Files have been successfully downloaded!
# downloading fileID: c15526e9-a198-4161-86f2-b60b72e46006
# Files have been successfully downloaded!
# downloading fileID: d1e4728c-b339-424f-a8a8-0704b5eee720
# Files have been successfully downloaded!
# downloading fileID: a2f81148-e9fa-48e2-8a5d-4548b9dbf2a4
# Files have been successfully downloaded!
# downloading fileID: 8ae55a23-07a8-484e-a250-9a0420de7e71
# Files have been successfully downloaded!
# downloading fileID: 55f8cd88-59b0-4a4f-bb8b-b5c23070e45e
# Files have been successfully downloaded!
# downloading fileID: 144ea1b3-d5b4-4639-bd9f-53415c90dac2
# Files have been successfully downloaded!
# downloading fileID: 5f2d6289-2eae-4849-b68c-48aa631eb279
# Files have been successfully downloaded!
# downloading fileID: d7660e92-a7f0-44e1-8d3e-4c571ea576f0
# Files have been successfully downloaded!
# downloading fileID: 04ad3351-8e26-44ad-8a0b-94158a66da79
# Files have been successfully downloaded!
# downloading fileID: f0ca9d87-c4fa-49f9-b390-2eb0e085cfdc
# Files have been successfully downloaded!
# downloading fileID: 8978e179-e899-442a-9ded-51611f6e4fd1
# Files have been successfully downloaded!
# downloading fileID: dbf57547-b1ac-4a0b-aa92-2c8989d37d17
# Files have been successfully downloaded!
# downloading fileID: d7530116-7c89-45f5-bf15-7522daee6b6c
# Files have been successfully downloaded!
# downloading fileID: 7516bd88-8037-4276-957a-451c595b4688
# Files have been successfully downloaded!
# downloading fileID: 9a22eebb-65dd-4886-808c-a16efe0b367d
# Files have been successfully downloaded!
# downloading fileID: e0de4f11-2544-4956-855c-487ba46d8951
# Files have been successfully downloaded!
# downloading fileID: 6ec1b183-72f0-44c1-89fe-00987af02143
# Files have been successfully downloaded!
# downloading fileID: b095fb97-abdc-4bc2-9048-371e2b178f74
# Files have been successfully downloaded!
# downloading fileID: 80b09375-4b7d-40be-a5db-55064d9d2002
# Files have been successfully downloaded!
# downloading fileID: 8d6a35ac-4481-43b2-ac62-cd6019b09d97
# Files have been successfully downloaded!
# downloading fileID: 0c657a97-9dad-44d6-b497-571318061038
# Files have been successfully downloaded!
# downloading fileID: f53f22be-ff27-4135-b15e-a2ea50b657a2
# Files have been successfully downloaded!
# downloading fileID: b8167d32-81cb-4f5c-8c4f-5fa4bba18319
# Files have been successfully downloaded!
# downloading fileID: 18e88dfd-7a92-467b-9585-0c8d8db7c76d
# Files have been successfully downloaded!
# downloading fileID: b62e216c-06ff-4817-b649-5b92355ad50e
# Files have been successfully downloaded!
# downloading fileID: 4ad72bf2-c01c-4088-8ee1-9aece50c4046
# Files have been successfully downloaded!
# downloading fileID: ae04a1a7-8c37-45d7-8377-b19b7aad66f1
# Files have been successfully downloaded!
# downloading fileID: db847942-83b7-495c-b347-59579b326652
# Files have been successfully downloaded!
# downloading fileID: 534292d1-cd8b-4e8e-b7a8-772a12bdf4b3
# Files have been successfully downloaded!
# downloading fileID: c49b84dc-e276-4829-bfb0-43fe1ef141b0
# Files have been successfully downloaded!
# downloading fileID: 8119b6dc-c11c-4329-968f-5f42d52ebd79
# Files have been successfully downloaded!
# downloading fileID: 536c5465-7aa4-4a8b-bb46-da92969f7494
# Files have been successfully downloaded!
# downloading fileID: d6042833-024f-43b9-98c1-c93a95f2cdc9
# Files have been successfully downloaded!
# downloading fileID: 61812fe7-345b-4069-adb6-163d3aa300c8
# Files have been successfully downloaded!
# downloading fileID: eb733e4a-f4c9-449f-ab06-3846b0f50a8b
# Files have been successfully downloaded!
# downloading fileID: 6c9d85f8-1b4d-4b61-8e0d-a6a641147e7e
# Files have been successfully downloaded!
# downloading fileID: fda4dbc8-529a-403a-85a7-f35a5955d196
# Files have been successfully downloaded!
# downloading fileID: bce1b68f-b241-4c32-8582-3905fa90469f
# Files have been successfully downloaded!
# downloading fileID: a7cc2716-cc24-47d1-9dca-99c31a4e0e04
# Files have been successfully downloaded!
# downloading fileID: e9f1b67f-6db8-46b2-8519-2af53a7cd26b
# Files have been successfully downloaded!
# downloading fileID: 75c9258d-760e-4b88-91f1-3aadeb21b8d7
# Files have been successfully downloaded!
# downloading fileID: eb2feb58-58f1-4adf-8359-05f6c0d5b2fe
# Files have been successfully downloaded!
# downloading fileID: 4b0b98c8-1a17-4f9f-865e-095ccf44a254
# Files have been successfully downloaded!
# downloading fileID: 12fc9dcc-0b27-4917-975d-2b8af8966ad8
# Files have been successfully downloaded!
# downloading fileID: a80badaf-0c05-45fa-96ea-356a74f77a68
# Files have been successfully downloaded!
# downloading fileID: 8e1057e3-ea20-4a3e-98e9-55b9ed21edb3
# Files have been successfully downloaded!
# downloading fileID: b67956b6-4f4c-40b9-b3bb-c2b5ce7734a1
# Files have been successfully downloaded!
# downloading fileID: 3245f331-7177-4acb-a9aa-756248c50959
# Files have been successfully downloaded!
# downloading fileID: bfa5ad1b-a5aa-42de-8ea7-542e3e86385d
# Files have been successfully downloaded!
# downloading fileID: e4301499-657b-430d-ad71-38ce71e30881
# Files have been successfully downloaded!
# downloading fileID: 3c66cb65-e28f-42fb-a278-fb65771b7a28
# Files have been successfully downloaded!
# downloading fileID: ee0a749a-2682-483d-af6f-2d44be5a424c
# Files have been successfully downloaded!
# downloading fileID: 1589aa62-23d6-435f-bad6-816b883576f7
# Files have been successfully downloaded!
# downloading fileID: d65a0da9-e77d-4bd7-b183-fb50d1a2258c
# Files have been successfully downloaded!
# downloading fileID: f8e4db45-8121-4d0c-98b9-509a26bf8c44
# Files have been successfully downloaded!
# downloading fileID: b6beb8a9-d553-4f43-a044-58c41ca50077
# Files have been successfully downloaded!
# downloading fileID: b516d1f6-3636-4e07-a6c3-c2055dede106
# Files have been successfully downloaded!
# downloading fileID: 14bc0bab-e76f-4939-b237-a8885159444e
# Files have been successfully downloaded!
# downloading fileID: 809bb99a-2665-4af8-8aac-3eadb593a22a
# Files have been successfully downloaded!
# downloading fileID: 3741f323-836b-4418-8d76-109461976931
# Files have been successfully downloaded!
# downloading fileID: 289942de-827d-4d1e-9dc8-60ecdad67283
# Files have been successfully downloaded!
# downloading fileID: f2c5d7ee-98d5-4a96-b052-16df981f35f2
# Files have been successfully downloaded!
# downloading fileID: fbfeb290-a628-4e4a-ae91-7599b63e66d6
# Files have been successfully downloaded!
# downloading fileID: eabf75f0-c16a-414b-be3a-bde462417e9d
# Files have been successfully downloaded!
# downloading fileID: 933ca418-a020-4531-941b-5c222dd9c659
# Files have been successfully downloaded!
# downloading fileID: f84c1453-34f1-4a5c-bbd1-865f7dc54c20
# Files have been successfully downloaded!
# downloading fileID: 231e3437-0ab2-4ac8-bc14-78665b9bdb12
# Files have been successfully downloaded!
# downloading fileID: d1666b9a-ce1c-4c3e-9d94-40c53ea9a948
# Files have been successfully downloaded!
# downloading fileID: f437e7a7-ea5a-4615-a113-267cc7c8133d
# Files have been successfully downloaded!
# downloading fileID: 41d2465e-e780-4bdc-9ee6-58f8d6d55b86
# Files have been successfully downloaded!
# downloading fileID: e4add0ba-4c43-4f67-bf22-b9b4a67563f2
# Files have been successfully downloaded!
# downloading fileID: 793d1f18-8abd-488b-9d5e-c8881147aca3
# Files have been successfully downloaded!
# downloading fileID: 156e4ec2-586d-450c-9a1e-5a51228a353d
# Files have been successfully downloaded!
# downloading fileID: aeb36ad5-d5f7-4b88-88f7-3cb1d5b4539e
# Files have been successfully downloaded!
# downloading fileID: 65971e40-0aad-44df-a7f2-d9bc1ac56f51
# Files have been successfully downloaded!
# downloading fileID: 9d2f90ed-d581-4d5f-a2fe-5ff80d6241fe
# Files have been successfully downloaded!
# downloading fileID: 27c35b51-898a-40e1-9cc8-c3c31b09874f
# Files have been successfully downloaded!
# downloading fileID: 49a52b7b-7a40-4c53-822f-edb89eb8e44c
# Files have been successfully downloaded!
# downloading fileID: 1ecf5979-2081-4de5-af85-8db8f56da46b
# Files have been successfully downloaded!
# downloading fileID: 0f53bbae-3a68-4834-a1fa-1fd4fc593bac
# Files have been successfully downloaded!
# downloading fileID: 2d470e1f-6401-46d3-bf0b-2084574fc005
# Files have been successfully downloaded!
# downloading fileID: 92539106-0b2e-4edb-afca-eb5c29da37f3
# Files have been successfully downloaded!
# downloading fileID: e361c795-cd40-424e-ae26-a7cfaa8e8134
# Files have been successfully downloaded!
# downloading fileID: 04936fd4-6e3f-4026-b9f6-10618a10a3c6
# Files have been successfully downloaded!
# downloading fileID: 6af11203-27dd-4f0b-9405-e9b73c2f90e4
# Files have been successfully downloaded!
# downloading fileID: dd387f77-9541-48fc-900e-2628babca252
# Files have been successfully downloaded!
# downloading fileID: 3823fb9e-79e2-487a-92b7-a44644dd2e21
# Files have been successfully downloaded!
# downloading fileID: e3814e93-e9fc-42d1-9f91-b039f5ad38e6
# Files have been successfully downloaded!
# downloading fileID: 8827dd87-f535-4fa6-b313-26e56260740c
# Files have been successfully downloaded!
# downloading fileID: 9ea4570f-2d6e-46e1-90fc-439f0c2c4dc7
# Files have been successfully downloaded!
# downloading fileID: 28fe412b-0e1b-460e-8ba6-022887f05f3f
# Files have been successfully downloaded!
# downloading fileID: 28e3d50f-640b-4008-9671-d87a1f4b00b0
# Files have been successfully downloaded!
# downloading fileID: 14ab3acd-6958-46aa-93d0-fe6ab6575d80
# Files have been successfully downloaded!
# downloading fileID: 1913ea88-d918-4059-b76d-e50cdc77a29e
# Files have been successfully downloaded!
# downloading fileID: 54dd3fae-78dc-4821-a6ba-5dab647f95a9
# Files have been successfully downloaded!
# downloading fileID: 033df296-b45d-427d-93be-4efdf182943b
# Files have been successfully downloaded!
# downloading fileID: d23768d0-87bc-480e-b2f7-a66049150501
# Files have been successfully downloaded!
# downloading fileID: 7d6daf23-5a5c-42b1-9b53-5c1f467f67c5
# Files have been successfully downloaded!
# downloading fileID: 835a1fdc-6835-4929-b3cf-1553107d4277
# Files have been successfully downloaded!
# downloading fileID: 805f66ef-a580-422a-a8e3-9edea812e8c6
# Files have been successfully downloaded!
# downloading fileID: baac95b5-c318-4650-9a21-96772f393ce2
# Files have been successfully downloaded!
# downloading fileID: e51a7298-24f6-4955-9343-dbe339dcbda3
# Files have been successfully downloaded!
# downloading fileID: e2688d08-7582-48b6-95a3-54b7140390ba
# Files have been successfully downloaded!
# downloading fileID: f53f6abf-f281-47e5-8764-1ec431042f07
# Files have been successfully downloaded!
# downloading fileID: 41485392-e9e5-40d2-9021-f979dbffa5c7
# Files have been successfully downloaded!
# downloading fileID: e3dd5a9d-7e4c-4fd8-a8fe-0d26ece97e4a
# Files have been successfully downloaded!
# downloading fileID: 324926d5-4ed6-48af-8938-c11f4f773381
# Files have been successfully downloaded!
# downloading fileID: 47788d8d-3a9f-461c-adb6-47eb53cb736f
# Files have been successfully downloaded!
# downloading fileID: 7bce341f-b615-48b7-b531-70c50816a921
# Files have been successfully downloaded!
# downloading fileID: 20da693f-5152-4e8d-8ef9-d4ed6a7b2c06
# Files have been successfully downloaded!
# downloading fileID: 8b457c66-25b0-4eac-81fa-5104bb49d766
# Files have been successfully downloaded!
# downloading fileID: 3df53931-ac80-4788-b1aa-d5bd0be64438
# Files have been successfully downloaded!
# downloading fileID: 0f83da89-a849-497e-ab48-42f9d4f001d5
# Files have been successfully downloaded!
# downloading fileID: 4aac1b5d-8426-4c30-8b76-ff8ee3ccb1a8
# Files have been successfully downloaded!
# downloading fileID: 52c8506e-7962-4ea0-8ce3-4c8fe8b5c557
# Files have been successfully downloaded!
# downloading fileID: e0537a81-d569-4dcb-bf7e-9a7717985b11
# Files have been successfully downloaded!
# downloading fileID: fd3c6a7b-04e5-4db0-af88-395b193af921
# Files have been successfully downloaded!
# downloading fileID: 90973814-229e-4a10-a49e-d0225b9de2c5
# Files have been successfully downloaded!
# downloading fileID: bfe6fada-e910-4b66-8aaa-a4b3d8920269
# Files have been successfully downloaded!
# downloading fileID: d16572d9-68d5-451c-9d68-f2b865cb23d5
# Files have been successfully downloaded!
# downloading fileID: 6b56d9d1-8b41-41cc-9ab0-1202c9ee877d
# Files have been successfully downloaded!
# downloading fileID: 7a99c4c8-5438-430a-a37a-5b5f4052c064
# Files have been successfully downloaded!
# downloading fileID: 4980030b-919e-4ca6-87fb-29b9163d393c
# Files have been successfully downloaded!
# downloading fileID: 9114124c-af57-47a7-bde3-ade4a150ac82
# Files have been successfully downloaded!
# downloading fileID: 6faaf111-1d15-47f5-ac83-eef28728c221
# Files have been successfully downloaded!
# downloading fileID: 4865c903-937d-41f6-ae85-82531011af5a
# Files have been successfully downloaded!
# downloading fileID: 5b74b13b-d951-4d55-88d2-0f3b5f22842a
# Files have been successfully downloaded!
# downloading fileID: 57f4ee83-5d68-499f-9dc2-03308c37a840
# Files have been successfully downloaded!
# downloading fileID: f7639a2a-f833-4aa6-b44e-f8f82c1be5ec
# Files have been successfully downloaded!
# downloading fileID: 34647c08-376a-44b9-a4da-149f218fae76
# Files have been successfully downloaded!
# downloading fileID: 251959c4-7df6-47bc-a71e-6f4e223a6c44
# Files have been successfully downloaded!
# downloading fileID: e54ead6d-e791-45b3-9666-6e7eba354378
# Files have been successfully downloaded!
# downloading fileID: 6cf9099b-6757-4f3d-87c0-bcdd7968ca5c
# Files have been successfully downloaded!
# downloading fileID: 697e0c9d-fab5-4dbf-8de1-8f7d5dc16895
# Files have been successfully downloaded!
# downloading fileID: cc4a7cfa-823a-4c8c-84e3-d8d0e95b3dab
# Files have been successfully downloaded!
# downloading fileID: 1bb95779-064e-4aff-8ae4-9f53ac53198f
# Files have been successfully downloaded!
# downloading fileID: 61222559-31ed-4257-9b59-c25efbba7bfb
# Files have been successfully downloaded!
# downloading fileID: 50e0228b-9d67-45a2-a5ee-a73ee6ab2a95
# Files have been successfully downloaded!
# downloading fileID: db99298a-23b2-488b-ae6c-4da161e1fca6
# Files have been successfully downloaded!
# downloading fileID: 83ad0b29-37c2-4644-8d03-9c0e13a99515
# Files have been successfully downloaded!
# downloading fileID: a124448e-9698-40d1-9ab2-0cb84561907c
# Files have been successfully downloaded!
# downloading fileID: 0dba018c-1787-4dc4-b385-9ee5af0385e8
# Files have been successfully downloaded!
# downloading fileID: de2f315a-7c23-4f06-b3be-914ad09a3cdc
# Files have been successfully downloaded!
# downloading fileID: b98f0e67-482b-4eaa-b795-bc8977084d14
# Files have been successfully downloaded!
# downloading fileID: eb88af98-2efc-4392-a653-db289f2bb115
# Files have been successfully downloaded!
# downloading fileID: 1b323268-7ea5-49de-a10e-d085b8c5ca69
# Files have been successfully downloaded!
# downloading fileID: 6f77c7c2-52d2-48b1-a7a9-d4154ff3ef38
# Files have been successfully downloaded!
# downloading fileID: ea52d9d6-c1c8-42f1-be3b-84e522ff6bd1
# Files have been successfully downloaded!
# downloading fileID: 77ebc989-f6e1-4f7e-9485-d8be8a1340d5
# Files have been successfully downloaded!
# downloading fileID: 8cb06afd-be05-40c6-8fbd-f9ebba9c0692
# Files have been successfully downloaded!
# downloading fileID: e9640d6b-96bb-4b79-b1d4-48d0c14417f7
# Files have been successfully downloaded!
# downloading fileID: 0f5d53e5-5799-4d4e-b70a-8b75021d660e
# Files have been successfully downloaded!
# downloading fileID: e9f52a27-69f7-4172-8968-8d174a247fbc
# Files have been successfully downloaded!
# downloading fileID: b81bd6e8-44ff-4a4b-8214-eb7718e6559f
# Files have been successfully downloaded!
# downloading fileID: 05f0ad64-5686-4161-900a-a7a5e8f92f04
# Files have been successfully downloaded!
# downloading fileID: 4ac47e0f-2bd5-48c8-9278-d280ed91e778
# Files have been successfully downloaded!
# downloading fileID: 0f524e3e-fe21-4af6-a0fb-a494d11e20d7
# Files have been successfully downloaded!
# downloading fileID: 26938f5a-c5ca-4abe-956f-08728076be2a
# Files have been successfully downloaded!
# downloading fileID: c4dcfa12-c487-42d6-b09a-f615721bead5
# Files have been successfully downloaded!
# downloading fileID: 3cd3ad80-f438-466a-a7f8-4acc74f54490
# Files have been successfully downloaded!
# downloading fileID: f033f7cd-bb5d-400e-830f-eb757388a54c
# Files have been successfully downloaded!
# downloading fileID: ed770dce-8059-401f-a019-ba6ea9e4eb21
# Files have been successfully downloaded!
# downloading fileID: 5dce5434-3aa7-4b0b-881b-c9989e21de20
# Files have been successfully downloaded!
# downloading fileID: 8196a87e-5a7a-48ba-afb4-33bb4897b9d3
# Files have been successfully downloaded!
# downloading fileID: a892cf86-0461-4738-a0e6-9cea3d163986
# Files have been successfully downloaded!
# downloading fileID: 946bd2a0-f6f5-4673-9ae5-4943a8bc3f06
# Files have been successfully downloaded!
# downloading fileID: 87988b81-cba2-4d9e-8a1c-f4b425a183ce
# Files have been successfully downloaded!
# downloading fileID: efbe2dfd-64d7-486d-98f0-88775d635674
# Files have been successfully downloaded!
# downloading fileID: 4e6839a7-95e2-4e14-bd90-3eb6040d3f3b
# Files have been successfully downloaded!
# downloading fileID: 0327efc5-3c81-4066-b20d-bed394a1d51a
# Files have been successfully downloaded!
# downloading fileID: 6028b8d4-bb32-412e-8fcf-8eb3cbb6352d
# Files have been successfully downloaded!
# downloading fileID: 4c6bc75c-a793-48ae-90b6-345caa7745eb
# Files have been successfully downloaded!
# downloading fileID: bb198d11-5562-4d6d-8a03-c34b5b011179
# Files have been successfully downloaded!
# downloading fileID: c3125cbc-0c01-49c3-9c35-699c6c0826a9
# Files have been successfully downloaded!
# downloading fileID: 722b7497-6cf5-49f6-ab4c-7bbe9731cde0
# Files have been successfully downloaded!
# downloading fileID: 2a552fd9-98f1-44d7-a587-3d8200fa62c5
# Files have been successfully downloaded!
# downloading fileID: 9758187f-d34a-462a-a273-162aad530596
# Files have been successfully downloaded!
# downloading fileID: 76ac2ba6-3ed1-4569-837f-d79fb8c6e765
# Files have been successfully downloaded!
# downloading fileID: 9fc0e199-a8dc-4b01-9ef7-c70ceb6d07b1
# Files have been successfully downloaded!
# downloading fileID: aaca43a9-a0bd-405a-bc5d-4c19c0329ed3
# Files have been successfully downloaded!
# downloading fileID: c102ab88-a8ac-476f-8506-37b6500760f2
# Files have been successfully downloaded!
# downloading fileID: 46f5b3a1-ccbd-451a-9214-39b7d7b2bfa2
# Files have been successfully downloaded!
# downloading fileID: b98f9286-3246-4651-a6df-62a480edba28
# Files have been successfully downloaded!
# downloading fileID: 961cd967-ce23-49a1-af6e-532c873ba3f3
# Files have been successfully downloaded!
# downloading fileID: ded9fd83-9f71-4b24-95ec-fb74463d22d9
# Files have been successfully downloaded!
# downloading fileID: c4a8a627-3184-4f06-85a2-df53da4217d8
# Files have been successfully downloaded!
# downloading fileID: 372bdfa6-eea8-4e26-b967-8b40895ec5fa
# Files have been successfully downloaded!
# downloading fileID: fd4052e7-d9e9-48de-8a67-d50e271aa804
# Files have been successfully downloaded!
# downloading fileID: 586b4983-ae26-4370-9eb6-c52b810c6543
# Files have been successfully downloaded!
# downloading fileID: 897f7304-ed36-4e42-a7d0-74967b63251b
# Files have been successfully downloaded!
# downloading fileID: d3b6c040-3c71-4f4d-8e40-0655dde37b9c
# Files have been successfully downloaded!
# downloading fileID: 84b398fe-cf74-4ef8-af6b-72aabcd9178b
# Files have been successfully downloaded!
# downloading fileID: 10d6568f-f8a9-4b8e-a384-25a0955caa4a
# Files have been successfully downloaded!
# downloading fileID: dd7df401-8005-44be-9da9-bf54efc65475
# Files have been successfully downloaded!
# downloading fileID: d1f262db-6fbd-4adf-b2d1-aafafe5e72eb
# Files have been successfully downloaded!
# downloading fileID: a563f08f-3d41-4435-b94c-04b95e982cde
# Files have been successfully downloaded!
# downloading fileID: 7c0c7979-eebd-4aba-b5b2-6e76b4643623
# Files have been successfully downloaded!
# downloading fileID: 68fbcd34-1d63-461d-8195-df5b8dc61b31
# Files have been successfully downloaded!
# downloading fileID: 4797becf-1e94-48fe-b78d-858740f75364
# Files have been successfully downloaded!
# downloading fileID: 237e41df-5616-4852-8a8f-b32835c9efcb
# Files have been successfully downloaded!
# downloading fileID: 7d2d66c4-aacc-4666-bfc2-638c7c76560e
# Files have been successfully downloaded!
# downloading fileID: f44ab1b8-ea74-47b7-8395-b5909254f67d
# Files have been successfully downloaded!
# downloading fileID: 247d580e-7b47-4f59-bc37-6e29188b7aff
# Files have been successfully downloaded!
# downloading fileID: 4d075c3d-1fb6-4464-a8d3-68987b638100
# Files have been successfully downloaded!
# downloading fileID: fdd6d672-8dcf-4802-8555-8ea7e73a9d2d
# Files have been successfully downloaded!
# downloading fileID: a71ce5da-6448-4e0f-8046-a510700bf4d2
# Files have been successfully downloaded!
# downloading fileID: 44cba3cd-d577-461d-8534-48b1ba85ac8f
# Files have been successfully downloaded!
# downloading fileID: d133cce0-1339-4082-88a0-471ecd011279
# Files have been successfully downloaded!
# downloading fileID: 76c1b860-541e-452d-a482-a0b4ce46d95b
# Files have been successfully downloaded!
# downloading fileID: 9c0baf87-0186-45a3-8b4d-eab7359d3140
# Files have been successfully downloaded!
# downloading fileID: ad749fe6-fb04-4dce-9c1d-0abc097b9837
# Files have been successfully downloaded!
# downloading fileID: 9c3c91fd-6d79-411e-ba01-6471ae34c39e
# Files have been successfully downloaded!
# downloading fileID: 3455441a-f8ff-4834-bc77-ae01f1bb991f
# Files have been successfully downloaded!
# downloading fileID: 9840143d-e1c6-46ab-aa37-2673ab63043c
# Files have been successfully downloaded!
# downloading fileID: e77c5398-56f8-4ab5-93dc-0dfc8abae54b
# Files have been successfully downloaded!
# downloading fileID: 5338486a-e70e-47da-9c20-84ffeea8cd60
# Files have been successfully downloaded!
# downloading fileID: 440e78dc-dd73-49f6-8db9-92c1b364fd91
# Files have been successfully downloaded!
# downloading fileID: d607db62-b5ea-4155-908f-c5f808d0e14d
# Files have been successfully downloaded!
# downloading fileID: aef3495c-09c8-4ea0-ad75-dd46462f842b
# Files have been successfully downloaded!
# downloading fileID: 1742df66-8ccd-4e25-a304-c943d3fb02b7
# Files have been successfully downloaded!
# downloading fileID: 6986301c-56b6-4d48-a94d-3eb6b2b3ee8e
# Files have been successfully downloaded!
# downloading fileID: 809f0be2-6ddc-4b3e-9c90-ffa4262f0a88
# Files have been successfully downloaded!
# downloading fileID: d9964082-5ce0-458a-b7b8-5e6112ef74e5
# Files have been successfully downloaded!
# downloading fileID: 19a86c99-ae6e-4b47-8bab-8d5751cc5d78
# Files have been successfully downloaded!
# downloading fileID: bd9fb5ec-23f3-4111-95df-a7f5c7f42e35
# Files have been successfully downloaded!
# downloading fileID: 442f1fa9-edeb-4f15-b695-f9d4484e7b89
# Files have been successfully downloaded!
# downloading fileID: 7bd45c7b-1c87-482a-a5d5-0de22cd2b23b
# Files have been successfully downloaded!
# downloading fileID: 36e16088-fc92-4b15-addf-f8c15eb7c872
# Files have been successfully downloaded!
# downloading fileID: 05c94047-a51d-477d-82d8-468afc9730b8
# Files have been successfully downloaded!
# downloading fileID: 329b1c76-1018-42b2-bdae-96a4c0da1a6e
# Files have been successfully downloaded!
# downloading fileID: 898348fc-40ea-4349-84fc-06b57735818d
# Files have been successfully downloaded!
# downloading fileID: 94a95eca-fa6a-4a7d-b7ff-1081ebe681fa
# Files have been successfully downloaded!
# downloading fileID: c2037820-71ae-49d8-808b-38b5e9b7dbe0
# Files have been successfully downloaded!
# downloading fileID: 13d81b61-3e7d-4d87-a859-9da3de2fb6cd
# Files have been successfully downloaded!
# downloading fileID: 7cfa4d1b-07a2-4e36-ab69-3dc58ea28355
# Files have been successfully downloaded!
# downloading fileID: c3c4c032-98b6-452a-b39e-02eddd9d64ff
# Files have been successfully downloaded!
# downloading fileID: a1017664-2cae-4155-9d78-9c80eb5fc8d4
# Files have been successfully downloaded!
# downloading fileID: 37a0a0ca-23d5-47b3-8f85-49d18cbaa491
# Files have been successfully downloaded!
# downloading fileID: 2da682f6-0f1a-48b9-bf99-59a5638af9f4
# Files have been successfully downloaded!
# downloading fileID: dc553ce5-73d6-4a7a-9828-1545119d56a3
# Files have been successfully downloaded!
# downloading fileID: 0b74a4a3-ee61-4f44-bc97-e3b0b62d0c55
# Files have been successfully downloaded!
# downloading fileID: 82c69933-6514-409b-86f2-8b68366a4c63
# Files have been successfully downloaded!
# downloading fileID: 21b1ca19-82ff-435e-9924-52e8543a5dee
# Files have been successfully downloaded!
# downloading fileID: 29c74f78-a58c-449b-a310-4c428c6cba2a
# Files have been successfully downloaded!
# downloading fileID: d6789700-c0a2-4aab-af42-c6026ffbdab2
# Files have been successfully downloaded!
# downloading fileID: 5ae04a10-4dcb-483b-ad76-33ea860fe7b7
# Files have been successfully downloaded!
# downloading fileID: f25a148f-3330-4870-8550-9d09933871fb
# Files have been successfully downloaded!
# downloading fileID: c554c9e0-fd87-4014-b8b7-7d722509cb96
# Files have been successfully downloaded!
# downloading fileID: f39efe2e-cc16-47f7-a2ee-8f185f6871ee
# Files have been successfully downloaded!
# downloading fileID: ee11bd74-5adb-4bbc-a769-ca54c2a3b68a
# Files have been successfully downloaded!
# downloading fileID: 29b95d60-3b32-4579-ad33-fac0cb3228bc
# Files have been successfully downloaded!
# downloading fileID: 1026cf1a-1219-4fd7-a110-f02ff661a2b1
# Files have been successfully downloaded!
# downloading fileID: 0619fbad-efd2-4612-90d6-b1a145467404
# Files have been successfully downloaded!
# downloading fileID: 44683694-c5c7-425a-80b9-6d8e64f0f7ab
# Files have been successfully downloaded!
# downloading fileID: f081055f-4bb2-4594-a34a-27113f3a15a2
# Files have been successfully downloaded!
# downloading fileID: 7c8f2e8f-757f-407c-a6a2-ed544bd88cfe
# Files have been successfully downloaded!
# downloading fileID: 61b6f746-2212-4965-9f9a-8b14a61a313a
# Files have been successfully downloaded!
# downloading fileID: a9e0c494-ac91-424d-8623-9652af142ad5
# Files have been successfully downloaded!
# downloading fileID: ed28e808-3d67-4a69-9ebf-e72224da8133
# Files have been successfully downloaded!
# downloading fileID: 281546d3-90b7-4519-86f6-485ec52f8790
# Files have been successfully downloaded!
# downloading fileID: 89d35aff-67af-4a7e-98a2-8bea5cf3e92f
# Files have been successfully downloaded!
# downloading fileID: 6f926b3b-be90-41b1-8022-9e7b626e4975
# Files have been successfully downloaded!
# downloading fileID: 2b0b0d32-83ac-41a7-8580-74fa931e11cc
# Files have been successfully downloaded!
# downloading fileID: b7eb8f4c-4592-45b4-b638-fb4d044505bd
# Files have been successfully downloaded!
# downloading fileID: e9276469-160d-4caa-954a-371c10d0b136
# Files have been successfully downloaded!
# downloading fileID: ae7b26dd-876e-4a6a-bafd-0575b5a50c7e
# Files have been successfully downloaded!
# downloading fileID: 61f0f750-28b2-4420-8383-018db93f9350
# Files have been successfully downloaded!
# downloading fileID: 65b7d82e-20b9-406a-a63b-a2330e80542d
# Files have been successfully downloaded!
# downloading fileID: 588321d4-a7b2-45be-872b-c90fd56b720f
# Files have been successfully downloaded!
# downloading fileID: d81fc71a-7c3f-4b6a-8f48-0f6163801ac9
# Files have been successfully downloaded!
# downloading fileID: 68494f13-e065-4023-80ec-455fc2175011
# Files have been successfully downloaded!
# downloading fileID: 9949058e-32d8-4dc3-b44c-06eb7c274754
# Files have been successfully downloaded!
# downloading fileID: 24b56624-e60e-476d-b096-1b3f19b1acf2
# Files have been successfully downloaded!
# downloading fileID: 139482ca-4101-4579-b490-ff96d2c77bb2
# Files have been successfully downloaded!
# downloading fileID: 8e76244d-99d7-4025-8df0-1246ffd875da
# Files have been successfully downloaded!
# downloading fileID: 6909d26e-e4d0-4325-85cb-07d44dfaea89
# Files have been successfully downloaded!
# downloading fileID: 50f266ea-6f55-459d-93a2-c5c924b4be92
# Files have been successfully downloaded!
# downloading fileID: cf4b798f-f54c-4ceb-bee1-118200191111
# Files have been successfully downloaded!
# downloading fileID: 77474297-8c4b-4da9-84a0-59ff3ddeb68c
# Files have been successfully downloaded!
# downloading fileID: b6bde212-6975-47c0-a3f2-f90398f7350e
# Files have been successfully downloaded!
# downloading fileID: 1883ccdd-7b0a-460c-9847-f95e8d140256
# Files have been successfully downloaded!
# downloading fileID: b8fadfec-28b3-46c1-a193-3e1362b80dc6
# Files have been successfully downloaded!
# downloading fileID: 5b1a1f23-eb2d-4e38-9e4e-edc8bace3c6a
# Files have been successfully downloaded!
# downloading fileID: 478a37ae-367e-44df-82ac-a519571f39ac
# Files have been successfully downloaded!
# downloading fileID: 2caf5da2-57ae-468c-a1c8-8f42041af2db
# Files have been successfully downloaded!
# downloading fileID: 465a702c-3808-4654-96a2-0e7f0fa82053
# Files have been successfully downloaded!
# downloading fileID: 7ef81ce4-0154-4e94-9f4e-75e4f8cbe9d3
# Files have been successfully downloaded!
# downloading fileID: ebd6cac6-2585-4684-947e-c82cc1385335
# Files have been successfully downloaded!
# downloading fileID: 6ee2b15f-e5ed-4a8b-8245-ac84d167fe91
# Files have been successfully downloaded!
# downloading fileID: 331af24a-2e69-4040-8569-b80c79245d3c
# Files have been successfully downloaded!
# downloading fileID: 3d4d2fd5-cbdf-4ecc-943f-6c9530c4d65d
# Files have been successfully downloaded!
# downloading fileID: 8b65e6d4-4f29-46f0-b767-b5e38253c0d5
# Files have been successfully downloaded!
# downloading fileID: 3ead596a-3689-44f1-a50a-a49368ee010b
# Files have been successfully downloaded!
# downloading fileID: 36993b57-a278-4f36-a40a-e09ccb608c31
# Files have been successfully downloaded!
# downloading fileID: b76e3a62-7647-407a-8953-185c33ddc8fa
# Files have been successfully downloaded!
# downloading fileID: 25a56088-9609-44f8-b7ea-f8d5b6189f00
# Files have been successfully downloaded!
# downloading fileID: e9488942-c84b-414a-8833-6f81d50ce195
# Files have been successfully downloaded!
# downloading fileID: 341b24ba-0c6d-45a3-9b5a-22c57a234e05
# Files have been successfully downloaded!
# downloading fileID: 8cbe3cbe-f065-4cc6-9727-08b21f92cf68
# Files have been successfully downloaded!
# downloading fileID: 4515d846-5003-4a25-ad03-f906f9733207
# Files have been successfully downloaded!
# downloading fileID: f335b60f-8cfa-499a-b93f-2fe9a74b979e
# Files have been successfully downloaded!
# downloading fileID: 123395e9-cc7f-4a32-93da-a5451d3d15bc
# Files have been successfully downloaded!
# downloading fileID: 133dd259-8450-4043-a131-ba37e7ec2eee
# Files have been successfully downloaded!
# downloading fileID: fbcbf51d-90f8-46ff-bd21-2f56d65306ad
# Files have been successfully downloaded!
# downloading fileID: 133389ad-3aa1-4be2-963b-f9d20758d42f
# Files have been successfully downloaded!
# downloading fileID: 139d1b1f-75d8-40ab-bcb5-70bd2cde9800
# Files have been successfully downloaded!
# downloading fileID: 3b4008bc-ee02-4944-80c9-7c99490bf607
# Files have been successfully downloaded!
# downloading fileID: 618b987c-700c-4f55-8217-0261302b7adf
# Files have been successfully downloaded!
# downloading fileID: ad208f42-6d75-40fa-afe5-c4dc71b3fdb6
# Files have been successfully downloaded!
# downloading fileID: fa9dc299-5b83-42b4-a90e-813359a58303
# Files have been successfully downloaded!
# downloading fileID: 41c53a83-5de4-45bf-9e33-af72a3fa3e22
# Files have been successfully downloaded!
# downloading fileID: bc9e18bc-d2f6-4e5d-a947-793967131eac
# Files have been successfully downloaded!
# downloading fileID: ca27497b-afcc-4bd0-bc10-863478add638
# Files have been successfully downloaded!
# downloading fileID: 9a7796ef-aa65-45b2-8942-b1897fcbbf40
# Files have been successfully downloaded!
# downloading fileID: 1b3416ca-81d0-4f1f-88ca-361885f2f083
# Files have been successfully downloaded!
# downloading fileID: 3d8bb11e-5fa4-46e8-a0b3-84df817f525b
# Files have been successfully downloaded!
# downloading fileID: 62bc926f-5113-464e-9cf5-1bdb68eba31d
# Files have been successfully downloaded!
# downloading fileID: d990f404-8f38-4bdc-8029-b36532ebbb0d
# Files have been successfully downloaded!
# downloading fileID: d3745aa4-da0b-45e1-bcb2-a68c969f436a
# Files have been successfully downloaded!
# downloading fileID: 62b54470-044a-403c-aa3c-ca3d101bc1eb
# Files have been successfully downloaded!
# downloading fileID: d8f8bffa-f672-4c2d-8aff-af19081f53d0
# Files have been successfully downloaded!
# downloading fileID: 9e1c89a4-faa1-457c-8fa5-390a9935b1d3
# Files have been successfully downloaded!
# downloading fileID: bf4259af-db7a-4423-82e9-b047289ba95b
# Files have been successfully downloaded!
# downloading fileID: 59cafe2c-5f6d-4043-8d6f-97f2f6f1a279
# Files have been successfully downloaded!
# downloading fileID: 42fad404-2c15-4d09-9d5e-4d54301ac9fc
# Files have been successfully downloaded!
# downloading fileID: c313baa6-6fc9-4809-82fa-41651ba29e9e
# Files have been successfully downloaded!
# downloading fileID: 2f0b80ff-7e8a-4399-8ec0-12c21939e620
# Files have been successfully downloaded!
# downloading fileID: fe219421-b9dd-4963-8e28-1ace3dff556c
# Files have been successfully downloaded!
# downloading fileID: 100a261f-a488-4afe-9b2d-4b92922d91f6
# Files have been successfully downloaded!
# downloading fileID: 272990d2-757e-4044-b4dd-b72d412175a4
# Files have been successfully downloaded!
# downloading fileID: 23a042c8-4c95-4cc8-a545-744b1dcccd5d
# Files have been successfully downloaded!
# downloading fileID: 00a3f4b2-9499-48b6-807e-1d019afe19eb
# Files have been successfully downloaded!
# downloading fileID: 08392ded-f5bb-4a22-9736-4df542a73764
# Files have been successfully downloaded!
# downloading fileID: b524b286-f54e-4dae-b28e-e275eff67931
# Files have been successfully downloaded!
# downloading fileID: eed25e59-dfa7-4099-a7d8-9d21d91009de
# Files have been successfully downloaded!
# downloading fileID: c0e2d007-e8e5-4bc8-9673-7df57c91864e
# Files have been successfully downloaded!
# downloading fileID: 24ceac5e-9d33-40df-875c-0077f3fae4e3
# Files have been successfully downloaded!
# downloading fileID: 963dd429-bea5-4b27-b6ca-0e9c196d695c
# Files have been successfully downloaded!
# downloading fileID: 1cadd5a8-9187-42e0-8df3-de3bd81e0803
# Files have been successfully downloaded!
# downloading fileID: c40e97cf-40f9-4cd4-a978-adc2c27d7a2f
# Files have been successfully downloaded!
# downloading fileID: 1b03ce8d-5e1d-4a94-ada1-73273c0bb5a1
# Files have been successfully downloaded!
# downloading fileID: 2c7715b5-6a11-449d-ad2d-811c34a718ca
# Files have been successfully downloaded!
# downloading fileID: 9cfc997e-9fa1-40ad-a54d-13821caecb0c
# Files have been successfully downloaded!
# downloading fileID: d24593c7-a859-4ec3-b6a2-a969d479fe1c
# Files have been successfully downloaded!
# downloading fileID: 98010981-2514-4cb6-b72e-d271f60ffae5
# Files have been successfully downloaded!
# downloading fileID: 98459549-81e2-4db7-afa6-c0bf46a02d8e
# Files have been successfully downloaded!
# downloading fileID: 2ceed958-03cd-4084-a31e-d4131cbf6751
# Files have been successfully downloaded!
# downloading fileID: 26730113-e5fe-4b09-90df-f4c0000b8a82
# Files have been successfully downloaded!
# downloading fileID: a043ac36-3dbf-433f-8e4a-d2b6690e5381
# Files have been successfully downloaded!
# downloading fileID: 297a24d4-d442-47f7-b94a-456de1dfa640
# Files have been successfully downloaded!
# downloading fileID: 437262f2-47f1-40a7-978b-47619fd65a44
# Files have been successfully downloaded!
# downloading fileID: d0676a85-2676-43c5-9787-c2064ed5f3de
# Files have been successfully downloaded!
# downloading fileID: 3d60ea0c-a398-4e54-97aa-7281254c0c41
# Files have been successfully downloaded!
# downloading fileID: 498b307c-ee99-4320-8b3a-2d85b910c5f2
# Files have been successfully downloaded!
# downloading fileID: 8a0eb7ad-6f98-4c47-a57a-7282a006a96a
# Files have been successfully downloaded!
# downloading fileID: f1446d90-6e46-4e28-859a-af3e371bf69d
# Files have been successfully downloaded!
# downloading fileID: b84bca16-4398-4c19-bfb9-4887c0259e00
# Files have been successfully downloaded!
# downloading fileID: 37913cdc-bace-45da-9005-27e544efa0b2
# Files have been successfully downloaded!
# downloading fileID: 3d6b9f37-6f09-49af-b2ee-c07193724730
# Files have been successfully downloaded!
# downloading fileID: 7b7635a9-bc03-495b-923f-ae6a791083c9
# Files have been successfully downloaded!
# downloading fileID: 8eecfa5c-e623-4d75-a750-79adaa5d0171
# Files have been successfully downloaded!
# downloading fileID: 9fb2551a-eab9-4622-a200-24b7cf5de957
# Files have been successfully downloaded!
# downloading fileID: 0102ccd4-c651-448e-b0ba-2551e8d5455d
# Files have been successfully downloaded!
# downloading fileID: dcfe46e0-4606-4117-a13b-2d253616243c
# Files have been successfully downloaded!
# downloading fileID: 799160c2-8895-47ab-887f-51d32cfccd93
# Files have been successfully downloaded!
# downloading fileID: 67266583-5246-48b8-86b9-848b16f191f1
# Files have been successfully downloaded!
# downloading fileID: 3c371849-5bb1-400c-8865-ef6ba72f6aa8
# Files have been successfully downloaded!
# downloading fileID: 4a12e749-eecc-48a9-861a-b4360c91d8dc
# Files have been successfully downloaded!
# downloading fileID: 64200d83-0b89-4a14-a42a-de31389cc4d0
# Files have been successfully downloaded!
# downloading fileID: be8a2d17-295e-4cfb-8663-d326f5f5db07
# Files have been successfully downloaded!
# downloading fileID: 1fece483-6681-406f-a29e-2b76bf407904
# Files have been successfully downloaded!
# downloading fileID: b216358a-7623-48ad-a01e-aafe26d21769
# Files have been successfully downloaded!
# downloading fileID: 553fc74f-96e5-4069-a372-624f7342fd48
# Files have been successfully downloaded!
# downloading fileID: 41ae3158-4ec5-461b-bdb3-fa5e9cde04a7
# Files have been successfully downloaded!
# downloading fileID: d0d4b034-0266-4ef1-a524-67cd82d74dce
# Files have been successfully downloaded!
# downloading fileID: e9c0d467-3217-4938-9400-9e8dd03f1997
# Files have been successfully downloaded!
# downloading fileID: d681c840-db09-4707-a1af-f24248bd47a5
# Files have been successfully downloaded!
# downloading fileID: f3c5744d-6214-4607-b6bc-f8359ae6a4b7
# Files have been successfully downloaded!
# downloading fileID: 060a65e8-29e5-4d81-8e8d-5c310444545b
# Files have been successfully downloaded!
# downloading fileID: 9ee7ee51-9899-4a70-a2aa-5656e777355a
# Files have been successfully downloaded!
# downloading fileID: 0d3ea673-4d0a-4e14-83c4-1e8a35d6ce69
# Files have been successfully downloaded!
# downloading fileID: c5149875-d0f9-48bd-9b90-9e15d353885c
# Files have been successfully downloaded!
# downloading fileID: 6da85060-b13e-4aac-acda-4ca163d88da6
# Files have been successfully downloaded!
# downloading fileID: 5afad890-abdd-48da-b037-23f490fa8e11
# Files have been successfully downloaded!
# downloading fileID: c7a00dea-e9a1-4a24-9eb7-14d6b588f4d4
# Files have been successfully downloaded!
# downloading fileID: 60f92e99-9895-427a-834e-472c0b378463
# Files have been successfully downloaded!
# downloading fileID: 1a659092-cc05-41b8-9dd7-909be6045c36
# Files have been successfully downloaded!
# downloading fileID: 28f38de5-b88e-4363-a613-9ece3233381c
# Files have been successfully downloaded!
# downloading fileID: 9c25260a-8ca1-48f8-9936-346fed137ebd
# Files have been successfully downloaded!
# downloading fileID: 749b8a7f-ec6e-4117-8830-d91c24fe6948
# Files have been successfully downloaded!
# downloading fileID: 36adc2a7-ece2-4311-9e41-fe054ebcc83b
# Files have been successfully downloaded!
# downloading fileID: 786a8844-aa65-43bf-9c4e-34deae3c9dcd
# Files have been successfully downloaded!
# downloading fileID: 1d80c4f2-6bc2-491d-9ff1-1907f8472e93
# Files have been successfully downloaded!
# downloading fileID: ef27d5be-cc24-4865-b3ad-318caa66aad9
# Files have been successfully downloaded!
# downloading fileID: 1f7f20a8-7f16-4f8c-a910-c6a01dc59b54
# Files have been successfully downloaded!
# downloading fileID: 15782906-23e0-46ac-90b2-87a15b5688e3
# Files have been successfully downloaded!
# downloading fileID: e6bed7ea-fbab-4a80-9a92-46745da28b5c
# Files have been successfully downloaded!
# downloading fileID: b7d4042d-08c7-4d99-a245-0ec3dc80b4e7
# Files have been successfully downloaded!
# downloading fileID: 6498d3f8-c87c-427b-a0f0-84a6b869285f
# Files have been successfully downloaded!
# downloading fileID: d1e5a9e2-69b6-4330-9452-8e562e035d4e
# Files have been successfully downloaded!
# downloading fileID: dff6d996-d6b2-448f-ba9d-65e8c20cc957
# Files have been successfully downloaded!
# downloading fileID: 7e819dbd-9de3-45eb-af36-605f06f2f391
# Files have been successfully downloaded!
# downloading fileID: 9d0d7aa9-6206-477c-9c69-a210529af7c2
# Files have been successfully downloaded!
# downloading fileID: 787b6586-66b3-4bde-b711-ced64d964fed
# Files have been successfully downloaded!
# downloading fileID: a69ae00b-9ba6-424a-ba99-26459361032f
# Files have been successfully downloaded!
# downloading fileID: 9adeeb18-b224-4afc-8e66-4731977ba450
# Files have been successfully downloaded!
# downloading fileID: b331f92a-2893-4c95-ba47-53402d9fda66
# Files have been successfully downloaded!
# downloading fileID: 33e58048-86b3-482c-b003-4aeafc98cd4c
# Files have been successfully downloaded!
# downloading fileID: 1fc755c3-abef-4fcb-b94e-b029548ef115
# Files have been successfully downloaded!
# downloading fileID: f9ed9bd6-4430-475f-926f-4df88e52c7ce
# Files have been successfully downloaded!
# downloading fileID: 9b3601ef-08a7-452f-8bc6-c7e5aa1e0cab
# Files have been successfully downloaded!
# downloading fileID: b4c410a9-8a45-49e1-98e8-9db4d951d372
# Files have been successfully downloaded!
# downloading fileID: 98f48d08-1320-49cb-90bc-763da1153bf6
# Files have been successfully downloaded!
# downloading fileID: 7b124983-e503-443d-9ddf-02fcd5feb70b
# Files have been successfully downloaded!
# downloading fileID: b357f023-ffd9-478f-9db0-4653f17c80a5
# Files have been successfully downloaded!
# downloading fileID: 6fea4254-3cdd-4ce5-bfc9-afd7f393ad9c
# Files have been successfully downloaded!
# downloading fileID: 5a98f570-9ae6-40d6-8c36-d1e109d6a591
# Files have been successfully downloaded!
# downloading fileID: 38112d84-e361-43b1-b0cf-e80a36fff710
# Files have been successfully downloaded!
# downloading fileID: 9b3530b1-1a37-404f-8b04-69efa505e7d9
# Files have been successfully downloaded!
# downloading fileID: c11e033d-01a8-4bbb-a2a6-c9e9dff509e5
# Files have been successfully downloaded!
# downloading fileID: 940eabbf-7531-42f7-8bc2-f16a928260bb
# Files have been successfully downloaded!
# downloading fileID: 55d4f686-a3f9-4ef2-8195-14b1d38718e0
# Files have been successfully downloaded!
# downloading fileID: 17cfdc2e-c6a3-4687-9762-239fa5dc75db
# Files have been successfully downloaded!
# downloading fileID: f3311f43-ba28-47bc-bb4c-4cc1efa65ae7
# Files have been successfully downloaded!
# downloading fileID: 4e9aacc0-d2d6-4e98-af3a-8aea54067f3d
# Files have been successfully downloaded!
# downloading fileID: d511cca6-7440-448b-9e08-207a98220947
# Files have been successfully downloaded!
# downloading fileID: 5ffc497f-109f-4f71-b6e7-f239b22aee89
# Files have been successfully downloaded!
# downloading fileID: 8e0068f6-9d9b-4e59-bf1c-1f38d8bc99ba
# Files have been successfully downloaded!
# downloading fileID: 440f21fd-b00f-4b3d-b6eb-d372a77a4af8
# Files have been successfully downloaded!
# downloading fileID: f87fcf21-6f23-4975-96b1-3ed8a55c5078
# Files have been successfully downloaded!
# downloading fileID: c0551073-24c5-4cc2-ba8d-3898c6f83804
# Files have been successfully downloaded!
# downloading fileID: d9124f70-9ef1-466a-81a5-418266684e19
# Files have been successfully downloaded!
# downloading fileID: 12028636-a753-4a46-80b5-f0b3917bda94
# Files have been successfully downloaded!
# downloading fileID: f0c6a8b7-f30b-4744-931f-912136f62824
# Files have been successfully downloaded!
# downloading fileID: 32b6556d-4bd5-483e-8a4f-692666a7cd4b
# Files have been successfully downloaded!
# downloading fileID: e49b7d1d-45f2-4eaf-a235-1b639f962265
# Files have been successfully downloaded!
# downloading fileID: 18100b0f-ab06-4a3f-9754-f757bd5aa097
# Files have been successfully downloaded!
# downloading fileID: 8c9635ef-f55f-495e-8784-137e4aa6dc93
# Files have been successfully downloaded!
# downloading fileID: ceaec642-5237-49da-9e2a-91c3ecaa08b6
# Files have been successfully downloaded!
# downloading fileID: 6be8682c-3b26-4074-9190-5693aa4d2fba
# Files have been successfully downloaded!
# downloading fileID: c1ee115b-b363-462e-92bf-576b5993e029
# Files have been successfully downloaded!
# downloading fileID: b083f65a-75a8-415f-b262-90f2fe991ebb
# Files have been successfully downloaded!
# downloading fileID: 783da7bf-32d2-47f8-bd0f-852e85a66dc2
# Files have been successfully downloaded!
# downloading fileID: 86a58a16-9e9b-47fe-805d-b3cf1a369b23
# Files have been successfully downloaded!
# downloading fileID: 8c468654-3ffb-416e-bfe1-287cd69636f5
# Files have been successfully downloaded!
# downloading fileID: a05ea909-fc2f-4463-94ae-c22cd8e2ac67
# Files have been successfully downloaded!
# downloading fileID: 5f4d2aad-4251-4691-9c7d-cfc9e2fdf4cf
# Files have been successfully downloaded!
# downloading fileID: d280a1ad-bb20-424a-8a44-3e27337e7629
# Files have been successfully downloaded!
# downloading fileID: a7d16b37-7bbf-4f2e-97cf-2bb76f48d688
# Files have been successfully downloaded!
# downloading fileID: 10374814-d5c6-4280-bbed-e298f1b5d19d
# Files have been successfully downloaded!
# downloading fileID: cb759c56-1cf0-4ac1-b308-24beb24271d2
# Files have been successfully downloaded!
# downloading fileID: a0a191e1-424e-42ac-a9d7-a71a9dddf89f
# ...
# downloading fileID: 97e2a207-9076-4933-ad9c-c60f99691b18
# Files have been successfully downloaded!
# downloading fileID: ce035f17-0b58-47ed-a91d-b252c34d6856
# Files have been successfully downloaded!
# downloading fileID: 573cccee-be3f-4e57-8725-91e1ecfb250a
# Files have been successfully downloaded!
# downloading fileID: dc772e8f-16ee-40a4-9316-3f4a7e672805
# Files have been successfully downloaded!
# downloading fileID: d0d14bff-8b7f-4863-9897-ef781595328f
# Files have been successfully downloaded!
# downloading fileID: a86fffee-c85d-4662-8d83-51e1eafdb16c
# Files have been successfully downloaded!
# downloading fileID: e519e2ac-f9cf-4e49-a34b-d6cef7afe5a0
# Files have been successfully downloaded!
# downloading fileID: c9d27984-8096-4723-8138-ca2192c11c0e
# Files have been successfully downloaded!
# downloading fileID: cc8ce350-a2e9-4f69-933e-76750edb0753
# Files have been successfully downloaded!
# downloading fileID: 4a50dc07-62b1-44e9-9d16-081f20357bad
# Files have been successfully downloaded!
# downloading fileID: d2e12153-afd7-4f4d-b2fe-5ecba21e4708
# Files have been successfully downloaded!
# downloading fileID: 4b975f02-c240-4c1a-ad73-7a6e41f12715
# Files have been successfully downloaded!
# downloading fileID: 3d50afe7-56c5-4215-9160-73bde675387b
# Files have been successfully downloaded!
# downloading fileID: 98f8fe81-bf69-4a28-9062-15fcbd74bed5
# Files have been successfully downloaded!
# downloading fileID: 8d46cba3-206b-4090-8811-e355b421eec7
# Files have been successfully downloaded!
# downloading fileID: 2280b8aa-b002-49ff-9b8a-ad3f4d5c12a3
# Files have been successfully downloaded!
# downloading fileID: a49a52a8-90c7-4682-9a5f-fb8e11bac97a
# Files have been successfully downloaded!
# downloading fileID: 2911043f-83b9-43e6-8340-23ad1ccdf00d
# Files have been successfully downloaded!
# downloading fileID: 7825096d-a446-4501-9c17-5fff3ad6f17b
# Files have been successfully downloaded!
# downloading fileID: f3ed8228-6eb6-4aad-ad25-5dc9ab9dc359
# Files have been successfully downloaded!
# downloading fileID: 6c2e802a-455b-4cfb-b6bf-64b76a73e495
# Files have been successfully downloaded!
# downloading fileID: 5a260502-e23d-4f0b-adb4-3f7379fc89af
# Files have been successfully downloaded!
# downloading fileID: c57bb4e4-8ad1-4d4a-b30c-f2afe3f816d9
# Files have been successfully downloaded!
# downloading fileID: 48c31046-0138-4514-9cfc-f9e7c0f8ea65
# Files have been successfully downloaded!
# downloading fileID: baac5168-4483-4800-a634-ea3fe3949270
# Files have been successfully downloaded!
# downloading fileID: ff9ec08e-a59e-4896-a8e9-a16c140fb893
# Files have been successfully downloaded!
# downloading fileID: 5c8fcc31-fd8d-4b91-b25f-586b5e90b443
# Files have been successfully downloaded!
# downloading fileID: 9e0012ec-66ec-4acc-8628-d833a100b424
# Files have been successfully downloaded!
# downloading fileID: a3cd9630-50ac-4ec7-818e-3cd41a0ce89a
# Files have been successfully downloaded!
# downloading fileID: cee5d1aa-eead-40f7-a374-f65d12f65cec
# Files have been successfully downloaded!
# downloading fileID: 6e59633d-d8df-4951-8882-7f0afb319f22
# Files have been successfully downloaded!
# downloading fileID: 142c42c8-3210-4887-9531-5de03aa412cb
# Files have been successfully downloaded!
# downloading fileID: 04653213-9e84-4db4-b1f3-a664d2e63361
# Files have been successfully downloaded!
# downloading fileID: 5b695d69-8db5-4e3b-a52c-52da954cf7f8
# Files have been successfully downloaded!
# downloading fileID: 227f2dd3-005a-4de3-b00a-83bd1199f1eb
# Files have been successfully downloaded!
# downloading fileID: c58ac96c-c8ba-47b2-a86f-34fe2f82251c
# Files have been successfully downloaded!
# downloading fileID: 29bca876-b706-47f4-9653-8a97106e76f0
# Files have been successfully downloaded!
# downloading fileID: 9ba69c4a-f9cd-48f0-8bba-a6b90152f6ce
# Files have been successfully downloaded!
# downloading fileID: 7ae740e4-39d8-4cae-a339-a0be980b7c5e
# Files have been successfully downloaded!
# downloading fileID: f6b90d92-42c8-4801-bb0e-510ff2ddeea1
# Files have been successfully downloaded!
# downloading fileID: f9909162-aac2-490b-b738-3a87721128f9
# Files have been successfully downloaded!
# downloading fileID: 00401b13-cd58-41ee-af3e-c37f9b21db19
# Files have been successfully downloaded!
# downloading fileID: b9c8dbfb-48c8-4ef7-b263-965b308f4856
# Files have been successfully downloaded!
# downloading fileID: 30b16b7a-e020-462c-af26-88fdaf8f76fb
# Files have been successfully downloaded!
# downloading fileID: 0bcc0812-a13e-4305-ab34-5cc2bd2c4cfc
# Files have been successfully downloaded!
# downloading fileID: ece0cb0e-431a-412e-941e-608f971e9d2e
# Files have been successfully downloaded!
# downloading fileID: d0b9d991-2f32-4c56-affc-fcd29157d988
# Files have been successfully downloaded!
# downloading fileID: af18db09-0b1c-4cbf-8290-3d74b8787c1e
# Files have been successfully downloaded!
# downloading fileID: 7b7b1767-e847-43bb-9f2c-d0077d94bf85
# Files have been successfully downloaded!
# downloading fileID: 1ba2e6f2-a670-41a9-b850-4764dab5af79
# Files have been successfully downloaded!
# downloading fileID: c93bece2-d872-4b8e-8d5b-6b94552ef454
# Files have been successfully downloaded!
# downloading fileID: 437c7afd-c134-4d6b-8885-571d5b5f6f5e
# Files have been successfully downloaded!
# downloading fileID: bcd3232e-4f56-44ca-83d6-9ecb339ade93
# Files have been successfully downloaded!
# downloading fileID: 34c1face-a401-4116-ab76-47b725d19d90
# Files have been successfully downloaded!
# downloading fileID: d237f111-ab98-47d0-a3ed-75025f7b11e2
# Files have been successfully downloaded!
# downloading fileID: c71beb18-5fb9-41b5-ae87-b2e0b627767f
# Files have been successfully downloaded!
# downloading fileID: fbc87159-73a6-4e25-abac-6c34c784c5a4
# Files have been successfully downloaded!
# downloading fileID: bca36378-a483-4c54-95a7-f08a5c6a10eb
# Files have been successfully downloaded!
# downloading fileID: 26cfc4b4-069f-47e1-b67b-62e7d0ebaff1
# Files have been successfully downloaded!
# downloading fileID: 256b14f4-9f49-4a12-8d48-7132b2445693
# Files have been successfully downloaded!
# downloading fileID: 07e766ef-f9ec-458d-baee-2e8d4ce7d37f
# Files have been successfully downloaded!
# downloading fileID: 7e0e8ed0-745c-4073-823a-f4af0942622d
# Files have been successfully downloaded!
# downloading fileID: a595c082-7941-465f-8c31-55ec56cd478d
# Files have been successfully downloaded!
# downloading fileID: 5c3733d6-65be-4961-bfc6-1fe7692c56f2
# Files have been successfully downloaded!
# downloading fileID: 21121395-2c0b-4159-a5c2-eafc863f5f81
# Files have been successfully downloaded!
# downloading fileID: 68b91fda-7412-41a4-bdc1-fde3ee90cb5c
# Files have been successfully downloaded!
# downloading fileID: 60f65fe8-8cdb-42a9-913a-c0d5dbf1f858
# Files have been successfully downloaded!
# downloading fileID: b2312287-8cda-4d68-951a-018703028d34
# Files have been successfully downloaded!
# downloading fileID: 4793f718-af6b-4163-aeb0-0e95888d9c13
# Files have been successfully downloaded!
# downloading fileID: 113968bd-0a0b-40e4-bde0-5d92548974b2
# Files have been successfully downloaded!
# downloading fileID: da0dfd43-9696-4fcf-af09-7f396472da03
# Files have been successfully downloaded!
# downloading fileID: 43d887eb-dcea-45b7-b4ae-0d08cb72acb3
# Files have been successfully downloaded!
# downloading fileID: 85b57075-8a03-4bfd-876d-27ee95f2931a
# Files have been successfully downloaded!
# downloading fileID: 9513fb83-b032-4c67-96f3-c2a75567712a
# Files have been successfully downloaded!
# downloading fileID: 20317bcd-57c9-46e6-9f5a-e56bfe6a04e9
# Files have been successfully downloaded!
# downloading fileID: 9062b641-6cc6-42e0-9a56-871b3fc06824
# Files have been successfully downloaded!
# downloading fileID: 922152cc-7793-4f0b-a5c0-310f50d44639
# Files have been successfully downloaded!
# downloading fileID: 82aa4078-8f18-4d9e-90fc-92ecacc37bdc
# Files have been successfully downloaded!
# downloading fileID: 36135bbc-2edc-4c62-b9ee-d408287bc010
# Files have been successfully downloaded!
# downloading fileID: e6a42443-62d4-4af2-bcf1-325bfd6885c3
# Files have been successfully downloaded!
# downloading fileID: ae58898f-c687-4f7d-a1a7-23b5626d8221
# Files have been successfully downloaded!
# downloading fileID: 88c339f2-3701-4c40-b8f1-2f59ed04dc36
# Files have been successfully downloaded!
# downloading fileID: e8942f8d-5482-457a-a38a-e62be80f18f9
# Files have been successfully downloaded!
# downloading fileID: 3a79df21-189b-4112-9995-b0cf91e2f57f
# Files have been successfully downloaded!
# downloading fileID: 4e0609b4-b2a3-4bcc-bed0-17d9ea67251d
# Files have been successfully downloaded!
# downloading fileID: b98e79ed-bc76-49b3-b68a-c7c012569485
# Files have been successfully downloaded!
# downloading fileID: b0ca5947-78d5-4920-980a-3573a6baffc2
# Files have been successfully downloaded!
# downloading fileID: 0d7409f0-010a-4433-964c-424ff0e58d6f
# Files have been successfully downloaded!
# downloading fileID: 1c9880b2-dd9d-460d-8288-fdaa093a12f4
# Files have been successfully downloaded!
# downloading fileID: f9096f66-6772-4dc4-bc1c-1a5e94d72aad
# Files have been successfully downloaded!
# downloading fileID: eb410e67-7b02-4233-9152-512baeffa30b
# Files have been successfully downloaded!
# downloading fileID: 06217882-45ea-49dd-82c1-b761b1f8d1b6
# Files have been successfully downloaded!
# downloading fileID: f5d8e063-dc7f-4bce-9645-8278b863e83f
# Files have been successfully downloaded!
# downloading fileID: d10eb883-df32-43c2-8ff6-8d2954031427
# Files have been successfully downloaded!
# downloading fileID: 8640d2eb-ecd7-4aec-a9c9-027fd4a7cfa7
# Files have been successfully downloaded!
# downloading fileID: cc951beb-275e-42bc-8a05-df5788c10949
# Files have been successfully downloaded!
# downloading fileID: f4900312-0c31-46f4-bb17-3f73a8943aa6
# Files have been successfully downloaded!
# downloading fileID: fce6dc78-afbd-44dc-aefc-dc7c170a2d55
# Files have been successfully downloaded!
# downloading fileID: e503a9be-35b1-4447-8150-cef059e1d740
# Files have been successfully downloaded!
# downloading fileID: 502ab7f7-9425-4421-812a-2bec3ba64df1
# Files have been successfully downloaded!
# downloading fileID: 747e70c4-42d2-4d66-921a-faa48c66cfbf
# Files have been successfully downloaded!
# downloading fileID: 7b251e5d-1255-4dfe-911f-4db23192e3b6
# Files have been successfully downloaded!
# downloading fileID: fbe1dd3b-4bb4-4800-91cf-3c0eca36d6b8
# Files have been successfully downloaded!
# downloading fileID: 3846db8b-f19f-4de1-a46d-2d03f9d32e4d
# Files have been successfully downloaded!
# downloading fileID: 3763250b-da39-42e3-815b-c021c69aeca7
# Files have been successfully downloaded!
# downloading fileID: d0738759-6a72-46b1-9302-a385b9bb1b4c
# Files have been successfully downloaded!
# downloading fileID: df95f7fd-3b7d-4c09-9967-e277a76d67e9
# Files have been successfully downloaded!
# downloading fileID: 3ec3c5f4-12ee-4431-a603-3a077e90176f
# Files have been successfully downloaded!
# downloading fileID: c767ff8f-5d0c-4e42-a84e-61793a788271
# Files have been successfully downloaded!
# downloading fileID: 8194bd66-afd0-414e-9955-1e206eb21d65
# Files have been successfully downloaded!
# downloading fileID: b1e83a5b-f10b-43c9-bcd2-749813c6731f
# Files have been successfully downloaded!
# downloading fileID: ed60ae31-2deb-4b7f-b8c6-553e95bc24b2
# Files have been successfully downloaded!
# downloading fileID: 12e8dca8-d742-4b85-8ba7-c830433c3822
# Files have been successfully downloaded!
# downloading fileID: 2dd12642-ee17-4c9f-9c20-7bc1de16256f
# Files have been successfully downloaded!
# downloading fileID: 96ebc9d4-6250-4c6e-b3c9-f8b61ba431ac
# Files have been successfully downloaded!
# downloading fileID: 198c1e9b-7d3e-4deb-9e55-3e8bb743a37a
# Files have been successfully downloaded!
# downloading fileID: 3ccb87fc-a1b4-46fb-b9dd-72588ee718ff
# Files have been successfully downloaded!
# downloading fileID: 3a38aee5-1ee8-4223-a020-b7fc30af2713
# Files have been successfully downloaded!
# downloading fileID: 2ddaf36b-9b85-44ff-92d6-18d942b6d9d9
# Files have been successfully downloaded!
# downloading fileID: 06846c53-6dca-4b3b-91f1-bd9be16fed36
# Files have been successfully downloaded!
# downloading fileID: ee8de156-876c-47aa-877d-dc84099500c6
# Files have been successfully downloaded!
# downloading fileID: b99ab25e-1f8a-4219-99d5-f7fcb852d024
# Files have been successfully downloaded!
# downloading fileID: 87daa4e5-2c23-4d04-9076-3efbbc3b9d10
# Files have been successfully downloaded!
# downloading fileID: c9e13c9d-d8aa-42bf-a940-ea5f7b1cbab5
# Files have been successfully downloaded!
# downloading fileID: da2c0ea4-eb59-4424-95ad-da0a59c09de0
# Files have been successfully downloaded!
# downloading fileID: 5e7b66bd-19b9-48dd-9a88-3d7784c86473
# Files have been successfully downloaded!
# downloading fileID: f3f64588-4c53-4951-b553-6c8e16c8292c
# Files have been successfully downloaded!
# downloading fileID: bda5ba64-d0dc-4a86-8094-78295c212093
# Files have been successfully downloaded!
# downloading fileID: ea957630-90b8-48c7-aa14-5448572460ed
# Files have been successfully downloaded!
# downloading fileID: faf92878-0484-4102-bc42-7e1f41387b32
# Files have been successfully downloaded!
# downloading fileID: 9110e2f1-f98d-4cde-9742-419fa20143e6
# Files have been successfully downloaded!
# downloading fileID: f8f4feff-13b7-4ec9-8c05-a1cf799d3a9e
# Files have been successfully downloaded!
# downloading fileID: 157dd280-c7ef-4d8c-b435-b1f55e4007e8
# Files have been successfully downloaded!
# downloading fileID: 3f0e1991-8b20-488d-a6d6-b61f9e51d8d2
# Files have been successfully downloaded!
# downloading fileID: d2527939-2fd1-47d9-9619-e211d4d2a5e9
# Files have been successfully downloaded!
# downloading fileID: 4efcf03c-21d0-4f45-b905-5284c88f9e82
# Files have been successfully downloaded!
# downloading fileID: 7bb7435d-ac08-45e2-8470-f9c54dc762e2
# Files have been successfully downloaded!
# downloading fileID: 7b37df74-99cf-47e0-81c6-91954185234b
# Files have been successfully downloaded!
# downloading fileID: a09ddcc0-87eb-48f9-8961-a453f66e9ecf
# Files have been successfully downloaded!
# downloading fileID: 0ecad8ad-53c4-4f85-97b0-ad028f5d18c4
# Files have been successfully downloaded!
# downloading fileID: 03d96f59-c610-476d-b343-3fb39ca7b2c0
# Files have been successfully downloaded!
# downloading fileID: 2efa4d73-f2af-421e-b3dc-ef7c2a65c918
# Files have been successfully downloaded!
# downloading fileID: ceac65c6-df3a-4737-84fb-5e6a6b86c6a1
# Files have been successfully downloaded!
# downloading fileID: dff8ec25-f2cf-4c33-805e-4344f852a9e5
# Files have been successfully downloaded!
# downloading fileID: eb564c43-d746-485a-8fd3-8797bce8fed5
# Files have been successfully downloaded!
# downloading fileID: 34714145-bab3-4530-b898-752d4816c874
# Files have been successfully downloaded!
# downloading fileID: 835c80f5-443c-49a0-95ad-6c261288105b
# Files have been successfully downloaded!
# downloading fileID: 20f66099-9bd7-4025-bc80-44a8faa6cf9a
# Files have been successfully downloaded!
# downloading fileID: 5c59901f-a0ac-4c68-aaee-5a63c37ca1b6
# Files have been successfully downloaded!
# downloading fileID: 0db0413a-2f69-4f28-ab2f-c1d2e01cd978
# Files have been successfully downloaded!
# downloading fileID: 17848ed2-9ae9-4019-a14a-f75ea7316ea4
# Files have been successfully downloaded!
# downloading fileID: a495993e-bbac-4f15-ad24-ae89786b04c6
# Files have been successfully downloaded!
# downloading fileID: fb944bb1-44a4-4dd9-81b0-f7ebe81ea03d
# Files have been successfully downloaded!
# downloading fileID: 0dc04bc8-4f31-4e74-86b0-d4874bd8f4cb
# Files have been successfully downloaded!
# downloading fileID: ac2b9192-a2f9-4c62-b40a-dfe2c8406b34
# Files have been successfully downloaded!
# downloading fileID: ddfa9d88-2d83-4859-9158-4a5c14eb498c
# Files have been successfully downloaded!
# downloading fileID: 3416e6fc-ed29-48cc-9ef1-7ab3ca65b1ed
# Files have been successfully downloaded!
# downloading fileID: c8711bad-142c-44c8-ab42-56e2908ba47b
# Files have been successfully downloaded!
# downloading fileID: f8ef5965-19ce-4318-b204-5c6b7df1097f
# Files have been successfully downloaded!
# downloading fileID: 345aa599-b095-4d2f-b747-64e961c2a473
# Files have been successfully downloaded!
# downloading fileID: d5fec916-d909-4051-9445-f5b489e62ec3
# Files have been successfully downloaded!
# downloading fileID: 3009bbc0-a6a3-42f6-ae5d-ce29f9136878
# Files have been successfully downloaded!
# downloading fileID: ec3947f1-95e9-4eb3-ac06-29836e25193b
# Files have been successfully downloaded!

# %%
group_adata_dict.keys()
# Out:
# dict_keys(['BR1_Female_Negative', 'BR1_Female_Positive', 'BR1_Male_Negative', 'BR1_Male_Positive', 'BR2_Female_Negative', 'BR2_Female_Positive', 'BR2_Male_Negative', 'BR2_Male_Positive'])

# %%
group_adata_dict['BR1_Female_Negative']
# Out:
# AnnData object with n_obs × n_vars = 2970934 × 33538
#     obs: 'barcodes', 'batch_id', 'cell_name', 'cell_uuid', 'chip_id', 'hto_barcode', 'hto_category', 'n_genes', 'n_mito_umis', 'n_reads', 'n_umis', 'original_barcodes', 'pbmc_sample_id', 'pool_id', 'seurat_pbmc_type', 'seurat_pbmc_type_score', 'umap_1', 'umap_2', 'well_id'

# %% [markdown]
# ## Update Observations with additional metadata
#
# Now, we'll add the sample metadata, CMV status, and BMI data to our scRNA-seq data.
#
# First, we'll convert `pbmc_sample_id` to `sample.sampleKitGuid` using a regular expression. PBMC samples are derived from kits in our LIMS system, so both share the same numerical core. The difference is that there can be multiple PBMC samples collected at the same time, so PBMC samples are prefixed with PB to indicate their sample type, and suffixed with -XX to indicate an aliquot number.

# %%
def sample_to_kit(sample):
    kit = re.sub('PB([0-9]+)-.+','KT\\1',sample)
    return(kit)

# %% [markdown]
# To keep things tidy, we'll also drop the `seurat_pbmc_type`, `seurat_pbmc_type_score`, and UMAP coordinates generated by our processing pipeline. These cell type assignments are from a now-outdated reference dataset, and the UMAP coordinates are generated for viewing individual samples - not helpful for our full dataset.

# %%
drop_columns = [
    'seurat_pbmc_type','seurat_pbmc_type_score',
    'umap_1', 'umap_2'
]

# %% [markdown]
# Then, we'll add our new sample data with a left join on the `sample.sampleKitGuid` values, and add our labels and doublet calls with a left join on cell `barcodes`.
#
# Next, we'll convert all of our text columns to categorical. This is used to make storage of text data more efficient when we write our output file, as we'll only need to store a single instance of our strings.
#
# We do this for all columns except barcodes, which we need to retain as a string type for use as an index.
#
# Finally, we'll add these back to our anndata object

# %%
for group_name, adata in group_adata_dict.items():
    print(group_name)
    obs = adata.obs
    
    # Convert sample.sampleKitGuid
    print('converting ids')
    obs['sample.sampleKitGuid'] = [sample_to_kit(sample) for sample in obs['pbmc_sample_id']]
    
    # Drop old columns
    obs = obs.drop(drop_columns, axis = 1)
    
    print('merging sample metadata')
    # Add new metadata
    obs = obs.merge(
        combined_sample_meta,
        how = 'left',
        on = 'sample.sampleKitGuid'
    )
    
    print('merging labels')
    # Add labels
    obs = obs.merge(all_labels, how = 'left', on = 'barcodes')
    
    print('converting to categorical')
    # Convert to categorical
    cat_obs = obs
    for i in range(cat_obs.shape[1]):
        col_name = cat_obs.dtypes.index.tolist()[i]
        col_type = cat_obs.dtypes[col_name]
        if col_name == 'barcodes':
            cat_obs[col_name] = cat_obs[col_name].astype(str)
        elif is_object_dtype(col_type):
            cat_obs[col_name] = cat_obs[col_name].astype('category')
    cat_obs = cat_obs.set_index('barcodes', drop = False)
    
    # Assign final observations back to anndata
    adata.obs = cat_obs
    
    group_adata_dict[group_name] = adata
# Out:
# BR1_Female_Negative
# converting ids
# merging sample metadata
# merging labels
# converting to categorical
# BR1_Female_Positive
# converting ids
# merging sample metadata
# merging labels
# converting to categorical
# BR1_Male_Negative
# converting ids
# merging sample metadata
# merging labels
# converting to categorical
# BR1_Male_Positive
# converting ids
# merging sample metadata
# merging labels
# converting to categorical
# BR2_Female_Negative
# converting ids
# merging sample metadata
# merging labels
# converting to categorical
# BR2_Female_Positive
# converting ids
# merging sample metadata
# merging labels
# converting to categorical
# BR2_Male_Negative
# converting ids
# merging sample metadata
# merging labels
# converting to categorical
# BR2_Male_Positive
# converting ids
# merging sample metadata
# merging labels
# converting to categorical

# %%
group_adata_dict['BR1_Female_Negative']
# Out:
# AnnData object with n_obs × n_vars = 2970934 × 33538
#     obs: 'barcodes', 'batch_id', 'cell_name', 'cell_uuid', 'chip_id', 'hto_barcode', 'hto_category', 'n_genes', 'n_mito_umis', 'n_reads', 'n_umis', 'original_barcodes', 'pbmc_sample_id', 'pool_id', 'well_id', 'sample.sampleKitGuid', 'cohort.cohortGuid', 'subject.subjectGuid', 'subject.biologicalSex', 'subject.race', 'subject.ethnicity', 'subject.birthYear', 'sample.visitName', 'sample.drawDate', 'file.id', 'subject.cmv', 'subject.bmi', 'AIFI_L1', 'AIFI_L1_score', 'AIFI_L2', 'AIFI_L2_score', 'predicted_doublet', 'doublet_score'

# %% [markdown]
# ## Write assembled data to disk

# %%
out_dir = 'output'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
out_h5ads = {}
for group_name, adata in group_adata_dict.items():
    out_h5ad = 'output/diha_PBMC_{g}_raw_labeled_{d}.h5ad'.format(g = group_name, d = date.today())
    adata.write_h5ad(out_h5ad)
    out_h5ads[group_name] = out_h5ad

# %%
out_csvs = {}
out_parquets = {}
for group_name, adata in group_adata_dict.items():
    obs = adata.obs
    
    out_csv = 'output/diha_PBMC_{g}_raw_labeled_meta_{d}.csv'.format(g = group_name, d = date.today())
    obs.to_csv(out_csv)
    out_csvs[group_name] = out_csv

    out_parquet = 'output/diha_PBMC_{g}_raw_labeled_meta_{d}.parquet'.format(g = group_name, d = date.today())
    obs.to_parquet(out_parquet)
    out_parquets[group_name] = out_parquet

# %% [markdown]
# ## Upload assembled data to HISE
#
# Finally, we'll use `hisepy.upload.upload_files()` to send a copy of our output to HISE to use for downstream analysis steps.

# %%
study_space_uuid = 'de025812-5e73-4b3c-9c3b-6d0eac412f2a'
title = 'DIHA PBMC Labeled Raw scRNA-seq Assembly {d}'.format(d = date.today())

# %%
search_id = element_id()
search_id
# Out:
# 'cobalt-neptunium-cadmium'

# %%
in_files = [sample_meta_uuid, cmv_meta_uuid, bmi_meta_uuid,
            l1_uuid, l2_uuid, doublet_uuid]
in_files = in_files + sample_meta['file.id'].tolist()

# %%
len(in_files)
# Out:
# 874

# %%
in_files[0:10]
# Out:
# ['d82c5c42-ae5f-4e67-956e-cd3b7bf88105',
#  '9469f67c-b09a-454d-9fb9-f50ff3494d69',
#  'e507258c-d175-4d8e-a455-5229870dc991',
#  '3935e870-cd4d-4daf-81dc-2e94bff46843',
#  '55c53d17-1a31-4a37-8d67-06d8e4218df7',
#  'b2bea832-a41e-4699-9d1d-a05a3ea1cf88',
#  'fec489f9-9a74-4635-aa91-d2bf09d1faec',
#  '7c0c7979-eebd-4aba-b5b2-6e76b4643623',
#  '40efd03a-cb2f-4677-af42-a056cbfe5a17',
#  '68fbcd34-1d63-461d-8195-df5b8dc61b31']

# %%
out_files = list(out_h5ads.values()) + list(out_csvs.values()) + list(out_parquets.values())

# %%
out_files
# Out:
# ['output/diha_PBMC_BR1_Female_Negative_raw_labeled_2024-04-19.h5ad',
#  'output/diha_PBMC_BR1_Female_Positive_raw_labeled_2024-04-19.h5ad',
#  'output/diha_PBMC_BR1_Male_Negative_raw_labeled_2024-04-19.h5ad',
#  'output/diha_PBMC_BR1_Male_Positive_raw_labeled_2024-04-19.h5ad',
#  'output/diha_PBMC_BR2_Female_Negative_raw_labeled_2024-04-19.h5ad',
#  'output/diha_PBMC_BR2_Female_Positive_raw_labeled_2024-04-19.h5ad',
#  'output/diha_PBMC_BR2_Male_Negative_raw_labeled_2024-04-19.h5ad',
#  'output/diha_PBMC_BR2_Male_Positive_raw_labeled_2024-04-19.h5ad',
#  'output/diha_PBMC_BR1_Female_Negative_raw_labeled_meta_2024-04-19.csv',
#  'output/diha_PBMC_BR1_Female_Positive_raw_labeled_meta_2024-04-19.csv',
#  'output/diha_PBMC_BR1_Male_Negative_raw_labeled_meta_2024-04-19.csv',
#  'output/diha_PBMC_BR1_Male_Positive_raw_labeled_meta_2024-04-19.csv',
#  'output/diha_PBMC_BR2_Female_Negative_raw_labeled_meta_2024-04-19.csv',
#  'output/diha_PBMC_BR2_Female_Positive_raw_labeled_meta_2024-04-19.csv',
#  'output/diha_PBMC_BR2_Male_Negative_raw_labeled_meta_2024-04-19.csv',
#  'output/diha_PBMC_BR2_Male_Positive_raw_labeled_meta_2024-04-19.csv',
#  'output/diha_PBMC_BR1_Female_Negative_raw_labeled_meta_2024-04-19.parquet',
#  'output/diha_PBMC_BR1_Female_Positive_raw_labeled_meta_2024-04-19.parquet',
#  'output/diha_PBMC_BR1_Male_Negative_raw_labeled_meta_2024-04-19.parquet',
#  'output/diha_PBMC_BR1_Male_Positive_raw_labeled_meta_2024-04-19.parquet',
#  'output/diha_PBMC_BR2_Female_Negative_raw_labeled_meta_2024-04-19.parquet',
#  'output/diha_PBMC_BR2_Female_Positive_raw_labeled_meta_2024-04-19.parquet',
#  'output/diha_PBMC_BR2_Male_Negative_raw_labeled_meta_2024-04-19.parquet',
#  'output/diha_PBMC_BR2_Male_Positive_raw_labeled_meta_2024-04-19.parquet']

# %%
hisepy.upload.upload_files(
    files = out_files,
    study_space_id = study_space_uuid,
    title = title,
    input_file_ids = in_files,
    destination = search_id
)
# Out:
# Cannot determine the current notebook.
# 1) /home/jupyter/IH-A-Aging-Analysis-Notebooks/scrna-seq_analysis/02-reference_labeling/06d-Python_partition_large_cell_classes_BR2_Male.ipynb
# 2) /home/jupyter/IH-A-Aging-Analysis-Notebooks/scrna-seq_analysis/02-reference_labeling/06c-Python_partition_large_cell_classes_BR2_Female.ipynb
# 3) /home/jupyter/IH-A-Aging-Analysis-Notebooks/scrna-seq_analysis/02-reference_labeling/04-Python_assembly_of_subsets.ipynb
# Please select (1-3)
#  3
# you are trying to upload file_ids... ['output/diha_PBMC_BR1_Female_Negative_raw_labeled_2024-04-19.h5ad', 'output/diha_PBMC_BR1_Female_Positive_raw_labeled_2024-04-19.h5ad', 'output/diha_PBMC_BR1_Male_Negative_raw_labeled_2024-04-19.h5ad', 'output/diha_PBMC_BR1_Male_Positive_raw_labeled_2024-04-19.h5ad', 'output/diha_PBMC_BR2_Female_Negative_raw_labeled_2024-04-19.h5ad', 'output/diha_PBMC_BR2_Female_Positive_raw_labeled_2024-04-19.h5ad', 'output/diha_PBMC_BR2_Male_Negative_raw_labeled_2024-04-19.h5ad', 'output/diha_PBMC_BR2_Male_Positive_raw_labeled_2024-04-19.h5ad', 'output/diha_PBMC_BR1_Female_Negative_raw_labeled_meta_2024-04-19.csv', 'output/diha_PBMC_BR1_Female_Positive_raw_labeled_meta_2024-04-19.csv', 'output/diha_PBMC_BR1_Male_Negative_raw_labeled_meta_2024-04-19.csv', 'output/diha_PBMC_BR1_Male_Positive_raw_labeled_meta_2024-04-19.csv', 'output/diha_PBMC_BR2_Female_Negative_raw_labeled_meta_2024-04-19.csv', 'output/diha_PBMC_BR2_Female_Positive_raw_labeled_meta_2024-04-19.csv', 'output/diha_PBMC_BR2_Male_Negative_raw_labeled_meta_2024-04-19.csv', 'output/diha_PBMC_BR2_Male_Positive_raw_labeled_meta_2024-04-19.csv', 'output/diha_PBMC_BR1_Female_Negative_raw_labeled_meta_2024-04-19.parquet', 'output/diha_PBMC_BR1_Female_Positive_raw_labeled_meta_2024-04-19.parquet', 'output/diha_PBMC_BR1_Male_Negative_raw_labeled_meta_2024-04-19.parquet', 'output/diha_PBMC_BR1_Male_Positive_raw_labeled_meta_2024-04-19.parquet', 'output/diha_PBMC_BR2_Female_Negative_raw_labeled_meta_2024-04-19.parquet', 'output/diha_PBMC_BR2_Female_Positive_raw_labeled_meta_2024-04-19.parquet', 'output/diha_PBMC_BR2_Male_Negative_raw_labeled_meta_2024-04-19.parquet', 'output/diha_PBMC_BR2_Male_Positive_raw_labeled_meta_2024-04-19.parquet']. Do you truly want to proceed?
# (y/n) y
# {'trace_id': '5467d987-3ce8-41b1-8f67-4efdcfc1edaf',
#  'files': ['output/diha_PBMC_BR1_Female_Negative_raw_labeled_2024-04-19.h5ad',
#   'output/diha_PBMC_BR1_Female_Positive_raw_labeled_2024-04-19.h5ad',
#   'output/diha_PBMC_BR1_Male_Negative_raw_labeled_2024-04-19.h5ad',
#   'output/diha_PBMC_BR1_Male_Positive_raw_labeled_2024-04-19.h5ad',
#   'output/diha_PBMC_BR2_Female_Negative_raw_labeled_2024-04-19.h5ad',
#   'output/diha_PBMC_BR2_Female_Positive_raw_labeled_2024-04-19.h5ad',
#   'output/diha_PBMC_BR2_Male_Negative_raw_labeled_2024-04-19.h5ad',
#   'output/diha_PBMC_BR2_Male_Positive_raw_labeled_2024-04-19.h5ad',
#   'output/diha_PBMC_BR1_Female_Negative_raw_labeled_meta_2024-04-19.csv',
#   'output/diha_PBMC_BR1_Female_Positive_raw_labeled_meta_2024-04-19.csv',
#   'output/diha_PBMC_BR1_Male_Negative_raw_labeled_meta_2024-04-19.csv',
#   'output/diha_PBMC_BR1_Male_Positive_raw_labeled_meta_2024-04-19.csv',
#   'output/diha_PBMC_BR2_Female_Negative_raw_labeled_meta_2024-04-19.csv',
#   'output/diha_PBMC_BR2_Female_Positive_raw_labeled_meta_2024-04-19.csv',
#   'output/diha_PBMC_BR2_Male_Negative_raw_labeled_meta_2024-04-19.csv',
#   'output/diha_PBMC_BR2_Male_Positive_raw_labeled_meta_2024-04-19.csv',
#   'output/diha_PBMC_BR1_Female_Negative_raw_labeled_meta_2024-04-19.parquet',
#   'output/diha_PBMC_BR1_Female_Positive_raw_labeled_meta_2024-04-19.parquet',
#   'output/diha_PBMC_BR1_Male_Negative_raw_labeled_meta_2024-04-19.parquet',
#   'output/diha_PBMC_BR1_Male_Positive_raw_labeled_meta_2024-04-19.parquet',
#   'output/diha_PBMC_BR2_Female_Negative_raw_labeled_meta_2024-04-19.parquet',
#   'output/diha_PBMC_BR2_Female_Positive_raw_labeled_meta_2024-04-19.parquet',
#   'output/diha_PBMC_BR2_Male_Negative_raw_labeled_meta_2024-04-19.parquet',
#   'output/diha_PBMC_BR2_Male_Positive_raw_labeled_meta_2024-04-19.parquet']}

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.10.3
# h5py                3.10.0
# hisepy              0.3.0
# pandas              2.1.4
# scanpy              1.9.6
# scipy               1.11.4
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.0.1
# anyio                       NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# beatrix_jupyterlab          NA
# brotli                      NA
# cachetools                  5.3.1
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# cloudpickle                 2.2.1
# colorama                    0.4.6
# comm                        0.1.4
# cryptography                41.0.7
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# db_dtypes                   1.1.1
# debugpy                     1.8.0
# decorator                   5.1.1
# defusedxml                  0.7.1
# deprecated                  1.2.14
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fqdn                        NA
# google                      NA
# greenlet                    2.0.2
# grpc                        1.58.0
# grpc_status                 NA
# idna                        3.6
# igraph                      0.10.8
# importlib_metadata          NA
# ipykernel                   6.28.0
# ipython_genutils            0.2.0
# ipywidgets                  8.1.1
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.2
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.20.0
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.1
# jupyterlab_server           2.25.2
# jwt                         2.8.0
# kiwisolver                  1.4.5
# leidenalg                   0.10.1
# llvmlite                    0.41.0
# lz4                         4.3.2
# markupsafe                  2.1.3
# matplotlib                  3.8.0
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# mpmath                      1.3.0
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.58.0
# numpy                       1.25.2
# opentelemetry               NA
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# periodictable               1.5.2
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                4.1.0
# plotly                      5.18.0
# prettytable                 3.9.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# proto                       NA
# psutil                      NA
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pyarrow                     13.0.0
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pynvml                      NA
# pyparsing                   3.1.1
# pyreadr                     0.5.0
# pythonjsonlogger            NA
# pytz                        2023.3.post1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# send2trash                  NA
# shapely                     1.8.5.post1
# six                         1.16.0
# sklearn                     1.3.2
# sniffio                     1.3.0
# socks                       1.7.1
# sql                         NA
# sqlalchemy                  2.0.21
# sqlparse                    0.4.4
# stack_data                  0.6.2
# sympy                       1.12
# termcolor                   NA
# texttable                   1.7.0
# threadpoolctl               3.2.0
# torch                       2.1.2+cu121
# torchgen                    NA
# tornado                     6.3.3
# tqdm                        4.66.1
# traitlets                   5.9.0
# typing_extensions           NA
# uri_template                NA
# urllib3                     1.26.18
# wcwidth                     0.2.12
# webcolors                   1.13
# websocket                   1.7.0
# wrapt                       1.15.0
# xarray                      2023.12.0
# yaml                        6.0.1
# zipp                        NA
# zmq                         25.1.2
# zoneinfo                    NA
# zstandard                   0.22.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.19.0
# jupyter_client      8.6.0
# jupyter_core        5.6.1
# jupyterlab          4.1.5
# notebook            6.5.4
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-5.15.0-1042-gcp-x86_64-with-glibc2.31
# -----
# Session information updated at 2024-04-19 22:32
# </pre>
# </details>

# %%
devtools::install_github("cellgeni/sceasy")
install.packages('anndata')
library(anndata)
# Out:
# Downloading GitHub repo cellgeni/sceasy@HEAD
# rprojroot  (2.0.3  -> 2.0.4 ) [CRAN]
# withr      (2.5.1  -> 2.5.2 ) [CRAN]
# rlang      (1.1.1  -> 1.1.2 ) [CRAN]
# jsonlite   (1.8.7  -> 1.8.8 ) [CRAN]
# reticulate (1.32.0 -> 1.34.0) [CRAN]
# Installing 5 packages: rprojroot, withr, rlang, jsonlite, reticulate
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
# ── R CMD build ─────────────────────────────────────────────────────────────────
# ✔  checking for file ‘/tmp/RtmpmSbMNq/remotes56cd4a2c54d7/cellgeni-sceasy-0cfc0e3/DESCRIPTION’
# ─  preparing ‘sceasy’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘sceasy_0.0.7.tar.gz’

# %%
library(sceasy)
suppressPackageStartupMessages(library(readxl))
suppressPackageStartupMessages(library(H5weaver))
suppressPackageStartupMessages(library(dplyr))
suppressPackageStartupMessages(library(tidyr))
suppressPackageStartupMessages(library(tibble))
suppressPackageStartupMessages(library(ggplot2))
suppressPackageStartupMessages(library(Seurat))
suppressPackageStartupMessages(library(patchwork))
suppressPackageStartupMessages(library(pheatmap))
suppressPackageStartupMessages(library(lme4))
suppressPackageStartupMessages(library(MAST))
suppressPackageStartupMessages(library(stringr))
library(hise)
library(parallel)
library(DESeq2)
options("mc.cores"=50)
# Out:
# Loading required package: reticulate

# %%
Sys.sleep(3)

# %%
h5ad_FILES<-list.files(path = "05_h5ad_by_celltype/", pattern = ".h5ad", all.files = TRUE,
           full.names = TRUE, recursive = FALSE,
           ignore.case = TRUE, include.dirs = TRUE, no.. = FALSE)
h5ad_FILES
# Out:
#   [1] "05_h5ad_by_celltype//ASDC_Y1D0.h5ad"
#   [2] "05_h5ad_by_celltype//ASDC_Y1D90.h5ad"
#   [3] "05_h5ad_by_celltype//ASDC_Y2D0.h5ad"
#   [4] "05_h5ad_by_celltype//ASDC_Y2D90.h5ad"
#   [5] "05_h5ad_by_celltype//B intermediate_Y1D0.h5ad"
#   [6] "05_h5ad_by_celltype//B intermediate_Y1D90.h5ad"
#   [7] "05_h5ad_by_celltype//B intermediate_Y2D0.h5ad"
#   [8] "05_h5ad_by_celltype//B intermediate_Y2D90.h5ad"
#   [9] "05_h5ad_by_celltype//B memory_Y1D0.h5ad"
#  [10] "05_h5ad_by_celltype//B memory_Y1D90.h5ad"
#  [11] "05_h5ad_by_celltype//B memory_Y2D0.h5ad"
#  [12] "05_h5ad_by_celltype//B memory_Y2D90.h5ad"
#  [13] "05_h5ad_by_celltype//B naive_Y1D0.h5ad"
#  [14] "05_h5ad_by_celltype//B naive_Y1D90.h5ad"
#  [15] "05_h5ad_by_celltype//B naive_Y2D0.h5ad"
#  [16] "05_h5ad_by_celltype//B naive_Y2D90.h5ad"
#  [17] "05_h5ad_by_celltype//CD14 Mono_Y1D0.h5ad"
#  [18] "05_h5ad_by_celltype//CD14 Mono_Y1D90.h5ad"
#  [19] "05_h5ad_by_celltype//CD14 Mono_Y2D0.h5ad"
#  [20] "05_h5ad_by_celltype//CD14 Mono_Y2D90.h5ad"
#  [21] "05_h5ad_by_celltype//CD16 Mono_Y1D0.h5ad"
#  [22] "05_h5ad_by_celltype//CD16 Mono_Y1D90.h5ad"
#  [23] "05_h5ad_by_celltype//CD16 Mono_Y2D0.h5ad"
#  [24] "05_h5ad_by_celltype//CD16 Mono_Y2D90.h5ad"
#  [25] "05_h5ad_by_celltype//CD4 CTL_Y1D0.h5ad"
#  [26] "05_h5ad_by_celltype//CD4 CTL_Y1D90.h5ad"
#  [27] "05_h5ad_by_celltype//CD4 CTL_Y2D0.h5ad"
#  [28] "05_h5ad_by_celltype//CD4 CTL_Y2D90.h5ad"
#  [29] "05_h5ad_by_celltype//CD4 Naive_Y1D0.h5ad"
#  [30] "05_h5ad_by_celltype//CD4 Naive_Y1D90.h5ad"
#  [31] "05_h5ad_by_celltype//CD4 Naive_Y2D0.h5ad"
#  [32] "05_h5ad_by_celltype//CD4 Naive_Y2D90.h5ad"
#  [33] "05_h5ad_by_celltype//CD4 Proliferating_Y1D0.h5ad"
#  [34] "05_h5ad_by_celltype//CD4 Proliferating_Y1D90.h5ad"
#  [35] "05_h5ad_by_celltype//CD4 Proliferating_Y2D0.h5ad"
#  [36] "05_h5ad_by_celltype//CD4 Proliferating_Y2D90.h5ad"
#  [37] "05_h5ad_by_celltype//CD4 TCM_Y1D0.h5ad"
#  [38] "05_h5ad_by_celltype//CD4 TCM_Y1D90.h5ad"
#  [39] "05_h5ad_by_celltype//CD4 TCM_Y2D0.h5ad"
#  [40] "05_h5ad_by_celltype//CD4 TCM_Y2D90.h5ad"
#  [41] "05_h5ad_by_celltype//CD4 TEM_Y1D0.h5ad"
#  [42] "05_h5ad_by_celltype//CD4 TEM_Y1D90.h5ad"
#  [43] "05_h5ad_by_celltype//CD4 TEM_Y2D0.h5ad"
#  [44] "05_h5ad_by_celltype//CD4 TEM_Y2D90.h5ad"
#  [45] "05_h5ad_by_celltype//CD8 Naive_Y1D0.h5ad"
#  [46] "05_h5ad_by_celltype//CD8 Naive_Y1D90.h5ad"
#  [47] "05_h5ad_by_celltype//CD8 Naive_Y2D0.h5ad"
#  [48] "05_h5ad_by_celltype//CD8 Naive_Y2D90.h5ad"
#  [49] "05_h5ad_by_celltype//CD8 Proliferating_Y1D0.h5ad"
#  [50] "05_h5ad_by_celltype//CD8 Proliferating_Y1D90.h5ad"
#  [51] "05_h5ad_by_celltype//CD8 Proliferating_Y2D0.h5ad"
#  [52] "05_h5ad_by_celltype//CD8 Proliferating_Y2D90.h5ad"
#  [53] "05_h5ad_by_celltype//CD8 TCM_Y1D0.h5ad"
#  [54] "05_h5ad_by_celltype//CD8 TCM_Y1D90.h5ad"
#  [55] "05_h5ad_by_celltype//CD8 TCM_Y2D0.h5ad"
#  [56] "05_h5ad_by_celltype//CD8 TCM_Y2D90.h5ad"
#  [57] "05_h5ad_by_celltype//CD8 TEM_Y1D0.h5ad"
#  [58] "05_h5ad_by_celltype//CD8 TEM_Y1D90.h5ad"
#  [59] "05_h5ad_by_celltype//CD8 TEM_Y2D0.h5ad"
#  [60] "05_h5ad_by_celltype//CD8 TEM_Y2D90.h5ad"
#  [61] "05_h5ad_by_celltype//CD8 TEMRA_Y1D0.h5ad"
#  [62] "05_h5ad_by_celltype//CD8 TEMRA_Y1D90.h5ad"
#  [63] "05_h5ad_by_celltype//CD8 TEMRA_Y2D0.h5ad"
#  [64] "05_h5ad_by_celltype//CD8 TEMRA_Y2D90.h5ad"
#  [65] "05_h5ad_by_celltype//cDC1_Y1D0.h5ad"
#  [66] "05_h5ad_by_celltype//cDC1_Y1D90.h5ad"
#  [67] "05_h5ad_by_celltype//cDC1_Y2D0.h5ad"
#  [68] "05_h5ad_by_celltype//cDC1_Y2D90.h5ad"
#  [69] "05_h5ad_by_celltype//cDC2_Y1D0.h5ad"
#  [70] "05_h5ad_by_celltype//cDC2_Y1D90.h5ad"
#  [71] "05_h5ad_by_celltype//cDC2_Y2D0.h5ad"
#  [72] "05_h5ad_by_celltype//cDC2_Y2D90.h5ad"
#  [73] "05_h5ad_by_celltype//dnT_Y1D0.h5ad"
#  [74] "05_h5ad_by_celltype//dnT_Y1D90.h5ad"
#  [75] "05_h5ad_by_celltype//dnT_Y2D0.h5ad"
#  [76] "05_h5ad_by_celltype//dnT_Y2D90.h5ad"
#  [77] "05_h5ad_by_celltype//Doublet_Y1D0.h5ad"
#  [78] "05_h5ad_by_celltype//Doublet_Y1D90.h5ad"
#  [79] "05_h5ad_by_celltype//Doublet_Y2D0.h5ad"
#  [80] "05_h5ad_by_celltype//Doublet_Y2D90.h5ad"
#  [81] "05_h5ad_by_celltype//Eryth_Y1D0.h5ad"
#  [82] "05_h5ad_by_celltype//Eryth_Y1D90.h5ad"
#  [83] "05_h5ad_by_celltype//Eryth_Y2D0.h5ad"
#  [84] "05_h5ad_by_celltype//Eryth_Y2D90.h5ad"
#  [85] "05_h5ad_by_celltype//gdT_Y1D0.h5ad"
#  [86] "05_h5ad_by_celltype//gdT_Y1D90.h5ad"
#  [87] "05_h5ad_by_celltype//gdT_Y2D0.h5ad"
#  [88] "05_h5ad_by_celltype//gdT_Y2D90.h5ad"
#  [89] "05_h5ad_by_celltype//HSPC_Y1D0.h5ad"
#  [90] "05_h5ad_by_celltype//HSPC_Y1D90.h5ad"
#  [91] "05_h5ad_by_celltype//HSPC_Y2D0.h5ad"
#  [92] "05_h5ad_by_celltype//HSPC_Y2D90.h5ad"
#  [93] "05_h5ad_by_celltype//ILC_Y1D0.h5ad"
#  [94] "05_h5ad_by_celltype//ILC_Y1D90.h5ad"
#  [95] "05_h5ad_by_celltype//ILC_Y2D0.h5ad"
#  [96] "05_h5ad_by_celltype//ILC_Y2D90.h5ad"
#  [97] "05_h5ad_by_celltype//MAIT_Y1D0.h5ad"
#  [98] "05_h5ad_by_celltype//MAIT_Y1D90.h5ad"
#  [99] "05_h5ad_by_celltype//MAIT_Y2D0.h5ad"
# [100] "05_h5ad_by_celltype//MAIT_Y2D90.h5ad"
# [101] "05_h5ad_by_celltype//NK Proliferating_Y1D0.h5ad"
# [102] "05_h5ad_by_celltype//NK Proliferating_Y1D90.h5ad"
# [103] "05_h5ad_by_celltype//NK Proliferating_Y2D0.h5ad"
# [104] "05_h5ad_by_celltype//NK Proliferating_Y2D90.h5ad"
# [105] "05_h5ad_by_celltype//NK_CD56bright_Y1D0.h5ad"
# [106] "05_h5ad_by_celltype//NK_CD56bright_Y1D90.h5ad"
# [107] "05_h5ad_by_celltype//NK_CD56bright_Y2D0.h5ad"
# [108] "05_h5ad_by_celltype//NK_CD56bright_Y2D90.h5ad"
# [109] "05_h5ad_by_celltype//NK_Y1D0.h5ad"
# [110] "05_h5ad_by_celltype//NK_Y1D90.h5ad"
# [111] "05_h5ad_by_celltype//NK_Y2D0.h5ad"
# [112] "05_h5ad_by_celltype//NK_Y2D90.h5ad"
# [113] "05_h5ad_by_celltype//pDC_Y1D0.h5ad"
# [114] "05_h5ad_by_celltype//pDC_Y1D90.h5ad"
# [115] "05_h5ad_by_celltype//pDC_Y2D0.h5ad"
# [116] "05_h5ad_by_celltype//pDC_Y2D90.h5ad"
# [117] "05_h5ad_by_celltype//Plasmablast_Y1D0.h5ad"
# [118] "05_h5ad_by_celltype//Plasmablast_Y1D90.h5ad"
# [119] "05_h5ad_by_celltype//Plasmablast_Y2D0.h5ad"
# [120] "05_h5ad_by_celltype//Plasmablast_Y2D90.h5ad"
# [121] "05_h5ad_by_celltype//Platelet_Y1D0.h5ad"
# [122] "05_h5ad_by_celltype//Platelet_Y1D90.h5ad"
# [123] "05_h5ad_by_celltype//Platelet_Y2D0.h5ad"
# [124] "05_h5ad_by_celltype//Platelet_Y2D90.h5ad"
# [125] "05_h5ad_by_celltype//Treg Memory_Y1D0.h5ad"
# [126] "05_h5ad_by_celltype//Treg Memory_Y1D90.h5ad"
# [127] "05_h5ad_by_celltype//Treg Memory_Y2D0.h5ad"
# [128] "05_h5ad_by_celltype//Treg Memory_Y2D90.h5ad"
# [129] "05_h5ad_by_celltype//Treg Naive_Y1D0.h5ad"
# [130] "05_h5ad_by_celltype//Treg Naive_Y1D90.h5ad"
# [131] "05_h5ad_by_celltype//Treg Naive_Y2D0.h5ad"
# [132] "05_h5ad_by_celltype//Treg Naive_Y2D90.h5ad"

# %% [markdown]
# # MAST

# %%
for (files in h5ad_FILES){
pbmc <-sceasy::convertFormat(files, from="anndata", to="seurat")
print(files)
pbmc <- NormalizeData(pbmc, normalization.method = "LogNormalize", scale.factor = 10000)
pbmc@meta.data$CDR <- scale(pbmc@meta.data$nFeature_RNA, scale = TRUE, center = TRUE)
pbmc@meta.data$CMV<-pbmc@meta.data$CMV.IgG.Serology.Result.Interpretation
pbmc@meta.data$Visit<-gsub(" ","_",pbmc@meta.data$sample.visitName)
pbmc@meta.data$Sex<-pbmc@meta.data$subject.biologicalSex
pbmc@meta.data$Donor<-pbmc@meta.data$subject.subjectGuid

i =unique(pbmc@meta.data$Visit)
selCells <- pbmc@meta.data %>%
                      as.data.frame() %>%
                      rownames(.)
esetNormsub2 <- pbmc[, selCells]
normCountssub <- esetNormsub2[["RNA"]]@data


min_expr = 0.1
selGenes <- data.frame(num_cells_expressed =
                                 rowSums(normCountssub > min_expr)) %>%
                      rownames_to_column(var = "Gene") %>%
                      filter(num_cells_expressed >=
                             min_expr*length(selCells))
# remove ribosomal, mitochondrial, LINCs, orfs
selGenes <-selGenes$Gene[!grepl("^RP|^MT-|^LINC|orf",selGenes$Gene)]
normCountssub <- normCountssub[selGenes, ]


fdat <- data.frame(rownames(x = normCountssub))
colnames(x = fdat)[1] <- "primerid"
rownames(x = fdat) <- fdat[, 1]


cdat <- esetNormsub2@meta.data %>%
                  as.data.frame() %>%
                  dplyr::select(pbmc_sample_id,Donor,cohort.cohortGuid,
                                CMV,Sex,Visit,CDR)
          cdat <- cdat[colnames(normCountssub), , drop = F]
          table(rownames(cdat) == colnames(normCountssub))
cdat[] <- lapply(cdat, as.character)
cdat$cohort.cohortGuid <- factor(cdat$cohort.cohortGuid)
cdat$cohort.cohortGuid <- relevel(cdat$cohort.cohortGuid, ref = "BR1")


cdat$CDR<-as.numeric(cdat$CDR)
sca <- FromMatrix(exprsArray = as.matrix(normCountssub),
                            cData = cdat,
                            fData = fdat)
zlmCond <- zlm(formula = ~cohort.cohortGuid+Sex+CMV+CDR +(1|Donor),
                         sca = sca,
                         method = "glmer",
                         ebayes = FALSE,
                         parallel = TRUE,
               fitArgsD=list(nAGQ = 0,
                             control = glmerControl(calc.derivs = FALSE)))


summaryCond <- summary(zlmCond, doLRT='cohort.cohortGuidBR2'  ,parallel = TRUE)

summaryDt <- summaryCond$datatable

write.csv(summaryDt,paste0("05B_MAST_BR1_VS_BR2/",as.character(unique(pbmc[[]]$predicted.celltype.l2.5)),'-',i,".csv"))

    
rm(pbmc)    
gc()    
    
}
# Out:
# X -> counts
# [1] "05_h5ad_by_celltype//CD14 Mono_Y1D0.h5ad"
# `cData` has no wellKey.  I'll make something up.
#
# Assuming data assay in position 1, with name et is log-transformed.
#
#
# Done!
#
# Combining coefficients and standard errors
#
# Calculating log-fold changes
#
# Calculating likelihood ratio tests
#
# Refitting on reduced model...
#
#
# Done!
#
# X -> counts
# [1] "05_h5ad_by_celltype//CD14 Mono_Y1D90.h5ad"
# `cData` has no wellKey.  I'll make something up.
#
# Assuming data assay in position 1, with name et is log-transformed.
#
#
# Done!
#
# Combining coefficients and standard errors
#
# Calculating log-fold changes
#
# Calculating likelihood ratio tests
#
# Refitting on reduced model...

# %% [markdown]
# # Deseq2

# %% [markdown]
# ### L2

# %%
h5ad_FILES<-list.files(path = "01_h5ad_by_AIFI_L2/", pattern = ".h5ad", all.files = TRUE,
           full.names = TRUE, recursive = FALSE,
           ignore.case = TRUE, include.dirs = TRUE,no.. = FALSE)
h5ad_FILES

# %%
mclapply(h5ad_FILES,function(files){
pbmc <- read_h5ad(files)
pbmc <- CreateSeuratObject(counts = t(pbmc$X), meta.data = pbmc$obs)
selCells <- pbmc@meta.data %>%as.data.frame() %>%rownames(.)

esetNormsub2 <- pbmc[, selCells]
normCountssub <- esetNormsub2[["RNA"]]@counts


min_expr = 0.1
selGenes <- data.frame(num_cells_expressed =
                                 rowSums(normCountssub > min_expr)) %>%
                      rownames_to_column(var = "Gene") %>%
                      filter(num_cells_expressed >=
                             min_expr*length(selCells))
# remove ribosomal, mitochondrial, LINCs, orfs
selGenes <-selGenes$Gene[!grepl("^RP|^MT-|^LINC|orf",selGenes$Gene)]
normCountssub <- normCountssub[selGenes, ]
df=AggregateExpression(pbmc,assays = "RNA",features = selGenes,return.seurat = FALSE,group.by = "pbmc_sample_id",slot = "counts")$RNA

meta_data<-unique(pbmc@meta.data[c('pbmc_sample_id',
                                   'CMV.IgG.Serology.Result.Interpretation',
                                   'subject.biologicalSex','batch_id',
                                   'cohort.cohortGuid',
                                   'subject.subjectGuid')])
rownames(meta_data)<-meta_data$pbmc_sample_id
df=df[,rownames(meta_data)]
dds <- DESeqDataSetFromMatrix(df, colData = meta_data, 
                              design = ~  cohort.cohortGuid+
                                          subject.biologicalSex+
                                          CMV.IgG.Serology.Result.Interpretation)
dds <- DESeq(dds,parallel=FALSE)

res <- data.frame(results(dds,contrast=c("cohort.cohortGuid", "BR1", "BR2")))
res$celltype<-as.character(unique(pbmc[[]]$AIFI_L3))

write.csv(res,paste0("02B_DESeq2_BR1_VS_BR2_L2/",as.character(unique(pbmc[[]]$AIFI_L2)),".csv"))
},mc.cores=3)

# %% [markdown]
# ### L3

# %%
h5ad_FILES<-list.files(path = "01_h5ad_by_AIFI_L3/", pattern = ".h5ad", all.files = TRUE,
           full.names = TRUE, recursive = FALSE,
           ignore.case = TRUE, include.dirs = TRUE,no.. = FALSE)
h5ad_FILES
# Out:
#  [1] "01_h5ad_by_AIFI_L3//Activated memory B cell.h5ad"
#  [2] "01_h5ad_by_AIFI_L3//Adaptive NK cell.h5ad"
#  [3] "01_h5ad_by_AIFI_L3//ASDC.h5ad"
#  [4] "01_h5ad_by_AIFI_L3//BaEoMaP cell.h5ad"
#  [5] "01_h5ad_by_AIFI_L3//C1Q+ CD16 monocyte.h5ad"
#  [6] "01_h5ad_by_AIFI_L3//CD14+ cDC2.h5ad"
#  [7] "01_h5ad_by_AIFI_L3//CD27- effector B cell.h5ad"
#  [8] "01_h5ad_by_AIFI_L3//CD27+ effector B cell.h5ad"
#  [9] "01_h5ad_by_AIFI_L3//CD4 MAIT.h5ad"
# [10] "01_h5ad_by_AIFI_L3//CD56bright NK cell.h5ad"
# [11] "01_h5ad_by_AIFI_L3//CD8 MAIT.h5ad"
# [12] "01_h5ad_by_AIFI_L3//CD8aa.h5ad"
# [13] "01_h5ad_by_AIFI_L3//CD95 memory B cell.h5ad"
# [14] "01_h5ad_by_AIFI_L3//cDC1.h5ad"
# [15] "01_h5ad_by_AIFI_L3//CLP cell.h5ad"
# [16] "01_h5ad_by_AIFI_L3//CM CD4 T cell.h5ad"
# [17] "01_h5ad_by_AIFI_L3//CM CD8 T cell.h5ad"
# [18] "01_h5ad_by_AIFI_L3//CMP cell.h5ad"
# [19] "01_h5ad_by_AIFI_L3//Core CD14 monocyte.h5ad"
# [20] "01_h5ad_by_AIFI_L3//Core CD16 monocyte.h5ad"
# [21] "01_h5ad_by_AIFI_L3//Core memory B cell.h5ad"
# [22] "01_h5ad_by_AIFI_L3//Core naive B cell.h5ad"
# [23] "01_h5ad_by_AIFI_L3//Core naive CD4 T cell.h5ad"
# [24] "01_h5ad_by_AIFI_L3//Core naive CD8 T cell .h5ad"
# [25] "01_h5ad_by_AIFI_L3//DN T cell.h5ad"
# [26] "01_h5ad_by_AIFI_L3//Early memory B cell.h5ad"
# [27] "01_h5ad_by_AIFI_L3//Erythrocyte.h5ad"
# [28] "01_h5ad_by_AIFI_L3//GZMB- CD27- EM CD4 T cell.h5ad"
# [29] "01_h5ad_by_AIFI_L3//GZMB- CD27+ EM CD4 T cell.h5ad"
# [30] "01_h5ad_by_AIFI_L3//GZMB+ Vd2 gdT.h5ad"
# [31] "01_h5ad_by_AIFI_L3//GZMK- CD27+ EM CD8 T cell.h5ad"
# [32] "01_h5ad_by_AIFI_L3//GZMK- CD56dim NK cell.h5ad"
# [33] "01_h5ad_by_AIFI_L3//GZMK+ CD27+ EM CD8 T cell.h5ad"
# [34] "01_h5ad_by_AIFI_L3//GZMK+ CD56dim NK cell.h5ad"
# [35] "01_h5ad_by_AIFI_L3//GZMK+ memory CD4 Treg.h5ad"
# [36] "01_h5ad_by_AIFI_L3//GZMK+ Vd2 gdT.h5ad"
# [37] "01_h5ad_by_AIFI_L3//HLA-DRhi cDC2.h5ad"
# [38] "01_h5ad_by_AIFI_L3//IL1B+ CD14 monocyte.h5ad"
# [39] "01_h5ad_by_AIFI_L3//ILC.h5ad"
# [40] "01_h5ad_by_AIFI_L3//Intermediate monocyte.h5ad"
# [41] "01_h5ad_by_AIFI_L3//ISG+ CD14 monocyte.h5ad"
# [42] "01_h5ad_by_AIFI_L3//ISG+ CD16 monocyte.h5ad"
# [43] "01_h5ad_by_AIFI_L3//ISG+ CD56dim NK cell.h5ad"
# [44] "01_h5ad_by_AIFI_L3//ISG+ cDC2.h5ad"
# [45] "01_h5ad_by_AIFI_L3//ISG+ MAIT.h5ad"
# [46] "01_h5ad_by_AIFI_L3//ISG+ memory CD4 T cell.h5ad"
# [47] "01_h5ad_by_AIFI_L3//ISG+ memory CD8 T cell.h5ad"
# [48] "01_h5ad_by_AIFI_L3//ISG+ naive B cell.h5ad"
# [49] "01_h5ad_by_AIFI_L3//ISG+ naive CD4 T cell.h5ad"
# [50] "01_h5ad_by_AIFI_L3//ISG+ naive CD8 T cell.h5ad"
# [51] "01_h5ad_by_AIFI_L3//KLRB1+ memory CD4 Treg.h5ad"
# [52] "01_h5ad_by_AIFI_L3//KLRB1+ memory CD8 Treg.h5ad"
# [53] "01_h5ad_by_AIFI_L3//KLRF1- effector Vd1 gdT.h5ad"
# [54] "01_h5ad_by_AIFI_L3//KLRF1- GZMB+ CD27- EM CD8 T cell.h5ad"
# [55] "01_h5ad_by_AIFI_L3//KLRF1- GZMB+ CD27- memory CD4 T cell.h5ad"
# [56] "01_h5ad_by_AIFI_L3//KLRF1+ effector Vd1 gdT.h5ad"
# [57] "01_h5ad_by_AIFI_L3//KLRF1+ GZMB+ CD27- EM CD8 T cell.h5ad"
# [58] "01_h5ad_by_AIFI_L3//Memory CD4 Treg.h5ad"
# [59] "01_h5ad_by_AIFI_L3//Memory CD8 Treg.h5ad"
# [60] "01_h5ad_by_AIFI_L3//Naive CD4 Treg.h5ad"
# [61] "01_h5ad_by_AIFI_L3//Naive Vd1 gdT.h5ad"
# [62] "01_h5ad_by_AIFI_L3//pDC.h5ad"
# [63] "01_h5ad_by_AIFI_L3//Plasma cell.h5ad"
# [64] "01_h5ad_by_AIFI_L3//Platelet.h5ad"
# [65] "01_h5ad_by_AIFI_L3//Proliferating NK cell.h5ad"
# [66] "01_h5ad_by_AIFI_L3//Proliferating T cell.h5ad"
# [67] "01_h5ad_by_AIFI_L3//SOX4+ naive CD4 T cell.h5ad"
# [68] "01_h5ad_by_AIFI_L3//SOX4+ naive CD8 T cell.h5ad"
# [69] "01_h5ad_by_AIFI_L3//SOX4+ Vd1 gdT.h5ad"
# [70] "01_h5ad_by_AIFI_L3//Transitional B cell.h5ad"
# [71] "01_h5ad_by_AIFI_L3//Type 2 polarized memory B cell.h5ad"

# %%
mclapply(h5ad_FILES,function(files){
pbmc <- read_h5ad(files)
pbmc <- CreateSeuratObject(counts = t(pbmc$X), meta.data = pbmc$obs)
selCells <- pbmc@meta.data %>%as.data.frame() %>%rownames(.)

esetNormsub2 <- pbmc[, selCells]
normCountssub <- esetNormsub2[["RNA"]]@counts


min_expr = 0.1
selGenes <- data.frame(num_cells_expressed =
                                 rowSums(normCountssub > min_expr)) %>%
                      rownames_to_column(var = "Gene") %>%
                      filter(num_cells_expressed >=
                             min_expr*length(selCells))
# remove ribosomal, mitochondrial, LINCs, orfs
selGenes <-selGenes$Gene[!grepl("^RP|^MT-|^LINC|orf",selGenes$Gene)]
normCountssub <- normCountssub[selGenes, ]
df=AggregateExpression(pbmc,assays = "RNA",features = selGenes,return.seurat = FALSE,group.by = "pbmc_sample_id",slot = "counts")$RNA

meta_data<-unique(pbmc@meta.data[c('pbmc_sample_id',
                                   'CMV.IgG.Serology.Result.Interpretation',
                                   'subject.biologicalSex','batch_id',
                                   'cohort.cohortGuid',
                                   'subject.subjectGuid')])
rownames(meta_data)<-meta_data$pbmc_sample_id
df=df[,rownames(meta_data)]
dds <- DESeqDataSetFromMatrix(df, colData = meta_data, 
                              design = ~  cohort.cohortGuid+
                                          subject.biologicalSex+
                                          CMV.IgG.Serology.Result.Interpretation)
dds <- DESeq(dds,parallel=FALSE)

res <- data.frame(results(dds,contrast=c("cohort.cohortGuid", "BR1", "BR2")))
res$celltype<-as.character(unique(pbmc[[]]$AIFI_L3))

write.csv(res,paste0("02B_DESeq2_BR1_VS_BR2_L3/",as.character(unique(pbmc[[]]$AIFI_L3)),".csv"))
},mc.cores=3)

# %% [markdown]
# ### L3.5

# %%
h5ad_FILES<-list.files(path = "01_h5ad_by_AIFI_L3.5/", pattern = ".h5ad", all.files = TRUE,
           full.names = TRUE, recursive = FALSE,
           ignore.case = TRUE, include.dirs = TRUE,no.. = FALSE)
h5ad_FILES
# Out:
#  [1] "01_h5ad_by_AIFI_L3//Activated memory B cell.h5ad"
#  [2] "01_h5ad_by_AIFI_L3//Adaptive NK cell.h5ad"
#  [3] "01_h5ad_by_AIFI_L3//ASDC.h5ad"
#  [4] "01_h5ad_by_AIFI_L3//BaEoMaP cell.h5ad"
#  [5] "01_h5ad_by_AIFI_L3//C1Q+ CD16 monocyte.h5ad"
#  [6] "01_h5ad_by_AIFI_L3//CD14+ cDC2.h5ad"
#  [7] "01_h5ad_by_AIFI_L3//CD27- effector B cell.h5ad"
#  [8] "01_h5ad_by_AIFI_L3//CD27+ effector B cell.h5ad"
#  [9] "01_h5ad_by_AIFI_L3//CD4 MAIT.h5ad"
# [10] "01_h5ad_by_AIFI_L3//CD56bright NK cell.h5ad"
# [11] "01_h5ad_by_AIFI_L3//CD8 MAIT.h5ad"
# [12] "01_h5ad_by_AIFI_L3//CD8aa.h5ad"
# [13] "01_h5ad_by_AIFI_L3//CD95 memory B cell.h5ad"
# [14] "01_h5ad_by_AIFI_L3//cDC1.h5ad"
# [15] "01_h5ad_by_AIFI_L3//CLP cell.h5ad"
# [16] "01_h5ad_by_AIFI_L3//CM CD4 T cell.h5ad"
# [17] "01_h5ad_by_AIFI_L3//CM CD8 T cell.h5ad"
# [18] "01_h5ad_by_AIFI_L3//CMP cell.h5ad"
# [19] "01_h5ad_by_AIFI_L3//Core CD14 monocyte.h5ad"
# [20] "01_h5ad_by_AIFI_L3//Core CD16 monocyte.h5ad"
# [21] "01_h5ad_by_AIFI_L3//Core memory B cell.h5ad"
# [22] "01_h5ad_by_AIFI_L3//Core naive B cell.h5ad"
# [23] "01_h5ad_by_AIFI_L3//Core naive CD4 T cell.h5ad"
# [24] "01_h5ad_by_AIFI_L3//Core naive CD8 T cell .h5ad"
# [25] "01_h5ad_by_AIFI_L3//DN T cell.h5ad"
# [26] "01_h5ad_by_AIFI_L3//Early memory B cell.h5ad"
# [27] "01_h5ad_by_AIFI_L3//Erythrocyte.h5ad"
# [28] "01_h5ad_by_AIFI_L3//GZMB- CD27- EM CD4 T cell.h5ad"
# [29] "01_h5ad_by_AIFI_L3//GZMB- CD27+ EM CD4 T cell.h5ad"
# [30] "01_h5ad_by_AIFI_L3//GZMB+ Vd2 gdT.h5ad"
# [31] "01_h5ad_by_AIFI_L3//GZMK- CD27+ EM CD8 T cell.h5ad"
# [32] "01_h5ad_by_AIFI_L3//GZMK- CD56dim NK cell.h5ad"
# [33] "01_h5ad_by_AIFI_L3//GZMK+ CD27+ EM CD8 T cell.h5ad"
# [34] "01_h5ad_by_AIFI_L3//GZMK+ CD56dim NK cell.h5ad"
# [35] "01_h5ad_by_AIFI_L3//GZMK+ memory CD4 Treg.h5ad"
# [36] "01_h5ad_by_AIFI_L3//GZMK+ Vd2 gdT.h5ad"
# [37] "01_h5ad_by_AIFI_L3//HLA-DRhi cDC2.h5ad"
# [38] "01_h5ad_by_AIFI_L3//IL1B+ CD14 monocyte.h5ad"
# [39] "01_h5ad_by_AIFI_L3//ILC.h5ad"
# [40] "01_h5ad_by_AIFI_L3//Intermediate monocyte.h5ad"
# [41] "01_h5ad_by_AIFI_L3//ISG+ CD14 monocyte.h5ad"
# [42] "01_h5ad_by_AIFI_L3//ISG+ CD16 monocyte.h5ad"
# [43] "01_h5ad_by_AIFI_L3//ISG+ CD56dim NK cell.h5ad"
# [44] "01_h5ad_by_AIFI_L3//ISG+ cDC2.h5ad"
# [45] "01_h5ad_by_AIFI_L3//ISG+ MAIT.h5ad"
# [46] "01_h5ad_by_AIFI_L3//ISG+ memory CD4 T cell.h5ad"
# [47] "01_h5ad_by_AIFI_L3//ISG+ memory CD8 T cell.h5ad"
# [48] "01_h5ad_by_AIFI_L3//ISG+ naive B cell.h5ad"
# [49] "01_h5ad_by_AIFI_L3//ISG+ naive CD4 T cell.h5ad"
# [50] "01_h5ad_by_AIFI_L3//ISG+ naive CD8 T cell.h5ad"
# [51] "01_h5ad_by_AIFI_L3//KLRB1+ memory CD4 Treg.h5ad"
# [52] "01_h5ad_by_AIFI_L3//KLRB1+ memory CD8 Treg.h5ad"
# [53] "01_h5ad_by_AIFI_L3//KLRF1- effector Vd1 gdT.h5ad"
# [54] "01_h5ad_by_AIFI_L3//KLRF1- GZMB+ CD27- EM CD8 T cell.h5ad"
# [55] "01_h5ad_by_AIFI_L3//KLRF1- GZMB+ CD27- memory CD4 T cell.h5ad"
# [56] "01_h5ad_by_AIFI_L3//KLRF1+ effector Vd1 gdT.h5ad"
# [57] "01_h5ad_by_AIFI_L3//KLRF1+ GZMB+ CD27- EM CD8 T cell.h5ad"
# [58] "01_h5ad_by_AIFI_L3//Memory CD4 Treg.h5ad"
# [59] "01_h5ad_by_AIFI_L3//Memory CD8 Treg.h5ad"
# [60] "01_h5ad_by_AIFI_L3//Naive CD4 Treg.h5ad"
# [61] "01_h5ad_by_AIFI_L3//Naive Vd1 gdT.h5ad"
# [62] "01_h5ad_by_AIFI_L3//pDC.h5ad"
# [63] "01_h5ad_by_AIFI_L3//Plasma cell.h5ad"
# [64] "01_h5ad_by_AIFI_L3//Platelet.h5ad"
# [65] "01_h5ad_by_AIFI_L3//Proliferating NK cell.h5ad"
# [66] "01_h5ad_by_AIFI_L3//Proliferating T cell.h5ad"
# [67] "01_h5ad_by_AIFI_L3//SOX4+ naive CD4 T cell.h5ad"
# [68] "01_h5ad_by_AIFI_L3//SOX4+ naive CD8 T cell.h5ad"
# [69] "01_h5ad_by_AIFI_L3//SOX4+ Vd1 gdT.h5ad"
# [70] "01_h5ad_by_AIFI_L3//Transitional B cell.h5ad"
# [71] "01_h5ad_by_AIFI_L3//Type 2 polarized memory B cell.h5ad"

# %%
mclapply(h5ad_FILES,function(files){
pbmc <- read_h5ad(files)
pbmc <- CreateSeuratObject(counts = t(pbmc$X), meta.data = pbmc$obs)
selCells <- pbmc@meta.data %>%as.data.frame() %>%rownames(.)

esetNormsub2 <- pbmc[, selCells]
normCountssub <- esetNormsub2[["RNA"]]@counts


min_expr = 0.1
selGenes <- data.frame(num_cells_expressed =
                                 rowSums(normCountssub > min_expr)) %>%
                      rownames_to_column(var = "Gene") %>%
                      filter(num_cells_expressed >=
                             min_expr*length(selCells))
# remove ribosomal, mitochondrial, LINCs, orfs
selGenes <-selGenes$Gene[!grepl("^RP|^MT-|^LINC|orf",selGenes$Gene)]
normCountssub <- normCountssub[selGenes, ]
df=AggregateExpression(pbmc,assays = "RNA",features = selGenes,return.seurat = FALSE,group.by = "pbmc_sample_id",slot = "counts")$RNA

meta_data<-unique(pbmc@meta.data[c('pbmc_sample_id',
                                   'CMV.IgG.Serology.Result.Interpretation',
                                   'subject.biologicalSex','batch_id',
                                   'cohort.cohortGuid',
                                   'subject.subjectGuid')])
rownames(meta_data)<-meta_data$pbmc_sample_id
df=df[,rownames(meta_data)]
dds <- DESeqDataSetFromMatrix(df, colData = meta_data, 
                              design = ~  cohort.cohortGuid+
                                          subject.biologicalSex+
                                          CMV.IgG.Serology.Result.Interpretation)
dds <- DESeq(dds,parallel=FALSE)

res <- data.frame(results(dds,contrast=c("cohort.cohortGuid", "BR1", "BR2")))
res$celltype<-as.character(unique(pbmc[[]]$AIFI_L3.5))

write.csv(res,paste0("02B_DESeq2_BR1_VS_BR2_L3.5/",as.character(unique(pbmc[[]]$AIFI_L3.5)),".csv"))
},mc.cores=3)

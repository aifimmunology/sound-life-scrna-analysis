# %%
suppressPackageStartupMessages(library(plyr))
suppressPackageStartupMessages(library(dplyr))
suppressPackageStartupMessages(library(tidyr))
suppressPackageStartupMessages(library(tibble))
suppressPackageStartupMessages(library(ggplot2))
library(parallel)
library(ggpubr)
library(rstatix)
library(parallel)
library(ggpubr)
library(anndata)
library(ggsci)
library(ggrepel)
library(patchwork)

# %%
file_list<-list.files(path ='/home//jupyter/BRI_Analysis/scRNA/Analysis-Longitudinal_Baselines/04C_LMM_Time', pattern = ".csv", all.files = FALSE,
           full.names = TRUE, recursive = FALSE,
           ignore.case = FALSE, include.dirs = TRUE, no.. = FALSE)

# %%
LMM_list<-mclapply(file_list,read.csv,mc.cores=length(file_list))
LMM_res<-do.call(rbind,LMM_list) %>%
  filter(factor == 'sample.daysSinceFirstVisit') %>%
  group_by(celltype) %>%
  mutate(padj = p.adjust(`Pr...t..`, method = 'BH'))

# %%
LMM_res$Estimate<-as.numeric(LMM_res$Estimate)

# %%
LMM_res %>% filter(Gene=='TSHZ2')
# Out:
#    X    Estimate      Std..Error           df               t.value
# 1    10 -4.959303e-05 1.37528234153207e-05 533.831824101102 -3.60602519046613
# 2  2070 -2.259845e-05 1.82846275968748e-05 1759.28221072034 -1.23592615136522
# 3  2070 -1.191280e-06 3.81831655937268e-06 1774.17530217485 -0.311990969420647
# 4  2070 -6.823383e-07 9.89774454913005e-07 1779.20475743111 -0.689387690954658
# 5  2070  1.251816e-06 1.87904099963434e-06 1837.27724679293 0.666199592906699
# 6  2070  3.990615e-07 1.21115343355216e-06 1822.87061678079 0.32948879520749
# 7  2070 -6.504241e-07 3.0881873091028e-07  1797.60980982038 -2.10616787551363
# 8  2070 -1.034106e-06 7.58221363655558e-07 1792.92594415357 -1.36385795741923
# 9  2070  2.693136e-06 1.31494052217237e-06 1846.50932323668 2.04810464336596
# 10 2070 -4.017697e-07 3.73149626513213e-07 1841.00661174591 -1.07669872854323
# 11 2046  7.043997e-06 2.26002125172047e-06 1818.20062900905 3.11678367342706
# 12 2070 -1.627190e-06 4.45714271354931e-07 1835.250176788   -3.65074765002798
# 13 2070 -3.886435e-07 2.64770690290985e-07 1837.84916135712 -1.46784948215183
# 14 2070 -2.700195e-05 1.55913614699995e-05 1811.03627585572 -1.73185329504256
# 15 2070 -7.497478e-05 1.67683071986164e-05 1787.00424317177 -4.47121929164387
# 16 2070 -5.840569e-05 1.69040651501338e-05 1798.11267818206 -3.45512704448114
# 17 2070 -1.655173e-05 4.67557921632755e-06 1303.81453114784 -3.54003783229927
# 18 2070  1.392489e-06 1.28792182225527e-06 1839.35692111178 1.08119085793547
# 19 2070 -6.436797e-06 1.45260699862273e-06 1785.82012598947 -4.43120360398869
# 20 2070 -1.479452e-05 5.05357277249098e-06 1789.97301788476 -2.92753734475505
# 21 1962 -3.499254e-05 2.87044792037792e-05 1341.56446197407 -1.21906204989129
# 22 2070 -8.066255e-06 3.25638307633886e-06 1789.15011940648 -2.47705945927105
# 23 2070 -1.145473e-05 6.1239258748285e-06  1692.48490547787 -1.87048846015104
# 24 2070 -2.404382e-05 1.16002553752523e-05 1778.81280632033 -2.07269769831954
# 25 2070 -1.811777e-06 1.16719271583201e-06 1829.67313020916 -1.55225192926967
# 26 2070  2.524760e-06 9.20910736328701e-06 1763.63871914315 0.274158999299559
# 27 2070 -2.603272e-06 1.15336340702117e-05 1728.48712440222 -0.225711315492687
# 28 2070 -4.933563e-06 2.56808574517706e-06 1624.83155407889 -1.92110539013289
# 29 2019  1.677615e-05 6.22473729502578e-06 1402.27472783123 2.6950768210955
#    Pr...t..             Gene  celltype
# 1  0.00034009237765401  TSHZ2 Core naive CD4 T cell
# 2  0.216651009559914    TSHZ2 Erythrocyte
# 3  0.755084046730092    TSHZ2 GZMB- CD27- EM CD4 T cell
# 4  0.49066922303195     TSHZ2 GZMB- CD27+ EM CD4 T cell
# 5  0.505367171453975    TSHZ2 GZMB+ Vd2 gdT
# 6  0.741824116314704    TSHZ2 GZMK- CD27+ EM CD8 T cell
# 7  0.035328091794137    TSHZ2 GZMK- CD56dim NK cell
# 8  0.172783470140364    TSHZ2 GZMK+ CD27+ EM CD8 T cell
# 9  0.0406909062291225   TSHZ2 GZMK+ Vd2 gdT
# 10 0.281755949667447    TSHZ2 HLA-DRhi cDC2
# 11 0.00185695625176405  TSHZ2 IL1B+ CD14 monocyte
# 12 0.000268799506684601 TSHZ2 Intermediate monocyte
# 13 0.142316225339103    TSHZ2 ISG+ CD14 monocyte
# 14 0.083469963420903    TSHZ2 ISG+ memory CD4 T cell
# 15 8.26638384277942e-06 TSHZ2 ISG+ naive CD4 T cell
# 16 0.000562805230215767 TSHZ2 KLRB1+ memory CD4 Treg
# 17 0.000414150112084084 TSHZ2 KLRF1- effector Vd1 gdT
# 18 0.279753956323157    TSHZ2 KLRF1- GZMB+ CD27- EM CD8 T cell
# 19 9.93988453791516e-06 TSHZ2 KLRF1+ GZMB+ CD27- EM CD8 T cell
# 20 0.00345971381116085  TSHZ2 Memory CD4 Treg
# 21 0.223034942734542    TSHZ2 Memory CD8 Treg
# 22 0.0133387733969299   TSHZ2 Naive CD4 Treg
# 23 0.0615884881335408   TSHZ2 Naive Vd1 gdT
# 24 0.0383441431726703   TSHZ2 Plasma cell
# 25 0.120774898754659    TSHZ2 Platelet
# 26 0.783994541667612    TSHZ2 Proliferating T cell
# 27 0.821452640769142    TSHZ2 SOX4+ naive CD4 T cell
# 28 0.0548932146051538   TSHZ2 SOX4+ naive CD8 T cell
# 29 0.007121321359782    TSHZ2 SOX4+ Vd1 gdT
#    factor                     padj
# 1  sample.daysSinceFirstVisit 0.0012298290
# 2  sample.daysSinceFirstVisit 0.4082653077
# 3  sample.daysSinceFirstVisit 0.8100594642
# 4  sample.daysSinceFirstVisit 0.5961561426
# 5  sample.daysSinceFirstVisit 0.6928969178
# 6  sample.daysSinceFirstVisit 0.8550903810
# 7  sample.daysSinceFirstVisit 0.0634453102
# 8  sample.daysSinceFirstVisit 0.2552103671
# 9  sample.daysSinceFirstVisit 0.1245656745
# 10 sample.daysSinceFirstVisit 0.4457794650
# 11 sample.daysSinceFirstVisit 0.0177295109
# 12 sample.daysSinceFirstVisit 0.0010813875
# 13 sample.daysSinceFirstVisit 0.2311457418
# 14 sample.daysSinceFirstVisit 0.2444170286
# 15 sample.daysSinceFirstVisit 0.0001263723
# 16 sample.daysSinceFirstVisit 0.0047799361
# 17 sample.daysSinceFirstVisit 0.0097404921
# 18 sample.daysSinceFirstVisit 0.4250175013
# 19 sample.daysSinceFirstVisit 0.0001220448
# 20 sample.daysSinceFirstVisit 0.0119864872
# 21 sample.daysSinceFirstVisit 0.6515755165
# 22 sample.daysSinceFirstVisit 0.0382941781
# 23 sample.daysSinceFirstVisit 0.3037206491
# 24 sample.daysSinceFirstVisit 0.1891974481
# 25 sample.daysSinceFirstVisit 0.3427092835
# 26 sample.daysSinceFirstVisit 0.8878012264
# 27 sample.daysSinceFirstVisit 0.9495619846
# 28 sample.daysSinceFirstVisit 0.2322989670
# 29 sample.daysSinceFirstVisit 0.0809365562

# %%
Plot_list<-list()
for (i in 1:length(unique(LMM_res$celltype))){

data <- LMM_res %>% filter(celltype==unique(LMM_res$celltype)[i])%>% mutate(Expression = case_when(Estimate >0 & padj <=  0.05 ~ "Up-regulated_along_time",
                                                     Estimate < 0 & padj <=  0.05 ~ "Down-regulated_along_time",
                                                     TRUE ~ "Unchanged"))
top <- 20
top_genes <- bind_rows(
  data %>% 
    filter(Expression == 'Up-regulated_along_time') %>% 
    arrange(padj, desc(abs(Estimate))) %>% 
    head(top),
  data %>% 
    filter(Expression == 'Down-regulated_along_time') %>% 
    arrange(padj, desc(abs(Estimate))) %>% 
    head(top)
)
    
Plot_list[[unique(LMM_res$celltype)[i]]]<-ggplot(data, aes(Estimate, -log(padj,10))) +
  geom_point(aes(color = Expression), size =0.1) +
  xlab(expression("Estimate")) + 
  ylab(expression("-log"[10]*"FDR")) +
  scale_color_manual(values = c("Down-regulated_along_time"="dodgerblue3", "Unchanged"="gray50", "Up-regulated_along_time"="firebrick3")) +
  guides(colour = guide_legend(override.aes = list(size=8))) +
  geom_text_repel(data = top_genes,box.padding = 0.5,force= 0.5,max.overlaps=15,

                   mapping = aes(Estimate, -log(padj,10), label = Gene),
                   size = 3)+ ggtitle(unique(LMM_res$celltype)[i])+theme_bw(base_size=11)

}

# %%
options(repr.plot.width = 5, repr.plot.height = 5)

Plot_list[[1]]
# Out:
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 5)

Plot_list
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# Warning message:
# “ggrepel: 22 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 26 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 23 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 24 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# plot without title
# plot without title
# plot without title
# Warning message:
# “ggrepel: 9 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 28 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 2 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 24 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 10 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 24 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 13 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 26 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 12 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 23 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 21 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 21 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 13 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 25 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 10 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 19 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 6 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 20 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 14 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 18 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 14 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 17 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 8 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 8 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 11 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 7 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 2 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# plot without title
# Warning message:
# “ggrepel: 8 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 3 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 23 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 8 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 5 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 9 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 17 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 20 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 11 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 21 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 11 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 5 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 19 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 5 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 10 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 13 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 1 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 1 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 4 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 24 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 23 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 22 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 3 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# Warning message:
# “ggrepel: 3 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 15 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title
# Warning message:
# “ggrepel: 3 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# $`CD27- effector B cell`
#
# $`CD27+ effector B cell`
#
# $`CD4 MAIT`
#
# $`CD56bright NK cell`
#
# $`CD8 MAIT`
#
# $CD8aa
#
# $cDC1
#
# $`CM CD4 T cell`
#
# $`CM CD8 T cell`
#
# $`Core CD14 monocyte`
#
# $`Core CD16 monocyte`
#
# $`Core memory B cell`
#
# $`Core naive B cell`
#
# $`Core naive CD4 T cell`
#
# $`Core naive CD8 T cell `
#
# $`DN T cell`
#
# $Erythrocyte
#
# $`GZMB- CD27- EM CD4 T cell`
#
# $`GZMB- CD27+ EM CD4 T cell`
#
# $`GZMB+ Vd2 gdT`
#
# $`GZMK- CD27+ EM CD8 T cell`
#
# $`GZMK- CD56dim NK cell`
#
# $`GZMK+ CD27+ EM CD8 T cell`
#
# $`GZMK+ Vd2 gdT`
#
# $`HLA-DRhi cDC2`
#
# $`IL1B+ CD14 monocyte`
#
# $`Intermediate monocyte`
#
# $`ISG+ CD14 monocyte`
#
# $`ISG+ memory CD4 T cell`
#
# $`ISG+ naive CD4 T cell`
#
# $`KLRB1+ memory CD4 Treg`
#
# $`KLRF1- effector Vd1 gdT`
#
# $`KLRF1- GZMB+ CD27- EM CD8 T cell`
#
# $`KLRF1+ GZMB+ CD27- EM CD8 T cell`
#
# $`Memory CD4 Treg`
#
# $`Memory CD8 Treg`
#
# $`Naive CD4 Treg`
#
# $`Naive Vd1 gdT`
#
# $`Plasma cell`
#
# $Platelet
#
# $`Proliferating T cell`
#
# $`SOX4+ naive CD4 T cell`
#
# $`SOX4+ naive CD8 T cell`
#
# $`SOX4+ Vd1 gdT`
# plot without title
# plot without title

# %%
options(repr.plot.width = 30, repr.plot.height = 70)

wrap_plots(Plot_list,ncol=5)+ plot_layout(guides = "collect")
# Out:
# ERROR while rich displaying an object: Error in Ops.data.frame(guide_loc, panel_loc): ‘==’ only defined for equally-sized data frames
#
# Traceback:
# 1. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 2. tryCatchList(expr, classes, parentenv, handlers)
# 3. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 4. doTryCatch(return(expr), name, parentenv, handler)
# 5. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 6. repr::mime2repr[[mime]](obj)
# 7. repr_text.default(obj)
# 8. paste(capture.output(print(obj)), collapse = "\n")
# 9. capture.output(print(obj))
# 10. withVisible(...elt(i))
# 11. print(obj)
# 12. print.patchwork(obj)
# 13. build_patchwork(plot, plot$layout$guides %||% "auto")
# 14. lapply(x$plots, plot_table, guides = guides)
# 15. FUN(X[[i]], ...)
# 16. plot_table.ggplot(X[[i]], ...)
# 17. add_guides(gt, guides == "collect")
# 18. unlist(guide_loc == panel_loc)
# 19. Ops.data.frame(guide_loc, panel_loc)
# 20. stop(gettextf("%s only defined for equally-sized data frames",
#   .     sQuote(.Generic)), domain = NA)

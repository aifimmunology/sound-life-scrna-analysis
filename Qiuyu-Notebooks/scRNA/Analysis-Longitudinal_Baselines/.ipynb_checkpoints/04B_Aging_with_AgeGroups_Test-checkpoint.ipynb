# %%
suppressPackageStartupMessages(library(plyr))
suppressPackageStartupMessages(library(dplyr))
suppressPackageStartupMessages(library(tidyr))
suppressPackageStartupMessages(library(tibble))
suppressPackageStartupMessages(library(ggplot2))
suppressPackageStartupMessages(library(DESeq2))
suppressPackageStartupMessages(library(stringr))
library(parallel)
library(ggpubr)
library(rstatix)
library(parallel)
library(ggpubr)
library(anndata)
library(ggsci)
library(ggrepel)

# %%
meta_data<-read.csv('/home//jupyter/BRI_Analysis/scRNA/hise_meta_data_2024-01-23_fixed.csv')

# %%
meta_data<-meta_data %>% filter(Covid_exlcusion=='no',sample.visitName %in% c('Flu Year 1 Day 0'))
meta_data$Ages<-as.numeric(substr(meta_data$sample.drawDate,1,4))-meta_data$subject.birthYear

# %%
colnames(meta_data)
# Out:
#  [1] "X.2"
#  [2] "X.1"
#  [3] "X"
#  [4] "lastUpdated"
#  [5] "sample.id"
#  [6] "sample.bridgingControl"
#  [7] "sample.sampleKitGuid"
#  [8] "sample.visitName"
#  [9] "sample.visitDetails"
# [10] "sample.drawDate"
# [11] "sample.daysSinceFirstVisit"
# [12] "file.id"
# [13] "file.name"
# [14] "file.batchID"
# [15] "file.panel"
# [16] "file.pool"
# [17] "file.fileType"
# [18] "file.majorVersion"
# [19] "subject.id"
# [20] "subject.biologicalSex"
# [21] "subject.birthYear"
# [22] "subject.ethnicity"
# [23] "subject.partnerCode"
# [24] "subject.race"
# [25] "subject.subjectGuid"
# [26] "cohort.cohortGuid"
# [27] "sample.diseaseStatesRecordedAtVisit"
# [28] "pbmc_sample_id"
# [29] "Sample_ID"
# [30] "Sample_Draw_date"
# [31] "Covid_Dose_1"
# [32] "Covid_Dose_2"
# [33] "Covid_exlcusion"
# [34] "CMV.IgG.Serology.Result.Interpretation"
# [35] "BMI"
# [36] "file.name.downloaded"
# [37] "file.path"
# [38] "Flu_Year"
# [39] "Strains_concat"
# [40] "Ages"

# %%
meta_data_subset<-meta_data#%>% filter(cohort.cohortGuid %in% c('BR2'))
meta_data_subset$Ages_scaled<-scale(meta_data_subset$Ages)
bulk_list<-mclapply(meta_data_subset$pbmc_sample_id,function(x){

pbmc <-sceasy::convertFormat(paste0('/home/jupyter/BRI_Analysis/scRNA/h5_cleaned_by_sample/',x,'.h5ad'), from="anndata", to="seurat")
bulk <- Seurat:::PseudobulkExpression(object = pbmc, pb.method = 'aggregate',   group.by = "AIFI_L3",slot = 'counts')$RNA
colnames(bulk)<-paste0(x,":",colnames(bulk))
return(bulk)

},mc.cores=60)

# %%
selected_gene_list<-read.csv('filtered_gene_list.csv')

# %%
celltype='Core naive CD4 T cell'

# %%
matirx_list<-mclapply(bulk_list,function(bulk_matrix){

matching_columns <- grepl(celltype, colnames(bulk_matrix),, fixed = TRUE)
matching_columns<-colnames(bulk_matrix)[matching_columns]
bulk_matrix_single <- as.data.frame(bulk_matrix[, matching_columns, drop = FALSE])
return(bulk_matrix_single)
},mc.cores=60)

df_all<-do.call(cbind,matirx_list)
df_meta_data<-as.data.frame(colnames(df_all))
colnames(df_meta_data)<-'sample_name'
split_columns <- strsplit(df_meta_data$sample_name, ":")
df_meta_data$pbmc_sample_id <- sapply(split_columns, `[`, 1)
df_meta_data$AIFI_L3 <- sapply(split_columns, `[`, 2)
df_meta_data<-left_join(df_meta_data,meta_data_subset)
rownames(df_meta_data)<-df_meta_data$sample_name
selGenes<-selected_gene_list %>% filter(AIFI_L3==celltype) %>% select(gene) %>% pull()  

dds <- DESeqDataSetFromMatrix(df_all[selGenes,], colData = df_meta_data, 
                              design = ~  Ages_scaled+subject.biologicalSex+Ages_scaled*cohort.cohortGuid+
                                          CMV.IgG.Serology.Result.Interpretation)
dds <- DESeq(dds,parallel=FALSE)
# Out:
# Joining with `by = join_by(pbmc_sample_id)`
# converting counts to integer mode
#
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# -- note: fitType='parametric', but the dispersion trend was not well captured by the
#    function: y = a/x + b, and a local regression fit was automatically substituted.
#    specify fitType='local' or 'mean' to avoid this message next time.
#
# final dispersion estimates
#
# fitting model and testing

# %%
data.frame(coef(dds))['TSHZ2',]
# Out:
#       Intercept Ages_scaled subject.biologicalSex_Male_vs_Female
# TSHZ2 10.38443  0.2753116   0.2202245
#       cohort.cohortGuid_BR2_vs_BR1
# TSHZ2 0.02251692
#       CMV.IgG.Serology.Result.Interpretation_Positive_vs_Negative
# TSHZ2 0.04835667
#       Ages_scaled.cohort.cohortGuidBR2
# TSHZ2 -0.0458585

# %%
res <-  results(dds, name="Ages_scaled.cohort.cohortGuid")
# Out:
# Error: subscript contains invalid names
# Traceback:
#
# 1. results(dds, name = "Ages_scaled.cohort.cohortGuid")
# 2. getCoef(object, name)
# 3. mcols(object)[name]
# 4. mcols(object)[name]
# 5. extractCOLS(x, j)
# 6. extractCOLS(x, j)
# 7. normalizeSingleBracketSubscript(i, xstub)
# 8. NSBS(i, x, exact = exact, strict.upper.bound = !allow.append,
#  .     allow.NAs = allow.NAs)
# 9. NSBS(i, x, exact = exact, strict.upper.bound = !allow.append,
#  .     allow.NAs = allow.NAs)
# 10. .subscript_error("subscript contains invalid ", what)
# 11. stop(wmsg(...), call. = FALSE)

# %%
data.frame(res) %>% arrange(padj)
# ACTB       37053.6702 -1.604416e-03  0.13682560 -0.0117259959 0.9906442
# PUF60        753.0594  9.624510e-04  0.08575282  0.0112235489 0.9910451
# WDR73        343.7721  1.459407e-03  0.13506996  0.0108048254 0.9913792
# TRIM28       587.8339 -1.253974e-03  0.11532603 -0.0108732922 0.9913245
# RRP7A        458.9997 -2.753096e-03  0.24208870 -0.0113722599 0.9909264
# ZC3H15      1545.1434 -5.514155e-04  0.06371659 -0.0086541904 0.9930950
# ARPC4       1310.5904 -9.043053e-04  0.10191631 -0.0088730185 0.9929204
# GIMAP6       676.8952  7.762434e-04  0.10176309  0.0076279464 0.9939138
# CAT          349.0370  1.046474e-03  0.13066188  0.0080090267 0.9936098
# KXD1         440.1424  9.145154e-04  0.11554549  0.0079147649 0.9936850
# SRSF2       1251.4905  8.483172e-04  0.16418147  0.0051669483 0.9958774
# DIP2A        471.3037  7.657290e-04  0.15760353  0.0048585778 0.9961234
# EXOSC6       719.2809  3.380230e-04  0.12611892  0.0026801924 0.9978615
# DDA1         364.5879  1.740454e-04  0.08033719  0.0021664364 0.9982714
# IL2RG       2229.6974 -1.133961e-04  0.10831004 -0.0010469583 0.9991646
# RETREG2      381.2081  6.375858e-05  0.11986080  0.0005319385 0.9995756
# ARF6        1079.4968 -3.522371e-06  0.07733096 -0.0000455493 0.9999637
#            padj
# MAN2A1     0.0002061279
# PNRC1      0.0013946574
# TNKS2      0.0022227821
# ERO1A      0.0022227821
# CYLD       0.0022227821
# DNTTIP2    0.0034100069
# ZNF146     0.0034100069
# SYNC       0.0047679019
# EML4       0.0047679019
# IMMT       0.0047679019
# MARCH7     0.0047679019
# HIPK3      0.0047679019
# NUDT5      0.0047679019
# ZNF770     0.0047679019
# BRD4       0.0047679019
# JUND       0.0047679019
# DDX3X      0.0048480629
# TLK1       0.0049071160
# GSPT1      0.0049440816
# NCL        0.0050308974
# ANP32E     0.0054090523
# DOCK10     0.0054090523
# NR1D2      0.0054090523
# SETD2      0.0054090523
# MSL2       0.0054090523
# AK6        0.0054090523
# SSR1       0.0054090523
# SP4        0.0054090523
# TSPYL2     0.0054090523
# VCP        0.0054090523
# ⋮          ⋮
# MAT2B      0.9865430
# RBM22      0.9884324
# TMEM109    0.9889229
# ESYT1      0.9889229
# TMED4      0.9891911
# OTUD6B-AS1 0.9891911
# AP1M1      0.9891911
# SSR3       0.9899146
# GNAS       0.9900869
# PPM1K      0.9920899
# RSRC2      0.9928250
# NCKAP1L    0.9929127
# RING1      0.9943818
# ACTB       0.9943818
# PUF60      0.9943818
# WDR73      0.9943818
# TRIM28     0.9943818
# RRP7A      0.9943818
# ZC3H15     0.9956003
# ARPC4      0.9956003
# GIMAP6     0.9956677
# CAT        0.9956677
# KXD1       0.9956677
# SRSF2      0.9973783
# DIP2A      0.9973783
# EXOSC6     0.9988669
# DDA1       0.9990256
# IL2RG      0.9996678
# RETREG2    0.9998272
# ARF6       0.9999637

# %%
for (celltype in unique(selected_gene_list$AIFI_L3)){
print(celltype)

    
matirx_list<-mclapply(bulk_list,function(bulk_matrix){

matching_columns <- grepl(celltype, colnames(bulk_matrix),, fixed = TRUE)
matching_columns<-colnames(bulk_matrix)[matching_columns]
bulk_matrix_single <- as.data.frame(bulk_matrix[, matching_columns, drop = FALSE])
return(bulk_matrix_single)
},mc.cores=60)

df_all<-do.call(cbind,matirx_list)
df_meta_data<-as.data.frame(colnames(df_all))
colnames(df_meta_data)<-'sample_name'
split_columns <- strsplit(df_meta_data$sample_name, ":")
df_meta_data$pbmc_sample_id <- sapply(split_columns, `[`, 1)
df_meta_data$AIFI_L3 <- sapply(split_columns, `[`, 2)
df_meta_data<-left_join(df_meta_data,meta_data_subset)
rownames(df_meta_data)<-df_meta_data$sample_name
selGenes<-selected_gene_list %>% filter(AIFI_L3==celltype) %>% select(gene) %>% pull()  

dds <- DESeqDataSetFromMatrix(df_all[selGenes,], colData = df_meta_data, 
                              design = ~  Ages+subject.biologicalSex+
                                          CMV.IgG.Serology.Result.Interpretation)
dds <- DESeq(dds,parallel=FALSE)

res <- data.frame(results(dds,contrast=c("sample.visitName", "Flu Year 1 Day 0", "Flu Year 2 Day 0")))
res$celltype<-celltype
res=res %>% arrange(padj) %>% mutate(Direction=case_when(log2FoldChange<0~'HigherInY2D0',log2FoldChange>0~'HigherInY1D0'))
res$Year<-"Y1"
write.csv(res,paste0("01B_DESeq2_Y1D0_VS_Y2D0_L3/",celltype,"_",Cohort,".csv"))

}

# %%
library(ChAI)
library(tidyr)
library(data.table)

# %%
Olink<-read.csv('/home/jupyter/BRI_Analysis/Olink/Cross-Sectional/Olink.csv')

# %%
Olink_wide<-spread(Olink[c('sample.sampleKitGuid','NPX_bridged','Assay')], key = sample.sampleKitGuid, value = NPX_bridged)

# %%
Olink[c('sample.sampleKitGuid','NPX_bridged','Assay')]
# Out:
#         sample.sampleKitGuid NPX_bridged Assay
# 1       KT02289              -0.0809     NPPB
# 2       KT03108              -1.2451     NPPB
# 3       KT02558               1.0804     NPPB
# 4       KT02507               1.9127     NPPB
# 5       KT03011               2.4303     NPPB
# 6       KT02977               2.3685     NPPB
# 7       KT02954               1.8223     NPPB
# 8       KT03024               0.1048     NPPB
# 9       KT02728               1.1355     NPPB
# 10                            0.1270     NPPB
# 11      KT03251              -0.5217     NPPB
# 12      KT01501              -0.7423     NPPB
# 13      KT02751               4.5382     NPPB
# 14      KT03040              -0.2416     NPPB
# 15      KT03948               0.1040     NPPB
# 16      KT02755               2.8576     NPPB
# 17      KT04092               0.4708     NPPB
# 18      KT02573              -1.6329     NPPB
# 19      KT02173               3.4109     NPPB
# ...

# %%
import sys
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import celltypist
import gc
import anndata
from celltypist import models
import h5py
import scipy.sparse as scs
from multiprocessing import Pool

models.download_models()
# Out:
# 📂 Storing models in /root/.celltypist/data/models
# ⏩ Skipping [1/44]: Immune_All_Low.pkl (file exists)
# ⏩ Skipping [2/44]: Immune_All_High.pkl (file exists)
# ⏩ Skipping [3/44]: Adult_CynomolgusMacaque_Hippocampus.pkl (file exists)
# ⏩ Skipping [4/44]: Adult_Human_PancreaticIslet.pkl (file exists)
# ⏩ Skipping [5/44]: Adult_Human_Skin.pkl (file exists)
# ⏩ Skipping [6/44]: Adult_Mouse_Gut.pkl (file exists)
# ⏩ Skipping [7/44]: Adult_Mouse_OlfactoryBulb.pkl (file exists)
# ⏩ Skipping [8/44]: Adult_Pig_Hippocampus.pkl (file exists)
# ⏩ Skipping [9/44]: Adult_RhesusMacaque_Hippocampus.pkl (file exists)
# ⏩ Skipping [10/44]: Autopsy_COVID19_Lung.pkl (file exists)
# ⏩ Skipping [11/44]: COVID19_HumanChallenge_Blood.pkl (file exists)
# ⏩ Skipping [12/44]: COVID19_Immune_Landscape.pkl (file exists)
# ⏩ Skipping [13/44]: Cells_Fetal_Lung.pkl (file exists)
# ⏩ Skipping [14/44]: Cells_Intestinal_Tract.pkl (file exists)
# ⏩ Skipping [15/44]: Cells_Lung_Airway.pkl (file exists)
# ⏩ Skipping [16/44]: Developing_Human_Brain.pkl (file exists)
# ⏩ Skipping [17/44]: Developing_Human_Gonads.pkl (file exists)
# ⏩ Skipping [18/44]: Developing_Human_Hippocampus.pkl (file exists)
# ⏩ Skipping [19/44]: Developing_Human_Organs.pkl (file exists)
# ⏩ Skipping [20/44]: Developing_Human_Thymus.pkl (file exists)
# ⏩ Skipping [21/44]: Developing_Mouse_Brain.pkl (file exists)
# ⏩ Skipping [22/44]: Developing_Mouse_Hippocampus.pkl (file exists)
# ⏩ Skipping [23/44]: Fetal_Human_AdrenalGlands.pkl (file exists)
# ⏩ Skipping [24/44]: Fetal_Human_Pancreas.pkl (file exists)
# ⏩ Skipping [25/44]: Fetal_Human_Pituitary.pkl (file exists)
# ⏩ Skipping [26/44]: Fetal_Human_Retina.pkl (file exists)
# ⏩ Skipping [27/44]: Fetal_Human_Skin.pkl (file exists)
# ⏩ Skipping [28/44]: Healthy_Adult_Heart.pkl (file exists)
# ⏩ Skipping [29/44]: Healthy_COVID19_PBMC.pkl (file exists)
# ⏩ Skipping [30/44]: Healthy_Human_Liver.pkl (file exists)
# ⏩ Skipping [31/44]: Healthy_Mouse_Liver.pkl (file exists)
# ⏩ Skipping [32/44]: Human_AdultAged_Hippocampus.pkl (file exists)
# ⏩ Skipping [33/44]: Human_Developmental_Retina.pkl (file exists)
# ⏩ Skipping [34/44]: Human_Embryonic_YolkSac.pkl (file exists)
# ⏩ Skipping [35/44]: Human_IPF_Lung.pkl (file exists)
# ⏩ Skipping [36/44]: Human_Longitudinal_Hippocampus.pkl (file exists)
# ⏩ Skipping [37/44]: Human_Lung_Atlas.pkl (file exists)
# ⏩ Skipping [38/44]: Human_PF_Lung.pkl (file exists)
# ⏩ Skipping [39/44]: Lethal_COVID19_Lung.pkl (file exists)
# ⏩ Skipping [40/44]: Mouse_Dentate_Gyrus.pkl (file exists)
# ⏩ Skipping [41/44]: Mouse_Isocortex_Hippocampus.pkl (file exists)
# ⏩ Skipping [42/44]: Mouse_Postnatal_DentateGyrus.pkl (file exists)
# ⏩ Skipping [43/44]: Nuclei_Lung_Airway.pkl (file exists)
# ⏩ Skipping [44/44]: Pan_Fetal_Human.pkl (file exists)

# %%
def read_mat(h5_con):
    mat = scs.csc_matrix(
        (h5_con['matrix']['data'][:], # Count values
         h5_con['matrix']['indices'][:], # Row indices
         h5_con['matrix']['indptr'][:]), # Pointers for column positions
        shape = tuple(h5_con['matrix']['shape'][:]) # Matrix dimensions
    )
    return mat

# define a function to obeservation (i.e. metadata)

def read_obs(h5con):
    bc = h5con['matrix']['barcodes'][:]
    bc = [x.decode('UTF-8') for x in bc]

    # Initialized the DataFrame with cell barcodes
    obs_df = pd.DataFrame({ 'barcodes' : bc })

    # Get the list of available metadata columns
    obs_columns = h5con['matrix']['observations'].keys()

    # For each column
    for col in obs_columns:
        # Read the values
        values = h5con['matrix']['observations'][col][:]
        # Check for byte storage
        if(isinstance(values[0], (bytes, bytearray))):
            # Decode byte strings
            values = [x.decode('UTF-8') for x in values]
        # Add column to the DataFrame
        obs_df[col] = values
    
    return obs_df
# define a function to construct anndata object from a h5 file
def read_h5_anndata(h5_file):
    h5_con = h5py.File(h5_file, mode = 'r')
    # extract the expression matrix
    mat = read_mat(h5_con)
    # extract gene names
    genes = h5_con['matrix']['features']['name'][:]
    genes = [x.decode('UTF-8') for x in genes]
    # extract metadata
    obs_df = read_obs(h5_con)
    # construct anndata
    adata = anndata.AnnData(mat.T,
                             obs = obs_df)
    # make sure the gene names aligned
    adata.var_names = genes

    adata.var_names_make_unique()
    return adata

# %%
meta_data=pd.read_csv('hise_meta_data_2024-01-23_fixed.csv')

# %%
def process_and_annotate_pbmc(args):
    # Read data
    data_file, model_base_path, output_base_path = args
    pbmc = read_h5_anndata(data_file)
    
    # Processing testing data
    pbmc_sample_id = pbmc.obs['pbmc_sample_id'].unique().tolist()[0]
    pbmc.obs.index = pbmc.obs['barcodes']
    
    # Normalization and log transformation
    sc.pp.normalize_total(pbmc, target_sum=1e4)
    sc.pp.log1p(pbmc)
    
    # Annotations
    levels = ['L1', 'L2', 'L3', 'L3.5']
    models = {'L1': 'ovr', 'L2': 'ovr', 'L3': 'multinomial', 'L3.5': 'multinomial'}
    predictions = {}

    for level, model_type in models.items():
        model_file = f'{model_base_path}/model_AIFI_{level}_{model_type}.pkl'
        predictions[level] = celltypist.annotate(pbmc, model=model_file)

        # Write out labels
        predictions[level].predicted_labels.reset_index().to_csv(f'{output_base_path}/{pbmc_sample_id}_{level}_predicted_labels.csv')
        # Write out probability matrix
        predictions[level].probability_matrix.reset_index().to_parquet(f'{output_base_path}/{pbmc_sample_id}_{level}_probability_matrix.parquet')
        # Write out decision matrix
        predictions[level].decision_matrix.reset_index().to_parquet(f'{output_base_path}/{pbmc_sample_id}_{level}_decision_matrix.parquet')

# %%
# Extracting the file paths from the 'meta_data' DataFrame.
file_list=meta_data['file.path']
# Setting the base path where the model files are stored and outpupath
model_base_path='/home/jupyter/AIFI_Reference_Model_Celltypist/Models'
output_base_path='Labels/'

# Creating a list of tuples, where each tuple contains the arguments required for a single function call.

args_list = [(file, model_base_path, output_base_path) for file in file_list]

with Pool(processes=60) as pool:
    pool.map(process_and_annotate_pbmc, args_list)
# Out:
# 🔬 Input data has 1137 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 14418 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 12837 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19537 cells and 33538 genes
# 🔬 Input data has 18094 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 14433 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 21940 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 16266 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19585 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20013 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18758 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16389 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16733 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17079 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17886 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18937 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 15753 cells and 33538 genes
# 🔬 Input data has 16812 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17597 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 15270 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16653 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19123 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16191 cells and 33538 genes
# 🔬 Input data has 17397 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17718 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19541 cells and 33538 genes
# 🔬 Input data has 25230 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20856 cells and 33538 genes
# 🔬 Input data has 17744 cells and 33538 genes
# 🔬 Input data has 17425 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18672 cells and 33538 genes
# 🔬 Input data has 17641 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19294 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19960 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19917 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17219 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20651 cells and 33538 genes
# 🔬 Input data has 19733 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18398 cells and 33538 genes
# 🔬 Input data has 20186 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21560 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18171 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16918 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18189 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21157 cells and 33538 genes
# 🔬 Input data has 21192 cells and 33538 genes
# 🔬 Input data has 19563 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21373 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19195 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19652 cells and 33538 genes
# 🧬 1077 features used for prediction
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🔬 Input data has 21200 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1077 features used for prediction
# 🔬 Input data has 22139 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1137 cells and 33538 genes
# 🔬 Input data has 19636 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20247 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🔬 Input data has 20289 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 25300 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17637 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 25663 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 29518 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🔬 Input data has 18871 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1077 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🔬 Input data has 12837 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1077 features used for prediction
# 🔬 Input data has 16389 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 14418 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# 🔬 Input data has 14433 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18094 cells and 33538 genes
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1077 features used for prediction
# 🔬 Input data has 19537 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 1077 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1077 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 21940 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 16266 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 18758 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1077 features used for prediction
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 19585 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 20013 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 16733 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 19294 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18189 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 17886 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17079 cells and 33538 genes
# 🧬 1077 features used for prediction
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔬 Input data has 15753 cells and 33538 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16812 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20856 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16653 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 17718 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 16191 cells and 33538 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 18171 cells and 33538 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17597 cells and 33538 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 17744 cells and 33538 genes
# 🔬 Input data has 15270 cells and 33538 genes
# 🔬 Input data has 17219 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18672 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 18937 cells and 33538 genes
# 🔬 Input data has 19123 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 17397 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19541 cells and 33538 genes
# 🔬 Input data has 17425 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 19960 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 17641 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 16918 cells and 33538 genes
# 🔬 Input data has 18398 cells and 33538 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 25230 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 20651 cells and 33538 genes
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 21200 cells and 33538 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19917 cells and 33538 genes
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 19733 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 20186 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 19195 cells and 33538 genes
# 🔬 Input data has 1137 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21373 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 19652 cells and 33538 genes
# 🔬 Input data has 21560 cells and 33538 genes
# 🔬 Input data has 22139 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19563 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20247 cells and 33538 genes
# 🔬 Input data has 17637 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21192 cells and 33538 genes
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21157 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19636 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 18871 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20289 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 25300 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 25663 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 29518 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1912 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# 🧬 1912 features used for prediction
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# 🧬 1912 features used for prediction
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 1912 features used for prediction
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 12837 cells and 33538 genes
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🧬 1912 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# 🧬 1912 features used for prediction
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 14418 cells and 33538 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16389 cells and 33538 genes
# 🧬 1912 features used for prediction
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# 🔬 Input data has 14433 cells and 33538 genes
# 🧬 1912 features used for prediction
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1912 features used for prediction
# 🔬 Input data has 16266 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🔬 Input data has 18094 cells and 33538 genes
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1912 features used for prediction
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔬 Input data has 18189 cells and 33538 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1912 features used for prediction
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 16653 cells and 33538 genes
# ✅ Prediction done!
# 🧬 1912 features used for prediction
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 18758 cells and 33538 genes
# 🔬 Input data has 16733 cells and 33538 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17718 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 15753 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19537 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21940 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 17425 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18672 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 20013 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 19294 cells and 33538 genes
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 16191 cells and 33538 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 15270 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17886 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 18937 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17079 cells and 33538 genes
# 🖋️ Predicting labels
# 🧬 2511 features used for prediction
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20856 cells and 33538 genes
# ⚖️ Scaling input data
# 🔬 Input data has 17219 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 19585 cells and 33538 genes
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 17744 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 16812 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 18171 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 19960 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 17397 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1912 features used for prediction
# 🔬 Input data has 1137 cells and 33538 genes
# 🔬 Input data has 19541 cells and 33538 genes
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 19123 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17597 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 17641 cells and 33538 genes
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 19733 cells and 33538 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18398 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16918 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21157 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 19195 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 20651 cells and 33538 genes
# ✅ Prediction done!
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 19917 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20186 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 19563 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 25230 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21192 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 22139 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18871 cells and 33538 genes
# 🔬 Input data has 21373 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 20247 cells and 33538 genes
# 🔬 Input data has 19636 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19652 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21200 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21560 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 17637 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20289 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 25663 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 25300 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2511 features used for prediction
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🔬 Input data has 29518 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# 🧬 2511 features used for prediction
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# 🧬 2511 features used for prediction
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 12837 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 14418 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1214 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# 🧬 2511 features used for prediction
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 16266 cells and 33538 genes
# 🧬 2511 features used for prediction
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 18094 cells and 33538 genes
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🔬 Input data has 14433 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 16389 cells and 33538 genes
# 🧬 2511 features used for prediction
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 18189 cells and 33538 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 18758 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 16653 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2511 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 15753 cells and 33538 genes
# 🔬 Input data has 16191 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 17425 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1077 features used for prediction
# 🔬 Input data has 17718 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 16733 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17886 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17744 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 21940 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1214 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17079 cells and 33538 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 17219 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 19294 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20013 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 15270 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 16812 cells and 33538 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 18171 cells and 33538 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 18672 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20856 cells and 33538 genes
# 🔬 Input data has 19537 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19541 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17641 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17397 cells and 33538 genes
# 🔬 Input data has 19123 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 18937 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 16918 cells and 33538 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19960 cells and 33538 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 17597 cells and 33538 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19195 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19585 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 18398 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21373 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 19733 cells and 33538 genes
# 🧬 2518 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 20651 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21157 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2518 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 19652 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 19917 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 21192 cells and 33538 genes
# 🧬 2518 features used for prediction
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🔬 Input data has 19563 cells and 33538 genes
# 🔬 Input data has 20289 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18871 cells and 33538 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20186 cells and 33538 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 17637 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 22139 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2518 features used for prediction
# 🔬 Input data has 21200 cells and 33538 genes
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# 🔬 Input data has 1214 cells and 33538 genes
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 20247 cells and 33538 genes
# 🧬 2518 features used for prediction
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 19636 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 21560 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 25230 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# 🧬 2518 features used for prediction
# 🧬 2518 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 25663 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2518 features used for prediction
# 🔬 Input data has 25300 cells and 33538 genes
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 29518 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ✅ Prediction done!
# 🔬 Input data has 18194 cells and 33538 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 19261 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 15039 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1214 cells and 33538 genes
# ✅ Prediction done!
# 🔬 Input data has 21455 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18769 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 18825 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 11372 cells and 33538 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🧬 1077 features used for prediction
# 🔬 Input data has 12705 cells and 33538 genes
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 11414 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 17971 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 14322 cells and 33538 genes
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18227 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 15039 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 20147 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 18194 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 23974 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 19403 cells and 33538 genes
# 🔬 Input data has 17160 cells and 33538 genes
# 🧬 1077 features used for prediction
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 16152 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 20420 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18346 cells and 33538 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1077 features used for prediction
# 🔬 Input data has 19261 cells and 33538 genes
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20456 cells and 33538 genes
# 🧬 1077 features used for prediction
# 🔗 Matching reference genes in the model
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🔬 Input data has 17732 cells and 33538 genes
# 🔬 Input data has 20901 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16781 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17629 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20481 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1077 features used for prediction
# 🧬 1077 features used for prediction
# 🔬 Input data has 22568 cells and 33538 genes
# 🔬 Input data has 23910 cells and 33538 genes
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 16560 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ...
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 16957 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 18642 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 14465 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 16188 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16896 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 17817 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16250 cells and 33538 genes
# 🧬 1912 features used for prediction
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 20099 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 14888 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 13939 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🔬 Input data has 13558 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1077 features used for prediction
# 🔬 Input data has 16743 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 11683 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 13360 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 1912 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 20204 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 17587 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 12174 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21775 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 16255 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 1912 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔬 Input data has 16957 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 10712 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16673 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 11337 cells and 33538 genes
# 🧬 2511 features used for prediction
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🔬 Input data has 20099 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🔬 Input data has 11683 cells and 33538 genes
# 🔬 Input data has 14888 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🧬 2511 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# 🔬 Input data has 17142 cells and 33538 genes
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🔬 Input data has 13811 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# 🔬 Input data has 16947 cells and 33538 genes
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 16896 cells and 33538 genes
# 🧬 2511 features used for prediction
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 19083 cells and 33538 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 21572 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 1912 features used for prediction
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 23743 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1549 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 15076 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 20826 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 14465 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2518 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 13939 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 13558 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 12529 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 17350 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 21322 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16188 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 17817 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 20204 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 16250 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16957 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 16743 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 11683 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 13360 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 21775 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🧬 2511 features used for prediction
# 🔬 Input data has 20099 cells and 33538 genes
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 14307 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 14888 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔬 Input data has 23743 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 10712 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16673 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 16255 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 11337 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 1077 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 14307 cells and 33538 genes
# 🧬 2511 features used for prediction
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 16896 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 19083 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 21572 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 13558 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 20826 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🔬 Input data has 20204 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 16957 cells and 33538 genes
# 🖋️ Predicting labels
# 🔬 Input data has 11683 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1912 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 23743 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 20099 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 14307 cells and 33538 genes
# 🔬 Input data has 14888 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 21775 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2511 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 14307 cells and 33538 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 23743 cells and 33538 genes
# 🔗 Matching reference genes in the model
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🧬 2518 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!

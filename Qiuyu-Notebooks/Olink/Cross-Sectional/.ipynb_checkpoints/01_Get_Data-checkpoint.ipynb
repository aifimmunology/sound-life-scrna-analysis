# %%
library("ggpubr")
library("cowplot")
library("tidyverse")
library(parallel)
library(pheatmap)
library(lme4)
suppressPackageStartupMessages(library(readxl))
suppressPackageStartupMessages(library(dplyr))
suppressPackageStartupMessages(library(tidyr))
suppressPackageStartupMessages(library(tibble))
suppressPackageStartupMessages(library(ggplot2))
suppressPackageStartupMessages(library(parallel))
suppressPackageStartupMessages(library(patchwork))
suppressPackageStartupMessages(library(plyr))
suppressPackageStartupMessages(library(stringr))

# %%
fileDescToDataframe_beta <- function(descriptors,
                                keep_labs = FALSE) {
  descriptors<-descriptors[[1]]
  assertthat::assert_that(typeof(descriptors) == "list")
  assertthat::assert_that(typeof(keep_labs) == "logical")
  
  do.call(
    rbind,
    lapply(
      descriptors,
      function(desc) {
        desc <- unlist(desc)
        desc <- desc[!grepl("scheme", names(desc))]
        names(desc) <- sub("^descriptors.","",names(desc))
        desc <- desc[!grepl("^specimens", names(desc))]
        desc <- desc[!grepl("^lab", names(desc))]
        desc <- desc[!grepl("^emr", names(desc))]
        desc <- desc[!grepl("^survey", names(desc))]
        desc <- desc[!grepl("^revision", names(desc))]
        desc <- desc[!grepl("^file.userTags", names(desc))]
        desc <- as.list(desc)
        df <- as.data.frame(desc)
        df
      }
    )
  )
}

fileDescToDataframe <- function(descriptors,
                                keep_labs = FALSE) {
  assertthat::assert_that(typeof(descriptors) == "list")
  assertthat::assert_that(typeof(keep_labs) == "logical")
  do.call(
    rbind,
    lapply(
      descriptors,
      function(desc) {
        desc <- unlist(desc)
        desc <- desc[!grepl("scheme", names(desc))]
        names(desc) <- sub("^descriptors.","",names(desc))
        desc <- desc[!grepl("^specimens", names(desc))]
        desc <- desc[!grepl("^lab", names(desc))]
        desc <- desc[!grepl("^emr", names(desc))]
        desc <- desc[!grepl("^survey", names(desc))]
        desc <- desc[!grepl("^revision", names(desc))]
        desc <- desc[!grepl("^file.userTags", names(desc))]

        desc <- as.list(desc)
        df <- as.data.frame(desc)
        df
      }
    )
  )
}

# %%
fres1 <- hise::readFiles(list("b494cce8-1314-4f6e-9666-42f0c6e1c702",
                              "00753770-4803-4947-a290-e7469c410067", 
                              "59f5f656-085f-4d0b-a240-68a9eb15e68e", 
                              "1a528317-bbf3-45b7-82c9-529577cf0b15", 
                              "55d5d20a-506a-459e-8315-7d66276fb8f9"))
# Out:
# Querying and downloading data onto IDE...

# %%
fres1<-fileDescToDataframe(fres1)

# %%
first_batch<-read_excel('/home//jupyter/BRI_Claire/Olink/cache/c142f67d-403b-457f-ae17-accc5089399f/20201752_Skene_1820_NPX_2020-12-03.xlsx')

# %%
first_batch$batch<-'first'

# %%
batch1<-read.csv(fres1$file[1])
batch2<-read.csv(fres1$file[2])
batch3<-read.csv(fres1$file[3])
batch4<-read.csv(fres1$file[4])
batch5<-read.csv(fres1$file[5])

# %%
batch1$batch<-"Batch1"
batch2$batch<-"Batch2"
batch3$batch<-"Batch3"
batch4$batch<-"Batch4"
batch5$batch<-"Batch5"

# %%
batch3$sample.sampleKitGuid<-batch3$SampleKitGuid

# %%
batch1$sample.sampleKitGuid<-batch1$SampleKitGuid

# %%
batch5$sample.sampleKitGuid<-batch5$SampleKitGuid

# %%
first_batch$sample.sampleKitGuid<-paste0("KT",str_sub(first_batch$SampleID,3,7))
first_batch$NPX_bridged<-first_batch$NPX

# %%
all<-rbind.fill(list(batch1,batch2,batch3,batch4,batch5,first_batch))

# %%
all<-all%>% filter(!(Panel%in% c('Cardiometabolic','Neurology','Oncology')&Assay %in% c('TNF',"IL6","CXCL8")))

# %%
Olink<-unique(all[c("sample.sampleKitGuid","NPX_bridged","Assay",'batch')])

# %%
write.csv(Olink,'Olink.csv')

# %%
Olink<-read.csv('Olink.csv')

# %%
Olink
# Out:
#         X       sample.sampleKitGuid NPX_bridged Assay     batch
# 1        1      KT02289              -0.0809     NPPB      Batch1
# 2        2      KT03108              -1.2451     NPPB      Batch1
# 3        3      KT02558               1.0804     NPPB      Batch1
# 4        4      KT02507               1.9127     NPPB      Batch1
# 5        5      KT03011               2.4303     NPPB      Batch1
# 6        6      KT02977               2.3685     NPPB      Batch1
# 7        7      KT02954               1.8223     NPPB      Batch1
# 8        8      KT03024               0.1048     NPPB      Batch1
# 9        9      KT02728               1.1355     NPPB      Batch1
# 10      10                            0.1270     NPPB      Batch1
# 11      11      KT03251              -0.5217     NPPB      Batch1
# 12      12      KT01501              -0.7423     NPPB      Batch1
# 13      13      KT02751               4.5382     NPPB      Batch1
# 14      14      KT03040              -0.2416     NPPB      Batch1
# 15      15      KT03948               0.1040     NPPB      Batch1
# 16      16      KT02755               2.8576     NPPB      Batch1
# 17      17      KT04092               0.4708     NPPB      Batch1
# 18      18      KT02573              -1.6329     NPPB      Batch1
# 19      19      KT02173               3.4109     NPPB      Batch1
# 20      20      KT04345              -0.9237     NPPB      Batch1
# 21      21      KT03910               2.6026     NPPB      Batch1
# 22      22                           -0.4027     NPPB      Batch1
# 23      23      KT03977               1.3880     NPPB      Batch1
# 24      24      KT02852               4.1106     NPPB      Batch1
# 25      25      KT03218              -1.6760     NPPB      Batch1
# 26      26      KT02549               4.2932     NPPB      Batch1
# 27      27      KT02981               1.1298     NPPB      Batch1
# 28      28      KT03902               1.7887     NPPB      Batch1
# 29      29      KT01266              -0.6814     NPPB      Batch1
# 30      30      KT02980               1.5252     NPPB      Batch1
# ⋮       ⋮       ⋮                    ⋮           ⋮         ⋮
# 3240242 3240429 KT00007               0.5028     PAPPA     first
# 3240243 3240430 KT00007              -0.4521     NCLN      first
# 3240244 3240431 KT00007               0.7214     EIF4G1    first
# 3240245 3240432 KT00007               0.9615     CD83      first
# 3240246 3240433 KT00007               0.1682     HLA-DRA   first
# 3240247 3240434 KT00007               0.5498     SIRPB1    first
# 3240248 3240435 KT00007              -0.2033     SULT2A1   first
# 3240249 3240436 KT00007               1.3205     PSMG3     first
# 3240250 3240437 KT00007              -0.8616     MLN       first
# 3240251 3240438 KT00007               0.0253     CD40      first
# 3240252 3240439 KT00007               0.6713     MATN2     first
# 3240253 3240440 KT00007              -0.2161     TRIM5     first
# 3240254 3240441 KT00007               0.6698     CD200     first
# 3240255 3240442 KT00007               0.6441     DNAJA2    first
# 3240256 3240443 KT00007               0.1770     TNFRSF13C first
# 3240257 3240444 KT00007              -0.2100     DNER      first
# 3240258 3240445 KT00007              -0.6569     TNFAIP8   first
# 3240259 3240446 KT00007              -0.4806     MMP10     first
# 3240260 3240447 KT00007               0.1694     TGFB1     first
# 3240261 3240448 KT00007               2.2592     CLIP2     first
# 3240262 3240449 KT00007               0.5236     LAT       first
# 3240263 3240450 KT00007               0.6361     BCL2L11   first
# 3240264 3240451 KT00007              -0.2100     GALNT3    first
# 3240265 3240452 KT00007               0.7282     PDGFB     first
# 3240266 3240453 KT00007               0.9787     CDSN      first
# 3240267 3240454 KT00007               0.3324     CHRDL1    first
# 3240268 3240455 KT00007              -0.7701     NRTN      first
# 3240269 3240456 KT00007              -0.0552     GZMA      first
# 3240270 3240457 KT00007              -0.2153     CCL4      first
# 3240271 3240458 KT00007               0.2044     NME3      first

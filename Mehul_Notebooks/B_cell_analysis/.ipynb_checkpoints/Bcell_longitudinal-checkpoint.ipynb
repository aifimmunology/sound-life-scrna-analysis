# %%
import scanpy as sc
import pandas as pd 
import numpy as np
import anndata as ad
import re
import scipy.sparse as scs
import concurrent.futures
import scanpy.external as sce
from concurrent.futures import ProcessPoolExecutor
import copy
import os
import glob
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
import warnings
from matplotlib.lines import Line2D
from matplotlib import cm
import math
from pathlib import Path
import scipy
from scipy.stats import zscore
import scipy.stats as stats
from statsmodels.stats.multitest import multipletests

# Suppress all warnings
warnings.filterwarnings('ignore')
import math
import decoupler as dc

# %% [markdown]
# # B cell specific analysis

# %%
# Load the metadata
meta_data = pd.read_csv('/home/jupyter/formal_BRIanalysis/DEG_Mehul/hise_meta_data_2024-03-7_fixed.csv')
meta_data = meta_data[meta_data['Covid_exlcusion'] == 'no']

# Define the conditions
conditions = [
    ("Flu Year 1 Day 0", 2020, "Phuket+Guangdong-Maonan+Hongkong+Washington"),
    ("Flu Year 1 Day 7", 2020, "Phuket+Guangdong-Maonan+Hongkong+Washington"),
    ("Flu Year 1 Day 90", 2020, "Phuket+Guangdong-Maonan+Hongkong+Washington"),
    ("Flu Year 2 Day 0", 2021, "Phuket+Victoria+Cambodia+Washington"),
    ("Flu Year 2 Day 7", 2021, "Phuket+Victoria+Cambodia+Washington"),
    ("Flu Year 2 Day 90", 2021, "Phuket+Victoria+Cambodia+Washington")
]

# Create an empty DataFrame to store the filtered data
filtered_data = pd.DataFrame()

# Filter the data based on the conditions
for visit_name, flu_year, strains_concat in conditions:
    subset = meta_data[(meta_data['sample.visitName'] == visit_name) & 
                       (meta_data['Flu_Year'] == flu_year) & 
                       (meta_data['Strains_concat'] == strains_concat)]
    filtered_data = pd.concat([filtered_data, subset])

# %%
from tqdm import tqdm
h5_list = []
for i in tqdm(range(len(filtered_data["pbmc_sample_id"].tolist()))):
    try:
        result = sc.read_h5ad("/home/jupyter/h5_cleaned_by_sample/"+filtered_data["pbmc_sample_id"].tolist()[i]+'.h5ad')
        h5_list.append(result)
        print()
    except Exception as e:
        print(f'Error reading {file_name}: {e}')
# Out:
#   0% 1/415 [00:01<13:26,  1.95s/it]
#   0% 2/415 [00:03<12:27,  1.81s/it]
#   1% 3/415 [00:05<12:24,  1.81s/it]
#   1% 4/415 [00:07<13:40,  2.00s/it]
#   1% 5/415 [00:10<14:40,  2.15s/it]
#   1% 6/415 [00:12<14:19,  2.10s/it]
#   2% 7/415 [00:14<14:19,  2.11s/it]
#   2% 8/415 [00:16<14:12,  2.10s/it]
#   2% 9/415 [00:18<14:19,  2.12s/it]
#   2% 10/415 [00:21<15:45,  2.33s/it]
#   3% 11/415 [00:23<15:01,  2.23s/it]
#   3% 12/415 [00:25<14:41,  2.19s/it]
#   3% 13/415 [00:27<14:37,  2.18s/it]
#   3% 14/415 [00:29<14:56,  2.24s/it]
#   4% 15/415 [00:31<14:12,  2.13s/it]
#   4% 16/415 [00:34<14:28,  2.18s/it]
#   4% 17/415 [00:36<15:08,  2.28s/it]
#   4% 18/415 [00:38<13:41,  2.07s/it]
#   5% 19/415 [00:40<14:04,  2.13s/it]
#   5% 20/415 [00:42<12:51,  1.95s/it]
#   5% 21/415 [00:43<12:37,  1.92s/it]
#   5% 22/415 [00:46<13:16,  2.03s/it]
#   6% 23/415 [00:48<12:52,  1.97s/it]
#   6% 24/415 [00:49<12:01,  1.84s/it]
#   6% 25/415 [00:51<12:37,  1.94s/it]
# ...

# %%
# %%time
combined= ad.concat(h5_list)
# Out:
# CPU times: user 13min 54s, sys: 1min 31s, total: 15min 25s
# Wall time: 15min 25s

# %%
combined
# Out:
# AnnData object with n_obs × n_vars = 6674479 × 33538
#     obs: 'barcodes', 'batch_id', 'cell_name', 'cell_uuid', 'chip_id', 'hto_barcode', 'hto_category', 'n_genes', 'n_mito_umis', 'n_reads', 'n_umis', 'original_barcodes', 'pbmc_sample_id', 'pool_id', 'seurat_pbmc_type', 'seurat_pbmc_type_score', 'umap_1', 'umap_2', 'well_id', 'subject.biologicalSex', 'subject.ethnicity', 'subject.partnerCode', 'subject.race', 'subject.subjectGuid', 'cohort.cohortGuid', 'sample.visitName', 'sample.visitDetails', 'subject.birthYear', 'CMV.IgG.Serology.Result.Interpretation', 'BMI', 'predicted_doublet', 'doublet_score', 'AIFI_L1', 'AIFI_L2', 'AIFI_L3', 'AIFI_L3.5', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito'

# %%
#subset on L3 B cells
B_cells = combined[combined.obs['AIFI_L3'].isin(['CD27- effector B cell', 'CD27+ effector B cell', 'Core naive B cell', 'Core memory B cell', 'Plasma cell', 'ISG+ naive B cell', 'Transitional B cell', 'Early memory B cell', 'Type 2 polarized memory B cell', 'CD95 memory B cell', 'Activated memory B cell'])]

# %%
B_cells
# Out:
# View of AnnData object with n_obs × n_vars = 602154 × 33538
#     obs: 'barcodes', 'batch_id', 'cell_name', 'cell_uuid', 'chip_id', 'hto_barcode', 'hto_category', 'n_genes', 'n_mito_umis', 'n_reads', 'n_umis', 'original_barcodes', 'pbmc_sample_id', 'pool_id', 'seurat_pbmc_type', 'seurat_pbmc_type_score', 'umap_1', 'umap_2', 'well_id', 'subject.biologicalSex', 'subject.ethnicity', 'subject.partnerCode', 'subject.race', 'subject.subjectGuid', 'cohort.cohortGuid', 'sample.visitName', 'sample.visitDetails', 'subject.birthYear', 'CMV.IgG.Serology.Result.Interpretation', 'BMI', 'predicted_doublet', 'doublet_score', 'AIFI_L1', 'AIFI_L2', 'AIFI_L3', 'AIFI_L3.5', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito'

# %%
# %%time
B_cells.write_h5ad('/home/jupyter/formal_BRIanalysis/B_cell_analysis/Bcell_3times_2yr.h5ad')
# Out:
# CPU times: user 12 s, sys: 23.9 s, total: 35.9 s
# Wall time: 36.5 s

# %% [markdown]
# ## Load B cell 3 time points over 2020 and 2021

# %%
# %%time
B_cell_flu=sc.read_h5ad('/home/jupyter/formal_BRIanalysis/B_cell_analysis/Bcell_3times_2yr.h5ad')
# Out:
# CPU times: user 2.72 s, sys: 3.16 s, total: 5.88 s
# Wall time: 5.88 s

# %%
#load new meta _ includes flu strain specific year
meta = pd.read_csv('/home/jupyter/formal_BRIanalysis/DEG_Mehul/hise_meta_data_2024-03-7_fixed.csv')

# %%
merged_df = pd.merge(B_cell_flu.obs, meta[['pbmc_sample_id', 'Flu_Year', 'Strains_concat']], 
                     on='pbmc_sample_id', how='left')

B_cell_flu.obs = merged_df

# %%
# %%time
# store raw data in .X
#B_cell_flu.X = np.round(B_cell_flu).astype(np.int_)
B_cell_flu.layers['counts'] = B_cell_flu.X
# Out:
# CPU times: user 28 µs, sys: 17 µs, total: 45 µs
# Wall time: 57 µs

# %%
# %%time
#make pseudobulk for each, based on L3 and pbmc_sampleID
pdata = dc.get_pseudobulk(
    B_cell_flu,
    sample_col='pbmc_sample_id',
    groups_col='AIFI_L3',
    layer='counts',
    mode='sum',
    min_cells= 5,
    min_counts= 0
)
pdata
# Out:
# CPU times: user 5min 53s, sys: 5.63 s, total: 5min 58s
# Wall time: 5min 58s
# AnnData object with n_obs × n_vars = 4080 × 27679
#     obs: 'batch_id', 'hto_barcode', 'hto_category', 'pbmc_sample_id', 'pool_id', 'subject.biologicalSex', 'subject.ethnicity', 'subject.partnerCode', 'subject.race', 'subject.subjectGuid', 'cohort.cohortGuid', 'sample.visitName', 'sample.visitDetails', 'subject.birthYear', 'CMV.IgG.Serology.Result.Interpretation', 'BMI', 'predicted_doublet', 'AIFI_L3', 'Flu_Year', 'Strains_concat', 'psbulk_n_cells', 'psbulk_counts'
#     layers: 'psbulk_props'

# %%
dc.plot_psbulk_samples(pdata, groupby=['AIFI_L3', 'sample.visitName'], figsize=(12, 4))

# %%
pdata.obs['subject.birthYear'] = pdata.obs['subject.birthYear'].astype(str)
pdata.obs['predicted_doublet'] = pdata.obs['predicted_doublet'].astype(str)
pdata.obs['Flu_Year'] = pdata.obs['Flu_Year'].astype(str)

# %%
# %%time
#write the psb data so that can use with limma in R
pdata.write('/home/jupyter/formal_BRIanalysis/B_cell_analysis/Bcell_long_L3_psb.h5ad')
# Out:
# CPU times: user 88.8 ms, sys: 945 ms, total: 1.03 s
# Wall time: 9.62 s

# %% [markdown]
# ### create subset specific psb

# %%
psb_object = sc.read('/home/jupyter/formal_BRIanalysis/B_cell_analysis/Bcell_long_L3_psb.h5ad')

# %%
psb_object.X = psb_object.X.astype(np.int_)

# %%
psb_object
# Out:
# AnnData object with n_obs × n_vars = 4080 × 27679
#     obs: 'batch_id', 'hto_barcode', 'hto_category', 'pbmc_sample_id', 'pool_id', 'subject.biologicalSex', 'subject.ethnicity', 'subject.partnerCode', 'subject.race', 'subject.subjectGuid', 'cohort.cohortGuid', 'sample.visitName', 'sample.visitDetails', 'subject.birthYear', 'CMV.IgG.Serology.Result.Interpretation', 'BMI', 'predicted_doublet', 'AIFI_L3', 'Flu_Year', 'Strains_concat', 'psbulk_n_cells', 'psbulk_counts'
#     layers: 'psbulk_props'

# %%
# %%time
dir_path = '/home/jupyter/formal_BRIanalysis/B_cell_analysis/psb_subsets'
unique_values = psb_object.obs['AIFI_L3'].unique()

for category in unique_values:
    subset = psb_object[psb_object.obs['AIFI_L3'] == category].copy()
    genes = dc.filter_by_expr(subset, group='AIFI_L3', min_count=5, min_prop=0.1)
    filtered_subset = subset[:, genes].copy()
    filtered_subset.obs = filtered_subset.obs.astype(str)
    filtered_subset.var = filtered_subset.var.astype(str)
    print(f'Category: {category}, Shape: {filtered_subset.shape}')
    subset_filename = os.path.join(dir_path, f'subset_{category}.h5ad')
    filtered_subset.write_h5ad(subset_filename)
# Out:
# Category: Activated memory B cell, Shape: (98, 1313)
# Category: CD27+ effector B cell, Shape: (414, 7911)
# Category: CD27- effector B cell, Shape: (408, 5552)
# Category: CD95 memory B cell, Shape: (408, 6034)
# Category: Core memory B cell, Shape: (415, 11162)
# Category: Core naive B cell, Shape: (415, 11942)
# Category: Early memory B cell, Shape: (359, 2592)
# Category: ISG+ naive B cell, Shape: (403, 3349)
# Category: Plasma cell, Shape: (350, 5884)
# Category: Transitional B cell, Shape: (412, 7369)
# Category: Type 2 polarized memory B cell, Shape: (398, 3121)
# CPU times: user 2.21 s, sys: 751 ms, total: 2.96 s
# Wall time: 3.87 s

# %% [markdown]
# ### Keep working with the B cell object

# %%
# %%time
#reload if we want to start from here
B_cell_flu=sc.read_h5ad('/home/jupyter/formal_BRIanalysis/B_cell_analysis/Bcell_3times_2yr.h5ad')

#load new meta _ includes flu strain specific year
meta = pd.read_csv('/home/jupyter/formal_BRIanalysis/DEG_Mehul/hise_meta_data_2024-03-7_fixed.csv')
# Out:
# CPU times: user 2.71 s, sys: 3.18 s, total: 5.9 s
# Wall time: 5.9 s

# %%
merged_df = pd.merge(B_cell_flu.obs, meta[['pbmc_sample_id', 'Flu_Year', 'Strains_concat']], 
                     on='pbmc_sample_id', how='left')

B_cell_flu.obs = merged_df

# %%
B_cell_flu
# Out:
# AnnData object with n_obs × n_vars = 602154 × 33538
#     obs: 'barcodes', 'batch_id', 'cell_name', 'cell_uuid', 'chip_id', 'hto_barcode', 'hto_category', 'n_genes', 'n_mito_umis', 'n_reads', 'n_umis', 'original_barcodes', 'pbmc_sample_id', 'pool_id', 'seurat_pbmc_type', 'seurat_pbmc_type_score', 'umap_1', 'umap_2', 'well_id', 'subject.biologicalSex', 'subject.ethnicity', 'subject.partnerCode', 'subject.race', 'subject.subjectGuid', 'cohort.cohortGuid', 'sample.visitName', 'sample.visitDetails', 'subject.birthYear', 'CMV.IgG.Serology.Result.Interpretation', 'BMI', 'predicted_doublet', 'doublet_score', 'AIFI_L1', 'AIFI_L2', 'AIFI_L3', 'AIFI_L3.5', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'Flu_Year', 'Strains_concat'

# %%
# %%time
sc.pp.normalize_total(B_cell_flu, target_sum=1e4)
sc.pp.log1p(B_cell_flu)
# Out:
# CPU times: user 4.09 s, sys: 567 ms, total: 4.65 s
# Wall time: 4.65 s

# %%
# %%time
# Identify highly variable genes
sc.pp.highly_variable_genes(B_cell_flu)

# Scale the data
sc.pp.scale(B_cell_flu, max_value=10)

# Generate PCA features
sc.tl.pca(B_cell_flu, svd_solver='arpack', use_highly_variable=True)

# Compute distances in the PCA space, and find cell neighbors
sc.pp.neighbors(B_cell_flu)

# Generate UMAP features
sc.tl.umap(B_cell_flu)
# Out:
# CPU times: user 1h 55min 55s, sys: 1h 13min 58s, total: 3h 9min 53s
# Wall time: 13min 41s

# %%
# Visualize
sc.pl.umap(B_cell_flu, color=['cohort.cohortGuid','AIFI_L3', 'sample.visitName'])

# %%
sc.pl.umap(B_cell_flu, color=['sample.visitName'])

# %%
suppressPackageStartupMessages(library(readxl))
suppressPackageStartupMessages(library(dplyr))
suppressPackageStartupMessages(library(tidyr))
suppressPackageStartupMessages(library(tibble))
suppressPackageStartupMessages(library(patchwork))
suppressPackageStartupMessages(library(pheatmap))
suppressPackageStartupMessages(library(stringr))
library(hise)
library(plyr)
library(purrr)
library(vegan)
#library(arrow)
library(rstatix)
library(parallel)
library(ggpubr)
library(ComplexHeatmap)
library(compositions)
library(ggsci)
library(math)
library(data.table)
# Out:
# Error in library(compositions): there is no package called ‘compositions’
# Traceback:
#
# 1. library(compositions)

# %% [markdown]
# # Reading the file

# %%
mydata = fread("/home/jupyter/Myeloid_cells/files/All_Flu_timepoints_raw.csv", header = TRUE)

# %%
unique(mydata$sample.visitName)
# Out:
# [1] "Flu Year 1 Day 0"  "Flu Year 1 Day 7"  "Flu Year 1 Day 90"
# [4] "Flu Year 2 Day 0"  "Flu Year 2 Day 7"  "Flu Year 2 Day 90"

# %%
unique(mydata$sample.visitDetails)
# Out:
# [1] "N/A - Flu-Series Timepoint Only"

# %%
colnames(mydata)
# Out:
#  [1] "barcodes"
#  [2] "barcodes"
#  [3] "batch_id"
#  [4] "cell_name"
#  [5] "cell_uuid"
#  [6] "chip_id"
#  [7] "hto_barcode"
#  [8] "hto_category"
#  [9] "n_genes"
# [10] "n_mito_umis"
# [11] "n_reads"
# [12] "n_umis"
# [13] "original_barcodes"
# [14] "pbmc_sample_id"
# [15] "pool_id"
# [16] "seurat_pbmc_type"
# [17] "seurat_pbmc_type_score"
# [18] "umap_1"
# [19] "umap_2"
# [20] "well_id"
# [21] "subject.biologicalSex"
# [22] "subject.ethnicity"
# [23] "subject.partnerCode"
# [24] "subject.race"
# [25] "subject.subjectGuid"
# [26] "cohort.cohortGuid"
# [27] "sample.visitName"
# [28] "sample.visitDetails"
# [29] "subject.birthYear"
# [30] "CMV.IgG.Serology.Result.Interpretation"
# [31] "BMI"
# [32] "predicted_doublet"
# [33] "doublet_score"
# [34] "AIFI_L1"
# [35] "AIFI_L2"
# [36] "AIFI_L3"
# [37] "AIFI_L3.5"
# [38] "n_genes_by_counts"
# [39] "log1p_n_genes_by_counts"
# [40] "total_counts"
# [41] "log1p_total_counts"
# [42] "pct_counts_in_top_50_genes"
# [43] "pct_counts_in_top_100_genes"
# [44] "pct_counts_in_top_200_genes"
# [45] "pct_counts_in_top_500_genes"
# [46] "total_counts_mito"
# [47] "log1p_total_counts_mito"
# [48] "pct_counts_mito"

# %%
# removing extra barcodes column
mydata <- subset(mydata, select = -barcodes)
head(mydata)
# Out:
#   barcodes                         batch_id cell_name
# 1 70ced6d648b611eaa65d9e7d578d66f2 B001     rhinestone_mannerly_argali
# 2 70da1ed848b611eaa65d9e7d578d66f2 B001     ghastful_sphinxian_zopilote
# 3 c67f8e0248bd11eab2ee7a6edf799b61 B001     feudal_respected_meadowhawk
# 4 c6aba74448bd11eab2ee7a6edf799b61 B001     atrophied_piercing_piglet
# 5 5cfb5a3048b111ea8fbed2ddb8e0a14a B001     absent_unsweet_chihuahua
# 6 6cc8428048b511ea87c666a4322bd84a B001     unpacified_greenish_xanclomys
#   cell_uuid                        chip_id   hto_barcode     hto_category
# 1 70ced6d648b611eaa65d9e7d578d66f2 B001-P1C1 TGATGGCCTATTGGG singlet
# 2 70da1ed848b611eaa65d9e7d578d66f2 B001-P1C1 TGATGGCCTATTGGG singlet
# 3 c67f8e0248bd11eab2ee7a6edf799b61 B001-P1C1 TGATGGCCTATTGGG singlet
# 4 c6aba74448bd11eab2ee7a6edf799b61 B001-P1C1 TGATGGCCTATTGGG singlet
# 5 5cfb5a3048b111ea8fbed2ddb8e0a14a B001-P1C1 TGATGGCCTATTGGG singlet
# 6 6cc8428048b511ea87c666a4322bd84a B001-P1C1 TGATGGCCTATTGGG singlet
#   n_genes n_mito_umis n_reads ⋯ log1p_n_genes_by_counts total_counts
# 1 2965    354         54033   ⋯ 7.994970                15237
# 2 2691    311         44212   ⋯ 7.898040                12929
# 3 2495    197         32319   ⋯ 7.822445                10139
# 4 3620    663         61476   ⋯ 8.194506                18496
# 5 2974    466         38227   ⋯ 7.997999                13444
# 6 2650    159         41769   ⋯ 7.882692                12027
#   log1p_total_counts pct_counts_in_top_50_genes pct_counts_in_top_100_genes
# 1 9.631548           38.82654                   54.99770
# 2 9.467305           39.77106                   55.07773
# 3 9.224243           38.48506                   50.99122
# 4 9.825364           35.21843                   52.34105
# 5 9.506363           35.79292                   51.91907
# 6 9.394993           40.35919                   52.97248
#   pct_counts_in_top_200_genes pct_counts_in_top_500_genes total_counts_mito
# 1 65.89880                    77.13461                    354
# 2 65.90610                    77.05932                    311
# 3 61.62343                    74.08028                    197
# 4 63.07850                    73.50779                    663
# 5 62.68224                    73.72806                    466
# 6 63.51542                    75.67972                    159
#   log1p_total_counts_mito pct_counts_mito
# 1 5.872118                2.323292
# 2 5.743003                2.405445
# 3 5.288267                1.942992
# 4 6.498282                3.584559
# 5 6.146329                3.466230
# 6 5.075174                1.322025

# %%
dict <- read.csv('/home/jupyter/Myeloid_cells/files/Dictionary_AIFI_Reference.csv')

# %%
## testing label organization
# Read the CSV file containing the desired labels
label_data <- read.csv("/home/jupyter/IH-A-Aging-Analysis-Notebooks/Mansi_Notebooks/scRNA/Frequency_Plot/Immune_Cell_Order_forDEGsummary - Sheet1.csv", header = TRUE)

# Extract the labels from the CSV file
desired_labels <- label_data$FINAL.ORDER

# %%
unique(mydata$cohort.cohortGuid)
#unique(flu_df$AIFI_L3.5)
#unique(flu_df$AIFI_L1)
# Out:
# [1] "BR1" "BR2"

# %%
nrow(mydata)
# Out:
# [1] 8277628

# %%
head(mydata)
# Out:
#   barcodes                         barcodes.1                       batch_id
# 1 70ced6d648b611eaa65d9e7d578d66f2 70ced6d648b611eaa65d9e7d578d66f2 B001
# 2 70da1ed848b611eaa65d9e7d578d66f2 70da1ed848b611eaa65d9e7d578d66f2 B001
# 3 c67f8e0248bd11eab2ee7a6edf799b61 c67f8e0248bd11eab2ee7a6edf799b61 B001
# 4 c6aba74448bd11eab2ee7a6edf799b61 c6aba74448bd11eab2ee7a6edf799b61 B001
# 5 5cfb5a3048b111ea8fbed2ddb8e0a14a 5cfb5a3048b111ea8fbed2ddb8e0a14a B001
# 6 6cc8428048b511ea87c666a4322bd84a 6cc8428048b511ea87c666a4322bd84a B001
#   cell_name                     cell_uuid                        chip_id
# 1 rhinestone_mannerly_argali    70ced6d648b611eaa65d9e7d578d66f2 B001-P1C1
# 2 ghastful_sphinxian_zopilote   70da1ed848b611eaa65d9e7d578d66f2 B001-P1C1
# 3 feudal_respected_meadowhawk   c67f8e0248bd11eab2ee7a6edf799b61 B001-P1C1
# 4 atrophied_piercing_piglet     c6aba74448bd11eab2ee7a6edf799b61 B001-P1C1
# 5 absent_unsweet_chihuahua      5cfb5a3048b111ea8fbed2ddb8e0a14a B001-P1C1
# 6 unpacified_greenish_xanclomys 6cc8428048b511ea87c666a4322bd84a B001-P1C1
#   hto_barcode     hto_category n_genes n_mito_umis ⋯ log1p_n_genes_by_counts
# 1 TGATGGCCTATTGGG singlet      2965    354         ⋯ 7.994970
# 2 TGATGGCCTATTGGG singlet      2691    311         ⋯ 7.898040
# 3 TGATGGCCTATTGGG singlet      2495    197         ⋯ 7.822445
# 4 TGATGGCCTATTGGG singlet      3620    663         ⋯ 8.194506
# 5 TGATGGCCTATTGGG singlet      2974    466         ⋯ 7.997999
# 6 TGATGGCCTATTGGG singlet      2650    159         ⋯ 7.882692
#   total_counts log1p_total_counts pct_counts_in_top_50_genes
# 1 15237        9.631548           38.82654
# 2 12929        9.467305           39.77106
# 3 10139        9.224243           38.48506
# 4 18496        9.825364           35.21843
# 5 13444        9.506363           35.79292
# 6 12027        9.394993           40.35919
#   pct_counts_in_top_100_genes pct_counts_in_top_200_genes
# 1 54.99770                    65.89880
# 2 55.07773                    65.90610
# 3 50.99122                    61.62343
# 4 52.34105                    63.07850
# 5 51.91907                    62.68224
# 6 52.97248                    63.51542
#   pct_counts_in_top_500_genes total_counts_mito log1p_total_counts_mito
# 1 77.13461                    354               5.872118
# 2 77.05932                    311               5.743003
# 3 74.08028                    197               5.288267
# 4 73.50779                    663               6.498282
# 5 73.72806                    466               6.146329
# 6 75.67972                    159               5.075174
#   pct_counts_mito
# 1 2.323292
# 2 2.405445
# 3 1.942992
# 4 3.584559
# 5 3.466230
# 6 1.322025

# %%
rownames(mydata)<-mydata$cell_uuid

# %% [markdown]
# # CLR transform

# %%
clr_transform <- function(x) {
  if (length(x) == 0) {
    return(NA)  # return NA for empty vectors
  }
  geom_mean <- exp(mean(log(x)))
  return(log(x / geom_mean))
}

# %% [markdown]
# # Data Transformation

# %%
head(mydata)
# Out:
#   barcodes                         batch_id cell_name
# 1 70ced6d648b611eaa65d9e7d578d66f2 B001     rhinestone_mannerly_argali
# 2 70da1ed848b611eaa65d9e7d578d66f2 B001     ghastful_sphinxian_zopilote
# 3 c67f8e0248bd11eab2ee7a6edf799b61 B001     feudal_respected_meadowhawk
# 4 c6aba74448bd11eab2ee7a6edf799b61 B001     atrophied_piercing_piglet
# 5 5cfb5a3048b111ea8fbed2ddb8e0a14a B001     absent_unsweet_chihuahua
# 6 6cc8428048b511ea87c666a4322bd84a B001     unpacified_greenish_xanclomys
#   cell_uuid                        chip_id   hto_barcode     hto_category
# 1 70ced6d648b611eaa65d9e7d578d66f2 B001-P1C1 TGATGGCCTATTGGG singlet
# 2 70da1ed848b611eaa65d9e7d578d66f2 B001-P1C1 TGATGGCCTATTGGG singlet
# 3 c67f8e0248bd11eab2ee7a6edf799b61 B001-P1C1 TGATGGCCTATTGGG singlet
# 4 c6aba74448bd11eab2ee7a6edf799b61 B001-P1C1 TGATGGCCTATTGGG singlet
# 5 5cfb5a3048b111ea8fbed2ddb8e0a14a B001-P1C1 TGATGGCCTATTGGG singlet
# 6 6cc8428048b511ea87c666a4322bd84a B001-P1C1 TGATGGCCTATTGGG singlet
#   n_genes n_mito_umis n_reads ⋯ log1p_n_genes_by_counts total_counts
# 1 2965    354         54033   ⋯ 7.994970                15237
# 2 2691    311         44212   ⋯ 7.898040                12929
# 3 2495    197         32319   ⋯ 7.822445                10139
# 4 3620    663         61476   ⋯ 8.194506                18496
# 5 2974    466         38227   ⋯ 7.997999                13444
# 6 2650    159         41769   ⋯ 7.882692                12027
#   log1p_total_counts pct_counts_in_top_50_genes pct_counts_in_top_100_genes
# 1 9.631548           38.82654                   54.99770
# 2 9.467305           39.77106                   55.07773
# 3 9.224243           38.48506                   50.99122
# 4 9.825364           35.21843                   52.34105
# 5 9.506363           35.79292                   51.91907
# 6 9.394993           40.35919                   52.97248
#   pct_counts_in_top_200_genes pct_counts_in_top_500_genes total_counts_mito
# 1 65.89880                    77.13461                    354
# 2 65.90610                    77.05932                    311
# 3 61.62343                    74.08028                    197
# 4 63.07850                    73.50779                    663
# 5 62.68224                    73.72806                    466
# 6 63.51542                    75.67972                    159
#   log1p_total_counts_mito pct_counts_mito
# 1 5.872118                2.323292
# 2 5.743003                2.405445
# 3 5.288267                1.942992
# 4 6.498282                3.584559
# 5 6.146329                3.466230
# 6 5.075174                1.322025

# %%
colnames(mydata)
# Out:
#  [1] "barcodes"
#  [2] "barcodes"
#  [3] "batch_id"
#  [4] "cell_name"
#  [5] "cell_uuid"
#  [6] "chip_id"
#  [7] "hto_barcode"
#  [8] "hto_category"
#  [9] "n_genes"
# [10] "n_mito_umis"
# [11] "n_reads"
# [12] "n_umis"
# [13] "original_barcodes"
# [14] "pbmc_sample_id"
# [15] "pool_id"
# [16] "seurat_pbmc_type"
# [17] "seurat_pbmc_type_score"
# [18] "umap_1"
# [19] "umap_2"
# [20] "well_id"
# [21] "subject.biologicalSex"
# [22] "subject.ethnicity"
# [23] "subject.partnerCode"
# [24] "subject.race"
# [25] "subject.subjectGuid"
# [26] "cohort.cohortGuid"
# [27] "sample.visitName"
# [28] "sample.visitDetails"
# [29] "subject.birthYear"
# [30] "CMV.IgG.Serology.Result.Interpretation"
# [31] "BMI"
# [32] "predicted_doublet"
# [33] "doublet_score"
# [34] "AIFI_L1"
# [35] "AIFI_L2"
# [36] "AIFI_L3"
# [37] "AIFI_L3.5"
# [38] "n_genes_by_counts"
# [39] "log1p_n_genes_by_counts"
# [40] "total_counts"
# [41] "log1p_total_counts"
# [42] "pct_counts_in_top_50_genes"
# [43] "pct_counts_in_top_100_genes"
# [44] "pct_counts_in_top_200_genes"
# [45] "pct_counts_in_top_500_genes"
# [46] "total_counts_mito"
# [47] "log1p_total_counts_mito"
# [48] "pct_counts_mito"

# %%
## Percentage of total

result <- mydata %>%
  dplyr::group_by(AIFI_L3, subject.subjectGuid, sample.visitName ) %>%               
  dplyr::summarise(count = n()) %>%                  # Count occurrences
  dplyr::group_by(subject.subjectGuid, ) %>%                       
  dplyr::mutate(percentage = (count / sum(count)) * 100) %>% 
  dplyr::group_by(subject.subjectGuid, ) %>%     
  dplyr::mutate(percentage_clr = clr_transform((percentage))) %>% # Group again by subjectGuid for CLR# Calculate percentage
  dplyr::ungroup()

head(result)
#sum(result$subject.subjectGuid)
# Out:
# `summarise()` has grouped output by 'AIFI_L3', 'subject.subjectGuid'. You can
# override using the `.groups` argument.
#   AIFI_L3 subject.subjectGuid sample.visitName  count percentage
# 1 ASDC    BR1001              Flu Year 1 Day 0  6     0.012381345
# 2 ASDC    BR1001              Flu Year 1 Day 7  5     0.010317788
# 3 ASDC    BR1001              Flu Year 1 Day 90 3     0.006190673
# 4 ASDC    BR1002              Flu Year 1 Day 0  3     0.003233525
# 5 ASDC    BR1002              Flu Year 1 Day 7  2     0.002155683
# 6 ASDC    BR1002              Flu Year 1 Day 90 2     0.002155683
#   percentage_clr
# 1 -2.014465
# 2 -2.196787
# 3 -2.707612
# 4 -2.497984
# 5 -2.903449
# 6 -2.903449

# %%
result %>% filter(subject.subjectGuid == "BR1001") %>% 
      select(percentage) %>%
      pull() %>% 
      sum()
# Out:
# [1] 100

# %%
nrow(result)
# Out:
# [1] 34833

# %%
#library(dplyr)

# Assuming 'result' is one dataframe and 'mydata' is another dataframe

# Extracting unique columns from mydata
unique_mydata <- mydata %>%
  select(cohort.cohortGuid, subject.subjectGuid, subject.biologicalSex, CMV.IgG.Serology.Result.Interpretation) %>%
  unique()

# Performing inner join
result <- inner_join(result, unique_mydata, by = 'subject.subjectGuid')

# %%
result$AIFI_L3 <- gsub("Core naive CD8 T cell ", "Core naive CD8 T cell", result$AIFI_L3 )

# %%
filtered_data <- result %>%
  group_by(AIFI_L3,subject.subjectGuid) %>%
  filter(all(c("Flu Year 1 Day 0", "Flu Year 1 Day 7", "Flu Year 1 Day 90", "Flu Year 2 Day 0", "Flu Year 2 Day 7", "Flu Year 2 Day 90") %in% sample.visitName))

head(filtered_data)
# Out:
#   AIFI_L3 subject.subjectGuid sample.visitName  count percentage
# 1 ASDC    BR1002              Flu Year 1 Day 0  3     0.003233525
# 2 ASDC    BR1002              Flu Year 1 Day 7  2     0.002155683
# 3 ASDC    BR1002              Flu Year 1 Day 90 2     0.002155683
# 4 ASDC    BR1002              Flu Year 2 Day 0  3     0.003233525
# 5 ASDC    BR1002              Flu Year 2 Day 7  2     0.002155683
# 6 ASDC    BR1002              Flu Year 2 Day 90 3     0.003233525
#   percentage_clr cohort.cohortGuid subject.biologicalSex
# 1 -2.497984      BR1               Male
# 2 -2.903449      BR1               Male
# 3 -2.903449      BR1               Male
# 4 -2.497984      BR1               Male
# 5 -2.903449      BR1               Male
# 6 -2.497984      BR1               Male
#   CMV.IgG.Serology.Result.Interpretation
# 1 Negative
# 2 Negative
# 3 Negative
# 4 Negative
# 5 Negative
# 6 Negative

# %% [markdown]
# ### Median

# %%
#continuous code
#
result_df <- filtered_data %>%
  dplyr::group_by(AIFI_L3, sample.visitName) %>%
  dplyr::summarise(mean_percentage = mean(percentage),
                    median_percentage = median(percentage))

result_df_median<- result_df[, c("AIFI_L3", "sample.visitName", "median_percentage")]


result_df_median <- result_df_median %>% spread(sample.visitName, median_percentage)

result_df_median <- result_df_median %>%  
          mutate(Median_Diff = (`Flu Year 1 Day 0` - `Flu Year 1 Day 7`)) %>%
          mutate(log2FC = log2(`Flu Year 1 Day 0` / `Flu Year 1 Day 7`))
#head(result_df_median)


stat_test<- filtered_data %>%
  select(percentage,percentage_clr, AIFI_L3, sample.visitName) %>%
  unique(.) %>%
  group_by(AIFI_L3) %>%
  wilcox_test(percentage_clr ~ sample.visitName, paired= TRUE) %>%
  adjust_pvalue(method = "BH") %>%
  add_significance()

significant_cell_types <- stat_test %>%
  filter(p.adj < 0.05) %>%
  select(AIFI_L3, .y., p, p.adj, p.adj.signif) %>%
  unique()

print(significant_cell_types)

merged_df <- merge(result_df_median, stat_test, by = "AIFI_L3")

merged_df <- merged_df %>% mutate(minus_log10_p_adj = -log(p.adj),
                                  sign_log2FC = sign(log2FC),
                                 product_column = (minus_log10_p_adj * sign_log2FC))

merged_df$AIFI_L3 <- factor(merged_df$AIFI_L3, levels = desired_labels)
# Out:
# `summarise()` has grouped output by 'AIFI_L3'. You can override using the
# `.groups` argument.
# Adding missing grouping variables: `subject.subjectGuid`
# # A tibble: 8 × 5
#   AIFI_L3               .y.                     p     p.adj p.adj.signif
#   <chr>                 <chr>               <dbl>     <dbl> <chr>
# 1 CD27+ effector B cell percentage_clr 0.0000376  0.000890  ***
# 2 CD27- effector B cell percentage_clr 0.000338   0.00480   **
# 3 CD95 memory B cell    percentage_clr 0.000603   0.00612   **
# 4 ISG+ CD14 monocyte    percentage_clr 0.0000263  0.000890  ***
# 5 ISG+ CD16 monocyte    percentage_clr 0.000594   0.00612   **
# 6 ISG+ CD56dim NK cell  percentage_clr 0.000257   0.00456   **
# 7 Intermediate monocyte percentage_clr 0.00168    0.0149    *
# 8 Plasma cell           percentage_clr 0.00000132 0.0000937 ****

# %%
result_df <- filtered_data %>%
  dplyr::group_by(AIFI_L3, sample.visitName) %>%
  dplyr::summarise(mean_percentage = mean(percentage),
                    median_percentage = median(percentage))

result_df
# Out:
# `summarise()` has grouped output by 'AIFI_L3'. You can override using the
# `.groups` argument.
#     AIFI_L3                        sample.visitName  mean_percentage
# 1   ASDC                           Flu Year 1 Day 0  0.0040851661
# 2   ASDC                           Flu Year 1 Day 7  0.0046828748
# 3   ASDC                           Flu Year 1 Day 90 0.0038974813
# 4   ASDC                           Flu Year 2 Day 0  0.0043780900
# 5   ASDC                           Flu Year 2 Day 7  0.0042781272
# 6   ASDC                           Flu Year 2 Day 90 0.0039279781
# 7   Activated memory B cell        Flu Year 1 Day 0  0.0046968077
# 8   Activated memory B cell        Flu Year 1 Day 7  0.0044055497
# 9   Activated memory B cell        Flu Year 1 Day 90 0.0036242499
# 10  Activated memory B cell        Flu Year 2 Day 0  0.0058702596
# 11  Activated memory B cell        Flu Year 2 Day 7  0.0049663419
# 12  Activated memory B cell        Flu Year 2 Day 90 0.0047702011
# 13  Adaptive NK cell               Flu Year 1 Day 0  0.1194262900
# 14  Adaptive NK cell               Flu Year 1 Day 7  0.0889574171
# 15  Adaptive NK cell               Flu Year 1 Day 90 0.1372880718
# 16  Adaptive NK cell               Flu Year 2 Day 0  0.1139973005
# 17  Adaptive NK cell               Flu Year 2 Day 7  0.1146672802
# 18  Adaptive NK cell               Flu Year 2 Day 90 0.1108738590
# 19  BaEoMaP cell                   Flu Year 1 Day 0  0.0023238200
# 20  BaEoMaP cell                   Flu Year 1 Day 7  0.0028709334
# 21  BaEoMaP cell                   Flu Year 1 Day 90 0.0014583415
# 22  BaEoMaP cell                   Flu Year 2 Day 0  0.0038279111
# 23  BaEoMaP cell                   Flu Year 2 Day 7  0.0009569778
# 24  BaEoMaP cell                   Flu Year 2 Day 90 0.0014125919
# 25  C1Q+ CD16 monocyte             Flu Year 1 Day 0  0.0380354012
# 26  C1Q+ CD16 monocyte             Flu Year 1 Day 7  0.0396025978
# 27  C1Q+ CD16 monocyte             Flu Year 1 Day 90 0.0413186773
# 28  C1Q+ CD16 monocyte             Flu Year 2 Day 0  0.0335383542
# 29  C1Q+ CD16 monocyte             Flu Year 2 Day 7  0.0341254134
# 30  C1Q+ CD16 monocyte             Flu Year 2 Day 90 0.0349878507
# ⋮   ⋮                              ⋮                 ⋮
# 397 SOX4+ naive CD8 T cell         Flu Year 1 Day 0  0.036567610
# 398 SOX4+ naive CD8 T cell         Flu Year 1 Day 7  0.037291457
# 399 SOX4+ naive CD8 T cell         Flu Year 1 Day 90 0.032258019
# 400 SOX4+ naive CD8 T cell         Flu Year 2 Day 0  0.031826740
# 401 SOX4+ naive CD8 T cell         Flu Year 2 Day 7  0.029596336
# 402 SOX4+ naive CD8 T cell         Flu Year 2 Day 90 0.023426113
# 403 Transitional B cell            Flu Year 1 Day 0  0.075582274
# 404 Transitional B cell            Flu Year 1 Day 7  0.078889142
# 405 Transitional B cell            Flu Year 1 Day 90 0.072772716
# 406 Transitional B cell            Flu Year 2 Day 0  0.072683241
# 407 Transitional B cell            Flu Year 2 Day 7  0.073908712
# 408 Transitional B cell            Flu Year 2 Day 90 0.064919930
# 409 Type 2 polarized memory B cell Flu Year 1 Day 0  0.021385573
# 410 Type 2 polarized memory B cell Flu Year 1 Day 7  0.022200336
# 411 Type 2 polarized memory B cell Flu Year 1 Day 90 0.020335153
# 412 Type 2 polarized memory B cell Flu Year 2 Day 0  0.023118281
# 413 Type 2 polarized memory B cell Flu Year 2 Day 7  0.024624890
# 414 Type 2 polarized memory B cell Flu Year 2 Day 90 0.021243535
# 415 cDC1                           Flu Year 1 Day 0  0.008573359
# 416 cDC1                           Flu Year 1 Day 7  0.009591017
# 417 cDC1                           Flu Year 1 Day 90 0.009267563
# 418 cDC1                           Flu Year 2 Day 0  0.008170161
# 419 cDC1                           Flu Year 2 Day 7  0.008835385
# 420 cDC1                           Flu Year 2 Day 90 0.007675747
# 421 pDC                            Flu Year 1 Day 0  0.062967199
# 422 pDC                            Flu Year 1 Day 7  0.062195171
# 423 pDC                            Flu Year 1 Day 90 0.071835401
# 424 pDC                            Flu Year 2 Day 0  0.059721605
# 425 pDC                            Flu Year 2 Day 7  0.060596782
# 426 pDC                            Flu Year 2 Day 90 0.061212388
#     median_percentage
# 1   0.0039135114
# 2   0.0047405497
# 3   0.0033974700
# 4   0.0041521773
# 5   0.0034295905
# 6   0.0033692722
# 7   0.0038951940
# 8   0.0026932553
# 9   0.0037476678
# 10  0.0035911334
# 11  0.0030300708
# 12  0.0039231291
# 13  0.0329089451
# 14  0.0299808123
# 15  0.0362396802
# 16  0.0343927654
# 17  0.0312626059
# 18  0.0358481676
# 19  0.0023238200
# 20  0.0028709334
# 21  0.0014583415
# 22  0.0038279111
# 23  0.0009569778
# 24  0.0014125919
# 25  0.0342880194
# 26  0.0332482337
# 27  0.0344730050
# 28  0.0257918085
# 29  0.0300904433
# 30  0.0300533890
# ⋮   ⋮
# 397 0.023478147
# 398 0.020215633
# 399 0.018847575
# 400 0.018152481
# 401 0.021390374
# 402 0.013477089
# 403 0.060545765
# 404 0.066687519
# 405 0.075839051
# 406 0.062813021
# 407 0.062283219
# 408 0.054846988
# 409 0.018336643
# 410 0.017548365
# 411 0.016299416
# 412 0.019608044
# 413 0.021356571
# 414 0.019069196
# 415 0.007861635
# 416 0.008823108
# 417 0.008828463
# 418 0.007215602
# 419 0.007513007
# 420 0.006626780
# 421 0.057883160
# 422 0.054907604
# 423 0.068407371
# 424 0.057649129
# 425 0.054448551
# 426 0.050658561

# %%
summary(result_df)
# Out:
#    AIFI_L3          sample.visitName   mean_percentage    median_percentage
#  Length:426         Length:426         Min.   :0.000957   Min.   :0.000957
#  Class :character   Class :character   1st Qu.:0.018023   1st Qu.:0.011552
#  Mode  :character   Mode  :character   Median :0.053526   Median :0.027010
#                                        Mean   :0.236553   Mean   :0.202029
#                                        3rd Qu.:0.168758   3rd Qu.:0.115801
#                                        Max.   :3.434365   Max.   :3.337619

# %%
table(result_df$AIFI_L3)
# Out:
#              Activated memory B cell                     Adaptive NK cell
#                                    6                                    6
#                                 ASDC                         BaEoMaP cell
#                                    6                                    6
#                   C1Q+ CD16 monocyte                           CD14+ cDC2
#                                    6                                    6
#                CD27- effector B cell                CD27+ effector B cell
#                                    6                                    6
#                             CD4 MAIT                   CD56bright NK cell
#                                    6                                    6
#                             CD8 MAIT                                CD8aa
#                                    6                                    6
#                   CD95 memory B cell                                 cDC1
#                                    6                                    6
#                             CLP cell                        CM CD4 T cell
#                                    6                                    6
#                        CM CD8 T cell                             CMP cell
#                                    6                                    6
#                   Core CD14 monocyte                   Core CD16 monocyte
#                                    6                                    6
#                   Core memory B cell                    Core naive B cell
#                                    6                                    6
#                Core naive CD4 T cell                Core naive CD8 T cell
#                                    6                                    6
#                            DN T cell                  Early memory B cell
#                                    6                                    6
#                          Erythrocyte            GZMB- CD27- EM CD4 T cell
#                                    6                                    6
#            GZMB- CD27+ EM CD4 T cell                        GZMB+ Vd2 gdT
#                                    6                                    6
#            GZMK- CD27+ EM CD8 T cell                GZMK- CD56dim NK cell
#                                    6                                    6
#            GZMK+ CD27+ EM CD8 T cell                GZMK+ CD56dim NK cell
#                                    6                                    6
#                GZMK+ memory CD4 Treg                        GZMK+ Vd2 gdT
#                                    6                                    6
#                        HLA-DRhi cDC2                  IL1B+ CD14 monocyte
#                                    6                                    6
#                                  ILC                Intermediate monocyte
#                                    6                                    6
#                   ISG+ CD14 monocyte                   ISG+ CD16 monocyte
#                                    6                                    6
#                 ISG+ CD56dim NK cell                            ISG+ cDC2
#                                    6                                    6
#                            ISG+ MAIT               ISG+ memory CD4 T cell
#                                    6                                    6
#               ISG+ memory CD8 T cell                    ISG+ naive B cell
#                                    6                                    6
#                ISG+ naive CD4 T cell                ISG+ naive CD8 T cell
#                                    6                                    6
#               KLRB1+ memory CD4 Treg               KLRB1+ memory CD8 Treg
#                                    6                                    6
#              KLRF1- effector Vd1 gdT     KLRF1- GZMB+ CD27- EM CD8 T cell
#                                    6                                    6
# KLRF1- GZMB+ CD27- memory CD4 T cell              KLRF1+ effector Vd1 gdT
#                                    6                                    6
#     KLRF1+ GZMB+ CD27- EM CD8 T cell                      Memory CD4 Treg
#                                    6                                    6
#                      Memory CD8 Treg                       Naive CD4 Treg
#                                    6                                    6
#                        Naive Vd1 gdT                                  pDC
#                                    6                                    6
#                          Plasma cell                             Platelet
#                                    6                                    6
#                Proliferating NK cell                 Proliferating T cell
#                                    6                                    6
#               SOX4+ naive CD4 T cell               SOX4+ naive CD8 T cell
#                                    6                                    6
#                        SOX4+ Vd1 gdT                  Transitional B cell
#                                    6                                    6
#       Type 2 polarized memory B cell
#                                    6

# %%
ggplot(result_df, aes(x = sample.visitName, y = median_percentage, color = AIFI_L3)) +
  geom_point() +
  geom_line() +
  theme_minimal() +
  theme(legend.position = "none")
# Out:
# `geom_line()`: Each group consists of only one observation.
# ℹ Do you need to adjust the group aesthetic?
# plot without title

# %%
options(repr.plot.width = 25, repr.plot.height = 15)
ggplot(result_df, aes(x = sample.visitName, y = median_percentage, group = AIFI_L3, colour = "grey")) + 
  geom_line() +
  theme_minimal()+
  theme(legend.position = "none") +
  facet_wrap(~AIFI_L3, scales = 'free')
# Out:
# plot without title

# %%
library(dplyr)
library(ggplot2)

# Assuming your dataframe is named 'df'

# Aggregate data to calculate mean and confidence intervals
summary_df <- filtered_data %>%
  dplyr::group_by(AIFI_L3, sample.visitName) %>%
  dplyr::summarise(mean_percentage = mean(percentage),
            ci_low = mean_percentage - 1.96 * sd(percentage) / sqrt(n()),
            ci_high = mean_percentage + 1.96 * sd(percentage) / sqrt(n()))

# Plot with confidence intervals
ggplot(summary_df, aes(x = sample.visitName, y = mean_percentage, color = AIFI_L3, group = AIFI_L3)) +
  geom_line() +
  geom_ribbon(aes(ymin = ci_low, ymax = ci_high, fill = AIFI_L3), alpha = 0.3) +
  theme_minimal() +
  labs(x = "Sample Visit Name", y = "Mean Percentage", color = "AIFI_L3") +
  theme(legend.position = "none")
# Out:
# `summarise()` has grouped output by 'AIFI_L3'. You can override using the
# `.groups` argument.
# plot without title

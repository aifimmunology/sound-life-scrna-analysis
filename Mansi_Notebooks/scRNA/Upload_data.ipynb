# %%
library(hise)

# %%
?hise::uploadFiles
# Out:
# uploadFiles                package:hise                R Documentation
#
# e.
#
# n:
#
#      Upload result files to HISE and save the IDE in its current state.
#
# e:
#
#      uploadFiles(
#        files,
#        studySpaceId = NULL,
#        project = NULL,
#        title = NULL,
#        inputFileIds = list(),
#        inputSampleIds = list(),
#        fileTypes = list(),
#        store = NULL,
#        destination = NULL,
#        doPrompt = TRUE
#      )
#
# s:
#
#    files: required: a list of local files to upload
#
# studySpaceId: optional: the UUID of the study space to which these
#           files should belong
#
#  project: optional: the project for the files. Required if study space
#           is not provided
#
#    title: required: title for the track record
#
# inputFileIds: required: UUIDs of files that provide data for these
#           files
#
# inputSampleIds: optional: other samples that provide data for these
#           files
#
# ...

# %%
getStudySpaces()
# Out:
# [1] "Authorization token invalid or expired."
# [1] "Retrying..."
# [[1]]
# [[1]]$id
# [1] "2e9dd243-6123-410c-aa39-2d6ed57ef2a4"
#
# [[1]]$accountGuid
# [1] "b34b9c66-aa5d-45d0-9569-f78ca8f6813f"
#
# [[1]]$projectGuid
# [1] "e206cf7a-5b13-478f-b842-a305fe4954d8"
#
# [[1]]$driveId
# [1] "0AEgFtzSiOc7hUk9PVA"
#
# [[1]]$auditInfo
# [[1]]$auditInfo$added
# [1] "2024-01-30T01:08:25.919Z"
#
# [[1]]$auditInfo$addedUser
# [1] "ziyuan.he@alleninstitute.org"
#
# [[1]]$auditInfo$lastModified
# [1] "2024-01-30T01:08:25.919Z"
#
# [[1]]$auditInfo$lastModifiedBy
# [1] "ziyuan.he@alleninstitute.org"
#
# [[1]]$auditInfo$version
# [1] 1
#
#
# [[1]]$name
# [1] "myeloid-teaseq"
#
# [[1]]$description
# [1] "study space for myeloid tea-seq project"
#
# [[1]]$externalDrive
# [[1]]$externalDrive$name
# [1] "myeloid-teaseqExternal"
#
# [[1]]$externalDrive$id
# [1] "19mPExiW1GKoQDY5VK4DdQ6RJjZt-z090"
#
# [[1]]$externalDrive$parents
# [[1]]$externalDrive$parents[[1]]
# [1] "1KiTz8v3PVmCBmTcIy_TR1H0l1RYwNQkl"
# ...

# %%
uploadFiles(
  list('/home/jupyter/Myeloid_cells/files/IL1B_CD14_Mono_ONLY_FluYr1D0_parallel.h5ad'),
  studySpaceId = 'de025812-5e73-4b3c-9c3b-6d0eac412f2a',
  title = 'IL1B+ Cd14 Monocyte object for Emma (parallel leiden)', fileTypes = list('h5#derived'),
  inputFileIds = list('8119dcb4-5c0b-42f7-82fa-11ab04fad221')
)
# Out:
# You are trying to upload the following files:  /home/jupyter/Myeloid_cells/files/IL1B_CD14_Mono_ONLY_FluYr1D0_parallel.h5ad
# (y/n) y
# $files
# $files[[1]]
# [1] "/home/jupyter/Myeloid_cells/files/IL1B_CD14_Mono_ONLY_FluYr1D0_parallel.h5ad"
#
#
# $traceId
# [1] "f6915026-5388-4055-b4a1-0e27f4390213"

# %%
celltype_claire<-c("KLRF1- effector Vd1 gdT.h5ad",
"KLRF1+ effector Vd1 gdT.h5ad",
"GZMB+ Vd2 gdT.h5ad",
"Erythrocyte_.h5ad",
"CMP cell.h5ad",
"CLP cell.h5ad",
"CD95 memory B cell.h5ad",
"CD27- effector B cell.h5ad",
"Adaptive NK cell.h5ad",
"pDC_.h5ad",
"Proliferating T cell.h5ad",
"Proliferating NK cell.h5ad")

# %%
celltype_claire<-paste0('/home/jupyter/BRI_Analysis/scRNA/h5_cleaned_by_celltype_claire/',celltype_claire)

# %%
celltype_claire<-gsub(' ','_',celltype_claire)

# %%
uploadFiles(
  as.list(celltype_claire),
  studySpaceId = 'de025812-5e73-4b3c-9c3b-6d0eac412f2a',
  title = paste0('BRI object for Claires-2023-02-01-retry'), fileTypes = list('h5#derived','h5#derived','h5#derived','h5#derived','h5#derived','h5#derived','h5#derived','h5#derived','h5#derived','h5#derived','h5#derived','h5#derived'),
  inputFileIds = list('fec489f9-9a74-4635-aa91-d2bf09d1faec')
)
# Out:
# You are trying to upload the following files:  /home/jupyter/BRI_Analysis/scRNA/h5_cleaned_by_celltype_claire/KLRF1-_effector_Vd1_gdT.h5ad /home/jupyter/BRI_Analysis/scRNA/h5_cleaned_by_celltype_claire/KLRF1+_effector_Vd1_gdT.h5ad /home/jupyter/BRI_Analysis/scRNA/h5_cleaned_by_celltype_claire/GZMB+_Vd2_gdT.h5ad /home/jupyter/BRI_Analysis/scRNA/h5_cleaned_by_celltype_claire/Erythrocyte_.h5ad /home/jupyter/BRI_Analysis/scRNA/h5_cleaned_by_celltype_claire/CMP_cell.h5ad /home/jupyter/BRI_Analysis/scRNA/h5_cleaned_by_celltype_claire/CLP_cell.h5ad /home/jupyter/BRI_Analysis/scRNA/h5_cleaned_by_celltype_claire/CD95_memory_B_cell.h5ad /home/jupyter/BRI_Analysis/scRNA/h5_cleaned_by_celltype_claire/CD27-_effector_B_cell.h5ad /home/jupyter/BRI_Analysis/scRNA/h5_cleaned_by_celltype_claire/Adaptive_NK_cell.h5ad /home/jupyter/BRI_Analysis/scRNA/h5_cleaned_by_celltype_claire/pDC_.h5ad /home/jupyter/BRI_Analysis/scRNA/h5_cleaned_by_celltype_claire/Proliferating_T_cell.h5ad /home/jupyter/BRI_Analysis
# ...

# %%
uploadFiles(
  list('/home/jupyter/BRI_Analysis/scRNA/BRI_Cleaned_All_Samples.tar'),
  studySpaceId = 'de025812-5e73-4b3c-9c3b-6d0eac412f2a',
  title = paste0('Cleaned BRI samples(868)_2024-02-06'), fileTypes = list('h5#derived'),
  inputFileIds = list('fec489f9-9a74-4635-aa91-d2bf09d1faec'), destination='BRI_Analysis'
)
# Out:
# [1] "Cannot determine the current notebook."
# [1] "1) /home/jupyter/BRI_Analysis/Upload_data.ipynb"
# [1] "2) /home/jupyter/BRI_Analysis/scRNA/Analysis-Longitudinal_Flu/01B_MAST_Individual_DEG.ipynb"
# [1] "3) /home/jupyter/BRI_Analysis/scRNA/04_Clean_Doublet.ipynb"
# Please select (1-3)  1
# You are trying to upload the following files:  /home/jupyter/BRI_Analysis/scRNA/BRI_Cleaned_All_Samples.tar
# (y/n) y
# [1] "Authorization token invalid or expired."
# [1] "Retrying..."
# $files
# $files[[1]]
# [1] "/home/jupyter/BRI_Analysis/scRNA/BRI_Cleaned_All_Samples.tar"
#
#
# $traceId
# [1] "5680e09b-ea55-4b0e-b0ee-8c97646be375"

# %%
uploadFiles(
  list('/home/jupyter/BRI_Analysis/scRNA/Analysis-Chai/Olink.RDS'),
  studySpaceId = 'de025812-5e73-4b3c-9c3b-6d0eac412f2a',
  title = paste0('ChAI-OLINK_RDS-2023-02-01'), fileTypes = list('h5#derived'),
  inputFileIds = list('fec489f9-9a74-4635-aa91-d2bf09d1faec')
)
# Out:
# You are trying to upload the following files:  /home/jupyter/BRI_Analysis/scRNA/Analysis-Chai/Olink.RDS
# (y/n) Y
# [1] "Authorization token invalid or expired."
# [1] "Retrying..."
# $files
# $files[[1]]
# [1] "/home/jupyter/BRI_Analysis/scRNA/Analysis-Chai/Olink.RDS"
#
#
# $traceId
# [1] "bd5ea16f-300e-4c4d-a58b-96f30dd2176c"

# %%
uploadFiles(
  list('/home/jupyter/BRI_Analysis/scRNA/Analysis-Chai/scRNA_Objects.tar.gz'),
  studySpaceId = 'de025812-5e73-4b3c-9c3b-6d0eac412f2a',
  title = paste0('ChAI-scRNA_RDS-2023-02-01'), fileTypes = list('h5#derived'),
  inputFileIds = list('fec489f9-9a74-4635-aa91-d2bf09d1faec')
)
# Out:
# You are trying to upload the following files:  /home/jupyter/BRI_Analysis/scRNA/Analysis-Chai/scRNA_Objects.tar.gz
# (y/n) Y
# $files
# $files[[1]]
# [1] "/home/jupyter/BRI_Analysis/scRNA/Analysis-Chai/scRNA_Objects.tar.gz"
#
#
# $traceId
# [1] "c855509a-dd88-4924-95b8-a463da1b8665"

# %%
uploadFiles(
  list('/home/jupyter/BRI_Analysis/scRNA/Analysis-Longitudinal_Flu/MAST_res.csv'),
  studySpaceId = 'de025812-5e73-4b3c-9c3b-6d0eac412f2a',
  title = paste0('MAST result for individual DEG D7 vs D0'), fileTypes = list('h5#derived'),
  inputFileIds = list('fec489f9-9a74-4635-aa91-d2bf09d1faec')
)
# Out:
# You are trying to upload the following files:  /home/jupyter/BRI_Analysis/scRNA/Analysis-Longitudinal_Flu/MAST_res.csv
# (y/n) Y
# $files
# $files[[1]]
# [1] "/home/jupyter/BRI_Analysis/scRNA/Analysis-Longitudinal_Flu/MAST_res.csv"
#
#
# $traceId
# [1] "3517f50c-123b-4cea-9420-dc028a449a56"

# %%
uploadFiles(
  list('/home/jupyter/BRI_Analysis/scRNA/all_imm_health_obs.parquet'),
  studySpaceId = 'de025812-5e73-4b3c-9c3b-6d0eac412f2a',
  title = paste0('all_imm_health_obs'), fileTypes = list('parquet'),
  inputFileIds = list('fec489f9-9a74-4635-aa91-d2bf09d1faec')
)
# Out:
# [1] "Cannot determine the current notebook."
# [1] "1) /home/jupyter/BRI_Analysis/scRNA/export_meta_data.ipynb"
# [1] "2) /home/jupyter/conda_python/lib/python3.7/site-packages/matplotlib/backends/web_backend/nbagg_uat.ipynb"
# [1] "3) /home/jupyter/examples/R/XX-R Tips and tricks.ipynb"
# Please select (1-3)  1
# You are trying to upload the following files:  /home/jupyter/BRI_Analysis/scRNA/all_imm_health_obs.parquet
# (y/n) y
# $files
# $files[[1]]
# [1] "/home/jupyter/BRI_Analysis/scRNA/all_imm_health_obs.parquet"
#
#
# $traceId
# [1] "4544b8ac-f266-4606-ac7b-9b90677470fc"

# %%
uploadFiles(
  list('/home/jupyter/BRI_Analysis/scRNA/Analysis-Cross-Sectional/TEAseq/PedSenior_TEAseq_Labels_2024-03-26.csv'),
  studySpaceId = 'de025812-5e73-4b3c-9c3b-6d0eac412f2a',
  title = paste0('labels from AIFI reference'), fileTypes = list('csv'),
  inputFileIds = list('fec489f9-9a74-4635-aa91-d2bf09d1faec')
)
# Out:
# You are trying to upload the following files:  /home/jupyter/BRI_Analysis/scRNA/Analysis-Cross-Sectional/TEAseq/PedSenior_TEAseq_Labels_2024-03-26.csv
# (y/n) y
# $files
# $files[[1]]
# [1] "/home/jupyter/BRI_Analysis/scRNA/Analysis-Cross-Sectional/TEAseq/PedSenior_TEAseq_Labels_2024-03-26.csv"
#
#
# $traceId
# [1] "e21a15dc-3544-4dfd-b755-036022d9b06a"

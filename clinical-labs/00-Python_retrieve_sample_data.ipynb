# %% [markdown]
# # Retrieve sample metadata and labs from HISE
#
# The Python version of the HISE SDK allows retrieval of sample metadata regardless of pipeline sample processing. We'll use this SDK to pull the data, then use R to do cleanup.

# %% [markdown]
# ## Load packages
#
# datetime: Used to add today's date to our output files
# hisepy: the HISE SDK
# os: Operating System files (used to make an output folder)
# pandas: DataFrames for Python
# session_info: displays the versioning Python and all of the packages we used
# warnings: Used to suppress some annoying warnings that don't impact data retrieval

# %%
from datetime import date
import hisepy
import os
import pandas
import session_info

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Retrieve sample metadata from HISE

# %%
sample_meta_file_uuid = 'd82c5c42-ae5f-4e67-956e-cd3b7bf88105'
res = hisepy.reader.read_files([sample_meta_file_uuid])
sample_meta = res['values']

# %% [markdown]
# ## Query HISE to get data
#
# First, we make a dictionary (with curly braces) that defines what we want to get. In this case, we want to get samples from our study that were previously specified in our sample metadata.
#
# Each entry in the dictionary has to be a list (square braces), even if it has a single entry.

# %%
query_dict = {
    'sampleKitGuid': sample_meta['sample.sampleKitGuid'].tolist()
}

# %% [markdown]
# Now, we send this dictionary to HISE via hisepy

# %%
sample_data = hisepy.reader.read_samples(
    query_dict = query_dict
)

# %% [markdown]
# What we get back is a dictionary containing multiple kinds of information.
#
# We can see what these are called with they `.keys()` method:

# %%
sample_data.keys()
# Out:
# dict_keys(['metadata', 'specimens', 'survey', 'labResults'])

# %% [markdown]
# And we can access each of these using square brackets:

# %%
sample_data['metadata'].columns
# Out:
# Index([                                    0,
#                                         'id',
#                                'lastUpdated',
#                          'latestBatchUpdate',
#                            'labLastModified',
#                         'surveyLastModified',
#                                'projectGuid',
#                                 'subject.id',
#                        'subject.subjectGuid',
#                             'subject.cohort',
#                      'subject.biologicalSex',
#                               'subject.race',
#                              'subject.races',
#                          'subject.ethnicity',
#                          'subject.birthYear',
#                    'subject.ageAtEnrollment',
#                           'sample.visitName',
#                        'sample.visitDetails',
#                          'sample.sampleGuid',
#                       'sample.sampleKitGuid',
#                            'sample.drawDate',
#                 'sample.daysSinceFirstVisit',
#        'sample.diseaseStatesRecordedAtVisit',
#                                'experiments',
#                         'experimentComments',
#                                   'batchIds',
#                                   'panelIds'],
#       dtype='object')

# %%
sample_data['metadata'].head()
# Out:
#   0                                    id               lastUpdated  \
# 0    f499ff83-e513-4d24-a10f-151348269fff  2024-04-08T17:45:36.871Z
# 1    750e90a9-a296-4f0f-969f-60225c2bca17  2024-04-08T17:45:36.972Z
# 2    2db6fb3f-e3f4-454b-891b-9b068541b51d  2024-04-08T17:45:37.259Z
# 3    f04693c5-563c-4b5b-ae58-877d0d9ae2fe   2024-04-08T17:45:37.26Z
# 4    eb5b3a3d-002e-40a6-aa19-aa0e6a7fff8f  2024-04-08T17:45:37.261Z
#
#           latestBatchUpdate           labLastModified  \
# 0  2023-03-31T13:38:16.091Z   2022-10-07T18:21:02.71Z
# 1  2023-03-31T13:38:16.091Z  2021-09-13T20:09:05.913Z
# 2  2023-03-31T13:38:16.091Z  2021-09-13T20:09:05.964Z
# 3  2023-11-19T10:33:50.333Z  2021-09-13T20:09:06.018Z
# 4  2023-11-19T05:06:39.737Z  2021-09-13T20:09:06.069Z
#
#          surveyLastModified                           projectGuid  \
# 0      0001-01-01T00:00:00Z  e206cf7a-5b13-478f-b842-a305fe4954d8
# 1  2022-11-19T06:45:11.967Z  e206cf7a-5b13-478f-b842-a305fe4954d8
# 2  2022-11-19T06:45:18.906Z  e206cf7a-5b13-478f-b842-a305fe4954d8
# 3  2022-11-19T06:44:06.495Z  e206cf7a-5b13-478f-b842-a305fe4954d8
# 4   2022-11-19T06:45:10.35Z  e206cf7a-5b13-478f-b842-a305fe4954d8
#
#                              subject.id subject.subjectGuid subject.cohort  \
# 0  9e77e518-3801-47ff-8324-7d1dca8a8fd1              BR1001            BR1
# 1  f9482e2e-d29f-4adc-9cd9-6803c778ffd6              BR1002            BR1
# 2  79ae1d71-8347-4115-a846-2d077cb5077c              BR1003            BR1
# 3  c77f3365-3e39-470b-b14c-049ffb49ea32              BR1004            BR1
# 4  e2698854-1524-482d-80dc-d0ecac105beb              BR1005            BR1
#
#    ...              sample.visitDetails sample.sampleGuid  \
# 0  ...  N/A - Flu-Series Timepoint Only          00000599
# 1  ...  N/A - Flu-Series Timepoint Only          00000641
# 2  ...  N/A - Flu-Series Timepoint Only          00000683
# 3  ...  N/A - Flu-Series Timepoint Only          00000725
# 4  ...  N/A - Flu-Series Timepoint Only          00000727
#
#   sample.sampleKitGuid       sample.drawDate  sample.daysSinceFirstVisit  \
# 0              KT00001  2019-10-01T00:00:00Z                           0
# 1              KT00002  2019-10-01T00:00:00Z                           0
# 2              KT00003  2019-10-01T00:00:00Z                           0
# 3              KT00004  2019-10-01T00:00:00Z                           0
# 4              KT00006  2019-10-01T00:00:00Z                           0
#
#   sample.diseaseStatesRecordedAtVisit  \
# 0                                  []
# 1                                  []
# 2                                  []
# 3                                  []
# 4                                  []
#
#                                          experiments  \
# 0  {'ATAC-seq': 'Completed', 'Flow cytometry': 'C...
# 1  {'ATAC-seq': 'Completed', 'Flow cytometry': 'C...
# 2  {'ATAC-seq': 'Completed', 'Flow cytometry': 'C...
# 3  {'ATAC-seq': 'Completed', 'Flow cytometry': 'C...
# 4  {'ATAC-seq': 'Completed', 'Flow cytometry': 'C...
#
#                                   experimentComments  \
# 0  {"ATAC-seq":[{"OrderStatus":"Completed","Order...
# 1  {"ATAC-seq":[{"OrderStatus":"Completed","Order...
# 2  {"ATAC-seq":[{"OrderStatus":"Completed","Order...
# 3  {"ATAC-seq":[{"OrderStatus":"Completed","Order...
# 4  {"ATAC-seq":[{"OrderStatus":"Completed","Order...
#
#                                             batchIds  \
# 0  {'FlowCytometry': {'id': 'B013', 'status': 'av...
# 1  {'FlowCytometry': {'id': 'B013', 'status': 'av...
# 2  {'FlowCytometry': {'id': 'B013', 'status': 'av...
# 3  {'FlowCytometry': {'id': 'B022', 'status': 'av...
# 4  {'FlowCytometry': {'id': 'B013', 'status': 'av...
#
#                                             panelIds
# 0  {'': {'batchId': '', 'status': 'available', 't...
# 1  {'': {'batchId': 'EXP-00447', 'status': 'avail...
# 2  {'': {'batchId': 'EXP-00447', 'status': 'avail...
# 3  {'': {'batchId': 'B002', 'status': 'available'...
# 4  {'': {'batchId': 'B002', 'status': 'available'...
#
# [5 rows x 27 columns]

# %%
sample_data['specimens'].columns
# Out:
# Index(['sampleId', 'specimenGuid', 'specimenType', 'specimenStatus',
#        'externalContainerID', 'timeToProcessingOnset', 'totalViableCellCount',
#        'subjectGuid', 'sampleKitGuid', 'projectGuid'],
#       dtype='object')

# %%
sample_data['specimens'].head()
# Out:
#                                sampleId specimenGuid specimenType  \
# 0  f499ff83-e513-4d24-a10f-151348269fff   CT00001-01        CyTOF
# 1  f499ff83-e513-4d24-a10f-151348269fff   PL00001-16       Plasma
# 2  f499ff83-e513-4d24-a10f-151348269fff   PL00001-19       Plasma
# 3  f499ff83-e513-4d24-a10f-151348269fff   PL00001-23       Plasma
# 4  f499ff83-e513-4d24-a10f-151348269fff   PB00001-02         PBMC
#
#   specimenStatus externalContainerID  timeToProcessingOnset  \
# 0        Removed                 N/A                    0.0
# 1         Stored                 N/A                 4800.0
# 2         Stored                 N/A                 4800.0
# 3         Stored                 N/A                 4800.0
# 4        Removed                 N/A                 3900.0
#
#   totalViableCellCount subjectGuid sampleKitGuid  \
# 0                           BR1001       KT00001
# 1                           BR1001       KT00001
# 2                           BR1001       KT00001
# 3                           BR1001       KT00001
# 4                           BR1001       KT00001
#
#                             projectGuid
# 0  e206cf7a-5b13-478f-b842-a305fe4954d8
# 1  e206cf7a-5b13-478f-b842-a305fe4954d8
# 2  e206cf7a-5b13-478f-b842-a305fe4954d8
# 3  e206cf7a-5b13-478f-b842-a305fe4954d8
# 4  e206cf7a-5b13-478f-b842-a305fe4954d8

# %%
sample_data['survey'].columns
# Out:
# Index(['subjectGuid', 'sampleKitGuid', 'projectGuid', 'id', 'surveyDesignGuid',
#        'revisionNumber', 'revisionHistory', 'auditInfo',
#        'answers.could_not_sleep', 'answers.depressed',
#        ...
#        'answers.health-history_chicken_pox_imm_lifetime',
#        'answers.health-history_covid19_diag_month',
#        'answers.health-history_covid19_diag_year',
#        'answers.health-history_has_covid19',
#        'answers.health-history_if_covid_diagnosis_month',
#        'answers.health-history_if_covid_diagnosis_year',
#        'answers.health-history_if_covid_hospitalized',
#        'answers.health-history_if_covid_pneumonia',
#        'answers.health-history_if_covid_testing_yn',
#        'answers.health-history_pneumococcal_imm_year'],
#       dtype='object', length=495)

# %% [markdown]
# \> 1000 columns, so we don't show all of them here for surveys

# %%
sample_data['survey'].head()
# Out:
#   subjectGuid sampleKitGuid                           projectGuid  \
# 0      BR1002       KT00002  e206cf7a-5b13-478f-b842-a305fe4954d8
# 1      BR1002       KT00002  e206cf7a-5b13-478f-b842-a305fe4954d8
# 2      BR1002       KT00002  e206cf7a-5b13-478f-b842-a305fe4954d8
# 3      BR1003       KT00003  e206cf7a-5b13-478f-b842-a305fe4954d8
# 4      BR1003       KT00003  e206cf7a-5b13-478f-b842-a305fe4954d8
#
#                                      id                      surveyDesignGuid  \
# 0  6aa938a8-8457-427a-ab17-2f010ef76144  fa47addf-be1b-482b-863b-5b3a4e1b1346
# 1  d0e669d0-b970-4d38-9d62-937b23021245  1ace95db-949a-4caa-9af7-2a0087beac29
# 2  00cb3a41-2a6c-48e9-b910-61a843b64f67  a3e8a6a6-9795-409c-90f6-78c6c3e10cb0
# 3  3f9be31a-52d8-4ffa-990b-80af8f26b4df  fa47addf-be1b-482b-863b-5b3a4e1b1346
# 4  4354c842-8ca9-4774-9bde-d45d9a115793  1ace95db-949a-4caa-9af7-2a0087beac29
#
#    revisionNumber                                    revisionHistory  \
# 0             1.0  [{'historicalRevisionNumber': 1, 'modifiedDate...
# 1             1.0  [{'historicalRevisionNumber': 1, 'modifiedDate...
# 2             9.0  [{'historicalRevisionNumber': 1, 'modifiedDate...
# 3             1.0  [{'historicalRevisionNumber': 1, 'modifiedDate...
# 4             0.0                                                 []
#
#                                            auditInfo answers.could_not_sleep  \
# 0  {'added': '2022-10-17T19:19:27.111Z', 'addedUs...                       2
# 1  {'added': '2022-11-14T22:09:52.205Z', 'addedUs...                     NaN
# 2  {'added': '2022-11-16T17:26:39.675Z', 'addedUs...                       2
# 3  {'added': '2022-10-17T19:19:27.363Z', 'addedUs...                       3
# 4  {'added': '2022-11-14T22:09:52.274Z', 'addedUs...                     NaN
#
#   answers.depressed  ... answers.health-history_chicken_pox_imm_lifetime  \
# 0                 1  ...                                             NaN
# 1               NaN  ...                                             NaN
# 2                 1  ...                                             NaN
# 3                 2  ...                                             NaN
# 4               NaN  ...                                             NaN
#
#   answers.health-history_covid19_diag_month  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   answers.health-history_covid19_diag_year answers.health-history_has_covid19  \
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                                NaN
#
#   answers.health-history_if_covid_diagnosis_month  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   answers.health-history_if_covid_diagnosis_year  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   answers.health-history_if_covid_hospitalized  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   answers.health-history_if_covid_pneumonia  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   answers.health-history_if_covid_testing_yn  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   answers.health-history_pneumococcal_imm_year
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
# [5 rows x 495 columns]

# %%
sample_data['labResults'].columns
# Out:
# Index(['id', 'revisionHistory', 'revisionNumber', '% Basophils',
#        '% Eosinophils', '% Lymphocytes', '% Monocytes', '% Neutrophils',
#        'Absolute Basophil Count', 'Absolute Eosinophil Count (AEC)',
#        ...
#        'CMV IgG Serology', 'Converted to IA During Course of Study',
#        'Covid-19 Vaccine Company Name', 'Covid-19 Vaccine Ever Received',
#        'Num. of Days to/From IA Conversion',
#        'Number of Days To/From Initial Covid-19 Vaccine',
#        'Number of Days To/From Second Covid-19 Vaccine',
#        'Number of Days To/From Third Covid-19 Vaccine',
#        'CMV Ab Screen Index Value', 'CMV Ab Screen Result'],
#       dtype='object', length=108)

# %%
sample_data['labResults'].head()
# Out:
#                                      id  \
# 0  075fc922-035f-401e-b90c-f88ea50d0a95
# 1  4708ad58-3759-4a83-8fe5-9d7117b6d34f
# 2  5f6e9c4c-1dc2-4d84-beee-a4752a8280c3
# 3  8f2760aa-5a8f-4857-810d-d73a7d6f01da
# 4  fec103ba-a651-470b-adf9-4f2577fa9308
#
#                                      revisionHistory  revisionNumber  \
# 0  [{'historicalRevisionNumber': 1, 'modifiedDate...               6
# 1  [{'historicalRevisionNumber': 1, 'modifiedDate...               3
# 2  [{'historicalRevisionNumber': 1, 'modifiedDate...               4
# 3  [{'historicalRevisionNumber': 1, 'modifiedDate...               4
# 4  [{'historicalRevisionNumber': 1, 'modifiedDate...               3
#
#   % Basophils % Eosinophils % Lymphocytes % Monocytes % Neutrophils  \
# 0         0.5           1.6          31.1         7.7          59.1
# 1         0.9           2.4          39.5         8.9          48.3
# 2         0.7           0.7          45.4        12.1          41.1
# 3         1.1           2.5          49.8        10.9          35.7
# 4         0.7           0.1          19.0        11.3          68.9
#
#   Absolute Basophil Count Absolute Eosinophil Count (AEC)  ...  \
# 0                    22.0                            69.0  ...
# 1                    50.0                           132.0  ...
# 2                    29.0                            29.0  ...
# 3                    32.0                            73.0  ...
# 4                    52.0                             7.0  ...
#
#   CMV IgG Serology Converted to IA During Course of Study  \
# 0              NaN                                    NaN
# 1              NaN                                    NaN
# 2              NaN                                    NaN
# 3              NaN                                    NaN
# 4              NaN                                    NaN
#
#   Covid-19 Vaccine Company Name Covid-19 Vaccine Ever Received  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#   Num. of Days to/From IA Conversion  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#   Number of Days To/From Initial Covid-19 Vaccine  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Number of Days To/From Second Covid-19 Vaccine  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Number of Days To/From Third Covid-19 Vaccine CMV Ab Screen Index Value  \
# 0                                           NaN                       NaN
# 1                                           NaN                       NaN
# 2                                           NaN                       NaN
# 3                                           NaN                       NaN
# 4                                           NaN                       NaN
#
#   CMV Ab Screen Result
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 108 columns]

# %% [markdown]
# ## Save results for formatting
#
# For our purposes, we'll output the sample metadata, clinical labs, and survey results using the `pandas` method `to_csv()` to write the results to files.
#
# We'll clean these up in R for later use.

# %%
out_dir = 'output'
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)

# %%
meta_file = '{folder}/br2_hise_metadata_{date}.csv'.format(folder = out_dir, date = date.today())

sample_data['metadata'].to_csv(meta_file)

# %%
labs_file = '{folder}/br2_hise_labs_{date}.csv'.format(folder = out_dir, date = date.today())

sample_data['labResults'].to_csv(labs_file)

# %% [markdown]
# ## Upload results to HISE
#
# Finally, we'll use `hisepy.upload.upload_files()` to send a copy of our output to HISE to use for downstream analysis steps.

# %%
study_space_uuid = 'de025812-5e73-4b3c-9c3b-6d0eac412f2a'
title = 'DIHA raw clinical labs {d}'.format(d = date.today())

# %%
in_files = [sample_meta_file_uuid]

# %%
out_files = [meta_file, labs_file]

# %%
hisepy.upload.upload_files(
    files = out_files,
    study_space_id = study_space_uuid,
    title = title,
    input_file_ids = in_files
)
# Out:
# Cannot determine the current notebook.
# 1) /home/jupyter/IH-A-Aging-Analysis-Notebooks/clinical-labs/00-Python_retrieve_sample_data.ipynb
# 2) /home/jupyter/IH-A-Aging-Analysis-Notebooks/clinical-labs/01-R_format_labs.ipynb
# 3) /home/jupyter/fh1-mm-labs/archive/00-R_retrieve_and_format_labs.ipynb
# Please select (1-3)
#  1
# you are trying to upload file_ids... ['output/br2_hise_metadata_2024-04-09.csv', 'output/br2_hise_labs_2024-04-09.csv']. Do you truly want to proceed?
# (y/n) y
# {'trace_id': 'ab4e0176-3448-4af2-9f1e-c3e3ba6e04b5',
#  'files': ['output/br2_hise_metadata_2024-04-09.csv',
#   'output/br2_hise_labs_2024-04-09.csv']}

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# hisepy              0.3.0
# pandas              2.1.4
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.0.1
# anyio                       NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# beatrix_jupyterlab          NA
# brotli                      NA
# cachetools                  5.3.1
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          3.3.2
# cloudpickle                 2.2.1
# colorama                    0.4.6
# comm                        0.1.4
# cryptography                41.0.7
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# db_dtypes                   1.1.1
# debugpy                     1.8.0
# decorator                   5.1.1
# defusedxml                  0.7.1
# deprecated                  1.2.14
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fqdn                        NA
# google                      NA
# greenlet                    2.0.2
# grpc                        1.58.0
# grpc_status                 NA
# h5py                        3.10.0
# idna                        3.6
# importlib_metadata          NA
# ipykernel                   6.28.0
# ipython_genutils            0.2.0
# ipywidgets                  8.1.1
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.20.0
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.12.1
# jupyterlab_server           2.25.2
# jwt                         2.8.0
# kiwisolver                  1.4.5
# markupsafe                  2.1.3
# matplotlib                  3.8.0
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# nbformat                    5.9.2
# numpy                       1.26.2
# opentelemetry               NA
# overrides                   NA
# packaging                   23.2
# parso                       0.8.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                4.1.0
# plotly                      5.18.0
# prettytable                 3.9.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# proto                       NA
# psutil                      NA
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pyarrow                     13.0.0
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyparsing                   3.1.1
# pyreadr                     0.5.0
# pythonjsonlogger            NA
# pytz                        2023.3.post1
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# send2trash                  NA
# shapely                     1.8.5.post1
# six                         1.16.0
# sniffio                     1.3.0
# socks                       1.7.1
# sql                         NA
# sqlalchemy                  2.0.21
# sqlparse                    0.4.4
# stack_data                  0.6.2
# termcolor                   NA
# tornado                     6.3.3
# tqdm                        4.66.1
# traitlets                   5.9.0
# typing_extensions           NA
# uri_template                NA
# urllib3                     1.26.18
# wcwidth                     0.2.12
# webcolors                   1.13
# websocket                   1.7.0
# wrapt                       1.15.0
# xarray                      2023.12.0
# yaml                        6.0.1
# zipp                        NA
# zmq                         25.1.2
# zoneinfo                    NA
# zstandard                   0.22.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.19.0
# jupyter_client      8.6.0
# jupyter_core        5.6.1
# jupyterlab          4.1.5
# notebook            6.5.4
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-5.15.0-1054-gcp-x86_64-with-glibc2.31
# -----
# Session information updated at 2024-04-09 04:39
# </pre>
# </details>
